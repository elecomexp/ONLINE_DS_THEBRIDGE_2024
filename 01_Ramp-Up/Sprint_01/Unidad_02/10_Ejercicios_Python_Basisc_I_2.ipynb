# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 2:
# ## Tipos y conversión de tipos

# %% [markdown]
# Completa los siguiente ejercicios, la solución a los mismos se publicarán en el repo del curso a lo largo del sprint

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 1
#
# 1. Crea dos variables numericas: un `int` y un `float`
# 2. Comprueba sus tipos
# 3. Sumalas en otra nueva
# 4. ¿De qué tipo es la nueva variable?
# 5. Elimina las dos primeras variables creadas

# %%
var_int = 1
var_float = 1.0
var_sum =  var_int + var_float
print(type(var_sum))
del var_int, var_float
# Out:
# <class 'float'>

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
import math

grados = input('Introduce los grados:')
grados = float(grados)

if grados >= 0.0 and grados <= 360.0:
    radianes = grados*math.pi/180
    print('Son ', round(radianes,2), ' radianes.')
else:
    print('No es un valor válido.')
# Out:
# Introduce los grados: 45.5
# Son  0.79  radianes.

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
base = input('Introduce la base del paralelogramo')
altura = input('Introduce la altura del paralelogramo')

base = float(base)
altura = float(altura)

area = base*altura
print(f'El área total es: {round(area,2)}')
# Out:
# Introduce la base del paralelogramo 3
# Introduce la altura del paralelogramo 4
# El área total es: 12.0

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 4
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`. En este caso debe ser capaz de admitir valores reales, con decimales, para base y altura en español. (PISTA: Recuerda que tendrás que hacer uso del método replace)

# %%
base = input('Introduce la base del paralelogramo')
altura = input('Introduce la altura del paralelogramo')

base = float(base.replace(',','.'))
altura = float(altura.replace(',','.'))

area = base*altura
print(f'El área total es: {round(area,2)}')
# Out:
# Introduce la base del paralelogramo 2,5
# Introduce la altura del paralelogramo 2
# El área total es: 5.0

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 5
# Complete el siguiente código para solicitar al usuario su nombre y su edad. Luego, calcule en qué año nació el usuario y muestre el resultado.

# %%
nombre = input("¿Cuál es tu nombre? ")
edad = int(input("¿Cuál es tu edad? "))
año_actual = 2024  # Puedes cambiarlo según el año en curso
año_nacimiento = año_actual - edad

print(f"{nombre}, naciste en el año {año_nacimiento}.")
# Out:
# ¿Cuál es tu nombre?  Lander
# ¿Cuál es tu edad?  32
# Lander, naciste en el año 1992.
