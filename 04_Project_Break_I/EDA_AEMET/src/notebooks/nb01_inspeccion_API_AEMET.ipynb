# %% [markdown]
# # Acceso a las API de Aemet, y recolección de datos
#
# El objetivo de este Notebook es familiarizarse con la API de AEMET, cuyos datos son distribuidos a través de AEMET OpenData, y realizar una primera inspección de en que forma están estructurados.
#
# https://opendata.aemet.es/dist/index.html
#
#
# ## Tabla de contenidos
#
# <nav>
#   <ol>
#     <li><a href="#1-API-AEMET">API Aemet y sintaxis del request</a></li>
#     <li><a href="#2-acceso-idema">Acceso al "idema"</a></li>
#     <li><a href="#3-acceso-EMA">Acceso a la información de las EMA</a></li>
#     <li><a href="#4-clima-mensual-anual">Climatologías mensuales anuales</a></li>
#     <li><a href="#5-clima-normal-1999-2020">Climatologías normales 1991-2020</a></li>
#     <li><a href="#6-valores-extremos">Valores extremos</a></li>
#   </ol>
# </nav>

# %%
# Importar librerías

import pandas as pd
import requests

# %% [markdown]
# ## 1 - API Aemet y sintaxis del `request` <a id="1-API-AEMET"></a>

# %%
# Cargar la API-key para acceder a los datos de AEMET OpenData

with open('C:/Users/Lander/Documents/API_Keys/apiKey_aemet.txt') as f:
    api_key = f.read()

# %%
base_url = 'https://opendata.aemet.es/opendata' # Base API AEMET

querystring = {"api_key": api_key}
headers = {'cache-control': "no-cache"}

# %% [markdown]
# ## 2 - Acceso al "idema" <a id="2-acceso-idema"></a>
#
# ### 2.1 - Necesito los "idema" (Indicativo climatológico de las Estaciones Metereológicas Autónomas) para posteriormente acceder a la información metereológica de estas.
#
# Puedo obtener esta información a través de AEMET OpenData (API REST desarrollado por AEMET que permite la difusión y la reutilización de la información meteorológica y climatológica de la Agencia)

# %%
# Inventario de todas las estaciones

end_point = '/api/valores/climatologicos/inventarioestaciones/todasestaciones'

# URL completa
url = base_url + end_point

# Inventario con las características de todas las estaciones climatológicas. 
# Periodicidad: 1 vez al día.response = requests.request("GET", url, headers=headers, params=querystring)
response = requests.request("GET", url, headers=headers, params=querystring)
print(response.status_code)
# Out:
# 200

# %%
# Inventario con las características de todas las estaciones climatológicas. 
idema_info = response.json()
idema_info
# Out:
# {'descripcion': 'exito',
#  'estado': 200,
#  'datos': 'https://opendata.aemet.es/opendata/sh/fa4a3c72',
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/0556af7a'}

# %% [markdown]
# Ha resultado que los datos y los metadatos con los id de las EMAs (Estación Metereológica Automática) están en otra URL, por tanto hay que hacer un nuevo request "GET" a esas direcciones. En concreto la que nos interesa está en la clave "datos".

# %%
response = requests.get(idema_info['datos'])

# Visualización de los datos obtenidos por el request
idema = response.json()
idema
# Out:
# [{'latitud': '394924N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '490',
#   'indicativo': 'B013X',
#   'nombre': 'ESCORCA, LLUC',
#   'indsinop': '08304',
#   'longitud': '025309E'},
#  {'latitud': '394744N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '5',
#   'indicativo': 'B051A',
#   'nombre': 'SÓLLER, PUERTO',
#   'indsinop': '08316',
#   'longitud': '024129E'},
#  {'latitud': '394121N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '60',
#   'indicativo': 'B087X',
#   'nombre': 'BANYALBUFAR',
#   'indsinop': '',
#   'longitud': '023046E'},
#  {'latitud': '393445N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '52',
#   'indicativo': 'B103B',
#   'nombre': 'ANDRATX - SANT ELM',
#   'indsinop': '99103',
#   'longitud': '022208E'},
#  {'latitud': '393305N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '50',
#   'indicativo': 'B158X',
#   'nombre': 'CALVIÀ, ES CAPDELLÀ',
#   'indsinop': '',
#   'longitud': '022759E'},
#  {'latitud': '393319N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '3',
#   'indicativo': 'B228',
#   'nombre': 'PALMA, PUERTO',
#   'indsinop': '08301',
#   'longitud': '023731E'},
#  {'latitud': '393832N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '95',
#   'indicativo': 'B236C',
#   'nombre': 'PALMA, UNIVERSIDAD',
#   'indsinop': '',
#   'longitud': '023837E'},
#  {'latitud': '394406N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '1030',
#   'indicativo': 'B248',
#   'nombre': 'SIERRA DE ALFABIA, BUNYOLA',
#   'indsinop': '08303',
#   'longitud': '024247E'},
#  {'latitud': '393621N',
#   'provincia': 'BALEARES',
#   'altitud': '49',
#   'indicativo': 'B275E',
#   'nombre': 'SON BONET, AEROPUERTO',
#   'indsinop': '08302',
#   'longitud': '024224E'},
#  {'latitud': '393339N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '8',
#   'indicativo': 'B278',
#   'nombre': 'PALMA DE MALLORCA, AEROPUERTO',
#   'indsinop': '08306',
#   'longitud': '024412E'},
#  {'latitud': '392247N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '113',
#   'indicativo': 'B301',
#   'nombre': 'LLUCMAJOR, CAP BLANC',
#   'indsinop': '08308',
#   'longitud': '024706E'},
#  {'latitud': '392944N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '140',
#   'indicativo': 'B334X',
#   'nombre': 'LLUCMAJOR',
#   'indsinop': '',
#   'longitud': '025330E'},
#  {'latitud': '393022N',
#   'provincia': 'BALEARES',
#   'altitud': '149',
#   'indicativo': 'B341X',
#   'nombre': 'PORRERES',
#   'indsinop': '',
#   'longitud': '030020E'},
#  {'latitud': '393118N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '120',
#   'indicativo': 'B346X',
#   'nombre': 'PORRERES',
#   'indsinop': '08310',
#   'longitud': '030109E'},
#  {'latitud': '392421N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '40',
#   'indicativo': 'B362X',
#   'nombre': 'CAMPOS, CAN SION',
#   'indsinop': '',
#   'longitud': '030351E'},
#  {'latitud': '392104N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '3',
#   'indicativo': 'B373X',
#   'nombre': 'CAMPOS, SALINES LLEVANT',
#   'indsinop': '',
#   'longitud': '030043E'},
#  {'latitud': '390808N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '165',
#   'indicativo': 'B398A',
#   'nombre': 'CABRERA, PARQUE NACIONAL DE CABRERA',
#   'indsinop': '',
#   'longitud': '025612E'},
#  {'latitud': '392024N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '45',
#   'indicativo': 'B410B',
#   'nombre': 'SANTANYÍ',
#   'indsinop': '',
#   'longitud': '030845E'},
#  {'latitud': '392452N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '17',
#   'indicativo': 'B434X',
#   'nombre': 'PORTOCOLOM  ',
#   'indsinop': '08309',
#   'longitud': '031618E'},
#  {'latitud': '393749N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '25',
#   'indicativo': 'B496X',
#   'nombre': 'SON SERVERA',
#   'indsinop': '',
#   'longitud': '032301E'},
#  {'latitud': '394119N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '110',
#   'indicativo': 'B526X',
#   'nombre': 'ARTÀ',
#   'indsinop': '',
#   'longitud': '032104E'},
#  {'latitud': '394300N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '57',
#   'indicativo': 'B569X',
#   'nombre': 'CAPDEPERA',
#   'indsinop': '08311',
#   'longitud': '032841E'},
#  {'latitud': '394323N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '99',
#   'indicativo': 'B603X',
#   'nombre': 'ARTÀ-COLÒNIA DE SANT PERE',
#   'indsinop': '',
#   'longitud': '031643E'},
#  {'latitud': '394748N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '2',
#   'indicativo': 'B605X',
#   'nombre': "MURO, S'ALBUFERA",
#   'indsinop': '',
#   'longitud': '030617E'},
#  {'latitud': '393325N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '95',
#   'indicativo': 'B614E',
#   'nombre': 'MANACOR',
#   'indsinop': '',
#   'longitud': '031304E'},
#  {'latitud': '393659N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '95',
#   'indicativo': 'B640X',
#   'nombre': 'PETRA',
#   'indsinop': '',
#   'longitud': '030716E'},
#  {'latitud': '393836N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '120',
#   'indicativo': 'B644B',
#   'nombre': 'SINEU',
#   'indsinop': '',
#   'longitud': '030008E'},
#  {'latitud': '393909N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '121',
#   'indicativo': 'B656A',
#   'nombre': 'SANTA MARÍA DEL CAMÍ',
#   'indsinop': '',
#   'longitud': '024801E'},
#  {'latitud': '394041N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '105',
#   'indicativo': 'B662X',
#   'nombre': 'BINISSALEM',
#   'indsinop': '',
#   'longitud': '025226E'},
#  {'latitud': '394734N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '842',
#   'indicativo': 'B684A',
#   'nombre': 'ESCORCA, SON TORRELLA',
#   'indsinop': '',
#   'longitud': '024716E'},
#  {'latitud': '394454N',
#   'provincia': 'BALEARES',
#   'altitud': '40',
#   'indicativo': 'B691',
#   'nombre': 'LA PUEBLA (SA CANOVA)',
#   'indsinop': '',
#   'longitud': '030055E'},
#  {'latitud': '394457N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '40',
#   'indicativo': 'B691Y',
#   'nombre': 'SA POBLA',
#   'indsinop': '08312',
#   'longitud': '030100E'},
#  {'latitud': '395237N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '35',
#   'indicativo': 'B760X',
#   'nombre': 'POLLENÇA',
#   'indsinop': '',
#   'longitud': '030127E'},
#  {'latitud': '395434N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '2',
#   'indicativo': 'B780X',
#   'nombre': 'PORT DE POLLENÇA',
#   'indsinop': '',
#   'longitud': '030601E'},
#  {'latitud': '395234N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '78',
#   'indicativo': 'B800X',
#   'nombre': 'LA MOLA, MAÓ',
#   'indsinop': '',
#   'longitud': '041926E'},
#  {'latitud': '395926N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '80',
#   'indicativo': 'B825B',
#   'nombre': 'ES MERCADAL',
#   'indsinop': '',
#   'longitud': '040511E'},
#  {'latitud': '395934N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '20',
#   'indicativo': 'B860X',
#   'nombre': 'CIUTADELLA',
#   'indsinop': '',
#   'longitud': '035114E'},
#  {'latitud': '395641N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '43',
#   'indicativo': 'B870C',
#   'nombre': 'CIUTADELLA, CALA GALDANA',
#   'indsinop': '',
#   'longitud': '035724E'},
#  {'latitud': '395117N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '91',
#   'indicativo': 'B893',
#   'nombre': 'MENORCA, AEROPUERTO',
#   'indsinop': '08314',
#   'longitud': '041256E'},
#  {'latitud': '390322N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '110',
#   'indicativo': 'B908X',
#   'nombre': 'SANT JOAN DE LABRITJA',
#   'indsinop': '',
#   'longitud': '012933E'},
#  {'latitud': '385747N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '32',
#   'indicativo': 'B925',
#   'nombre': 'SANT ANTONI DE PORTMANY',
#   'indsinop': '',
#   'longitud': '011917E'},
#  {'latitud': '385235N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '6',
#   'indicativo': 'B954',
#   'nombre': 'IBIZA, AEROPUERTO',
#   'indsinop': '08373',
#   'longitud': '012304E'},
#  {'latitud': '385521N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '3',
#   'indicativo': 'B957',
#   'nombre': 'EIVISSA',
#   'indsinop': '',
#   'longitud': '012629E'},
#  {'latitud': '384137N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '24',
#   'indicativo': 'B986',
#   'nombre': 'FORMENTERA',
#   'indsinop': '',
#   'longitud': '012749E'},
#  {'latitud': '285806N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '376',
#   'indicativo': 'C018J',
#   'nombre': 'TÍAS',
#   'indsinop': '',
#   'longitud': '134129W'},
#  {'latitud': '285127N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '6',
#   'indicativo': 'C019V',
#   'nombre': 'YAIZA',
#   'indsinop': '',
#   'longitud': '135010W'},
#  {'latitud': '285707N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '14',
#   'indicativo': 'C029O',
#   'nombre': 'LANZAROTE AEROPUERTO',
#   'indsinop': '60040',
#   'longitud': '133601W'},
#  {'latitud': '290837N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '277',
#   'indicativo': 'C038N',
#   'nombre': 'HARÍA',
#   'indsinop': '',
#   'longitud': '132921W'},
#  {'latitud': '290233N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '275',
#   'indicativo': 'C048W',
#   'nombre': 'TINAJO',
#   'indsinop': '',
#   'longitud': '134051W'},
#  {'latitud': '284521N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '2223',
#   'indicativo': 'C101A',
#   'nombre': 'ROQUE DE LOS MUCHACHOS',
#   'indsinop': '',
#   'longitud': '175343W'},
#  {'latitud': '284539N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '684',
#   'indicativo': 'C117A',
#   'nombre': 'PUNTAGORDA',
#   'indsinop': '',
#   'longitud': '175908W'},
#  {'latitud': '284029N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '733',
#   'indicativo': 'C117Z',
#   'nombre': 'TIJARAFE',
#   'indsinop': '',
#   'longitud': '175613W'},
#  {'latitud': '283914N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '844',
#   'indicativo': 'C126A',
#   'nombre': 'EL PASO',
#   'indsinop': '',
#   'longitud': '175112W'},
#  {'latitud': '282718N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '30',
#   'indicativo': 'C129V',
#   'nombre': 'FUENCALIENTE',
#   'indsinop': '',
#   'longitud': '175028W'},
#  {'latitud': '283545N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '62',
#   'indicativo': 'C129Z',
#   'nombre': 'TAZACORTE',
#   'indsinop': '60004',
#   'longitud': '175455W'},
#  {'latitud': '283759N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '33',
#   'indicativo': 'C139E',
#   'nombre': 'LA PALMA AEROPUERTO',
#   'indsinop': '60005',
#   'longitud': '174518W'},
#  {'latitud': '284818N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '362',
#   'indicativo': 'C148F',
#   'nombre': 'SAN ANDRÉS Y SAUCES',
#   'indsinop': '',
#   'longitud': '174657W'},
#  {'latitud': '280257N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '15',
#   'indicativo': 'C229J',
#   'nombre': 'PÁJARA',
#   'indsinop': '60034',
#   'longitud': '142129W'},
#  {'latitud': '281231N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '1',
#   'indicativo': 'C239N',
#   'nombre': 'TUINEJE,PUERTO GRAN TARAJAL',
#   'indsinop': '',
#   'longitud': '140123W'},
#  {'latitud': '282502N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '252',
#   'indicativo': 'C248E',
#   'nombre': 'ANTIGUA',
#   'indsinop': '',
#   'longitud': '140110W'},
#  {'latitud': '282641N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '25',
#   'indicativo': 'C249I',
#   'nombre': 'FUERTEVENTURA AEROPUERTO',
#   'indsinop': '60035',
#   'longitud': '135147W'},
#  {'latitud': '283645N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '217',
#   'indicativo': 'C258K',
#   'nombre': 'LA OLIVA',
#   'indsinop': '',
#   'longitud': '135555W'},
#  {'latitud': '280625N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1475',
#   'indicativo': 'C314Z',
#   'nombre': 'VALLEHERMOSO, ALTO IGUALERO  ',
#   'indsinop': '',
#   'longitud': '171457W'},
#  {'latitud': '280742N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '916',
#   'indicativo': 'C316I',
#   'nombre': 'ARURE',
#   'indsinop': '',
#   'longitud': '171854W'},
#  {'latitud': '281044N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '765',
#   'indicativo': 'C317B',
#   'nombre': 'AGULO',
#   'indsinop': '',
#   'longitud': '171247W'},
#  {'latitud': '280316N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '190',
#   'indicativo': 'C319W',
#   'nombre': 'VALLEHERMOSO, DAMA',
#   'indsinop': '',
#   'longitud': '171824W'},
#  {'latitud': '280949N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '252',
#   'indicativo': 'C328W',
#   'nombre': 'HERMIGUA',
#   'indsinop': '',
#   'longitud': '171139W'},
#  {'latitud': '280154N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '219',
#   'indicativo': 'C329B',
#   'nombre': 'LA GOMERA, AEROPUERTO',
#   'indsinop': '60007',
#   'longitud': '171239W'},
#  {'latitud': '280523N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '15',
#   'indicativo': 'C329Z',
#   'nombre': 'SAN SEBASTIÁN DE LA GOMERA',
#   'indsinop': '60008',
#   'longitud': '170641W'},
#  {'latitud': '281327N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '2150',
#   'indicativo': 'C406G',
#   'nombre': 'LA OROTAVA, CAÑADAS TEIDE',
#   'indsinop': '',
#   'longitud': '163735W'},
#  {'latitud': '281311N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '2071',
#   'indicativo': 'C412N',
#   'nombre': 'CITFAGRO_89_CHAVAO',
#   'indsinop': '',
#   'longitud': '164219W'},
#  {'latitud': '281819N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '990',
#   'indicativo': 'C415A',
#   'nombre': 'CITFAGRO_64_HOYOS',
#   'indsinop': '',
#   'longitud': '164820W'},
#  {'latitud': '281400N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '735',
#   'indicativo': 'C417J',
#   'nombre': 'CITFAGRO_74_CHIO',
#   'indsinop': '',
#   'longitud': '164721W'},
#  {'latitud': '281252N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '476',
#   'indicativo': 'C418I',
#   'nombre': 'CITFAGRO_05_GUIAISO1',
#   'indsinop': '',
#   'longitud': '164723W'},
#  {'latitud': '281201N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '700',
#   'indicativo': 'C418L',
#   'nombre': 'CITFAGRO_76_POZO',
#   'indsinop': '',
#   'longitud': '164547W'},
#  {'latitud': '281225N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '403',
#   'indicativo': 'C419L',
#   'nombre': 'LOMO DEL BALO',
#   'indsinop': '',
#   'longitud': '164731W'},
#  {'latitud': '280453N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '130',
#   'indicativo': 'C419X',
#   'nombre': 'ADEJE',
#   'indsinop': '',
#   'longitud': '164240W'},
#  {'latitud': '281019N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1833',
#   'indicativo': 'C422A',
#   'nombre': 'CITFAGRO_94_LOSTOPOS',
#   'indsinop': '',
#   'longitud': '163905W'},
#  {'latitud': '281327N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1654',
#   'indicativo': 'C423R',
#   'nombre': 'CITFAGRO_90_PICACHO',
#   'indsinop': '',
#   'longitud': '163116W'},
#  {'latitud': '280839N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1258',
#   'indicativo': 'C426E',
#   'nombre': 'CITFAGRO_13_VILAFLOR',
#   'indsinop': '',
#   'longitud': '163741W'},
#  {'latitud': '280737N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '880',
#   'indicativo': 'C426I',
#   'nombre': 'CITFAGRO_77_PINAL',
#   'indsinop': '',
#   'longitud': '163621W'},
#  {'latitud': '281301N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '930',
#   'indicativo': 'C426R',
#   'nombre': 'CITFAGRO_09_HELECHO',
#   'indsinop': '',
#   'longitud': '162926W'},
#  {'latitud': '281052N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '418',
#   'indicativo': 'C428T',
#   'nombre': 'ARICO',
#   'indsinop': '',
#   'longitud': '162901W'},
#  {'latitud': '280752N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '135',
#   'indicativo': 'C428U',
#   'nombre': 'CITFAGRO_01_ARICO',
#   'indsinop': '',
#   'longitud': '162821W'},
#  {'latitud': '280249N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'indsinop': '60025',
#   'longitud': '163340W'},
#  {'latitud': '281832N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '2369',
#   'indicativo': 'C430E',
#   'nombre': 'IZAÑA',
#   'indsinop': '60010',
#   'longitud': '162958W'},
#  {'latitud': '281935N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '290',
#   'indicativo': 'C436I',
#   'nombre': 'CITFAGRO_54_TOPONEGRO',
#   'indsinop': '',
#   'longitud': '162420W'},
#  {'latitud': '282214N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '525',
#   'indicativo': 'C436L',
#   'nombre': 'CITFAGRO_96_ARAYA',
#   'indsinop': '',
#   'longitud': '162351W'},
#  {'latitud': '281611N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '500',
#   'indicativo': 'C437E',
#   'nombre': 'CITFAGRO_81_MENA',
#   'indsinop': '',
#   'longitud': '162511W'},
#  {'latitud': '282132N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '463',
#   'indicativo': 'C438N',
#   'nombre': 'CANDELARIA',
#   'indsinop': '',
#   'longitud': '162405W'},
#  {'latitud': '281906N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'indsinop': '60018',
#   'longitud': '162256W'},
#  {'latitud': '283136N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '868',
#   'indicativo': 'C446G',
#   'nombre': 'SAN CRISTÓBAL DE LA LAGUNA,LLANO DE LOS LOROS',
#   'indsinop': '',
#   'longitud': '161650W'},
#  {'latitud': '282839N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'indsinop': '60015',
#   'longitud': '161946W'},
#  {'latitud': '282745N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '136',
#   'indicativo': 'C448C',
#   'nombre': 'CITFAGRO_92_SANTACRUZ',
#   'indsinop': '',
#   'longitud': '161624W'},
#  {'latitud': '282748N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '36',
#   'indicativo': 'C449C',
#   'nombre': 'STA. CRUZ DE TENERIFE',
#   'indsinop': '60020',
#   'longitud': '161519W'},
#  {'latitud': '283029N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '19',
#   'indicativo': 'C449F',
#   'nombre': 'ANAGA ',
#   'indsinop': '',
#   'longitud': '161144W'},
#  {'latitud': '283336N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '305',
#   'indicativo': 'C449Q',
#   'nombre': 'CITFAGRO_97_TAGANANA',
#   'indsinop': '',
#   'longitud': '161341W'},
#  {'latitud': '282341N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1744',
#   'indicativo': 'C453I',
#   'nombre': 'CITFAGRO_88_GAITERO',
#   'indsinop': '',
#   'longitud': '162600W'},
#  {'latitud': '282142N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1065',
#   'indicativo': 'C455M',
#   'nombre': 'CITFAGRO_87_AGUAMANSA',
#   'indsinop': '',
#   'longitud': '162949W'},
#  {'latitud': '282714N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '922',
#   'indicativo': 'C456E',
#   'nombre': 'CITFAGRO_10_RAVELO',
#   'indsinop': '',
#   'longitud': '162431W'},
#  {'latitud': '282141N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '906',
#   'indicativo': 'C456P',
#   'nombre': 'CITFAGRO_70_BENIJO',
#   'indsinop': '',
#   'longitud': '163248W'},
#  {'latitud': '282222N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '551',
#   'indicativo': 'C456R',
#   'nombre': 'CITFAGRO_69_SUERTE',
#   'indsinop': '',
#   'longitud': '163231W'},
#  {'latitud': '282658N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '650',
#   'indicativo': 'C457E',
#   'nombre': 'CITFAGRO_67_MATANZA',
#   'indsinop': '',
#   'longitud': '162617W'},
#  {'latitud': '282605N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '567',
#   'indicativo': 'C457I',
#   'nombre': 'LA VICTORIA DE ACENTEJO',
#   'indsinop': '',
#   'longitud': '162717W'},
#  {'latitud': '282947N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '310',
#   'indicativo': 'C458A',
#   'nombre': 'TACORONTE',
#   'indsinop': '',
#   'longitud': '162512W'},
#  {'latitud': '282207N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '595',
#   'indicativo': 'C458U',
#   'nombre': 'CITFAGRO_71_PALOB',
#   'indsinop': '',
#   'longitud': '163441W'},
#  {'latitud': '282505N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '25',
#   'indicativo': 'C459Z',
#   'nombre': 'PUERTO DE LA CRUZ',
#   'indsinop': '60012',
#   'longitud': '163253W'},
#  {'latitud': '282021N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '878',
#   'indicativo': 'C466O',
#   'nombre': 'CITFAGRO_91_CUBO',
#   'indsinop': '',
#   'longitud': '164740W'},
#  {'latitud': '282112N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '525',
#   'indicativo': 'C467I',
#   'nombre': 'CITFAGRO_73_REDON',
#   'indsinop': '',
#   'longitud': '164230W'},
#  {'latitud': '282201N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '218',
#   'indicativo': 'C468I',
#   'nombre': 'CITFAGRO_98_ELDRAGO',
#   'indsinop': '',
#   'longitud': '164320W'},
#  {'latitud': '282125N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '450',
#   'indicativo': 'C468O',
#   'nombre': 'CITFAGRO_62_TRIGO',
#   'indsinop': '',
#   'longitud': '164805W'},
#  {'latitud': '282223N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '677',
#   'indicativo': 'C468X',
#   'nombre': 'SAN JUAN DE LA RAMBLA',
#   'indsinop': '',
#   'longitud': '163733W'},
#  {'latitud': '275838N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '1702',
#   'indicativo': 'C611E',
#   'nombre': 'VEGA DE SAN MATEO',
#   'indsinop': '',
#   'longitud': '153502W'},
#  {'latitud': '280025N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '1514',
#   'indicativo': 'C612F',
#   'nombre': 'TEJEDA, CRUZ DE TEJEDA',
#   'indsinop': '',
#   'longitud': '153556W'},
#  {'latitud': '275943N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '1060',
#   'indicativo': 'C614H',
#   'nombre': 'TEJEDA',
#   'indsinop': '60038',
#   'longitud': '153657W'},
#  {'latitud': '280003N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C619I',
#   'nombre': 'LA ALDEA DE SAN NICOLÁS',
#   'indsinop': '60027',
#   'longitud': '154850W'},
#  {'latitud': '280604N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '5',
#   'indicativo': 'C619X',
#   'nombre': 'AGAETE',
#   'indsinop': '',
#   'longitud': '154246W'},
#  {'latitud': '280004N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '13',
#   'indicativo': 'C619Y',
#   'nombre': 'LA ALDEA DE SAN NICOLÁS',
#   'indsinop': '60027',
#   'longitud': '154827W'},
#  {'latitud': '275536N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '1220',
#   'indicativo': 'C623I',
#   'nombre': 'SAN BARTOLOME TIRAJANA, CUEVAS DEL PINAR',
#   'indsinop': '',
#   'longitud': '153600W'},
#  {'latitud': '275125N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '806',
#   'indicativo': 'C625O',
#   'nombre': 'SAN BARTOLOME TIRAJANA, LOMOS PEDRO AFONSO',
#   'indsinop': '',
#   'longitud': '153842W'},
#  {'latitud': '275432N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '318',
#   'indicativo': 'C628B',
#   'nombre': 'LA ALDEA DE SAN NICOLÁS, TASARTE',
#   'indsinop': '',
#   'longitud': '154612W'},
#  {'latitud': '274648N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C629Q',
#   'nombre': 'MOGÁN, PUERTO RICO',
#   'indsinop': '',
#   'longitud': '154240W'},
#  {'latitud': '274859N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C629X',
#   'nombre': 'MOGÁN, PUERTO',
#   'indsinop': '60036',
#   'longitud': '154551W'},
#  {'latitud': '275512N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '960',
#   'indicativo': 'C635B',
#   'nombre': 'SAN BARTOLOME TIRAJANA, LAS TIRAJANAS',
#   'indsinop': '',
#   'longitud': '153427W'},
#  {'latitud': '274529N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '45',
#   'indicativo': 'C639M',
#   'nombre': 'MASPALOMAS, C. INSULAR TURISMO ',
#   'indsinop': '',
#   'longitud': '153432W'},
#  {'latitud': '274845N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '41',
#   'indicativo': 'C639U',
#   'nombre': 'SAN BARTOLOME TIRAJANA, EL MATORRAL',
#   'indsinop': '',
#   'longitud': '152712W'},
#  {'latitud': '275409N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '306',
#   'indicativo': 'C648C',
#   'nombre': 'AGÜIMES',
#   'indsinop': '',
#   'longitud': '152714W'},
#  {'latitud': '275915N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '344',
#   'indicativo': 'C648N',
#   'nombre': 'TELDE, CENTRO FORESTAL DORAMAS',
#   'indsinop': '',
#   'longitud': '152728W'},
#  {'latitud': '275504N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '24',
#   'indicativo': 'C649I',
#   'nombre': 'GRAN CANARIA AEROPUERTO',
#   'indsinop': '60030',
#   'longitud': '152343W'},
#  {'latitud': '275913N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '9',
#   'indicativo': 'C649R',
#   'nombre': 'TELDE, MELENARA',
#   'indsinop': '',
#   'longitud': '152240W'},
#  {'latitud': '280431N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '683',
#   'indicativo': 'C656V',
#   'nombre': 'TEROR',
#   'indsinop': '',
#   'longitud': '153250W'},
#  {'latitud': '280430N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '269',
#   'indicativo': 'C658L',
#   'nombre': 'LAS PALMAS DE G.C. (TAFIRA CMT)',
#   'indsinop': '',
#   'longitud': '152703W'},
#  {'latitud': '280441N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '269',
#   'indicativo': 'C658X',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, TAFIRA',
#   'indsinop': '',
#   'longitud': '152712W'},
#  {'latitud': '280523N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '55',
#   'indicativo': 'C659H',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, SAN CRISTOBAL',
#   'indsinop': '60029',
#   'longitud': '152458W'},
#  {'latitud': '280647N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '15',
#   'indicativo': 'C659M',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, PL. DE LA FERIA',
#   'indsinop': '60032',
#   'longitud': '152517W'},
#  {'latitud': '280358N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '900',
#   'indicativo': 'C665T',
#   'nombre': 'VALLESECO',
#   'indsinop': '',
#   'longitud': '153357W'},
#  {'latitud': '280540N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '352',
#   'indicativo': 'C668V',
#   'nombre': 'AGAETE - SUERTE ALTA',
#   'indsinop': '',
#   'longitud': '154030W'},
#  {'latitud': '280830N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '86',
#   'indicativo': 'C669B',
#   'nombre': 'ARUCAS',
#   'indsinop': '',
#   'longitud': '153025W'},
#  {'latitud': '274409N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '6',
#   'indicativo': 'C689E',
#   'nombre': 'MASPALOMAS',
#   'indsinop': '60037',
#   'longitud': '153545W'},
#  {'latitud': '291355N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C839I',
#   'nombre': 'TEGUISE',
#   'indsinop': '',
#   'longitud': '133007W'},
#  {'latitud': '291346N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '19',
#   'indicativo': 'C839X',
#   'nombre': 'LA GRACIOSA',
#   'indsinop': '60045',
#   'longitud': '133037W'},
#  {'latitud': '274308N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '948',
#   'indicativo': 'C916Q',
#   'nombre': 'EL PINAR, DEPÓSITO',
#   'indsinop': '',
#   'longitud': '175841W'},
#  {'latitud': '274331N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '715',
#   'indicativo': 'C917E',
#   'nombre': 'EL PINAR, LA DEHESA',
#   'indsinop': '',
#   'longitud': '180654W'},
#  {'latitud': '273955N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '98',
#   'indicativo': 'C919K',
#   'nombre': 'TACORON-LAPILLAS-TORTUGA',
#   'indsinop': '',
#   'longitud': '180107W'},
#  {'latitud': '274607N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1070',
#   'indicativo': 'C925F',
#   'nombre': 'SAN ANDRÉS, VALVERDE',
#   'indsinop': '',
#   'longitud': '175736W'},
#  {'latitud': '274839N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '670',
#   'indicativo': 'C928I',
#   'nombre': 'VALVERDE',
#   'indsinop': '',
#   'longitud': '175510W'},
#  {'latitud': '274908N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '32',
#   'indicativo': 'C929I',
#   'nombre': 'HIERRO AEROPUERTO',
#   'indsinop': '60001',
#   'longitud': '175320W'},
#  {'latitud': '274523N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '20',
#   'indicativo': 'C939T',
#   'nombre': 'FRONTERA, SABINOSA',
#   'indsinop': '',
#   'longitud': '180624W'},
#  {'latitud': '405729N',
#   'provincia': 'TARRAGONA',
#   'altitud': '32',
#   'indicativo': '0002I',
#   'nombre': 'VANDELLÒS  ',
#   'indsinop': '08169',
#   'longitud': '005217E'},
#  {'latitud': '411250N',
#   'provincia': 'TARRAGONA',
#   'altitud': '406',
#   'indicativo': '0009X',
#   'nombre': 'ALFORJA',
#   'indsinop': '',
#   'longitud': '005748E'},
#  {'latitud': '410842N',
#   'provincia': 'TARRAGONA',
#   'altitud': '71',
#   'indicativo': '0016A',
#   'nombre': 'REUS AEROPUERTO',
#   'indsinop': '08175',
#   'longitud': '010949E'},
#  {'latitud': '410915N',
#   'provincia': 'TARRAGONA',
#   'altitud': '118',
#   'indicativo': '0016B',
#   'nombre': 'REUS (CENTRE LECTURA)',
#   'indsinop': '',
#   'longitud': '010632E'},
#  {'latitud': '411735N',
#   'provincia': 'TARRAGONA',
#   'altitud': '233',
#   'indicativo': '0034X',
#   'nombre': 'VALLS',
#   'indsinop': '',
#   'longitud': '011539E'},
#  {'latitud': '410726N',
#   'provincia': 'TARRAGONA',
#   'altitud': '55',
#   'indicativo': '0042Y',
#   'nombre': 'TARRAGONA ',
#   'indsinop': '',
#   'longitud': '011457E'},
#  {'latitud': '412501N',
#   'provincia': 'BARCELONA',
#   'altitud': '632',
#   'indicativo': '0061X',
#   'nombre': 'PONTONS',
#   'indsinop': '',
#   'longitud': '013109E'},
#  {'latitud': '411949N',
#   'provincia': 'BARCELONA',
#   'altitud': '177',
#   'indicativo': '0066X',
#   'nombre': 'VILAFRANCA DEL PENEDÈS',
#   'indsinop': '',
#   'longitud': '014037E'},
#  {'latitud': '411438N',
#   'provincia': 'BARCELONA',
#   'altitud': '58',
#   'indicativo': '0073X',
#   'nombre': 'SITGES',
#   'indsinop': '',
#   'longitud': '015109E'},
#  {'latitud': '411734N',
#   'provincia': 'BARCELONA',
#   'altitud': '4',
#   'indicativo': '0076',
#   'nombre': 'BARCELONA AEROPUERTO',
#   'indsinop': '08181',
#   'longitud': '020412E'},
#  {'latitud': '420605N',
#   'provincia': 'BARCELONA',
#   'altitud': '682',
#   'indicativo': '0092X',
#   'nombre': 'BERGA',
#   'indsinop': '',
#   'longitud': '015127E'},
#  {'latitud': '415159N',
#   'provincia': 'BARCELONA',
#   'altitud': '361',
#   'indicativo': '0106X',
#   'nombre': 'BALSARENY',
#   'indsinop': '',
#   'longitud': '015221E'},
#  {'latitud': '420025N',
#   'provincia': 'BARCELONA',
#   'altitud': '700',
#   'indicativo': '0114X',
#   'nombre': 'PRATS DE LLUÇANÈS',
#   'indsinop': '',
#   'longitud': '020136E'},
#  {'latitud': '414848N',
#   'provincia': 'BARCELONA',
#   'altitud': '742',
#   'indicativo': '0120X',
#   'nombre': 'MOIÀ',
#   'indsinop': '',
#   'longitud': '020543E'},
#  {'latitud': '414312N',
#   'provincia': 'BARCELONA',
#   'altitud': '291',
#   'indicativo': '0149D',
#   'nombre': 'MANRESA (LA CULLA)',
#   'indsinop': '',
#   'longitud': '015025E'},
#  {'latitud': '414312N',
#   'provincia': 'BARCELONA',
#   'altitud': '291',
#   'indicativo': '0149X',
#   'nombre': 'MANRESA',
#   'indsinop': '08174',
#   'longitud': '015025E'},
#  {'latitud': '413540N',
#   'provincia': 'BARCELONA',
#   'altitud': '738',
#   'indicativo': '0158O',
#   'nombre': 'MONTSERRAT',
#   'indsinop': '',
#   'longitud': '015021E'},
#  {'latitud': '413540N',
#   'provincia': 'BARCELONA',
#   'altitud': '738',
#   'indicativo': '0158X',
#   'nombre': 'MONISTROL DE MONTSERRAT',
#   'indsinop': '',
#   'longitud': '015021E'},
#  {'latitud': '413444N',
#   'provincia': 'BARCELONA',
#   'altitud': '313',
#   'indicativo': '0171X',
#   'nombre': 'IGUALADA',
#   'indsinop': '08172',
#   'longitud': '013704E'},
#  {'latitud': '412429N',
#   'provincia': 'BARCELONA',
#   'altitud': '647',
#   'indicativo': '0194D',
#   'nombre': "CORBERA, PIC D'AGULLES",
#   'indsinop': '08179',
#   'longitud': '015306E'},
#  {'latitud': '412506N',
#   'provincia': 'BARCELONA',
#   'altitud': '408',
#   'indicativo': '0200E',
#   'nombre': 'BARCELONA, FABRA',
#   'indsinop': '',
#   'longitud': '020727E'},
#  {'latitud': '412326N',
#   'provincia': 'BARCELONA',
#   'altitud': '26',
#   'indicativo': '0201D',
#   'nombre': 'BARCELONA',
#   'indsinop': '08180',
#   'longitud': '021200E'},
#  {'latitud': '412230N',
#   'provincia': 'BARCELONA',
#   'altitud': '11',
#   'indicativo': '0201X',
#   'nombre': 'BARCELONA, MUSEO MARÍTIMO',
#   'indsinop': '',
#   'longitud': '021026E'},
#  {'latitud': '413646N',
#   'provincia': 'BARCELONA',
#   'altitud': '175',
#   'indicativo': '0222X',
#   'nombre': 'CALDES DE MONTBUI',
#   'indsinop': '',
#   'longitud': '021006E'},
#  {'latitud': '413125N',
#   'provincia': 'BARCELONA',
#   'altitud': '146',
#   'indicativo': '0229I',
#   'nombre': 'SABADELL AEROPUERTO',
#   'indsinop': '08192',
#   'longitud': '020611E'},
#  {'latitud': '413018N',
#   'provincia': 'BARCELONA',
#   'altitud': '56',
#   'indicativo': '0244X',
#   'nombre': 'VILASSAR DE DALT',
#   'indsinop': '',
#   'longitud': '022145E'},
#  {'latitud': '413515N',
#   'provincia': 'BARCELONA',
#   'altitud': '74',
#   'indicativo': '0252D',
#   'nombre': 'ARENYS DE MAR',
#   'indsinop': '08186',
#   'longitud': '023224E'},
#  {'latitud': '413903N',
#   'provincia': 'BARCELONA',
#   'altitud': '40',
#   'indicativo': '0255B',
#   'nombre': 'SANTA SUSANNA',
#   'indsinop': '08188',
#   'longitud': '024149E'},
#  {'latitud': '414536N',
#   'provincia': 'BARCELONA',
#   'altitud': '936',
#   'indicativo': '0260X',
#   'nombre': 'FOGARS DE MONTCLÚS',
#   'indsinop': '',
#   'longitud': '022552E'},
#  {'latitud': '414037N',
#   'provincia': 'GIRONA',
#   'altitud': '45',
#   'indicativo': '0281Y',
#   'nombre': 'BLANES',
#   'indsinop': '',
#   'longitud': '024818E'},
#  {'latitud': '414828N',
#   'provincia': 'GIRONA',
#   'altitud': '14',
#   'indicativo': '0284X',
#   'nombre': "CASTELL, PLATJA D'ARO ",
#   'indsinop': '',
#   'longitud': '030151E'},
#  {'latitud': '415804N',
#   'provincia': 'GIRONA',
#   'altitud': '51',
#   'indicativo': '0294B',
#   'nombre': "LA BISBAL (D'EMPORDA 3)",
#   'indsinop': '',
#   'longitud': '030232E'},
#  {'latitud': '421530N',
#   'provincia': 'GIRONA',
#   'altitud': '851',
#   'indicativo': '0312X',
#   'nombre': 'SANT PAU DE SEGÚRIES',
#   'indsinop': '',
#   'longitud': '022152E'},
#  {'latitud': '421901N',
#   'provincia': 'GIRONA',
#   'altitud': '1151',
#   'indicativo': '0320I',
#   'nombre': 'PLANOLES',
#   'indsinop': '',
#   'longitud': '020610E'},
#  {'latitud': '421322N',
#   'provincia': 'GIRONA',
#   'altitud': '731',
#   'indicativo': '0321',
#   'nombre': 'CAMPDEVANOL',
#   'indsinop': '',
#   'longitud': '021002E'},
#  {'latitud': '421129N',
#   'provincia': 'GIRONA',
#   'altitud': '675',
#   'indicativo': '0324A',
#   'nombre': 'RIPOLL',
#   'indsinop': '08118',
#   'longitud': '021146E'},
#  {'latitud': '415048N',
#   'provincia': 'BARCELONA',
#   'altitud': '611',
#   'indicativo': '0341',
#   'nombre': 'TONA (ESCOLA)',
#   'indsinop': '',
#   'longitud': '021336E'},
#  {'latitud': '415049N',
#   'provincia': 'BARCELONA',
#   'altitud': '607',
#   'indicativo': '0341X',
#   'nombre': 'TONA',
#   'indsinop': '',
#   'longitud': '021321E'},
#  {'latitud': '415534N',
#   'provincia': 'BARCELONA',
#   'altitud': '578',
#   'indicativo': '0349',
#   'nombre': 'SANT JULIÀ  DE VILATORTA',
#   'indsinop': '08119',
#   'longitud': '021903E'},
#  {'latitud': '420310N',
#   'provincia': 'GIRONA',
#   'altitud': '322',
#   'indicativo': '0360X',
#   'nombre': "LES PLANES D'HOSTOLES",
#   'indsinop': '',
#   'longitud': '023304E'},
#  {'latitud': '415251N',
#   'provincia': 'GIRONA',
#   'altitud': '810',
#   'indicativo': '0363X',
#   'nombre': 'SANT HILARI',
#   'indsinop': '',
#   'longitud': '023048E'},
#  {'latitud': '415442N',
#   'provincia': 'GIRONA',
#   'altitud': '143',
#   'indicativo': '0367',
#   'nombre': 'GIRONA AEROPUERTO',
#   'indsinop': '08184',
#   'longitud': '024548E'},
#  {'latitud': '415848N',
#   'provincia': 'GIRONA',
#   'altitud': '95',
#   'indicativo': '0370B',
#   'nombre': 'GIRONA, ANTIC INSTITUT',
#   'indsinop': '',
#   'longitud': '024931E'},
#  {'latitud': '415820N',
#   'provincia': 'GIRONA',
#   'altitud': '76',
#   'indicativo': '0370E',
#   'nombre': 'GIRONA',
#   'indsinop': '',
#   'longitud': '024910E'},
#  {'latitud': '420616N',
#   'provincia': 'GIRONA',
#   'altitud': '157',
#   'indicativo': '0372C',
#   'nombre': 'PORQUERES',
#   'indsinop': '08120',
#   'longitud': '024549E'},
#  {'latitud': '420314N',
#   'provincia': 'GIRONA',
#   'altitud': '1',
#   'indicativo': '0385X',
#   'nombre': "L'ESTARTIT",
#   'indsinop': '',
#   'longitud': '031205E'},
#  {'latitud': '421238N',
#   'provincia': 'GIRONA',
#   'altitud': '350',
#   'indicativo': '0394X',
#   'nombre': 'LA VALL DE BIANYA',
#   'indsinop': '',
#   'longitud': '022819E'},
#  {'latitud': '421329N',
#   'provincia': 'GIRONA',
#   'altitud': '2',
#   'indicativo': '0411X',
#   'nombre': "CASTELLÓ D'EMPÚRIES",
#   'indsinop': '',
#   'longitud': '030535E'},
#  {'latitud': '422313N',
#   'provincia': 'GIRONA',
#   'altitud': '355',
#   'indicativo': '0413A',
#   'nombre': 'MAÇANET DE CABRENYS',
#   'indsinop': '',
#   'longitud': '024520E'},
#  {'latitud': '422324N',
#   'provincia': 'GIRONA',
#   'altitud': '100',
#   'indicativo': '0421E',
#   'nombre': "ESPOLLA 'LES ALBERES'",
#   'indsinop': '',
#   'longitud': '030022E'},
#  {'latitud': '422324N',
#   'provincia': 'GIRONA',
#   'altitud': '100',
#   'indicativo': '0421X',
#   'nombre': 'ESPOLLA',
#   'indsinop': '',
#   'longitud': '030022E'},
#  {'latitud': '421533N',
#   'provincia': 'GIRONA',
#   'altitud': '45',
#   'indicativo': '0429X',
#   'nombre': 'FIGUERES',
#   'indsinop': '',
#   'longitud': '025737E'},
#  {'latitud': '421909N',
#   'provincia': 'GIRONA',
#   'altitud': '75',
#   'indicativo': '0433D',
#   'nombre': 'CABO DE CREUS',
#   'indsinop': '08121',
#   'longitud': '031856E'},
#  {'latitud': '430809N',
#   'provincia': 'NAVARRA',
#   'altitud': '183',
#   'indicativo': '1002Y',
#   'nombre': 'BAZTAN, IRURITA ',
#   'indsinop': '08030',
#   'longitud': '013235W'},
#  {'latitud': '431643N',
#   'provincia': 'NAVARRA',
#   'altitud': '54',
#   'indicativo': '1010X',
#   'nombre': 'BERA',
#   'indsinop': '',
#   'longitud': '014033W'},
#  {'latitud': '431935N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '120',
#   'indicativo': '1012P',
#   'nombre': 'IRUN',
#   'indsinop': '',
#   'longitud': '014748W'},
#  {'latitud': '432125N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '4',
#   'indicativo': '1014',
#   'nombre': 'HONDARRIBIA, MALKARROA',
#   'indsinop': '08029',
#   'longitud': '014732W'},
#  {'latitud': '432125N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '4',
#   'indicativo': '1014A',
#   'nombre': 'DONOSTIA / SAN SEBASTIÁN AEROPUERTO',
#   'indsinop': '08029',
#   'longitud': '014732W'},
#  {'latitud': '431247N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '165',
#   'indicativo': '1021X',
#   'nombre': 'ERRENTERIA, AÑARBE',
#   'indsinop': '',
#   'longitud': '015244W'},
#  {'latitud': '431244N',
#   'provincia': 'NAVARRA',
#   'altitud': '305',
#   'indicativo': '1021Y',
#   'nombre': 'ARTICUTZA (AUTOMATICA)',
#   'indsinop': '',
#   'longitud': '014752W'},
#  {'latitud': '431823N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '250',
#   'indicativo': '1024E',
#   'nombre': 'DONOSTIA / SAN SEBASTIÁN, IGELDO',
#   'indsinop': '08027',
#   'longitud': '020228W'},
#  {'latitud': '430056N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '255',
#   'indicativo': '1025A',
#   'nombre': 'SEGURA',
#   'indsinop': '',
#   'longitud': '021524W'},
#  {'latitud': '430317N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '255',
#   'indicativo': '1025X',
#   'nombre': 'BEASAIN, ARRIARAN',
#   'indsinop': '',
#   'longitud': '021355W'},
#  {'latitud': '430329N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '290',
#   'indicativo': '1026X',
#   'nombre': 'ORDIZIA',
#   'indsinop': '',
#   'longitud': '021103W'},
#  {'latitud': '430506N',
#   'provincia': 'NAVARRA',
#   'altitud': '520',
#   'indicativo': '1033X',
#   'nombre': 'ARESO',
#   'indsinop': '',
#   'longitud': '015703W'},
#  {'latitud': '430306N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '460',
#   'indicativo': '1037X',
#   'nombre': 'LEGAZPI',
#   'indsinop': '',
#   'longitud': '022013W'},
#  {'latitud': '430448N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '420',
#   'indicativo': '1037Y',
#   'nombre': 'ZUMARRAGA',
#   'indsinop': '08037',
#   'longitud': '021903W'},
#  {'latitud': '431021N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '180',
#   'indicativo': '1038X',
#   'nombre': 'AZPEITIA',
#   'indsinop': '',
#   'longitud': '021602W'},
#  {'latitud': '431808N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '28',
#   'indicativo': '1041A',
#   'nombre': 'ZUMAIA',
#   'indsinop': '08026',
#   'longitud': '021504W'},
#  {'latitud': '430328N',
#   'provincia': 'ARABA/ALAVA',
#   'altitud': '617',
#   'indicativo': '1044X',
#   'nombre': 'ARAMAIO, ETXAGUEN',
#   'indsinop': '',
#   'longitud': '023522W'},
#  {'latitud': '430130N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '308',
#   'indicativo': '1048X',
#   'nombre': 'ARETXABALETA',
#   'indsinop': '',
#   'longitud': '022756W'},
#  {'latitud': '430818N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '470',
#   'indicativo': '1049N',
#   'nombre': 'ELGETA',
#   'indsinop': '',
#   'longitud': '022945W'},
#  {'latitud': '431234N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '119',
#   'indicativo': '1050J',
#   'nombre': 'ELGOIBAR',
#   'indsinop': '08036',
#   'longitud': '022448W'},
#  {'latitud': '431902N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '150',
#   'indicativo': '1052A',
#   'nombre': 'MUTRIKU',
#   'indsinop': '',
#   'longitud': '022350W'},
#  {'latitud': '432237N',
#   'provincia': 'BIZKAIA',
#   'altitud': '12',
#   'indicativo': '1055B',
#   'nombre': 'LEKEITIO',
#   'indsinop': '08024',
#   'longitud': '023037W'},
#  {'latitud': '432033N',
#   'provincia': 'BIZKAIA',
#   'altitud': '45',
#   'indicativo': '1056K',
#   'nombre': 'FORUA',
#   'indsinop': '',
#   'longitud': '024016W'},
#  {'latitud': '432714N',
#   'provincia': 'BIZKAIA',
#   'altitud': '93',
#   'indicativo': '1057B',
#   'nombre': 'MATXITXAKO',
#   'indsinop': '',
#   'longitud': '024510W'},
#  {'latitud': '432230N',
#   'provincia': 'BIZKAIA',
#   'altitud': '90',
#   'indicativo': '1059X',
#   'nombre': 'PUNTA GALEA',
#   'indsinop': '08059',
#   'longitud': '030118W'},
#  {'latitud': '430301N',
#   'provincia': 'ARABA/ALAVA',
#   'altitud': '240',
#   'indicativo': '1060X',
#   'nombre': 'AMURRIO',
#   'indsinop': '',
#   'longitud': '030020W'},
#  {'latitud': '430544N',
#   'provincia': 'BIZKAIA',
#   'altitud': '270',
#   'indicativo': '1064L',
#   'nombre': 'OROZKO, IBARRA',
#   'indsinop': '',
#   'longitud': '025137W'},
#  {'latitud': '430557N',
#   'provincia': 'BIZKAIA',
#   'altitud': '747',
#   'indicativo': '1069Y',
#   'nombre': 'ABADIÑO, URKIOLA',
#   'indsinop': '',
#   'longitud': '023839W'},
#  {'latitud': '431210N',
#   'provincia': 'BIZKAIA',
#   'altitud': '100',
#   'indicativo': '1074C',
#   'nombre': 'AMOREBIETA-ETXANO',
#   'indsinop': '',
#   'longitud': '024222W'},
#  {'latitud': '431050N',
#   'provincia': 'BIZKAIA',
#   'altitud': '210',
#   'indicativo': '1078C',
#   'nombre': 'BALMASEDA',
#   'indsinop': '',
#   'longitud': '031235W'},
#  {'latitud': '431212N',
#   'provincia': 'BIZKAIA',
#   'altitud': '208',
#   'indicativo': '1078I',
#   'nombre': 'GÜEÑES',
#   'indsinop': '08035',
#   'longitud': '030617W'},
#  {'latitud': '431753N',
#   'provincia': 'BIZKAIA',
#   'altitud': '42',
#   'indicativo': '1082',
#   'nombre': 'BILBAO AEROPUERTO',
#   'indsinop': '08025',
#   'longitud': '025423W'},
#  {'latitud': '431647N',
#   'provincia': 'BIZKAIA',
#   'altitud': '177',
#   'indicativo': '1083B',
#   'nombre': 'SOPUERTA',
#   'indsinop': '',
#   'longitud': '031007W'},
#  {'latitud': '432341N',
#   'provincia': 'CANTABRIA',
#   'altitud': '45',
#   'indicativo': '1083L',
#   'nombre': 'CASTRO URDIALES',
#   'indsinop': '08020',
#   'longitud': '031402W'},
#  {'latitud': '431521N',
#   'provincia': 'CANTABRIA',
#   'altitud': '80',
#   'indicativo': '1089U',
#   'nombre': 'RAMALES DE LA VICTORIA',
#   'indsinop': '',
#   'longitud': '032815W'},
#  {'latitud': '432348N',
#   'provincia': 'CANTABRIA',
#   'altitud': '1',
#   'indicativo': '1096X',
#   'nombre': 'BARCENA DE CICERO, TRETO',
#   'indsinop': '',
#   'longitud': '032811W'},
#  {'latitud': '431339N',
#   'provincia': 'CANTABRIA',
#   'altitud': '849',
#   'indicativo': '1103X',
#   'nombre': 'SAN ROQUE DE RIOMIERA',
#   'indsinop': '',
#   'longitud': '034316W'},
#  {'latitud': '432526N',
#   'provincia': 'CANTABRIA',
#   'altitud': '3',
#   'indicativo': '1109',
#   'nombre': 'SANTANDER AEROPUERTO',
#   'indsinop': '08021',
#   'longitud': '034932W'},
#  {'latitud': '432543N',
#   'provincia': 'CANTABRIA',
#   'altitud': '3',
#   'indicativo': '1109X',
#   'nombre': 'SANTANDER AEROPUERTO',
#   'indsinop': '08021',
#   'longitud': '034953W'},
#  {'latitud': '432754N',
#   'provincia': 'CANTABRIA',
#   'altitud': '64',
#   'indicativo': '1110',
#   'nombre': 'SANTANDER, CIUDAD',
#   'indsinop': '',
#   'longitud': '034908W'},
#  {'latitud': '432928N',
#   'provincia': 'CANTABRIA',
#   'altitud': '52',
#   'indicativo': '1111',
#   'nombre': 'SANTANDER',
#   'indsinop': '08023',
#   'longitud': '034802W'},
#  {'latitud': '432928N',
#   'provincia': 'CANTABRIA',
#   'altitud': '51',
#   'indicativo': '1111X',
#   'nombre': 'SANTANDER',
#   'indsinop': '08023',
#   'longitud': '034802W'},
#  {'latitud': '431444N',
#   'provincia': 'CANTABRIA',
#   'altitud': '196',
#   'indicativo': '1124E',
#   'nombre': 'VILLACARRIEDO',
#   'indsinop': '',
#   'longitud': '035058W'},
#  {'latitud': '430849N',
#   'provincia': 'CANTABRIA',
#   'altitud': '460',
#   'indicativo': '1135C',
#   'nombre': 'LOS TOJOS, BÁRCENA MAYOR',
#   'indsinop': '',
#   'longitud': '041251W'},
#  {'latitud': '431619N',
#   'provincia': 'CANTABRIA',
#   'altitud': '105',
#   'indicativo': '1152C',
#   'nombre': 'SAN FELICES DE BUELNA',
#   'indsinop': '',
#   'longitud': '040255W'},
#  {'latitud': '432131N',
#   'provincia': 'CANTABRIA',
#   'altitud': '110',
#   'indicativo': '1154H',
#   'nombre': 'TORRELAVEGA, SIERRAPANDO',
#   'indsinop': '',
#   'longitud': '040139W'},
#  {'latitud': '432336N',
#   'provincia': 'CANTABRIA',
#   'altitud': '38',
#   'indicativo': '1159',
#   'nombre': 'SAN VICENTE DE LA BARQUERA',
#   'indsinop': '08017',
#   'longitud': '042332W'},
#  {'latitud': '430838N',
#   'provincia': 'CANTABRIA',
#   'altitud': '1100',
#   'indicativo': '1167B',
#   'nombre': 'CAMALEÑO, FUENTE DE',
#   'indsinop': '',
#   'longitud': '044846W'},
#  {'latitud': '430918N',
#   'provincia': 'CANTABRIA',
#   'altitud': '1910',
#   'indicativo': '1167G',
#   'nombre': 'MIRADOR DEL CABLE, PARQUE NACIONAL PICOS DE EUROPA',
#   'indsinop': '',
#   'longitud': '044811W'},
#  {'latitud': '430521N',
#   'provincia': 'CANTABRIA',
#   'altitud': '1722',
#   'indicativo': '1167J',
#   'nombre': 'CORISCAO, PARQUE NACIONAL PICOS DE EUROPA',
#   'indsinop': '',
#   'longitud': '044626W'},
#  {'latitud': '431058N',
#   'provincia': 'CANTABRIA',
#   'altitud': '251',
#   'indicativo': '1174I',
#   'nombre': 'CILLÓRIGO DE LIÉBANA, TAMA',
#   'indsinop': '',
#   'longitud': '043606W'},
#  {'latitud': '431521N',
#   'provincia': 'CANTABRIA',
#   'altitud': '940',
#   'indicativo': '1176A',
#   'nombre': 'TRESVISO',
#   'indsinop': '',
#   'longitud': '044006W'},
#  {'latitud': '431415N',
#   'provincia': 'ASTURIAS',
#   'altitud': '1236',
#   'indicativo': '1178R',
#   'nombre': 'SOTRES, PARQUE NACIONAL PICOS DE EUROPA',
#   'indsinop': '',
#   'longitud': '044412W'},
#  {'latitud': '430843N',
#   'provincia': 'LEON',
#   'altitud': '953',
#   'indicativo': '1178Y',
#   'nombre': 'POSADA DE VALDEÓN, SOTO ',
#   'indsinop': '',
#   'longitud': '045554W'},
#  {'latitud': '431840N',
#   'provincia': 'ASTURIAS',
#   'altitud': '458',
#   'indicativo': '1179B',
#   'nombre': 'CABRALES',
#   'indsinop': '',
#   'longitud': '045110W'},
#  {'latitud': '432513N',
#   'provincia': 'ASTURIAS',
#   'altitud': '10',
#   'indicativo': '1183X',
#   'nombre': 'LLANES',
#   'indsinop': '08016',
#   'longitud': '044453W'},
#  {'latitud': '431600N',
#   'provincia': 'ASTURIAS',
#   'altitud': '370',
#   'indicativo': '1186P',
#   'nombre': 'AMIEVA, PANIZALES',
#   'indsinop': '',
#   'longitud': '050709W'},
#  {'latitud': '432240N',
#   'provincia': 'ASTURIAS',
#   'altitud': '280',
#   'indicativo': '1199X',
#   'nombre': 'PILOÑA, BARGAÉU',
#   'indsinop': '',
#   'longitud': '052348W'},
#  {'latitud': '432933N',
#   'provincia': 'ASTURIAS',
#   'altitud': '30',
#   'indicativo': '1203D',
#   'nombre': 'COLUNGA',
#   'indsinop': '',
#   'longitud': '051450W'},
#  {'latitud': '433123N',
#   'provincia': 'ASTURIAS',
#   'altitud': '26',
#   'indicativo': '1207U',
#   'nombre': 'GIJÓN, CAMPUS',
#   'indsinop': '08065',
#   'longitud': '053716W'},
#  {'latitud': '433220N',
#   'provincia': 'ASTURIAS',
#   'altitud': '3',
#   'indicativo': '1208',
#   'nombre': 'GIJÓN',
#   'indsinop': '',
#   'longitud': '053815W'},
#  {'latitud': '433230N',
#   'provincia': 'ASTURIAS',
#   'altitud': '22',
#   'indicativo': '1208A',
#   'nombre': 'GIJÓN. LA MERCED',
#   'indsinop': '',
#   'longitud': '053943W'},
#  {'latitud': '433336N',
#   'provincia': 'ASTURIAS',
#   'altitud': '5',
#   'indicativo': '1208H',
#   'nombre': 'GIJÓN, PUERTO',
#   'indsinop': '08014',
#   'longitud': '054203W'},
#  {'latitud': '433921N',
#   'provincia': 'ASTURIAS',
#   'altitud': '100',
#   'indicativo': '1210X',
#   'nombre': 'CABO PEÑAS',
#   'indsinop': '08012',
#   'longitud': '055055W'},
#  {'latitud': '433401N',
#   'provincia': 'ASTURIAS',
#   'altitud': '127',
#   'indicativo': '1212E',
#   'nombre': 'ASTURIAS AEROPUERTO',
#   'indsinop': '08011',
#   'longitud': '060239W'},
#  {'latitud': '425843N',
#   'provincia': 'ASTURIAS',
#   'altitud': '1480',
#   'indicativo': '1221D',
#   'nombre': 'PAJARES-VALGRANDE',
#   'indsinop': '08031',
#   'longitud': '054635W'},
#  {'latitud': '430758N',
#   'provincia': 'ASTURIAS',
#   'altitud': '370',
#   'indicativo': '1223P',
#   'nombre': 'LENA, RONZÓN',
#   'indsinop': '',
#   'longitud': '054922W'},
#  {'latitud': '430543N',
#   'provincia': 'ASTURIAS',
#   'altitud': '750',
#   'indicativo': '1226X',
#   'nombre': 'ALLER, FELECHOSA',
#   'indsinop': '',
#   'longitud': '052837W'},
#  {'latitud': '431630N',
#   'provincia': 'ASTURIAS',
#   'altitud': '170',
#   'indicativo': '1234P',
#   'nombre': 'MIERES, BAIÑA',
#   'indsinop': '',
#   'longitud': '054909W'},
#  {'latitud': '432112N',
#   'provincia': 'ASTURIAS',
#   'altitud': '336',
#   'indicativo': '1249I',
#   'nombre': 'OVIEDO',
#   'indsinop': '08015',
#   'longitud': '055227W'},
#  {'latitud': '432112N',
#   'provincia': 'ASTURIAS',
# ...
#   'indsinop': '08087',
#   'longitud': '012831W'},
#  {'latitud': '415453N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '475',
#   'indicativo': '9299X',
#   'nombre': 'TARAZONA',
#   'indsinop': '',
#   'longitud': '014324W'},
#  {'latitud': '415732N',
#   'provincia': 'NAVARRA',
#   'altitud': '410',
#   'indicativo': '9301X',
#   'nombre': 'MONTEAGUDO',
#   'indsinop': '',
#   'longitud': '014126W'},
#  {'latitud': '420320N',
#   'provincia': 'NAVARRA',
#   'altitud': '297',
#   'indicativo': '9302Y',
#   'nombre': 'TUDELA',
#   'indsinop': '',
#   'longitud': '013634W'},
#  {'latitud': '420716N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '321',
#   'indicativo': '9321X',
#   'nombre': 'EJEA DE LOS CABALLEROS',
#   'indsinop': '',
#   'longitud': '010823W'},
#  {'latitud': '415903N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '543',
#   'indicativo': '9336D',
#   'nombre': 'CASTEJON DE VALDEJASA',
#   'indsinop': '',
#   'longitud': '005945W'},
#  {'latitud': '411259N',
#   'provincia': 'SORIA',
#   'altitud': '863',
#   'indicativo': '9344C',
#   'nombre': 'ARCOS DE JALÓN',
#   'indsinop': '',
#   'longitud': '021735W'},
#  {'latitud': '413429N',
#   'provincia': 'SORIA',
#   'altitud': '1000',
#   'indicativo': '9352A',
#   'nombre': 'ALMAZUL',
#   'indsinop': '',
#   'longitud': '020825W'},
#  {'latitud': '411735N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '703',
#   'indicativo': '9354X',
#   'nombre': 'ALHAMA DE ARAGON',
#   'indsinop': '',
#   'longitud': '015343W'},
#  {'latitud': '403400N',
#   'provincia': 'TERUEL',
#   'altitud': '1000',
#   'indicativo': '9374X',
#   'nombre': 'SANTA EULALIA DEL CAMPO',
#   'indsinop': '',
#   'longitud': '011915W'},
#  {'latitud': '404643N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '1185',
#   'indicativo': '9377Y',
#   'nombre': 'EL PEDREGAL',
#   'indsinop': '',
#   'longitud': '013406W'},
#  {'latitud': '405154N',
#   'provincia': 'TERUEL',
#   'altitud': '932',
#   'indicativo': '9381',
#   'nombre': 'CALAMOCHA, AERÓDROMO',
#   'indsinop': '',
#   'longitud': '011818W'},
#  {'latitud': '405534N',
#   'provincia': 'TERUEL',
#   'altitud': '884',
#   'indicativo': '9381I',
#   'nombre': 'CALAMOCHA',
#   'indsinop': '08233',
#   'longitud': '011736W'},
#  {'latitud': '410652N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '779',
#   'indicativo': '9390',
#   'nombre': 'DAROCA',
#   'indsinop': '08157',
#   'longitud': '012436W'},
#  {'latitud': '411952N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '582',
#   'indicativo': '9394X',
#   'nombre': 'CALATAYUD',
#   'indsinop': '08156',
#   'longitud': '013843W'},
#  {'latitud': '412852N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '370',
#   'indicativo': '9427X',
#   'nombre': 'LA ALMUNIA DE DOÑA GODINA',
#   'indsinop': '',
#   'longitud': '012251W'},
#  {'latitud': '413938N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '249',
#   'indicativo': '9434',
#   'nombre': 'ZARAGOZA, AEROPUERTO',
#   'indsinop': '08160',
#   'longitud': '010015W'},
#  {'latitud': '413716N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '258',
#   'indicativo': '9434P',
#   'nombre': 'ZARAGOZA, VALDESPARTERA',
#   'indsinop': '08159',
#   'longitud': '005605W'},
#  {'latitud': '405943N',
#   'provincia': 'TERUEL',
#   'altitud': '1255',
#   'indicativo': '9436X',
#   'nombre': 'FONFRÍA',
#   'indsinop': '',
#   'longitud': '010515W'},
#  {'latitud': '424545N',
#   'provincia': 'HUESCA',
#   'altitud': '1800',
#   'indicativo': '9445L',
#   'nombre': 'FORMIGAL, SARRIOS',
#   'indsinop': '08096',
#   'longitud': '002334W'},
#  {'latitud': '424216N',
#   'provincia': 'HUESCA',
#   'altitud': '1850',
#   'indicativo': '9451F',
#   'nombre': 'PANTICOSA, PETROSOS',
#   'indsinop': '08915',
#   'longitud': '001631W'},
#  {'latitud': '424157N',
#   'provincia': 'HUESCA',
#   'altitud': '1100',
#   'indicativo': '9453X',
#   'nombre': 'BIESCAS, EMBALSE DE BÚBAL',
#   'indsinop': '',
#   'longitud': '001908W'},
#  {'latitud': '423046N',
#   'provincia': 'HUESCA',
#   'altitud': '775',
#   'indicativo': '9460X',
#   'nombre': 'SABIÑÁNIGO',
#   'indsinop': '',
#   'longitud': '002120W'},
#  {'latitud': '420146N',
#   'provincia': 'HUESCA',
#   'altitud': '390',
#   'indicativo': '9491X',
#   'nombre': 'ALMUDÉVAR',
#   'indsinop': '',
#   'longitud': '003509W'},
#  {'latitud': '414748N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '405',
#   'indicativo': '9495Y',
#   'nombre': 'LECIÑENA',
#   'indsinop': '',
#   'longitud': '003702W'},
#  {'latitud': '412635N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '535',
#   'indicativo': '9501X',
#   'nombre': 'VALMADRID ',
#   'indsinop': '',
#   'longitud': '005309W'},
#  {'latitud': '412545N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '205',
#   'indicativo': '9510X',
#   'nombre': 'QUINTO',
#   'indsinop': '',
#   'longitud': '003014W'},
#  {'latitud': '410152N',
#   'provincia': 'TERUEL',
#   'altitud': '800',
#   'indicativo': '9513X',
#   'nombre': 'MUNIESA',
#   'indsinop': '',
#   'longitud': '004820W'},
#  {'latitud': '404943N',
#   'provincia': 'TERUEL',
#   'altitud': '895',
#   'indicativo': '9531Y',
#   'nombre': 'MONTALBÁN',
#   'indsinop': '',
#   'longitud': '004735W'},
#  {'latitud': '411019N',
#   'provincia': 'TERUEL',
#   'altitud': '305',
#   'indicativo': '9546B',
#   'nombre': 'HIJAR',
#   'indsinop': '',
#   'longitud': '002631W'},
#  {'latitud': '405828N',
#   'provincia': 'TERUEL',
#   'altitud': '762',
#   'indicativo': '9550C',
#   'nombre': 'ANDORRA, HORCALLANA',
#   'indsinop': '',
#   'longitud': '002428W'},
#  {'latitud': '404754N',
#   'provincia': 'TERUEL',
#   'altitud': '755',
#   'indicativo': '9561X',
#   'nombre': 'CASTELLOTE',
#   'indsinop': '',
#   'longitud': '001855W'},
#  {'latitud': '403718N',
#   'provincia': 'CASTELLON',
#   'altitud': '990',
#   'indicativo': '9562X',
#   'nombre': 'MORELLA',
#   'indsinop': '',
#   'longitud': '000607W'},
#  {'latitud': '402955N',
#   'provincia': 'CASTELLON',
#   'altitud': '1220',
#   'indicativo': '9563X',
#   'nombre': 'CASTELLFORT',
#   'indsinop': '08237',
#   'longitud': '001112W'},
#  {'latitud': '405648N',
#   'provincia': 'TERUEL',
#   'altitud': '466',
#   'indicativo': '9569A',
#   'nombre': 'CALANDA',
#   'indsinop': '08166',
#   'longitud': '001416W'},
#  {'latitud': '410329N',
#   'provincia': 'TERUEL',
#   'altitud': '334',
#   'indicativo': '9573X',
#   'nombre': 'ALCAÑIZ',
#   'indsinop': '08164',
#   'longitud': '000830W'},
#  {'latitud': '411433N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '215',
#   'indicativo': '9574B',
#   'nombre': 'CASPE, PLANA DEL PILÓN',
#   'indsinop': '08165',
#   'longitud': '000407W'},
#  {'latitud': '413121N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '357',
#   'indicativo': '9576C',
#   'nombre': 'BUJARALOZ',
#   'indsinop': '08165',
#   'longitud': '001028W'},
#  {'latitud': '421957N',
#   'provincia': 'GIRONA',
#   'altitud': '1699',
#   'indicativo': '9585',
#   'nombre': 'LA MOLINA',
#   'indsinop': '08117',
#   'longitud': '015622E'},
#  {'latitud': '422144N',
#   'provincia': 'LLEIDA',
#   'altitud': '1038',
#   'indicativo': '9590',
#   'nombre': 'MARTINET  ',
#   'indsinop': '',
#   'longitud': '014136E'},
#  {'latitud': '422549N',
#   'provincia': 'LLEIDA',
#   'altitud': '1940',
#   'indicativo': '9590D',
#   'nombre': 'CAP DE REC',
#   'indsinop': '08940',
#   'longitud': '014004E'},
#  {'latitud': '422117N',
#   'provincia': 'LLEIDA',
#   'altitud': '677',
#   'indicativo': '9619',
#   'nombre': "LA SEU D'URGELL",
#   'indsinop': '08115',
#   'longitud': '012747E'},
#  {'latitud': '421349N',
#   'provincia': 'LLEIDA',
#   'altitud': '1196',
#   'indicativo': '9632X',
#   'nombre': 'TUIXENT',
#   'indsinop': '',
#   'longitud': '013410E'},
#  {'latitud': '420916N',
#   'provincia': 'LLEIDA',
#   'altitud': '609',
#   'indicativo': '9638D',
#   'nombre': 'COLL DE NARGÓ',
#   'indsinop': '',
#   'longitud': '011843E'},
#  {'latitud': '414821N',
#   'provincia': 'LLEIDA',
#   'altitud': '435',
#   'indicativo': '9647X',
#   'nombre': 'TORÀ',
#   'indsinop': '',
#   'longitud': '012344E'},
#  {'latitud': '415253N',
#   'provincia': 'LLEIDA',
#   'altitud': '400',
#   'indicativo': '9650X',
#   'nombre': 'ARTESA DE SEGRE',
#   'indsinop': '',
#   'longitud': '010631E'},
#  {'latitud': '423730N',
#   'provincia': 'LLEIDA',
#   'altitud': '952',
#   'indicativo': '9657X',
#   'nombre': "ESTERRI D'ÀNEU",
#   'indsinop': '',
#   'longitud': '010734E'},
#  {'latitud': '423451N',
#   'provincia': 'LLEIDA',
#   'altitud': '1907',
#   'indicativo': '9660',
#   'nombre': 'SANT MAURICI (LLAC)',
#   'indsinop': '',
#   'longitud': '010027E'},
#  {'latitud': '422436N',
#   'provincia': 'LLEIDA',
#   'altitud': '2410',
#   'indicativo': '9677',
#   'nombre': 'PORT AINÉ',
#   'indsinop': '08938',
#   'longitud': '011253E'},
#  {'latitud': '422759N',
#   'provincia': 'LLEIDA',
#   'altitud': '1273',
#   'indicativo': '9689X',
#   'nombre': 'TORRE DE CABDELLA ',
#   'indsinop': '',
#   'longitud': '005927E'},
#  {'latitud': '421219N',
#   'provincia': 'LLEIDA',
#   'altitud': '807',
#   'indicativo': '9698U',
#   'nombre': 'TALARN',
#   'indsinop': '08112',
#   'longitud': '005155E'},
#  {'latitud': '420401N',
#   'provincia': 'LLEIDA',
#   'altitud': '515',
#   'indicativo': '9707',
#   'nombre': 'LLIMIANA',
#   'indsinop': '',
#   'longitud': '005426E'},
#  {'latitud': '414052N',
#   'provincia': 'LLEIDA',
#   'altitud': '463',
#   'indicativo': '9718X',
#   'nombre': 'TORDERA - GRANYANELLA',
#   'indsinop': '',
#   'longitud': '011323E'},
#  {'latitud': '413902N',
#   'provincia': 'LLEIDA',
#   'altitud': '388',
#   'indicativo': '9720X',
#   'nombre': 'TÀRREGA',
#   'indsinop': '08173',
#   'longitud': '010858E'},
#  {'latitud': '415224N',
#   'provincia': 'LLEIDA',
#   'altitud': '520',
#   'indicativo': '9724X',
#   'nombre': 'OS DE BALAGUER',
#   'indsinop': '',
#   'longitud': '004522E'},
#  {'latitud': '413326N',
#   'provincia': 'TARRAGONA',
#   'altitud': '657',
#   'indicativo': '9726E',
#   'nombre': 'LLORAC',
#   'indsinop': '',
#   'longitud': '011834E'},
#  {'latitud': '413701N',
#   'provincia': 'LLEIDA',
#   'altitud': '252',
#   'indicativo': '9729X',
#   'nombre': 'MOLLERUSSA',
#   'indsinop': '',
#   'longitud': '005200E'},
#  {'latitud': '423012N',
#   'provincia': 'LLEIDA',
#   'altitud': '1089',
#   'indicativo': '9744B',
#   'nombre': 'VALL DE BOÍ',
#   'indsinop': '',
#   'longitud': '004756E'},
#  {'latitud': '421907N',
#   'provincia': 'HUESCA',
#   'altitud': '760',
#   'indicativo': '9751',
#   'nombre': 'SOPEIRA',
#   'indsinop': '',
#   'longitud': '004449E'},
#  {'latitud': '420645N',
#   'provincia': 'HUESCA',
#   'altitud': '765',
#   'indicativo': '9756X',
#   'nombre': 'BENABARRE',
#   'indsinop': '',
#   'longitud': '002848E'},
#  {'latitud': '413702N',
#   'provincia': 'LLEIDA',
#   'altitud': '199',
#   'indicativo': '9771',
#   'nombre': 'LLEIDA, OBSERVATORIO',
#   'indsinop': '',
#   'longitud': '003716E'},
#  {'latitud': '413734N',
#   'provincia': 'LLEIDA',
#   'altitud': '186',
#   'indicativo': '9771C',
#   'nombre': 'LLEIDA',
#   'indsinop': '08171',
#   'longitud': '003553E'},
#  {'latitud': '412158N',
#   'provincia': 'LLEIDA',
#   'altitud': '673',
#   'indicativo': '9772X',
#   'nombre': 'LA POBLA DE CÉRVOLES',
#   'indsinop': '',
#   'longitud': '005449E'},
#  {'latitud': '412449N',
#   'provincia': 'LLEIDA',
#   'altitud': '392',
#   'indicativo': '9775X',
#   'nombre': 'EL SOLERÀS',
#   'indsinop': '',
#   'longitud': '004042E'},
#  {'latitud': '412336N',
#   'provincia': 'LLEIDA',
#   'altitud': '488',
#   'indicativo': '9776D',
#   'nombre': 'ELS TORMS',
#   'indsinop': '',
#   'longitud': '004403E'},
#  {'latitud': '423748N',
#   'provincia': 'HUESCA',
#   'altitud': '992',
#   'indicativo': '9784P',
#   'nombre': 'BIELSA',
#   'indsinop': '08103',
#   'longitud': '001329E'},
#  {'latitud': '422518N',
#   'provincia': 'HUESCA',
#   'altitud': '610',
#   'indicativo': '9808X',
#   'nombre': 'AÍNSA-SOBRARBE, LA SERRETA',
#   'indsinop': '',
#   'longitud': '000817E'},
#  {'latitud': '423919N',
#   'provincia': 'HUESCA',
#   'altitud': '1206',
#   'indicativo': '9812M',
#   'nombre': 'PARADOR DE ORDESA, PARQUE NACIONAL ORDESA Y MONTEPERDIDO',
#   'indsinop': '',
#   'longitud': '000557W'},
#  {'latitud': '423736N',
#   'provincia': 'HUESCA',
#   'altitud': '1020',
#   'indicativo': '9814A',
#   'nombre': 'TORLA',
#   'indsinop': '08101',
#   'longitud': '000642W'},
#  {'latitud': '423922N',
#   'provincia': 'HUESCA',
#   'altitud': '1905',
#   'indicativo': '9814I',
#   'nombre': 'TORLA-ORDESA, EL CEBOLLAR',
#   'indsinop': '08919',
#   'longitud': '000728W'},
#  {'latitud': '423815N',
#   'provincia': 'HUESCA',
#   'altitud': '1076',
#   'indicativo': '9814X',
#   'nombre': 'TORLA - ORDESA',
#   'indsinop': '',
#   'longitud': '000644W'},
#  {'latitud': '423558N',
#   'provincia': 'HUESCA',
#   'altitud': '1120',
#   'indicativo': '9838B',
#   'nombre': 'BENASQUE',
#   'indsinop': '',
#   'longitud': '003114E'},
#  {'latitud': '423318N',
#   'provincia': 'HUESCA',
#   'altitud': '2374',
#   'indicativo': '9839V',
#   'nombre': 'CERLER, COGULLA',
#   'indsinop': '08923',
#   'longitud': '003235E'},
#  {'latitud': '422837N',
#   'provincia': 'HUESCA',
#   'altitud': '825',
#   'indicativo': '9843A',
#   'nombre': 'SEIRA',
#   'indsinop': '',
#   'longitud': '002603E'},
#  {'latitud': '421205N',
#   'provincia': 'HUESCA',
#   'altitud': '600',
#   'indicativo': '9855E',
#   'nombre': 'CAPELLA, LAGUARRES',
#   'indsinop': '',
#   'longitud': '002758E'},
#  {'latitud': '420117N',
#   'provincia': 'HUESCA',
#   'altitud': '305',
#   'indicativo': '9866C',
#   'nombre': 'BARBASTRO',
#   'indsinop': '',
#   'longitud': '000826E'},
#  {'latitud': '414757N',
#   'provincia': 'HUESCA',
#   'altitud': '300',
#   'indicativo': '9894Y',
#   'nombre': 'SARIÑENA',
#   'indsinop': '',
#   'longitud': '000939W'},
#  {'latitud': '420504N',
#   'provincia': 'HUESCA',
#   'altitud': '546',
#   'indicativo': '9898',
#   'nombre': 'HUESCA, AEROPUERTO',
#   'indsinop': '08094',
#   'longitud': '001932W'},
#  {'latitud': '420820N',
#   'provincia': 'HUESCA',
#   'altitud': '463',
#   'indicativo': '9901X',
#   'nombre': 'HUESCA',
#   'indsinop': '',
#   'longitud': '002342W'},
#  {'latitud': '414626N',
#   'provincia': 'HUESCA',
#   'altitud': '380',
#   'indicativo': '9908X',
#   'nombre': 'LANAJA',
#   'indsinop': '',
#   'longitud': '001959W'},
#  {'latitud': '413710N',
#   'provincia': 'HUESCA',
#   'altitud': '178',
#   'indicativo': '9911X',
#   'nombre': 'BALLOBAR',
#   'indsinop': '',
#   'longitud': '001116E'},
#  {'latitud': '414651N',
#   'provincia': 'HUESCA',
#   'altitud': '218',
#   'indicativo': '9918Y',
#   'nombre': 'TAMARITE DE LITERA, LA MELUSA',
#   'indsinop': '',
#   'longitud': '002237E'},
#  {'latitud': '413129N',
#   'provincia': 'HUESCA',
#   'altitud': '170',
#   'indicativo': '9924X',
#   'nombre': 'FRAGA',
#   'indsinop': '',
#   'longitud': '002120E'},
#  {'latitud': '405224N',
#   'provincia': 'TERUEL',
#   'altitud': '483',
#   'indicativo': '9935X',
#   'nombre': 'VALDERROBRES',
#   'indsinop': '',
#   'longitud': '000847E'},
#  {'latitud': '405711N',
#   'provincia': 'TARRAGONA',
#   'altitud': '495',
#   'indicativo': '9946X',
#   'nombre': 'HORTA DE SANT JOAN',
#   'indsinop': '',
#   'longitud': '001842E'},
#  {'latitud': '411038N',
#   'provincia': 'TARRAGONA',
#   'altitud': '370',
#   'indicativo': '9947X',
#   'nombre': 'LA POBLA DE MASSALUCA',
#   'indsinop': '',
#   'longitud': '002112E'},
#  {'latitud': '411458N',
#   'provincia': 'TARRAGONA',
#   'altitud': '363',
#   'indicativo': '9961X',
#   'nombre': 'CABACÉS',
#   'indsinop': '',
#   'longitud': '004407E'},
#  {'latitud': '410018N',
#   'provincia': 'TARRAGONA',
#   'altitud': '112',
#   'indicativo': '9975X',
#   'nombre': 'RASQUERA',
#   'indsinop': '',
#   'longitud': '003649E'},
#  {'latitud': '404913N',
#   'provincia': 'TARRAGONA',
#   'altitud': '50',
#   'indicativo': '9981A',
#   'nombre': 'ESTACIÓN DE TORTOSA (ROQUETES)',
#   'indsinop': '08238',
#   'longitud': '002936E'},
#  {'latitud': '404157N',
#   'provincia': 'TARRAGONA',
#   'altitud': '1',
#   'indicativo': '9987P',
#   'nombre': "SANT JAUME D'ENVEJA",
#   'indsinop': '08240',
#   'longitud': '004836E'},
#  {'latitud': '424131N',
#   'provincia': 'LLEIDA',
#   'altitud': '2467',
#   'indicativo': '9988B',
#   'nombre': 'CAP DE VAQUÈIRA',
#   'indsinop': '08936',
#   'longitud': '005826E'},
#  {'latitud': '424201N',
#   'provincia': 'LLEIDA',
#   'altitud': '1161',
#   'indicativo': '9990X',
#   'nombre': 'NAUT ARAN, ARTIES ',
#   'indsinop': '08107',
#   'longitud': '005237E'},
#  {'latitud': '424634N',
#   'provincia': 'LLEIDA',
#   'altitud': '722',
#   'indicativo': '9994X',
#   'nombre': 'BOSSÒST',
#   'indsinop': '',
#   'longitud': '004123E'},
#  {'latitud': '430528N',
#   'provincia': 'NAVARRA',
#   'altitud': '334',
#   'indicativo': '9995Y',
#   'nombre': 'VALCARLOS/LUZAIDE',
#   'indsinop': '',
#   'longitud': '011803W'},
#  {'latitud': '405517N',
#   'provincia': 'TERUEL',
#   'altitud': '1006',
#   'indicativo': '9998X',
#   'nombre': 'BELLO',
#   'indsinop': '',
#   'longitud': '012940W'}]

# %% [markdown]
# "idema" es ahora una lista de diccionarios, que podemos convertir sencillamente en un pandas.DataFrame.
# `df_stations` contendrá la información de todas estaciones de España.

# %%
df_stations = pd.DataFrame(idema)
df_stations
# Out:
#      latitud      provincia altitud indicativo               nombre indsinop  \
# 0    394924N  ILLES BALEARS     490      B013X        ESCORCA, LLUC    08304
# 1    394744N  ILLES BALEARS       5      B051A       SÓLLER, PUERTO    08316
# 2    394121N  ILLES BALEARS      60      B087X          BANYALBUFAR
# 3    393445N  ILLES BALEARS      52      B103B   ANDRATX - SANT ELM    99103
# 4    393305N  ILLES BALEARS      50      B158X  CALVIÀ, ES CAPDELLÀ
# ..       ...            ...     ...        ...                  ...      ...
# 942  424131N         LLEIDA    2467      9988B      CAP DE VAQUÈIRA    08936
# 943  424201N         LLEIDA    1161      9990X   NAUT ARAN, ARTIES     08107
# 944  424634N         LLEIDA     722      9994X              BOSSÒST
# 945  430528N        NAVARRA     334      9995Y    VALCARLOS/LUZAIDE
# 946  405517N         TERUEL    1006      9998X                BELLO
#
#     longitud
# 0    025309E
# 1    024129E
# 2    023046E
# 3    022208E
# 4    022759E
# ..       ...
# 942  005826E
# 943  005237E
# 944  004123E
# 945  011803W
# 946  012940W
#
# [947 rows x 7 columns]

# %% [markdown]
# La columna "indicativo" es el denominado "idema" por la propia API de Aemet, así que voy a renombrarla.

# %%
df_stations.rename(columns = {'indicativo' : 'idema'}, inplace = True)

# %% [markdown]
# ### 2.2 - Guardar el dataset en local para poder acceder a él en cualquier momento.

# %%
df_stations.to_csv('./data/raw/EMA_info_raw.csv',
                   sep = ',',
                   index = False)

# %% [markdown]
# ### 2.3 - Información de los metadatos

# %%
# Para comprender mejor el significado de cada columna también quiero la información de los metadatos.

# Como ya me conozco la estructura de como almacena AEMET los datos, puedo hacerlo en una única línea de código
df_meta_idema = pd.DataFrame(requests.get(idema_info['metadatos']).json()['campos'])
df_meta_idema
# Out:
#            id                              descripcion tipo_datos  requerido
# 0     latitud                   latitud de la estación     string       True
# 1   provincia       provincia donde reside la estación     string       True
# 2  indicativo  indicativo climatológico de la estación     string       True
# 3     altitud                  altitud de la estación      string       True
# 4      nombre                 ubicación de la estación     string       True
# 5    indsinop                     Indicativo sinóptico     string       True
# 6    longitud                  longitud de la estación     string       True

# %%
# Guardar la info de los metadatos
df_meta_idema.to_csv('./data/raw/metadatos_EMA.csv',
                     sep = ',',
                     index = False)

# %% [markdown]
# ### 2.4 - Cargar el DataSet de las estaciones.

# %%
df_stations = pd.read_csv('./data/raw/EMA_info_raw.csv')

# Información general del dataset de las estaciones
display(df_stations['provincia'].unique())
display(df_stations.info())
display(df_stations['idema'].nunique())
display(df_stations.duplicated().value_counts())
# Out:
# array(['ILLES BALEARS', 'BALEARES', 'LAS PALMAS', 'STA. CRUZ DE TENERIFE',
#        'TARRAGONA', 'BARCELONA', 'GIRONA', 'NAVARRA', 'GIPUZKOA',
#        'ARABA/ALAVA', 'BIZKAIA', 'CANTABRIA', 'ASTURIAS', 'LEON', 'LUGO',
#        'A CORUÑA', 'PONTEVEDRA', 'OURENSE', 'SORIA', 'BURGOS', 'SEGOVIA',
#        'VALLADOLID', 'PALENCIA', 'AVILA', 'MADRID', 'SALAMANCA', 'ZAMORA',
#        'GUADALAJARA', 'CUENCA', 'TOLEDO', 'CACERES', 'ALBACETE',
#        'CIUDAD REAL', 'BADAJOZ', 'CORDOBA', 'HUELVA', 'CEUTA', 'JAEN',
#        'GRANADA', 'ALMERIA', 'SEVILLA', 'CADIZ', 'MELILLA', 'MALAGA',
#        'MURCIA', 'ALICANTE', 'VALENCIA', 'TERUEL', 'CASTELLON',
#        'LA RIOJA', 'HUESCA', 'ZARAGOZA', 'LLEIDA'], dtype=object)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 947 entries, 0 to 946
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitud    947 non-null    object
#  1   provincia  947 non-null    object
#  2   altitud    947 non-null    int64
#  3   idema      947 non-null    object
#  4   nombre     947 non-null    object
#  5   indsinop   301 non-null    float64
#  6   longitud   947 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 51.9+ KB
# None
# 947
# False    947
# Name: count, dtype: int64

# %% [markdown]
# ### 2.5 - Tengo una primeras `conclusiones` de este dataset:
# - Está bastante limpio, con la mayoría de sus columnas completas
# - Tengo el "idema" (único), que era el dato que venía a buscar para poder hacer más `requets` a la API

# %% [markdown]
# ## 3 - Acceso a la información de las EMA <a id="3-acceso-EMA"></a>

# %%
# Ejemplo de acceso a la información de dos estaciones
end_point = '/api/valores/climatologicos/inventarioestaciones/estaciones/B013X,B051A'

url = base_url + end_point

# Información de dos estaciones
response = requests.request("GET", url, headers=headers, params=querystring)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/d48279d1', 'metadatos': 'https://opendata.aemet.es/opendata/sh/0556af7a'}

# %% [markdown]
# De nuevo la información está incrustada en otra URL, por tanto hay que hacer un nuevo "request".
# Si toda la información de Aemet está estructurada de esta forma, pensaré en hacer una "request" doble directamente.

# %%
# Acceso a los "datos" reales de las dos EMA
response = requests.get(response.json()['datos'])
station_info = response.json()  
station_info
# Out:
# [{'latitud': '394924N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '490',
#   'indicativo': 'B013X',
#   'nombre': 'ESCORCA, LLUC',
#   'indsinop': '08304',
#   'longitud': '025309E'},
#  {'latitud': '394744N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '5',
#   'indicativo': 'B051A',
#   'nombre': 'SÓLLER, PUERTO',
#   'indsinop': '08316',
#   'longitud': '024129E'}]

# %% [markdown]
# ### Conclusiones
#
# - La información que tiene este data set es el mismo que ya tengo almacenado en el fichero "EMA_info_raw.csv". Por tanto, este "request" no tiene ningún valor añadido.

# %% [markdown]
# ## 4 - Acceso a las climatologias mensuales anuales <a id="4-clima-mensual-anual"></a>
#
# Valores medios mensuales y anuales de los datos climatológicos para la estación y el periodo de años pasados por parámetro. Periodicidad de actualización: 1 vez al día.

# %%
# Acceso a los datos de una única EMA
end_point = '/api/valores/climatologicos/mensualesanuales/datos/anioini/{anioIniStr}/aniofin/{anioFinStr}/estacion/{idema}'

anioIniStr = '1900'
anioFinStr = '2024'
idema = 'B013X' # idema de Baleares

end_point = end_point.format(anioIniStr = anioIniStr, anioFinStr = anioFinStr, idema = idema)

url = base_url + end_point
url     # No es accesible sin API-Key
# Out:
# 'https://opendata.aemet.es/opendata/api/valores/climatologicos/mensualesanuales/datos/anioini/1900/aniofin/2024/estacion/B013X'

# %%
response = requests.request("GET", url, headers=headers, params=querystring)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'descripcion': 'El rango de las fechas no puede ser superior a 36 mesess', 'estado': 404}

# %% [markdown]
# ### `El rango de las fechas NO puede ser superior a tres meses.`
#
# Por tanto si quiero seguir con esta estrategia debo hacer las consultas iterativamente, o buscar una `nueva estrategia`.

# %%
# Acceso a los datos de una única EMA con NUEVO rango de años
end_point = '/api/valores/climatologicos/mensualesanuales/datos/anioini/{anioIniStr}/aniofin/{anioFinStr}/estacion/{idema}'

anioIniStr = '2021'
anioFinStr = '2024'
idema = 'B013X' # idema de Baleares

end_point = end_point.format(anioIniStr = anioIniStr, anioFinStr = anioFinStr, idema = idema)

url = base_url + end_point

response = requests.request("GET", url, headers=headers, params=querystring)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/47715e04', 'metadatos': 'https://opendata.aemet.es/opendata/sh/997c0034'}

# %% [markdown]
# ### 4.2 Acceso a los metatados para comprender la información de las columnas

# %%
# Acceso a la información de los METADATOS, que describe la información de las columnas
metadatos = requests.get(response.json()['metadatos']).json()
metadatos
# Out:
# {'unidad_generadora': 'Servicio del Banco Nacional de Datos Climatológicos',
#  'periodicidad': '1 vez al día',
#  'descripcion': 'Climatologías mensuales anuales',
#  'formato': 'application/json',
#  'copyright': '© AEMET. Autorizado el uso de la información y su reproducción citando a AEMET como autora de la misma.',
#  'notaLegal': 'https://www.aemet.es/es/nota_legal',
#  'campos': [{'id': 'fecha',
#    'descripcion': 'año y mes (AAAA-X) donde X es un número del 1 aa 13, indicando el mes y el valor 13 indica valor anual',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'indicativo',
#    'descripcion': 'indicativo climatológico',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'nombre',
#    'descripcion': 'nombre (ubicación) de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'provincia',
#    'descripcion': 'provincia de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'altitud',
#    'descripcion': 'altitud de la estación en m sobre el nivel del mar',
#    'tipo_datos': 'string',
#    'unidad': 'm',
#    'requerido': True},
#   {'id': 'tm_mes',
#    'descripcion': 'Temperatura media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_max',
#    'descripcion': 'Temperatura media mensual/anual de las máximas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min',
#    'descripcion': 'Temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ta_max',
#    'descripcion': 'Temperatura máxima absoluta del mes/año y fecha',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ta_min',
#    'descripcion': 'Temperatura mínima absoluta del mes/año y fecha',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min',
#    'descripcion': 'Temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ti_max',
#    'descripcion': 'Temperatura máxima mas baja del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'nt_30',
#    'descripcion': 'Nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00',
#    'descripcion': 'Nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'número de días',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'p_mes',
#    'descripcion': 'Precipitación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'mm',
#    'requerido': False},
#   {'id': 'p_max',
#    'descripcion': 'Precipitación máxima diaria del mes/año y fecha',
#    'tipo_datos': 'string',
#    'unidad': 'mm (dia o fecha del año)',
#    'requerido': False},
#   {'id': 'np_001',
#    'descripcion': 'Nº de días de precipitación apreciable (>= 0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010',
#    'descripcion': 'Nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100',
#    'descripcion': 'Nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300',
#    'descripcion': 'Nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'hr',
#    'descripcion': 'Humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '%',
#    'requerido': False},
#   {'id': 'e',
#    'descripcion': 'Tensión de vapor media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'décimas de hPa',
#    'requerido': False},
#   {'id': 'n_llu',
#    'descripcion': 'Nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie',
#    'descripcion': 'Nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra',
#    'descripcion': 'Nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor',
#    'descripcion': 'Nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog',
#    'descripcion': 'Nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_des',
#    'descripcion': 'Nº de días despejados en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub',
#    'descripcion': 'Nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub',
#    'descripcion': 'Nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'inso',
#    'descripcion': 'Media mensual/anual de la insolación diaria',
#    'tipo_datos': 'string',
#    'unidad': 'horas',
#    'requerido': False},
#   {'id': 'p_sol',
#    'descripcion': 'Porcentaje medio mensual de la insolación diaria frente a la insolación teórica',
#    'tipo_datos': 'string',
#    'unidad': '%',
#    'requerido': False},
#   {'id': 'glo',
#    'descripcion': 'Radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'decenas de kJ/m2',
#    'requerido': False},
#   {'id': 'evap',
#    'descripcion': 'Evaporación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'décimas de mm',
#    'requerido': False},
#   {'id': 'w_rec',
#    'descripcion': 'Recorrido medio diario (de 07 a 07 UTC) del mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'km',
#    'requerido': False},
#   {'id': 'w_racha',
#    'descripcion': 'Dirección, Velocidad y fecha de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Dirección en decenas de grado (99 = dirección variable)(88 = sin dato de dirección). Velocidad en m/sg',
#    'requerido': False},
#   {'id': 'nw_55',
#    'descripcion': 'Nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_91',
#    'descripcion': 'Nº de días de velocidad del viento mayor o igual a 91 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'w_med',
#    'descripcion': 'Velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'q_med',
#    'descripcion': 'Presión media mensual/anual al nivel de la estación)',
#    'tipo_datos': 'string',
#    'unidad': 'hPa',
#    'requerido': False},
#   {'id': 'q_max',
#    'descripcion': 'Presión máxima absoluta mensual/anual y fecha',
#    'tipo_datos': 'string',
#    'unidad': 'hPa',
#    'requerido': False},
#   {'id': 'q_min',
#    'descripcion': 'Presión máxima mínima mensual/anual y fecha',
#    'tipo_datos': 'string',
#    'unidad': 'hPa',
#    'requerido': False},
#   {'id': 'q_mar',
#    'descripcion': 'Presión media mensual/anual al nivel del mar',
#    'tipo_datos': 'string',
#    'unidad': 'hPa',
#    'requerido': False},
#   {'id': 'ts_10',
#    'descripcion': 'Temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20',
#    'descripcion': 'Temperatura media mensual/anual a 20 cm',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50',
#    'descripcion': 'Temperatura media mensual/anual a 20 cm',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'nv_0050',
#    'descripcion': 'Nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100',
#    'descripcion': 'Nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000',
#    'descripcion': 'Nº de días con visibilidad superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False}]}

# %%
# La información de las columnas está en la columna "campos"
df_metadatos = pd.DataFrame(metadatos['campos'])
df_metadatos.head(10)
# Out:
#            id                                        descripcion tipo_datos  \
# 0       fecha  año y mes (AAAA-X) donde X es un número del 1 ...     string
# 1  indicativo                           indicativo climatológico     string
# 2      nombre                  nombre (ubicación) de la estación     string
# 3   provincia                           provincia de la estación     string
# 4     altitud  altitud de la estación en m sobre el nivel del...     string
# 5      tm_mes                    Temperatura media mensual/anual     string
# 6      tm_max     Temperatura media mensual/anual de las máximas     string
# 7      tm_min     Temperatura media mensual/anual de las mínimas     string
# 8      ta_max    Temperatura máxima absoluta del mes/año y fecha     string
# 9      ta_min    Temperatura mínima absoluta del mes/año y fecha     string
#
#    requerido unidad
# 0       True    NaN
# 1       True    NaN
# 2       True    NaN
# 3       True    NaN
# 4       True      m
# 5      False     °C
# 6      False     °C
# 7      False     °C
# 8      False     °C
# 9      False     °C

# %% [markdown]
# ### La información de los metadatos es muy útil. Voy a almacenarla en local también, para poder consultar el signinficado de cada columna en el futuro.

# %%
# Guardar la información de los metadatos del clima mensual por anyo
df_metadatos.to_csv('./data/metadatos_clima_mes_anyo.csv',
                    index = False)

# %% [markdown]
# ### 4.2 - Acceso a los datos de tres años en una única EMA.

# %%
# Acceso a los DATOS
B013X_2021_2024 = requests.get(response.json()['datos']).json()
B013X_2021_2024
# Out:
# [{'fecha': '2021-10',
#   'indicativo': 'B013X',
#   'p_max': '36.3(03)',
#   'n_cub': '8',
#   'hr': '85',
#   'nw_55': '1',
#   'tm_min': '10.0',
#   'ta_max': '25.4(03)',
#   'ts_min': '16.1',
#   'nt_30': '0',
#   'n_des': '6',
#   'w_racha': '23/16.7(30)',
#   'np_100': '3',
#   'n_nub': '17',
#   'nw_91': '0',
#   'np_001': '14',
#   'ta_min': '5.0(12)',
#   'w_rec': '35',
#   'e': '150',
#   'np_300': '1',
#   'p_mes': '107.1',
#   'w_med': '1',
#   'nt_00': '0',
#   'ti_max': '16.2',
#   'tm_mes': '15.4',
#   'tm_max': '20.8',
#   'np_010': '10'},
#  {'fecha': '2021-11',
#   'indicativo': 'B013X',
#   'p_max': '99.1(09)',
#   'n_cub': '21',
#   'hr': '88',
#   'nw_55': '2',
#   'tm_min': '8.5',
#   'ta_max': '20.8(01)',
#   'ts_min': '12.0',
#   'nt_30': '0',
#   'n_des': '1',
#   'w_racha': '14/17.8(29)',
#   'np_100': '12',
#   'n_nub': '8',
#   'nw_91': '0',
#   'np_001': '23',
#   'ta_min': '3.6(29)',
#   'w_rec': '56',
#   'e': '116',
#   'np_300': '6',
#   'p_mes': '502.5',
#   'w_med': '2',
#   'nt_00': '0',
#   'ti_max': '9.4',
#   'tm_mes': '10.8',
#   'tm_max': '13.2',
#   'np_010': '19'},
#  {'fecha': '2021-12',
#   'indicativo': 'B013X',
#   'p_max': '28.8(02)',
#   'n_cub': '8',
#   'hr': '81',
#   'tm_min': '4.4',
#   'ta_max': '20.7(31)',
#   'ts_min': '13.3',
#   'nt_30': '0',
#   'n_des': '6',
#   'np_100': '2',
#   'n_nub': '16',
#   'np_001': '6',
#   'ta_min': '0.1(03)',
#   'e': '96',
#   'np_300': '0',
#   'p_mes': '59.1',
#   'nt_00': '0',
#   'ti_max': '9.8',
#   'tm_mes': '9.7',
#   'tm_max': '15.0',
#   'np_010': '4'},
#  {'fecha': '2021-13',
#   'indicativo': 'B013X',
#   'p_max': '99.1(09/nov)',
#   'hr': '74',
#   'tm_min': '9.7',
#   'ta_max': '40.5(13/ago)',
#   'ts_min': '22.8',
#   'nt_30': '39',
#   'np_100': '35',
#   'np_001': '115',
#   'ta_min': '-1.2(19/ene)',
#   'e': '136',
#   'np_300': '13',
#   'p_mes': '1235.6',
#   'nt_00': '13',
#   'ti_max': '5.4',
#   'tm_mes': '15.1',
#   'tm_max': '20.3',
#   'np_010': '84'},
#  {'fecha': '2021-1',
#   'indicativo': 'B013X',
#   'p_max': '61.8(10)',
#   'hr': '80',
#   'nw_55': '4',
#   'tm_min': '3.0',
#   'ta_max': '23.0(28)',
#   'ts_min': '9.5',
#   'nt_30': '0',
#   'w_racha': '25/18.9(23)',
#   'np_100': '7',
#   'nw_91': '0',
#   'np_001': '13',
#   'ta_min': '-1.2(19)',
#   'w_rec': '63',
#   'e': '84',
#   'np_300': '2',
#   'p_mes': '196.5',
#   'w_med': '3',
#   'nt_00': '9',
#   'ti_max': '5.4',
#   'tm_mes': '7.6',
#   'tm_max': '12.1',
#   'np_010': '12'},
#  {'fecha': '2021-2',
#   'indicativo': 'B013X',
#   'p_max': '10.2(12)',
#   'hr': '73',
#   'nw_55': '3',
#   'tm_min': '4.8',
#   'ta_max': '23.2(03)',
#   'ts_min': '12.8',
#   'nt_30': '0',
#   'w_racha': '27/19.2(10)',
#   'np_100': '1',
#   'nw_91': '0',
#   'np_001': '6',
#   'ta_min': '0.5(17)',
#   'w_rec': '79',
#   'e': '93',
#   'np_300': '0',
#   'p_mes': '17.6',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '9.0',
#   'tm_mes': '10.5',
#   'tm_max': '16.1',
#   'np_010': '4'},
#  {'fecha': '2021-3',
#   'indicativo': 'B013X',
#   'p_max': '45.8(08)',
#   'hr': '75',
#   'nw_55': '0',
#   'tm_min': '4.3',
#   'ta_max': '20.5(26)',
#   'ts_min': '11.2',
#   'nt_30': '0',
#   'w_racha': '16/13.3(14)',
#   'np_100': '4',
#   'nw_91': '0',
#   'np_001': '6',
#   'ta_min': '-0.4(11)',
#   'w_rec': '67',
#   'e': '92',
#   'np_300': '3',
#   'p_mes': '127.6',
#   'w_med': '3',
#   'nt_00': '4',
#   'ti_max': '5.8',
#   'tm_mes': '9.5',
#   'tm_max': '14.7',
#   'np_010': '5'},
#  {'fecha': '2021-4',
#   'indicativo': 'B013X',
#   'p_max': '9.6(11)',
#   'hr': '75',
#   'nw_55': '0',
#   'tm_min': '5.9',
#   'ta_max': '21.0(02)',
#   'ts_min': '12.6',
#   'nt_30': '0',
#   'w_racha': '13/10.8(25)',
#   'np_100': '0',
#   'nw_91': '0',
#   'np_001': '8',
#   'ta_min': '0.8(08)',
#   'w_rec': '63',
#   'e': '109',
#   'np_300': '0',
#   'p_mes': '28.9',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '8.8',
#   'tm_mes': '11.0',
#   'tm_max': '16.1',
#   'np_010': '6'},
#  {'fecha': '2021-5',
#   'indicativo': 'B013X',
#   'p_max': '36.4(23)',
#   'hr': '63',
#   'nw_55': '1',
#   'tm_min': '10.1',
#   'ta_max': '29.2(16)',
#   'ts_min': '16.0',
#   'nt_30': '0',
#   'w_racha': '16/15.6(10)',
#   'np_100': '2',
#   'nw_91': '0',
#   'np_001': '9',
#   'ta_min': '5.3(12)',
#   'w_rec': '74',
#   'e': '125',
#   'np_300': '1',
#   'p_mes': '57.7',
#   'w_med': '4',
#   'nt_00': '0',
#   'ti_max': '15.2',
#   'tm_mes': '15.8',
#   'tm_max': '21.4',
#   'np_010': '4'},
#  {'fecha': '2021-6',
#   'indicativo': 'B013X',
#   'p_max': '15.2(23)',
#   'hr': '65',
#   'nw_55': '0',
#   'tm_min': '15.1',
#   'ta_max': '31.1(14)',
#   'ts_min': '21.8',
#   'nt_30': '3',
#   'w_racha': '19/13.9(23)',
#   'np_100': '1',
#   'nw_91': '0',
#   'np_001': '6',
#   'ta_min': '11.8(07)',
#   'w_rec': '63',
#   'e': '178',
#   'np_300': '0',
#   'p_mes': '24.2',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '20.0',
#   'tm_mes': '20.9',
#   'tm_max': '26.6',
#   'np_010': '4'},
#  {'fecha': '2021-7',
#   'indicativo': 'B013X',
#   'p_max': '3.2(31)',
#   'hr': '56',
#   'nw_55': '0',
#   'tm_min': '16.5',
#   'ta_max': '36.2(24)',
#   'ts_min': '22.8',
#   'nt_30': '16',
#   'w_racha': '22/14.4(24)',
#   'np_100': '0',
#   'nw_91': '0',
#   'np_001': '3',
#   'ta_min': '13.8(09)',
#   'w_rec': '67',
#   'e': '183',
#   'np_300': '0',
#   'p_mes': '4.2',
#   'w_med': '4',
#   'nt_00': '0',
#   'ti_max': '24.6',
#   'tm_mes': '23.3',
#   'tm_max': '30.0',
#   'np_010': '1'},
#  {'fecha': '2021-8',
#   'indicativo': 'B013X',
#   'p_max': '4.8(01)',
#   'hr': '62',
#   'nw_55': '0',
#   'tm_min': '17.6',
#   'ta_max': '40.5(13)',
#   'ts_min': '22.4',
#   'nt_30': '14',
#   'w_racha': '15/11.4(30)',
#   'np_100': '0',
#   'nw_91': '0',
#   'np_001': '5',
#   'ta_min': '12.7(03)',
#   'w_rec': '57',
#   'e': '199',
#   'np_300': '0',
#   'p_mes': '10.8',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '22.8',
#   'tm_mes': '24.3',
#   'tm_max': '30.9',
#   'np_010': '3'},
#  {'fecha': '2021-9',
#   'indicativo': 'B013X',
#   'p_max': '26.4(21)',
#   'hr': '80',
#   'nw_55': '1',
#   'tm_min': '16.5',
#   'ta_max': '30.9(06)',
#   'ts_min': '22.6',
#   'nt_30': '6',
#   'w_racha': '28/16.1(15)',
#   'np_100': '3',
#   'nw_91': '0',
#   'np_001': '16',
#   'ta_min': '12.6(20)',
#   'w_rec': '56',
#   'e': '210',
#   'np_300': '0',
#   'p_mes': '99.4',
#   'w_med': '2',
#   'nt_00': '0',
#   'ti_max': '18.4',
#   'tm_mes': '21.8',
#   'tm_max': '27.0',
#   'np_010': '12'},
#  {'fecha': '2022-10',
#   'indicativo': 'B013X',
#   'p_max': '16.2(06)',
#   'n_cub': '8',
#   'hr': '76',
#   'nw_55': '0',
#   'tm_min': '12.6',
#   'ta_max': '31.5(26)',
#   'ts_min': '17.1',
#   'nt_30': '4',
#   'n_des': '8',
#   'w_racha': '26/13.1(24)',
#   'np_100': '2',
#   'n_nub': '15',
#   'nw_91': '0',
#   'np_001': '7',
#   'ta_min': '6.7(30)',
#   'w_rec': '55',
#   'e': '165',
#   'np_300': '0',
#   'p_mes': '44.5',
#   'w_med': '2',
#   'nt_00': '0',
#   'ti_max': '18.1',
#   'tm_mes': '19.0',
#   'tm_max': '25.3',
#   'np_010': '5'},
#  {'fecha': '2022-11',
#   'indicativo': 'B013X',
#   'p_max': '34.2(18)',
#   'n_cub': '14',
#   'hr': '84',
#   'nw_55': '2',
#   'tm_min': '8.5',
#   'ta_max': '24.8(01)',
#   'ts_min': '13.9',
#   'nt_30': '0',
#   'n_des': '5',
#   'w_racha': '13/16.1(22)',
#   'np_100': '7',
#   'n_nub': '11',
#   'nw_91': '0',
#   'np_001': '11',
#   'ta_min': '1.0(27)',
#   'w_rec': '70',
#   'e': '133',
#   'np_300': '2',
#   'p_mes': '180.5',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '12.2',
#   'tm_mes': '13.6',
#   'tm_max': '18.7',
#   'np_010': '9'},
#  {'fecha': '2022-12',
#   'indicativo': 'B013X',
#   'p_max': '31.4(02)',
#   'n_cub': '10',
#   'hr': '82',
#   'nw_55': '2',
#   'tm_min': '6.4',
#   'ta_max': '23.4(25)',
#   'ts_min': '14.6',
#   'nt_30': '0',
#   'n_des': '7',
#   'w_racha': '19/19.2(12)',
#   'np_100': '3',
#   'n_nub': '14',
#   'nw_91': '0',
#   'np_001': '12',
#   'ta_min': '1.3(29)',
#   'w_rec': '56',
#   'e': '111',
#   'np_300': '1',
#   'p_mes': '89.5',
#   'w_med': '2',
#   'nt_00': '0',
#   'ti_max': '10.5',
#   'tm_mes': '12.1',
#   'tm_max': '17.6',
#   'np_010': '10'},
#  {'fecha': '2022-13',
#   'indicativo': 'B013X',
#   'n_cub': '95',
#   'hr': '71',
#   'tm_min': '10.3',
#   'ta_max': '38.9(13/ago)',
#   'ts_min': '26.4',
#   'nt_30': '87',
#   'n_des': '117',
#   'n_nub': '150',
#   'ta_min': '-4.0(18/ene)',
#   'e': '141',
#   'w_med': '3',
#   'nt_00': '22',
#   'ti_max': '5.9',
#   'tm_mes': '16.5',
#   'tm_max': '22.6'},
#  {'fecha': '2022-1',
#   'indicativo': 'B013X',
#   'p_max': '21.0(05)',
#   'n_cub': '5',
#   'hr': '82',
#   'tm_min': '0.4',
#   'ta_max': '22.2(04)',
#   'ts_min': '8.4',
#   'nt_30': '0',
#   'n_des': '13',
#   'np_100': '1',
#   'n_nub': '13',
#   'np_001': '5',
#   'ta_min': '-4.0(18)',
#   'e': '78',
#   'np_300': '0',
#   'p_mes': '33.2',
#   'w_med': '1',
#   'nt_00': '17',
#   'ti_max': '5.9',
#   'tm_mes': '7.0',
#   'tm_max': '13.5',
#   'np_010': '5'},
#  {'fecha': '2022-2',
#   'indicativo': 'B013X',
#   'p_max': '7.8(14)',
#   'n_cub': '5',
#   'hr': '76',
#   'nw_55': '0',
#   'tm_min': '2.3',
#   'ta_max': '22.5(03)',
#   'ts_min': '7.1',
#   'nt_30': '0',
#   'n_des': '12',
#   'w_racha': '20/11.9(13)',
#   'np_100': '0',
#   'n_nub': '11',
#   'nw_91': '0',
#   'np_001': '2',
#   'ta_min': '-2.1(11)',
#   'w_rec': '59',
#   'e': '88',
#   'np_300': '0',
#   'p_mes': '7.9',
#   'w_med': '2',
#   'nt_00': '2',
#   'ti_max': '11.0',
#   'tm_mes': '9.0',
#   'tm_max': '15.7',
#   'np_010': '1'},
#  {'fecha': '2022-3',
#   'indicativo': 'B013X',
#   'p_max': '44.1(23)',
#   'n_cub': '23',
#   'hr': '88',
#   'nw_55': '0',
#   'tm_min': '6.6',
#   'ta_max': '18.6(15)',
#   'ts_min': '12.7',
#   'nt_30': '0',
#   'n_des': '1',
#   'w_racha': '09/14.2(14)',
#   'np_100': '7',
#   'n_nub': '7',
#   'nw_91': '0',
#   'np_001': '20',
#   'ta_min': '-0.7(01)',
#   'w_rec': '129',
#   'e': '110',
#   'np_300': '2',
#   'p_mes': '184.1',
#   'w_med': '6',
#   'nt_00': '2',
#   'ti_max': '9.8',
#   'tm_mes': '10.2',
#   'tm_max': '13.7',
#   'np_010': '15'},
#  {'fecha': '2022-4',
#   'indicativo': 'B013X',
#   'p_max': '78.3(21)',
#   'n_cub': '10',
#   'hr': '67',
#   'nw_55': '1',
#   'tm_min': '6.6',
#   'ta_max': '23.5(30)',
#   'ts_min': '11.2',
#   'nt_30': '0',
#   'n_des': '6',
#   'w_racha': '12/15.6(21)',
#   'np_100': '3',
#   'n_nub': '11',
#   'nw_91': '0',
#   'np_001': '8',
#   'ta_min': '-0.4(03)',
#   'w_rec': '93',
#   'e': '102',
#   'np_300': '1',
#   'p_mes': '114.3',
#   'w_med': '4',
#   'nt_00': '1',
#   'ti_max': '7.8',
#   'tm_mes': '12.1',
#   'tm_max': '17.7',
#   'np_010': '6'},
#  {'fecha': '2022-5',
#   'indicativo': 'B013X',
#   'n_cub': '6',
#   'hr': '58',
#   'nw_55': '0',
#   'tm_min': '11.4',
#   'ta_max': '34.6(22)',
#   'ts_min': '18.1',
#   'nt_30': '4',
#   'n_des': '10',
#   'w_racha': '01/10.3(05)',
#   'n_nub': '15',
#   'nw_91': '0',
#   'ta_min': '7.1(10)',
#   'w_rec': '83',
#   'e': '136',
#   'w_med': '4',
#   'nt_00': '0',
#   'ti_max': '16.1',
#   'tm_mes': '18.3',
#   'tm_max': '25.1'},
#  {'fecha': '2022-6',
#   'indicativo': 'B013X',
#   'p_max': '2.1(22)',
#   'n_cub': '3',
#   'hr': '54',
#   'nw_55': '1',
#   'tm_min': '16.4',
#   'ta_max': '36.0(17)',
#   'ts_min': '25.1',
#   'nt_30': '16',
#   'n_des': '16',
#   'w_racha': '23/17.2(21)',
#   'np_100': '0',
#   'n_nub': '11',
#   'nw_91': '0',
#   'np_001': '3',
#   'ta_min': '11.8(29)',
#   'w_rec': '84',
#   'e': '178',
#   'np_300': '0',
#   'p_mes': '3.7',
#   'w_med': '4',
#   'nt_00': '0',
#   'ti_max': '26.0',
#   'tm_mes': '23.4',
#   'tm_max': '30.4',
#   'np_010': '2'},
#  {'fecha': '2022-7',
#   'indicativo': 'B013X',
#   'p_max': '0.3(05)',
#   'n_cub': '0',
#   'hr': '50',
#   'nw_55': '0',
#   'tm_min': '18.1',
#   'ta_max': '37.8(25)',
#   'ts_min': '22.5',
#   'nt_30': '25',
#   'n_des': '21',
#   'w_racha': '14/13.3(26)',
#   'np_100': '0',
#   'n_nub': '10',
#   'nw_91': '0',
#   'np_001': '1',
#   'ta_min': '14.7(08)',
#   'w_rec': '63',
#   'e': '182',
#   'np_300': '0',
#   'p_mes': '0.3',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '26.5',
#   'tm_mes': '25.6',
#   'tm_max': '33.1',
#   'np_010': '0'},
#  {'fecha': '2022-8',
#   'indicativo': 'B013X',
#   'p_max': '42.6(27)',
#   'n_cub': '1',
#   'hr': '60',
#   'nw_55': '0',
#   'tm_min': '18.4',
#   'ta_max': '38.9(13)',
#   'ts_min': '26.4',
#   'nt_30': '25',
#   'n_des': '16',
#   'w_racha': '12/14.4(18)',
#   'np_100': '2',
#   'n_nub': '14',
#   'nw_91': '0',
#   'np_001': '5',
#   'ta_min': '14.3(20)',
#   'w_rec': '54',
#   'e': '203',
#   'np_300': '1',
#   'p_mes': '66.2',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '25.9',
#   'tm_mes': '25.5',
#   'tm_max': '32.6',
#   'np_010': '3'},
#  {'fecha': '2022-9',
#   'indicativo': 'B013X',
#   'p_max': '22.0(24)',
#   'n_cub': '10',
#   'hr': '75',
#   'nw_55': '0',
#   'tm_min': '15.7',
#   'ta_max': '33.4(13)',
#   'ts_min': '21.8',
#   'nt_30': '13',
#   'n_des': '2',
#   'w_racha': '16/12.8(23)',
#   'np_100': '3',
#   'n_nub': '18',
#   'nw_91': '0',
#   'np_001': '7',
#   'ta_min': '10.0(20)',
#   'w_rec': '63',
#   'e': '202',
#   'np_300': '0',
#   'p_mes': '56.7',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '16.7',
#   'tm_mes': '21.6',
#   'tm_max': '27.4',
#   'np_010': '4'},
#  {'fecha': '2023-10',
#   'indicativo': 'B013X',
#   'p_max': '39.7(15)',
#   'n_cub': '3',
#   'hr': '77',
#   'nw_55': '4',
#   'tm_min': '12.5',
#   'ta_max': '30.6(01)',
#   'ts_min': '18.1',
#   'nt_30': '1',
#   'n_des': '13',
#   'w_racha': '22/22.5(26)',
#   'np_100': '5',
#   'n_nub': '15',
#   'nw_91': '0',
#   'np_001': '10',
#   'ta_min': '6.7(22)',
#   'w_rec': '74',
#   'e': '164',
#   'np_300': '1',
#   'p_mes': '99.5',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '18.8',
#   'tm_mes': '18.5',
#   'tm_max': '24.3',
#   'np_010': '7'},
#  {'fecha': '2023-1',
#   'indicativo': 'B013X',
#   'n_cub': '12',
#   'hr': '80',
#   'nw_55': '2',
#   'tm_min': '2.3',
#   'ta_max': '20.6(01)',
#   'ts_min': '10.5',
#   'nt_30': '0',
#   'n_des': '9',
#   'w_racha': '28/21.1(17)',
#   'n_nub': '10',
#   'nw_91': '0',
#   'ta_min': '-1.4(30)',
#   'w_rec': '77',
#   'e': '81',
#   'w_med': '3',
#   'nt_00': '6',
#   'ti_max': '4.5',
#   'tm_mes': '7.5',
#   'tm_max': '12.7'},
#  {'fecha': '2023-2',
#   'indicativo': 'B013X',
#   'p_max': '112.1(06)',
#   'n_cub': '9',
#   'hr': '81',
#   'nw_55': '0',
#   'tm_min': '1.0',
#   'ta_max': '21.0(20)',
#   'ts_min': '6.0',
#   'nt_30': '0',
#   'n_des': '10',
#   'w_racha': '08/12.5(06)',
#   'np_100': '4',
#   'n_nub': '9',
#   'nw_91': '0',
#   'np_001': '9',
#   'ta_min': '-2.4(11)',
#   'w_rec': '52',
#   'e': '82',
#   'np_300': '2',
#   'p_mes': '196.5',
#   'w_med': '2',
#   'nt_00': '11',
#   'ti_max': '7.8',
#   'tm_mes': '7.5',
#   'tm_max': '14.0',
#   'np_010': '5'},
#  {'fecha': '2023-3',
#   'indicativo': 'B013X',
#   'p_max': '1.8(03)',
#   'n_cub': '3',
#   'hr': '66',
#   'nw_55': '1',
#   'tm_min': '5.4',
#   'ta_max': '25.8(13)',
#   'ts_min': '16.3',
#   'nt_30': '0',
#   'n_des': '7',
#   'w_racha': '24/18.6(13)',
#   'np_100': '0',
#   'n_nub': '21',
#   'nw_91': '0',
#   'np_001': '1',
#   'ta_min': '-3.2(05)',
#   'w_rec': '91',
#   'e': '97',
#   'np_300': '0',
#   'p_mes': '1.8',
#   'w_med': '3',
#   'nt_00': '3',
#   'ti_max': '10.4',
#   'tm_mes': '12.5',
#   'tm_max': '19.6',
#   'np_010': '1'},
#  {'fecha': '2023-4',
#   'indicativo': 'B013X',
#   'p_max': '25.3(01)',
#   'n_cub': '4',
#   'hr': '64',
#   'nw_55': '0',
#   'tm_min': '7.1',
#   'ta_max': '32.9(29)',
#   'ts_min': '16.5',
#   'nt_30': '1',
#   'n_des': '7',
#   'w_racha': '16/13.9(15)',
#   'np_100': '1',
#   'n_nub': '19',
#   'nw_91': '0',
#   'np_001': '5',
#   'ta_min': '0.9(05)',
#   'w_rec': '80',
#   'e': '109',
#   'np_300': '0',
#   'p_mes': '31.3',
#   'w_med': '4',
#   'nt_00': '0',
#   'ti_max': '15.0',
#   'tm_mes': '14.1',
#   'tm_max': '21.0',
#   'np_010': '5'},
#  {'fecha': '2023-5',
#   'indicativo': 'B013X',
#   'p_max': '21.5(19)',
#   'n_cub': '9',
#   'hr': '68',
#   'nw_55': '0',
#   'tm_min': '10.7',
#   'ta_max': '26.7(05)',
#   'ts_min': '14.6',
#   'nt_30': '0',
#   'n_des': '4',
#   'w_racha': '08/11.4(20)',
#   'np_100': '2',
#   'n_nub': '18',
#   'nw_91': '0',
#   'np_001': '13',
#   'ta_min': '6.2(03)',
#   'w_rec': '73',
#   'e': '135',
#   'np_300': '0',
#   'p_mes': '58.5',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '14.1',
#   'tm_mes': '16.2',
#   'tm_max': '21.7',
#   'np_010': '7'},
#  {'fecha': '2023-6',
#   'indicativo': 'B013X',
#   'p_max': '41.8(01)',
#   'n_cub': '5',
#   'hr': '68',
#   'nw_55': '0',
#   'tm_min': '15.0',
#   'ta_max': '34.0(20)',
#   'ts_min': '22.5',
#   'nt_30': '10',
#   'n_des': '6',
#   'w_racha': '26/11.4(19)',
#   'np_100': '2',
#   'n_nub': '19',
#   'nw_91': '0',
#   'np_001': '12',
#   'ta_min': '10.5(05)',
#   'w_rec': '66',
#   'e': '192',
#   'np_300': '1',
#   'p_mes': '95.6',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '21.2',
#   'tm_mes': '21.4',
#   'tm_max': '27.7',
#   'np_010': '8'},
#  {'fecha': '2023-7',
#   'indicativo': 'B013X',
#   'p_max': '0.3(05)',
#   'n_cub': '1',
#   'hr': '64',
#   'nw_55': '0',
#   'tm_min': '19.8',
#   'ta_max': '41.4(18)',
#   'ts_min': '24.4',
#   'nt_30': '22',
#   'n_des': '9',
#   'w_racha': '15/10.3(24)',
#   'np_100': '0',
#   'n_nub': '21',
#   'nw_91': '0',
#   'np_001': '2',
#   'ta_min': '14.1(02)',
#   'w_rec': '85',
#   'e': '232',
#   'np_300': '0',
#   'p_mes': '0.4',
#   'w_med': '4',
#   'nt_00': '0',
#   'ti_max': '25.7',
#   'tm_mes': '26.2',
#   'tm_max': '32.5',
#   'np_010': '0'},
#  {'fecha': '2023-8',
#   'indicativo': 'B013X',
#   'p_max': '6.6(03)',
#   'n_cub': '1',
#   'hr': '60',
#   'nw_55': '0',
#   'tm_min': '18.6',
#   'ta_max': '37.8(23)',
#   'ts_min': '26.0',
#   'nt_30': '22',
#   'n_des': '19',
#   'w_racha': '17/11.4(28)',
#   'np_100': '0',
#   'n_nub': '11',
#   'nw_91': '0',
#   'np_001': '3',
#   'ta_min': '13.4(06)',
#   'w_rec': '85',
#   'e': '206',
#   'np_300': '0',
#   'p_mes': '13.3',
#   'w_med': '4',
#   'nt_00': '0',
#   'ti_max': '24.8',
#   'tm_mes': '25.5',
#   'tm_max': '32.3',
#   'np_010': '3'},
#  {'fecha': '2023-9',
#   'indicativo': 'B013X',
#   'p_max': '50.8(19)',
#   'n_cub': '8',
#   'hr': '77',
#   'nw_55': '1',
#   'tm_min': '15.0',
#   'ta_max': '33.8(17)',
#   'ts_min': '23.0',
#   'nt_30': '4',
#   'n_des': '12',
#   'w_racha': '13/15.3(03)',
#   'np_100': '2',
#   'n_nub': '10',
#   'nw_91': '0',
#   'np_001': '9',
#   'ta_min': '9.8(24)',
#   'w_rec': '84',
#   'e': '194',
#   'np_300': '1',
#   'p_mes': '87.9',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '22.3',
#   'tm_mes': '21.2',
#   'tm_max': '27.4',
#   'np_010': '6'},
#  {'fecha': '2023-11',
#   'indicativo': 'B013X',
#   'p_max': '9.6(02)',
#   'n_cub': '5',
#   'hr': '76',
#   'nw_55': '2',
#   'tm_min': '7.8',
#   'ta_max': '25.2(14)',
#   'ts_min': '15.1',
#   'nt_30': '0',
#   'n_des': '6',
#   'w_racha': '26/21.7(04)',
#   'np_100': '0',
#   'n_nub': '19',
#   'nw_91': '0',
#   'np_001': '4',
#   'ta_min': '3.0(08)',
#   'w_rec': '80',
#   'e': '114',
#   'np_300': '0',
#   'p_mes': '18.8',
#   'w_med': '4',
#   'nt_00': '0',
#   'ti_max': '11.9',
#   'tm_mes': '13.3',
#   'tm_max': '18.7',
#   'np_010': '3'},
#  {'fecha': '2023-12',
#   'indicativo': 'B013X',
#   'p_max': '6.8(07)',
#   'n_cub': '7',
#   'hr': '80',
#   'nw_55': '0',
#   'tm_min': '3.5',
#   'ta_max': '23.2(12)',
#   'ts_min': '10.4',
#   'nt_30': '0',
#   'n_des': '8',
#   'w_racha': '26/14.2(01)',
#   'np_100': '0',
#   'n_nub': '16',
#   'nw_91': '0',
#   'np_001': '6',
#   'ta_min': '-1.9(27)',
#   'w_rec': '53',
#   'e': '93',
#   'np_300': '0',
#   'p_mes': '10.8',
#   'w_med': '2',
#   'nt_00': '7',
#   'ti_max': '11.2',
#   'tm_mes': '9.4',
#   'tm_max': '15.3',
#   'np_010': '3'},
#  {'fecha': '2023-13',
#   'indicativo': 'B013X',
#   'n_cub': '67',
#   'hr': '72',
#   'nw_55': '10',
#   'tm_min': '9.9',
#   'ta_max': '41.4(18/jul)',
#   'ts_min': '26.0',
#   'nt_30': '60',
#   'n_des': '110',
#   'w_racha': '22/22.5(26/oct)',
#   'n_nub': '188',
#   'nw_91': '0',
#   'ta_min': '-3.2(05/mar)',
#   'w_rec': '75',
#   'e': '142',
#   'w_med': '3',
#   'nt_00': '27',
#   'ti_max': '4.5',
#   'tm_mes': '16.1',
#   'tm_max': '22.3'},
#  {'fecha': '2024-10', 'indicativo': 'B013X'},
#  {'fecha': '2024-11', 'indicativo': 'B013X'},
#  {'fecha': '2024-12', 'indicativo': 'B013X'},
#  {'fecha': '2024-13', 'indicativo': 'B013X'},
#  {'fecha': '2024-7', 'indicativo': 'B013X'},
#  {'fecha': '2024-8', 'indicativo': 'B013X'},
#  {'fecha': '2024-9', 'indicativo': 'B013X'},
#  {'fecha': '2024-1',
#   'indicativo': 'B013X',
#   'p_max': '67.1(11)',
#   'n_cub': '13',
#   'hr': '82',
#   'nw_55': '3',
#   'tm_min': '4.1',
#   'ta_max': '22.5(25)',
#   'ts_min': '15.0',
#   'nt_30': '0',
#   'n_des': '5',
#   'w_racha': '24/17.8(17)',
#   'np_100': '4',
#   'n_nub': '13',
#   'nw_91': '0',
#   'np_001': '8',
#   'ta_min': '-2.1(22)',
#   'w_rec': '70',
#   'e': '95',
#   'np_300': '3',
#   'p_mes': '184.2',
#   'w_med': '3',
#   'nt_00': '6',
#   'ti_max': '7.3',
#   'tm_mes': '9.7',
#   'tm_max': '15.3',
#   'np_010': '6'},
#  {'fecha': '2024-2',
#   'indicativo': 'B013X',
#   'n_cub': '8',
#   'hr': '75',
#   'nw_55': '2',
#   'tm_min': '4.0',
#   'ta_max': '21.3(22)',
#   'ts_min': '10.6',
#   'nt_30': '0',
#   'n_des': '5',
#   'w_racha': '24/18.3(22)',
#   'n_nub': '16',
#   'nw_91': '0',
#   'ta_min': '0.0(05)',
#   'w_rec': '76',
#   'e': '89',
#   'w_med': '3',
#   'nt_00': '1',
#   'ti_max': '9.1',
#   'tm_mes': '9.8',
#   'tm_max': '15.6'},
#  {'fecha': '2024-3',
#   'indicativo': 'B013X',
#   'p_max': '39.0(09)',
#   'n_cub': '8',
#   'hr': '69',
#   'nw_55': '5',
#   'tm_min': '6.1',
#   'ta_max': '23.7(17)',
#   'ts_min': '13.0',
#   'nt_30': '0',
#   'n_des': '8',
#   'w_racha': '21/20.6(28)',
#   'np_100': '4',
#   'n_nub': '15',
#   'nw_91': '0',
#   'np_001': '14',
#   'ta_min': '0.3(06)',
#   'w_rec': '109',
#   'e': '95',
#   'np_300': '2',
#   'p_mes': '127.9',
#   'w_med': '5',
#   'nt_00': '0',
#   'ti_max': '10.8',
#   'tm_mes': '11.5',
#   'tm_max': '16.9',
#   'np_010': '10'},
#  {'fecha': '2024-4',
#   'indicativo': 'B013X',
#   'n_cub': '5',
#   'hr': '65',
#   'nw_55': '0',
#   'tm_min': '7.7',
#   'ta_max': '30.4(08)',
#   'ts_min': '20.7',
#   'nt_30': '1',
#   'n_des': '5',
#   'w_racha': '20/13.3(08)',
#   'n_nub': '18',
#   'nw_91': '0',
#   'ta_min': '1.0(20)',
#   'w_rec': '86',
#   'e': '99',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '10.6',
#   'tm_mes': '13.2',
#   'tm_max': '18.7'},
#  {'fecha': '2024-5',
#   'indicativo': 'B013X',
#   'p_max': '9.1(20)',
#   'n_cub': '3',
#   'hr': '63',
#   'nw_55': '0',
#   'tm_min': '9.4',
#   'ta_max': '27.7(30)',
#   'ts_min': '15.0',
#   'nt_30': '0',
#   'n_des': '11',
#   'w_racha': '22/12.2(01)',
#   'np_100': '0',
#   'n_nub': '17',
#   'nw_91': '0',
#   'np_001': '8',
#   'ta_min': '3.0(03)',
#   'w_rec': '68',
#   'e': '130',
#   'np_300': '0',
#   'p_mes': '44.3',
#   'w_med': '3',
#   'nt_00': '0',
#   'ti_max': '15.9',
#   'tm_mes': '15.8',
#   'tm_max': '22.1',
#   'np_010': '6'},
#  {'fecha': '2024-6',
#   'indicativo': 'B013X',
#   'p_max': '17.5(11)',
#   'n_cub': '4',
#   'hr': '61',
#   'nw_55': '0',
#   'tm_min': '14.4',
#   'ta_max': '31.5(18)',
#   'ts_min': '21.4',
#   'nt_30': '3',
#   'n_des': '8',
#   'w_racha': '22/12.8(08)',
#   'np_100': '1',
#   'n_nub': '18',
#   'nw_91': '0',
#   'np_001': '4',
#   'ta_min': '9.2(01)',
#   'w_rec': '99',
#   'e': '159',
#   'np_300': '0',
#   'p_mes': '17.8',
#   'w_med': '5',
#   'nt_00': '0',
#   'ti_max': '18.7',
#   'tm_mes': '20.3',
#   'tm_max': '26.1',
#   'np_010': '1'}]

# %%
df_B013X_2021_2024 = pd.DataFrame(B013X_2021_2024)
display(df_B013X_2021_2024.head())
df_B013X_2021_2024.info()
# Out:
#      fecha indicativo         p_max n_cub  hr nw_55 tm_min        ta_max  \
# 0  2021-10      B013X      36.3(03)     8  85     1   10.0      25.4(03)
# 1  2021-11      B013X      99.1(09)    21  88     2    8.5      20.8(01)
# 2  2021-12      B013X      28.8(02)     8  81   NaN    4.4      20.7(31)
# 3  2021-13      B013X  99.1(09/nov)   NaN  74   NaN    9.7  40.5(13/ago)
# 4   2021-1      B013X      61.8(10)   NaN  80     4    3.0      23.0(28)
#
#   ts_min nt_30  ... w_rec    e np_300   p_mes w_med nt_00 ti_max tm_mes  \
# 0   16.1     0  ...    35  150      1   107.1     1     0   16.2   15.4
# 1   12.0     0  ...    56  116      6   502.5     2     0    9.4   10.8
# 2   13.3     0  ...   NaN   96      0    59.1   NaN     0    9.8    9.7
# 3   22.8    39  ...   NaN  136     13  1235.6   NaN    13    5.4   15.1
# 4    9.5     0  ...    63   84      2   196.5     3     9    5.4    7.6
#
#   tm_max np_010
# 0   20.8     10
# 1   13.2     19
# 2   15.0      4
# 3   20.3     84
# 4   12.1     12
#
# [5 rows x 27 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fecha       52 non-null     object
#  1   indicativo  52 non-null     object
#  2   p_max       39 non-null     object
#  3   n_cub       35 non-null     object
#  4   hr          45 non-null     object
#  5   nw_55       41 non-null     object
#  6   tm_min      45 non-null     object
#  7   ta_max      45 non-null     object
#  8   ts_min      45 non-null     object
#  9   nt_30       45 non-null     object
#  10  n_des       35 non-null     object
#  11  w_racha     41 non-null     object
#  12  np_100      39 non-null     object
#  13  n_nub       35 non-null     object
#  14  nw_91       41 non-null     object
#  15  np_001      39 non-null     object
#  16  ta_min      45 non-null     object
#  17  w_rec       41 non-null     object
#  18  e           45 non-null     object
#  19  np_300      39 non-null     object
#  20  p_mes       39 non-null     object
#  21  w_med       43 non-null     object
#  22  nt_00       45 non-null     object
#  23  ti_max      45 non-null     object
#  24  tm_mes      45 non-null     object
#  25  tm_max      45 non-null     object
#  26  np_010      39 non-null     object
# dtypes: object(27)
# memory usage: 11.1+ KB

# %%
df_B013X_2021_2024.to_csv('./data/raw/clima_mes_B013X_2021_2024.csv',
                          index = False)

# %% [markdown]
# ## 5 - Climatologias normales 1991-2020 <a id="5-clima-normal-1999-2020"></a>
#
# Valores climatológicos normales (periodo 1991-2020) para la estación pasada por parámetro. Periodicidad: 1 vez al día.

# %%
# Climatologías normales sw 1991 a 2020
end_point = '/api/valores/climatologicos/normales/estacion/{idema}'

idema = 'B013X' # idema de Baleares

end_point = end_point.format(idema = idema)

url = base_url + end_point

response = requests.request("GET", url, headers=headers, params=querystring)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/e9400f61', 'metadatos': 'https://opendata.aemet.es/opendata/sh/98527307'}

# %%
# Acceso a la información de los METADATOS, que describe la información de las columnas
metadatos = requests.get(response.json()['metadatos']).json()
metadatos
# Out:
# {'unidad_generadora': 'Servicio del Banco Nacional de Datos Climatológicos',
#  'periodicidad': '1 vez al día',
#  'descripcion': 'Valores normales para el periodo de referencia 1991-2020',
#  'formato': 'application/json',
#  'copyright': '© AEMET. Autorizado el uso de la información y su reproducción citando a AEMET como autora de la misma.',
#  'notaLegal': 'https://www.aemet.es/es/nota_legal',
#  'campos': [{'id': 'mes',
#    'descripcion': 'mes al que se refieren los datos o 13 de la indicar valor anual',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'indicativo',
#    'descripcion': 'indicativo climatológico',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'e_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'e_max',
#    'descripcion': 'valor máximo de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'unidad': '(décimas hPa)',
#    'requerido': False},
#   {'id': 'e_md',
#    'descripcion': 'media aritmética de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'unidad': '(décimas hPa)',
#    'requerido': False},
#   {'id': 'e_min',
#    'descripcion': 'valor mínimo de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'unidad': '(décimas hPa)',
#    'requerido': False},
#   {'id': 'e_mn',
#    'descripcion': 'mediana de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'unidad': '(décimas hPa)',
#    'requerido': False},
#   {'id': 'e_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'e_q1',
#    'descripcion': 'primer quintil de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'unidad': '(décimas hPa)',
#    'requerido': False},
#   {'id': 'e_q2',
#    'descripcion': 'segundo quintil de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'unidad': '(décimas hPa)',
#    'requerido': False},
#   {'id': 'e_q3',
#    'descripcion': 'tercer quintil de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'unidad': '(décimas hPa)',
#    'requerido': False},
#   {'id': 'e_q4',
#    'descripcion': 'cuarto quintil de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'unidad': '(décimas hPa)',
#    'requerido': False},
#   {'id': 'e_s',
#    'descripcion': 'desviación típica de la tensión de vapor media',
#    'tipo_datos': 'string',
#    'unidad': '(décimas hPa)',
#    'requerido': False},
#   {'id': 'evap_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la evaporación total mensual/anual',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'evap_max',
#    'descripcion': 'valor máximo de la evaporación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(décimas mm)',
#    'requerido': False},
#   {'id': 'evap_md',
#    'descripcion': 'media aritmética de la evaporación total mensual/anual (décimas de mm)',
#    'tipo_datos': 'string',
#    'unidad': '(décimas mm)',
#    'requerido': False},
#   {'id': 'evap_min',
#    'descripcion': 'valor mínimo de la evaporación total mensual/anual (décimas de mm)',
#    'tipo_datos': 'string',
#    'unidad': '(décimas mm)',
#    'requerido': False},
#   {'id': 'evap_mn',
#    'descripcion': 'mediana de la evaporación total mensual/anual (décimas de mm)',
#    'tipo_datos': 'string',
#    'unidad': '(décimas mm)',
#    'requerido': False},
#   {'id': 'evap_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la evaporación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'evap_q1',
#    'descripcion': 'primer quintil de la evaporación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(décimas mm)',
#    'requerido': False},
#   {'id': 'evap_q2',
#    'descripcion': 'segundo quintil de la evaporación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(décimas mm)',
#    'requerido': False},
#   {'id': 'evap_q3',
#    'descripcion': 'tercer quintil de la evaporación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(décimas mm)',
#    'requerido': False},
#   {'id': 'evap_q4',
#    'descripcion': 'cuarto quintil de la evaporación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(décimas mm)',
#    'requerido': False},
#   {'id': 'evap_s',
#    'descripcion': 'desviación típica de la evaporación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(décimas mm)',
#    'requerido': False},
#   {'id': 'glo_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'glo_max',
#    'descripcion': 'valor máximo de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(decenas de kJ/m2)',
#    'requerido': False},
#   {'id': 'glo_md',
#    'descripcion': 'media aritmética de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(decenas de kJ/m2)',
#    'requerido': False},
#   {'id': 'glo_min',
#    'descripcion': 'valor mínimo de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(decenas de kJ/m2)',
#    'requerido': False},
#   {'id': 'glo_mn',
#    'descripcion': 'mediana de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(decenas de kJ/m2)',
#    'requerido': False},
#   {'id': 'glo_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'glo_q1',
#    'descripcion': 'primer quintil de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(decenas de kJ/m2)',
#    'requerido': False},
#   {'id': 'glo_q2',
#    'descripcion': 'segundo quintil de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(decenas de kJ/m2)',
#    'requerido': False},
#   {'id': 'glo_q3',
#    'descripcion': 'tercer quintil de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(decenas de kJ/m2)',
#    'requerido': False},
#   {'id': 'glo_q4',
#    'descripcion': 'cuarto quintil de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(decenas de kJ/m2)',
#    'requerido': False},
#   {'id': 'glo_s',
#    'descripcion': 'desviación típica de la radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(decenas de kJ/m2)',
#    'requerido': False},
#   {'id': 'hr_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'hr_max',
#    'descripcion': 'valor máximo de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(%)',
#    'requerido': False},
#   {'id': 'hr_md',
#    'descripcion': 'media aritmética de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(%)',
#    'requerido': False},
#   {'id': 'hr_min',
#    'descripcion': 'valor mínimo de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(%)',
#    'requerido': False},
#   {'id': 'hr_mn',
#    'descripcion': 'mediana de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(%)',
#    'requerido': False},
#   {'id': 'hr_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'hr_q1',
#    'descripcion': 'primer quintil de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(%)',
#    'requerido': False},
#   {'id': 'hr_q2',
#    'descripcion': 'segundo quintil de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(%)',
#    'requerido': False},
#   {'id': 'hr_q3',
#    'descripcion': 'tercer quintil de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(%)',
#    'requerido': False},
#   {'id': 'hr_q4',
#    'descripcion': 'cuarto quintil de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(%)',
#    'requerido': False},
#   {'id': 'hr_s',
#    'descripcion': 'desviación típica de la humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '(%)',
#    'requerido': False},
#   {'id': 'inso_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'inso_max',
#    'descripcion': 'valor máximo de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'unidad': 'horas',
#    'requerido': False},
#   {'id': 'inso_md',
#    'descripcion': 'media aritmética de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'unidad': 'horas',
#    'requerido': False},
#   {'id': 'inso_min',
#    'descripcion': 'valor mínimo de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'unidad': 'horas',
#    'requerido': False},
#   {'id': 'inso_mn',
#    'descripcion': 'mediana de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'unidad': 'horas',
#    'requerido': False},
#   {'id': 'inso_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'inso_q1',
#    'descripcion': 'primer quintil de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'unidad': 'horas',
#    'requerido': False},
#   {'id': 'inso_q2',
#    'descripcion': 'segundo quintil de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'unidad': 'horas',
#    'requerido': False},
#   {'id': 'inso_q3',
#    'descripcion': 'tercer quintil de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'unidad': 'horas',
#    'requerido': False},
#   {'id': 'inso_q4',
#    'descripcion': 'cuarto quintil de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'unidad': 'horas',
#    'requerido': False},
#   {'id': 'inso_s',
#    'descripcion': 'desviación típica de la media mensual/anual de la insolación diaria ',
#    'tipo_datos': 'string',
#    'unidad': '(horas)',
#    'requerido': False},
#   {'id': 'n_cub_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'n_cub_max',
#    'descripcion': 'valor máximo del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub_md',
#    'descripcion': 'media aritmética del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub_min',
#    'descripcion': 'valor mínimo del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub_mn',
#    'descripcion': 'mediana del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub_q1',
#    'descripcion': 'primer quintil del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub_q2',
#    'descripcion': 'segundo quintil del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub_q3',
#    'descripcion': 'tercer quintil del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub_q4',
#    'descripcion': 'cuarto quintil del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub_s',
#    'descripcion': 'desviación típica del nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': '(Nº de días)',
#    'requerido': False},
#   {'id': 'n_fog_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'n_fog_max',
#    'descripcion': 'valor máximo del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog_md',
#    'descripcion': 'media aritmética del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog_min',
#    'descripcion': 'valor mínimo del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog_mn',
#    'descripcion': 'mediana del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog_q1',
#    'descripcion': 'primer quintil del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog_q2',
#    'descripcion': 'segundo quintil del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog_q3',
#    'descripcion': 'tercer quintil del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog_q4',
#    'descripcion': 'cuarto quintil del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog_s',
#    'descripcion': 'desviación típica del nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'n_gra_max',
#    'descripcion': 'valor máximo del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra_md',
#    'descripcion': 'media aritmética del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra_min',
#    'descripcion': 'valor mínimo del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra_mn',
#    'descripcion': 'mediana del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra_q1',
#    'descripcion': 'primer quintil del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra_q2',
#    'descripcion': 'segundo quintil del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra_q3',
#    'descripcion': 'tercer quintil del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra_q4',
#    'descripcion': 'cuarto quintil del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra_s',
#    'descripcion': 'desviación típica del nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_llu_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'n_llu_max',
#    'descripcion': 'valor máximo del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_llu_md',
#    'descripcion': 'media aritmética del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_llu_min',
#    'descripcion': 'valor mínimo del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_llu_mn',
#    'descripcion': 'mediana del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_llu_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_llu_q1',
#    'descripcion': 'primer quintil del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_llu_q2',
#    'descripcion': 'segundo quintil del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_llu_q3',
#    'descripcion': 'tercer quintil del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_llu_q4',
#    'descripcion': 'cuarto quintil del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_llu_s',
#    'descripcion': 'desviación típica del nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'n_nie_max',
#    'descripcion': 'valor máximo del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie_md',
#    'descripcion': 'media aritmética del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie_min',
#    'descripcion': 'valor mínimo del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie_mn',
#    'descripcion': 'mediana del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie_q1',
#    'descripcion': 'primer quintil del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie_q2',
#    'descripcion': 'segundo quintil del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie_q3',
#    'descripcion': 'tercer quintil del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie_q4',
#    'descripcion': 'cuarto quintil del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie_s',
#    'descripcion': 'desviación típica del nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'n_nub_max',
#    'descripcion': 'valor máximo del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub_md',
#    'descripcion': 'media aritmética del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub_min',
#    'descripcion': 'valor mínimo del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub_mn',
#    'descripcion': 'mediana del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub_q1',
#    'descripcion': 'primer quintil del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub_q2',
#    'descripcion': 'segundo quintil del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub_q3',
#    'descripcion': 'tercer quintil del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub_q4',
#    'descripcion': 'cuarto quintil del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub_s',
#    'descripcion': 'desviación típica del nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_001_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'np_001_max',
#    'descripcion': 'valor máximo del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_001_md',
#    'descripcion': 'media aritmética del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_001_min',
#    'descripcion': 'valor mínimo del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_001_mn',
#    'descripcion': 'mediana del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_001_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_001_q1',
#    'descripcion': 'primer quintil del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_001_q2',
#    'descripcion': 'segundo quintil del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_001_q3',
#    'descripcion': 'tercer quintil del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_001_q4',
#    'descripcion': 'cuarto quintil del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_001_s',
#    'descripcion': 'desviación típica del nº de días de precipitación apreciable (>=0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'np_010_max',
#    'descripcion': 'valor máximo del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010_md',
#    'descripcion': 'media aritmética del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010_min',
#    'descripcion': 'valor mínimo del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010_mn',
#    'descripcion': 'mediana del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010_q1',
#    'descripcion': 'primer quintil del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010_q2',
#    'descripcion': 'segundo quintil del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010_q3',
#    'descripcion': 'tercer quintil del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010_q4',
#    'descripcion': 'cuarto quintil del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010_s',
#    'descripcion': 'desviación típica del nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'np_100_max',
#    'descripcion': 'valor máximo del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100_md',
#    'descripcion': 'media aritmética del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100_min',
#    'descripcion': 'valor mínimo del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100_mn',
#    'descripcion': 'mediana del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100_q1',
#    'descripcion': 'primer quintil del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100_q2',
#    'descripcion': 'segundo quintil del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100_q3',
#    'descripcion': 'tercer quintil del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100_q4',
#    'descripcion': 'cuarto quintil del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100_s',
#    'descripcion': 'desviación típica del nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'np_300_max',
#    'descripcion': 'valor máximo del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300_md',
#    'descripcion': 'media aritmética del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300_min',
#    'descripcion': 'valor mínimo del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300_mn',
#    'descripcion': 'mediana del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300_q1',
#    'descripcion': 'primer quintil del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300_q2',
#    'descripcion': 'segundo quintil del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300_q3',
#    'descripcion': 'tercer quintil del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300_q4',
#    'descripcion': 'cuarto quintil del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300_s',
#    'descripcion': 'desviación típica del nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'nt_00_max',
#    'descripcion': 'valor máximo del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00_md',
#    'descripcion': 'media aritmética del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00_min',
#    'descripcion': 'valor mínimo del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00_mn',
#    'descripcion': 'mediana del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00_q1',
#    'descripcion': 'primer quintil del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00_q2',
#    'descripcion': 'segundo quintil del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00_q3',
#    'descripcion': 'tercer quintil del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00_q4',
#    'descripcion': 'cuarto quintil del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00_s',
#    'descripcion': 'desviación típica del nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_30_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'nt_30_max',
#    'descripcion': 'valor máximo del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_30_md',
#    'descripcion': 'media aritmética del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_30_min',
#    'descripcion': 'valor mínimo del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_30_mn',
#    'descripcion': 'mediana del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_30_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_30_q1',
#    'descripcion': 'primer quintil del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_30_q2',
#    'descripcion': 'segundo quintil del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_30_q3',
#    'descripcion': 'tercer quintil del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_30_q4',
#    'descripcion': 'cuarto quintil del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_30_s',
#    'descripcion': 'desviación típica del nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'n_tor_max',
#    'descripcion': 'valor máximo del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor_md',
#    'descripcion': 'media aritmética del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor_min',
#    'descripcion': 'valor mínimo del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor_mn',
#    'descripcion': 'mediana del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor_q1',
#    'descripcion': 'primer quintil del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor_q2',
#    'descripcion': 'segundo quintil del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor_q3',
#    'descripcion': 'tercer quintil del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor_q4',
#    'descripcion': 'cuarto quintil del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor_s',
#    'descripcion': 'desviación típica del nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0050_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'nv_0050_max',
#    'descripcion': 'valor máximo del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0050_md',
#    'descripcion': 'media aritmética del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0050_min',
#    'descripcion': 'valor mínimo del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0050_mn',
#    'descripcion': 'mediana del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0050_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0050_q1',
#    'descripcion': 'primer quintil del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0050_q2',
#    'descripcion': 'segundo quintil del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0050_q3',
#    'descripcion': 'tercer quintil del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0050_q4',
#    'descripcion': 'cuarto quintil del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0050_s',
#    'descripcion': 'desviación típica del nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'nv_0100_max',
#    'descripcion': 'valor máximo del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100_md',
#    'descripcion': 'media aritmética del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100_min',
#    'descripcion': 'valor mínimo del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100_mn',
#    'descripcion': 'mediana del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100_q1',
#    'descripcion': 'primer quintil del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100_q2',
#    'descripcion': 'segundo quintil del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100_q3',
#    'descripcion': 'tercer quintil del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100_q4',
#    'descripcion': 'cuarto quintil del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100_s',
#    'descripcion': 'desviación típica del nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'nv_1000_max',
#    'descripcion': 'valor máximo del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000_md',
#    'descripcion': 'media aritmética del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000_min',
#    'descripcion': 'valor mínimo del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000_mn',
#    'descripcion': 'mediana del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000_q1',
#    'descripcion': 'primer quintil del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000_q2',
#    'descripcion': 'segundo quintil del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000_q3',
#    'descripcion': 'tercer quintil del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000_q4',
#    'descripcion': 'cuarto quintil del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': '(%)',
#    'requerido': False},
#   {'id': 'nv_1000_s',
#    'descripcion': 'desviación típica del nº de días con visibilidad  superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_55_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'nw_55_max',
#    'descripcion': 'valor máximo del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_55_md',
#    'descripcion': 'media aritmética del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_55_min',
#    'descripcion': 'valor mínimo del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_55_mn',
#    'descripcion': 'mediana del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_55_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_55_q1',
#    'descripcion': 'primer quintil del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_55_q2',
#    'descripcion': 'segundo quintil del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_55_q3',
#    'descripcion': 'tercer quintil del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_55_q4',
#    'descripcion': 'cuarto quintil del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_55_s',
#    'descripcion': 'desviación típica del nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_91_cv',
#    'descripcion': 'coeficiente de variación de Pearson del nº de días de velocidad del viento mayor o igual a 91 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'nw_91_max',
#    'descripcion': 'valor máximo del nº de días de velocidad del viento mayor o igual a 91 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_91_md',
#    'descripcion': 'media aritmética del nº de días de velocidad del viento mayor o igual a 91 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_91_min',
#    'descripcion': 'valor mínimo del nº de días de velocidad del viento mayor o igual a 91 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_91_mn',
#    'descripcion': 'mediana del nº de días de velocidad del viento mayor o igual a 91 km/h en el mes/año',
#    'tipo_datos': 'string',
# ...
#   {'id': 'tm_mes_mn',
#    'descripcion': 'mediana de la temperatura media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_mes_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la temperatura media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'tm_mes_q1',
#    'descripcion': 'primer quintil de la temperatura media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_mes_q2',
#    'descripcion': 'segundo quintil de la temperatura media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_mes_q3',
#    'descripcion': 'tercer quintil de la temperatura media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_mes_q4',
#    'descripcion': 'cuarto quintil de la temperatura media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_mes_s',
#    'descripcion': 'desviación típica de la temperatura media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'tm_min_max',
#    'descripcion': 'valor máximo de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min_md',
#    'descripcion': 'media aritmética de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min_min',
#    'descripcion': 'valor mínimo de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min_mn',
#    'descripcion': 'mediana de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'tm_min_q1',
#    'descripcion': 'primer quintil de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min_q2',
#    'descripcion': 'segundo quintil de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min_q3',
#    'descripcion': 'tercer quintil de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min_q4',
#    'descripcion': 'cuarto quintil de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min_s',
#    'descripcion': 'desviación típica de la temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_10_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'ts_10_max',
#    'descripcion': 'valor máximo de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_10_md',
#    'descripcion': 'media aritmética de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_10_min',
#    'descripcion': 'valor mínimo de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_10_mn',
#    'descripcion': 'mediana de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_10_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'ts_10_q1',
#    'descripcion': 'primer quintil de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_10_q2',
#    'descripcion': 'segundo quintil de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_10_q3',
#    'descripcion': 'tercer quintil de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_10_q4',
#    'descripcion': 'cuarto quintil de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_10_s',
#    'descripcion': 'desviación típica de la temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'ts_20_max',
#    'descripcion': 'valor máximo de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20_md',
#    'descripcion': 'media aritmética de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20_min',
#    'descripcion': 'valor mínimo de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20_mn',
#    'descripcion': 'mediana de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'ts_20_q1',
#    'descripcion': 'primer quintil de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20_q2',
#    'descripcion': 'segundo quintil de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20_q3',
#    'descripcion': 'tercer quintil de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20_q4',
#    'descripcion': 'cuarto quintil de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20_s',
#    'descripcion': 'desviación típica de la temperatura media mensual/anual a 20 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'ts_50_max',
#    'descripcion': 'valor máximo de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50_md',
#    'descripcion': 'media aritmética de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50_min',
#    'descripcion': 'valor mínimo de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50_mn',
#    'descripcion': 'mediana de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'ts_50_q1',
#    'descripcion': 'primer quintil de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50_q2',
#    'descripcion': 'segundo quintil de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50_q3',
#    'descripcion': 'tercer quintil de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50_q4',
#    'descripcion': 'cuarto quintil de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50_s',
#    'descripcion': 'desviación típica de la temperatura media mensual/anual a 50 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'ts_min_max',
#    'descripcion': 'valor máximo de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min_md',
#    'descripcion': 'media aritmética de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min_min',
#    'descripcion': 'valor mínimo de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min_mn',
#    'descripcion': 'mediana de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'ts_min_q1',
#    'descripcion': 'primer quintil de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min_q2',
#    'descripcion': 'segundo quintil de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min_q3',
#    'descripcion': 'tercer quintil de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min_q4',
#    'descripcion': 'cuarto quintil de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min_s',
#    'descripcion': 'desviación típica de la temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'w_med_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'w_med_max',
#    'descripcion': 'valor máximo de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'w_med_md',
#    'descripcion': 'media aritmética de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'w_med_min',
#    'descripcion': 'valor mínimo de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'w_med_mn',
#    'descripcion': 'mediana de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'w_med_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'w_med_q1',
#    'descripcion': 'primer quintil de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'w_med_q2',
#    'descripcion': 'segundo quintil de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'w_med_q3',
#    'descripcion': 'tercer quintil de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'w_med_q4',
#    'descripcion': 'cuarto quintil de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'w_med_s',
#    'descripcion': 'desviación típica de la velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'w_racha_cv',
#    'descripcion': 'coeficiente de variación de Pearson de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'requerido': False},
#   {'id': 'w_racha_max',
#    'descripcion': 'valor máximo de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'm/sg',
#    'requerido': False},
#   {'id': 'w_racha_md',
#    'descripcion': 'media aritmética de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'm/sg',
#    'requerido': False},
#   {'id': 'w_racha_min',
#    'descripcion': 'valor mínimo de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'm/sg',
#    'requerido': False},
#   {'id': 'w_racha_mn',
#    'descripcion': 'mediana de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'm/sg',
#    'requerido': False},
#   {'id': 'w_racha_n',
#    'descripcion': 'frecuencia absoluta (nº de años con dato disponible) de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'w_racha_q1',
#    'descripcion': 'primer quintil de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'm/sg',
#    'requerido': False},
#   {'id': 'w_racha_q2',
#    'descripcion': 'segundo quintil de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'm/sg',
#    'requerido': False},
#   {'id': 'w_racha_q3',
#    'descripcion': 'tercer quintil de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'm/sg',
#    'requerido': False},
#   {'id': 'w_racha_q4',
#    'descripcion': 'cuarto quintil de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'm/sg',
#    'requerido': False},
#   {'id': 'w_racha_s',
#    'descripcion': 'desviación típica de la velocidad de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False}]}

# %%
# La información de las columnas está en la columna "campos"
df_metadatos = pd.DataFrame(metadatos['campos'])
df_metadatos.head(10)
# Out:
#            id                                        descripcion tipo_datos  \
# 0         mes  mes al que se refieren los datos o 13 de la in...     string
# 1  indicativo                           indicativo climatológico     string
# 2        e_cv  coeficiente de variación de Pearson de la tens...     string
# 3       e_max          valor máximo de la tensión de vapor media     string
# 4        e_md      media aritmética de la tensión de vapor media     string
# 5       e_min          valor mínimo de la tensión de vapor media     string
# 6        e_mn               mediana de la tensión de vapor media     string
# 7         e_n  frecuencia absoluta (nº de años con dato dispo...     string
# 8        e_q1        primer quintil de la tensión de vapor media     string
# 9        e_q2       segundo quintil de la tensión de vapor media     string
#
#    requerido         unidad
# 0       True            NaN
# 1       True            NaN
# 2      False            NaN
# 3      False  (décimas hPa)
# 4      False  (décimas hPa)
# 5      False  (décimas hPa)
# 6      False  (décimas hPa)
# 7      False     Nº de días
# 8      False  (décimas hPa)
# 9      False  (décimas hPa)

# %%
# Guardar la información de los metadatos de la climatología normal (1991-2020)
df_metadatos.to_csv('./data/raw/metadatos_clima_normales_1991_2020.csv',
                    index = False)

# %%
# Acceso a los DATOS
B013X_clima_normal_1991_2020 = requests.get(response.json()['datos']).json()
B013X_clima_normal_1991_2020
# Out:
# [{'indicativo': 'B013X',
#   'w_racha_max': '23.1',
#   'np_010_n': '24',
#   'np_010_s': '3.44',
#   'q_max_s': '',
#   'n_tor_n': '0',
#   'n_tor_s': '',
#   'q_max_n': '0',
#   'tm_min_q4': '3.3',
#   'tm_min_q1': '1.0',
#   'tm_min_q3': '2.4',
#   'tm_min_q2': '1.8',
#   'q_mar_n': '0',
#   'n_des_min': '',
#   'q_mar_s': '',
#   'q_med_n': '0',
#   'ts_20_q1': '',
#   'ts_20_q2': '',
#   'e_cv': '0.09',
#   'ts_20_q4': '',
#   'e_min': '67.0',
#   'np_300_q4': '2.0',
#   'np_300_q1': '0.0',
#   'np_300_q3': '1.0',
#   'hr_max': '84.0',
#   'np_300_cv': '1.06',
#   'n_nub_max': '',
#   'tm_min_cv': '0.63',
#   'n_des_mn': '',
#   'n_des_md': '',
#   'ts_20_s': '',
#   'q_med_mn': '',
#   'evap_cv': '',
#   'q_med_md': '',
#   'nt_30_cv': '-',
#   'mes': '01',
#   'ts_20_cv': '',
#   'inso_max': '',
#   'ts_20_max': '',
#   'np_001_max': '22.0',
#   'n_llu_md': '',
#   'nv_1000_s': '',
#   'ta_min_mn': '-2.5',
#   'tm_mes_max': '9.5',
#   'ta_max_mn': '18.5',
#   'nv_1000_n': '0',
#   'ta_max_md': '18.6',
#   'nw_91_min': '0.0',
#   'ta_max_n': '24',
#   'ta_max_s': '2.15',
#   'ts_10_md': '',
#   'nw_55_mn': '1.5',
#   'ta_min_s': '1.33',
#   'nw_55_md': '1.7',
#   'np_300_mn': '1.0',
#   'evap_q4': '',
#   'evap_q1': '',
#   'np_300_md': '1.3',
#   'evap_q3': '',
#   'evap_q2': '',
#   'p_mes_min': '22.2',
#   'ts_min_min': '6.1',
#   'n_des_s': '',
#   'nv_0100_mn': '',
#   'p_mes_md': '131.8',
#   'n_tor_cv': '',
#   'nv_0100_md': '',
#   'q_min_max': '',
#   'n_des_n': '0',
#   'p_sol_s': '',
#   'ts_20_n': '0',
#   'ts_10_cv': '',
#   'nw_91_s': '0.0',
#   'nw_91_n': '20',
#   'nt_00_min': '3.0',
#   'p_sol_n': '0',
#   'n_nie_mn': '',
#   'n_nub_n': '0',
#   'n_nie_md': '',
#   'tm_mes_md': '7.2',
#   'p_sol_cv': '',
#   'n_nub_s': '',
#   'w_racha_min': '9.2',
#   'np_300_max': '6.0',
#   'nv_0050_md': '',
#   'ta_min_min': '-6.3',
#   'glo_mn': '',
#   'inso_s': '',
#   'glo_md': '',
#   'n_nie_q1': '',
#   'w_med_q4': '4.0',
#   'n_tor_max': '',
#   'w_med_q2': '3.0',
#   'w_med_q3': '3.0',
#   'n_gra_md': '',
#   'inso_q4': '',
#   'q_max_min': '',
#   'ts_10_max': '',
#   'nt_30_min': '0.0',
#   'n_nub_cv': '',
#   'p_mes_n': '24',
#   'p_mes_q1': '75.1',
#   'p_mes_q2': '102.3',
#   'p_mes_q3': '135.9',
#   'p_mes_q4': '177.2',
#   'hr_cv': '0.05',
#   'n_tor_md': '',
#   'p_mes_s': '88.95',
#   'nw_91_cv': '-',
#   'n_tor_mn': '',
#   'nv_1000_max': '',
#   'n_gra_cv': '',
#   'w_racha_n': '20',
#   'w_med_min': '2.0',
#   'w_racha_s': '3.32',
#   'np_100_max': '7.0',
#   'e_s': '7.49',
#   'w_med_s': '1.18',
#   'p_sol_md': '',
#   'n_cub_q4': '',
#   'n_cub_q3': '',
#   'n_cub_q2': '',
#   'n_cub_q1': '',
#   'nw_55_max': '5.0',
#   'p_sol_mn': '',
#   'n_cub_s': '',
#   'hr_mn': '77.0',
#   'q_med_max': '',
#   'hr_md': '77.0',
#   'np_010_md': '8.3',
#   'n_cub_n': '0',
#   'np_010_mn': '8.0',
#   'nw_91_q4': '0.0',
#   'p_max_n': '24',
#   'nw_91_q2': '0.0',
#   'nw_91_q3': '0.0',
#   'nw_91_q1': '0.0',
#   'n_gra_q4': '',
#   'n_gra_q1': '',
#   'n_gra_q3': '',
#   'nw_55_s': '1.56',
#   'nw_55_n': '20',
#   'w_med_mn': '3.0',
#   'n_nub_min': '',
#   'p_max_s': '33.88',
#   'ts_20_min': '',
#   'inso_min': '',
#   'n_gra_max': '',
#   'p_sol_q1': '',
#   'p_sol_q3': '',
#   'p_sol_q2': '',
#   'p_sol_q4': '',
#   'n_fog_q1': '',
#   'ta_min_md': '-2.8',
#   'n_fog_q3': '',
#   'n_fog_q2': '',
#   'n_fog_q4': '',
#   'w_med_cv': '0.37',
#   'p_max_max': '117.5',
#   'e_n': '23',
#   'q_min_md': '',
#   'n_fog_cv': '',
#   'p_mes_cv': '0.68',
#   'nv_0100_max': '',
#   'np_300_q2': '1.0',
#   'q_min_mn': '',
#   'ti_max_min': '1.2',
#   'np_100_cv': '0.56',
#   'hr_q3': '78.0',
#   'hr_q2': '76.0',
#   'hr_q1': '74.0',
#   'nv_0050_s': '',
#   'hr_q4': '80.0',
#   'evap_s': '',
#   'w_med_q1': '2.0',
#   'evap_n': '0',
#   'nv_0050_n': '0',
#   'nv_0050_q2': '',
#   'nv_0050_q3': '',
#   'q_max_md': '',
#   'nv_0050_q1': '',
#   'nv_0050_q4': '',
#   'q_max_mn': '',
#   'n_llu_min': '',
#   'ts_min_max': '13.1',
#   'evap_max': '',
#   'ta_min_q1': '-4.0',
#   'ta_min_q3': '-2.1',
#   'n_cub_cv': '',
#   'ta_min_q4': '-1.7',
#   'tm_mes_n': '24',
#   'tm_max_s': '1.52',
#   'nt_30_md': '0.0',
#   'tm_max_n': '24',
#   'tm_mes_s': '1.29',
#   'nt_30_mn': '0.0',
#   'ts_50_q4': '',
#   'ts_50_q3': '',
#   'ts_50_q2': '',
#   'ts_50_q1': '',
#   'q_mar_mn': '',
#   'np_100_q4': '4.4',
#   'np_100_q3': '4.0',
#   'np_100_q2': '3.0',
#   'np_100_q1': '2.0',
#   'n_des_cv': '',
#   'q_mar_md': '',
#   'tm_mes_q4': '8.4',
#   'tm_mes_q2': '6.5',
#   'tm_mes_q3': '7.4',
#   'np_300_min': '0.0',
#   'p_sol_min': '',
#   'n_cub_min': '',
#   'n_gra_s': '',
#   'w_racha_mn': '15.8',
#   'p_max_cv': '0.65',
#   'n_des_q4': '',
#   'n_des_q1': '',
#   'n_des_q3': '',
#   'n_des_q2': '',
#   'ti_max_max': '9.1',
#   'n_gra_n': '0',
#   'tm_min_n': '24',
#   'nt_30_max': '0.0',
#   'q_max_max': '',
#   'tm_min_s': '1.43',
#   'nt_00_n': '24',
#   'nv_0050_min': '',
#   'ts_10_s': '',
#   'n_nub_q4': '',
#   'n_nub_q1': '',
#   'n_nub_q2': '',
#   'n_nub_q3': '',
#   'ts_50_s': '',
#   'ts_10_n': '0',
#   'nt_00_s': '4.31',
#   'ts_10_min': '',
#   'tm_mes_mn': '7.1',
#   'np_100_min': '0.0',
#   'nv_1000_min': '',
#   'nt_30_s': '0.0',
#   'nt_00_q3': '9.0',
#   'nt_00_q2': '7.2',
#   'nt_00_q1': '6.6',
#   'n_tor_min': '',
#   'nt_00_q4': '11.4',
#   'ts_20_q3': '',
#   'nt_00_max': '21.0',
#   'nw_55_min': '0.0',
#   'n_llu_mn': '',
#   'ts_50_mn': '',
#   'glo_min': '',
#   'ts_50_md': '',
#   'q_med_min': '',
#   'nv_0050_cv': '',
#   'inso_q2': '',
#   'inso_q3': '',
#   'inso_q1': '',
#   'n_fog_max': '',
#   'np_100_s': '1.91',
#   'np_300_s': '1.37',
#   'ta_min_cv': '-0.47',
#   'tm_mes_cv': '0.18',
#   'ts_min_md': '8.9',
#   'ts_min_mn': '8.2',
#   'inso_cv': '',
#   'np_300_n': '24',
#   'np_100_n': '24',
#   'ts_min_n': '24',
#   'tm_max_md': '12.1',
#   'tm_max_mn': '12.3',
#   'ts_min_s': '2.04',
#   'tm_mes_q1': '6.0',
#   'p_max_q1': '28.2',
#   'p_max_q3': '55.0',
#   'p_max_q2': '36.2',
#   'p_max_q4': '78.6',
#   'n_nie_s': '',
#   'n_gra_min': '',
#   'nt_30_n': '24',
#   'n_nie_n': '0',
#   'ts_50_n': '0',
#   'nv_0100_min': '',
#   'q_mar_q1': '',
#   'q_mar_q2': '',
#   'q_mar_q3': '',
#   'q_mar_q4': '',
#   'p_max_min': '7.5',
#   'n_llu_cv': '',
#   'n_nub_mn': '',
#   'w_racha_q1': '14.7',
#   'w_racha_q3': '16.5',
#   'w_racha_q2': '15.8',
#   'n_nub_md': '',
#   'w_racha_q4': '19.6',
#   'nt_00_cv': '0.47',
#   'np_010_q4': '11.0',
#   'np_010_q1': '5.0',
#   'np_010_q3': '8.8',
#   'np_010_q2': '7.0',
#   'nv_1000_q3': '',
#   'ts_50_cv': '',
#   'nv_0100_s': '',
#   'n_llu_max': '',
#   'tm_max_min': '9.3',
#   'tm_min_md': '2.3',
#   'q_mar_cv': '',
#   'nv_0100_n': '0',
#   'tm_min_mn': '2.0',
#   'ts_10_mn': '',
#   'w_racha_cv': '0.2',
#   'evap_min': '',
#   'ta_max_cv': '0.12',
#   'n_llu_q4': '',
#   'n_llu_q2': '',
#   'n_llu_q3': '',
#   'n_llu_q1': '',
#   'q_min_q4': '',
#   'hr_min': '70.0',
#   'w_med_max': '6.0',
#   'nw_91_mn': '0.0',
#   'q_min_q1': '',
#   'q_min_q2': '',
#   'q_min_q3': '',
#   'q_min_n': '0',
#   'nw_91_md': '0.0',
#   'q_min_s': '',
#   'n_tor_q4': '',
#   'n_tor_q1': '',
#   'n_tor_q2': '',
#   'n_tor_q3': '',
#   'tm_mes_min': '5.6',
#   'n_cub_max': '',
#   'nw_55_cv': '0.92',
#   'tm_min_min': '-0.2',
#   'q_mar_max': '',
#   'nv_0100_q4': '',
#   'nv_0100_q1': '',
#   'nv_0100_q2': '',
#   'nv_0100_q3': '',
#   'q_max_q2': '',
#   'q_max_q3': '',
#   'q_max_q1': '',
#   'q_max_q4': '',
#   'nv_0100_cv': '',
#   'ts_10_q3': '',
#   'ts_10_q2': '',
#   'ts_10_q1': '',
#   'ts_10_q4': '',
#   'q_max_cv': '',
#   'ta_max_max': '22.2',
#   'np_010_cv': '0.42',
#   'ta_max_q4': '20.4',
#   'ta_max_q3': '18.9',
#   'ta_max_q2': '18.3',
#   'ta_max_q1': '17.0',
#   'np_010_min': '4.0',
#   'w_med_n': '24',
#   'nv_1000_q4': '',
#   'nv_1000_q2': '',
#   'n_nie_max': '',
#   'nv_1000_q1': '',
#   'nv_1000_cv': '',
#   'glo_max': '',
#   'n_fog_s': '',
#   'ti_max_q2': '4.7',
#   'n_fog_n': '0',
#   'n_nie_cv': '',
#   'np_001_min': '5.0',
#   'nw_55_q4': '2.2',
#   'n_fog_min': '',
#   'nw_55_q2': '1.0',
#   'nw_55_q3': '2.0',
#   'nw_55_q1': '0.0',
#   'hr_n': '22',
#   'hr_s': '4.0',
#   'q_med_s': '',
#   'nv_0050_max': '',
#   'ta_min_q2': '-3.1',
#   'n_des_max': '',
#   'n_fog_mn': '',
#   'p_sol_max': '',
#   'np_001_s': '4.53',
#   'n_fog_md': '',
#   'q_min_cv': '',
#   'np_001_n': '24',
#   'e_max': '96.0',
#   'nt_00_md': '9.3',
#   'np_100_mn': '3.0',
#   'nt_30_q1': '0.0',
#   'nt_00_mn': '8.5',
#   'glo_q4': '',
#   'glo_q2': '',
#   'glo_q3': '',
#   'np_100_md': '3.4',
#   'inso_n': '0',
#   'q_med_q1': '',
#   'np_001_md': '11.3',
#   'np_001_mn': '10.0',
#   'ti_max_cv': '0.44',
#   'nv_1000_mn': '',
#   'nv_1000_md': '',
#   'evap_md': '',
#   'ta_min_max': '-0.8',
#   'e_md': '79.0',
#   'e_mn': '79.0',
#   'nt_30_q3': '0.0',
#   'ti_max_md': '5.4',
#   'n_llu_n': '0',
#   'ti_max_mn': '5.6',
#   'glo_s': '',
#   'glo_n': '0',
#   'ts_min_cv': '0.23',
#   'n_llu_s': '',
#   'nv_0050_mn': '',
#   'n_nie_q3': '',
#   'n_nie_q2': '',
#   'n_nie_q4': '',
#   'glo_cv': '',
#   'tm_max_max': '15.2',
#   'ts_20_mn': '',
#   'tm_max_cv': '0.13',
#   'ts_20_md': '',
#   'np_001_cv': '0.4',
#   'p_max_mn': '40.5',
#   'nw_91_max': '0.0',
#   'p_max_md': '51.9',
#   'q_med_cv': '',
#   'ts_50_max': '',
#   'ts_50_min': '',
#   'ta_min_n': '24',
#   'e_q4': '85.0',
#   'e_q3': '81.0',
#   'e_q2': '77.0',
#   'e_q1': '73.0',
#   'glo_q1': '',
#   'w_racha_md': '16.8',
#   'q_min_min': '',
#   'ts_min_q3': '8.8',
#   'ts_min_q2': '8.0',
#   'ts_min_q1': '7.6',
#   'p_mes_max': '434.2',
#   'ts_min_q4': '10.9',
#   'q_mar_min': '',
#   'tm_max_q3': '12.7',
#   'tm_max_q2': '11.7',
#   'tm_max_q1': '10.6',
#   'p_mes_mn': '120.3',
#   'tm_max_q4': '13.4',
#   'n_gra_mn': '',
#   'tm_min_max': '5.3',
#   'np_001_q4': '15.4',
#   'np_001_q3': '10.8',
#   'np_001_q2': '9.2',
#   'np_001_q1': '7.6',
#   'ti_max_n': '24',
#   'w_med_md': '3.2',
#   'ti_max_q4': '7.5',
#   'ti_max_q3': '6.2',
#   'n_gra_q2': '',
#   'ti_max_q1': '2.7',
#   'ti_max_s': '2.34',
#   'q_med_q2': '',
#   'q_med_q3': '',
#   'nt_30_q2': '0.0',
#   'n_nie_min': '',
#   'nt_30_q4': '0.0',
#   'q_med_q4': '',
#   'n_cub_md': '',
#   'n_cub_mn': '',
#   'ta_max_min': '13.8',
#   'np_010_max': '18.0',
#   'inso_md': '',
#   'inso_mn': '',
#   'evap_mn': ''},
#  {'indicativo': 'B013X',
#   'w_racha_max': '23.9',
#   'np_010_n': '25',
#   'np_010_s': '4.92',
#   'q_max_s': '',
#   'n_tor_n': '0',
#   'n_tor_s': '',
#   'q_max_n': '0',
#   'tm_min_q4': '3.0',
#   'tm_min_q1': '1.1',
#   'tm_min_q3': '2.1',
#   'tm_min_q2': '1.6',
#   'q_mar_n': '0',
#   'n_des_min': '',
#   'q_mar_s': '',
#   'q_med_n': '0',
#   'ts_20_q1': '',
#   'ts_20_q2': '',
#   'e_cv': '0.1',
#   'ts_20_q4': '',
#   'e_min': '61.0',
#   'np_300_q4': '1.0',
#   'np_300_q1': '0.0',
#   'np_300_q3': '1.0',
#   'hr_max': '84.0',
#   'np_300_cv': '1.35',
#   'n_nub_max': '',
#   'tm_min_cv': '0.63',
#   'n_des_mn': '',
#   'n_des_md': '',
#   'ts_20_s': '',
#   'q_med_mn': '',
#   'evap_cv': '',
#   'q_med_md': '',
#   'nt_30_cv': '-',
#   'mes': '02',
#   'ts_20_cv': '',
#   'inso_max': '',
#   'ts_20_max': '',
#   'np_001_max': '22.0',
#   'n_llu_md': '',
#   'nv_1000_s': '',
#   'ta_min_mn': '-2.7',
#   'tm_mes_max': '9.9',
#   'ta_max_mn': '19.3',
#   'nv_1000_n': '0',
#   'ta_max_md': '18.9',
#   'nw_91_min': '0.0',
#   'ta_max_n': '25',
#   'ta_max_s': '2.57',
#   'ts_10_md': '',
#   'nw_55_mn': '1.0',
#   'ta_min_s': '1.31',
#   'nw_55_md': '1.5',
#   'np_300_mn': '1.0',
#   'evap_q4': '',
#   'evap_q1': '',
#   'np_300_md': '0.8',
#   'evap_q3': '',
#   'evap_q2': '',
#   'p_mes_min': '0.7',
#   'ts_min_min': '3.0',
#   'n_des_s': '',
#   'nv_0100_mn': '',
#   'p_mes_md': '97.0',
#   'n_tor_cv': '',
#   'nv_0100_md': '',
#   'q_min_max': '',
#   'n_des_n': '0',
#   'p_sol_s': '',
#   'ts_20_n': '0',
#   'ts_10_cv': '',
#   'nw_91_s': '0.0',
#   'nw_91_n': '22',
#   'nt_00_min': '4.0',
#   'p_sol_n': '0',
#   'n_nie_mn': '',
#   'n_nub_n': '0',
#   'n_nie_md': '',
#   'tm_mes_md': '7.3',
#   'p_sol_cv': '',
#   'n_nub_s': '',
#   'w_racha_min': '10.8',
#   'np_300_max': '5.0',
#   'nv_0050_md': '',
#   'ta_min_min': '-5.1',
#   'glo_mn': '',
#   'inso_s': '',
#   'glo_md': '',
#   'n_nie_q1': '',
#   'w_med_q4': '3.4',
#   'n_tor_max': '',
#   'w_med_q2': '3.0',
#   'w_med_q3': '3.0',
#   'n_gra_md': '',
#   'inso_q4': '',
#   'q_max_min': '',
#   'ts_10_max': '',
#   'nt_30_min': '0.0',
#   'n_nub_cv': '',
#   'p_mes_n': '25',
#   'p_mes_q1': '19.9',
#   'p_mes_q2': '63.3',
#   'p_mes_q3': '85.1',
#   'p_mes_q4': '146.1',
#   'hr_cv': '0.06',
#   'n_tor_md': '',
#   'p_mes_s': '88.11',
#   'nw_91_cv': '-',
#   'n_tor_mn': '',
#   'nv_1000_max': '',
#   'n_gra_cv': '',
#   'w_racha_n': '22',
#   'w_med_min': '2.0',
#   'w_racha_s': '3.14',
#   'np_100_max': '10.0',
#   'e_s': '7.67',
#   'w_med_s': '0.85',
#   'p_sol_md': '',
#   'n_cub_q4': '',
#   'n_cub_q3': '',
#   'n_cub_q2': '',
#   'n_cub_q1': '',
#   'nw_55_max': '5.0',
#   'p_sol_mn': '',
#   'n_cub_s': '',
#   'hr_mn': '75.0',
#   'q_med_max': '',
#   'hr_md': '75.0',
#   'np_010_md': '7.7',
#   'n_cub_n': '0',
#   'np_010_mn': '7.0',
#   'nw_91_q4': '0.0',
#   'p_max_n': '25',
#   'nw_91_q2': '0.0',
#   'nw_91_q3': '0.0',
#   'nw_91_q1': '0.0',
#   'n_gra_q4': '',
#   'n_gra_q1': '',
#   'n_gra_q3': '',
#   'nw_55_s': '1.6',
#   'nw_55_n': '22',
#   'w_med_mn': '3.0',
#   'n_nub_min': '',
#   'p_max_s': '30.4',
#   'ts_20_min': '',
#   'inso_min': '',
#   'n_gra_max': '',
#   'p_sol_q1': '',
#   'p_sol_q3': '',
#   'p_sol_q2': '',
#   'p_sol_q4': '',
#   'n_fog_q1': '',
#   'ta_min_md': '-2.7',
#   'n_fog_q3': '',
#   'n_fog_q2': '',
#   'n_fog_q4': '',
#   'w_med_cv': '0.3',
#   'p_max_max': '109.9',
#   'e_n': '25',
#   'q_min_md': '',
#   'n_fog_cv': '',
#   'p_mes_cv': '0.91',
#   'nv_0100_max': '',
#   'np_300_q2': '0.0',
#   'q_min_mn': '',
#   'ti_max_min': '0.0',
#   'np_100_cv': '0.86',
#   'hr_q3': '76.0',
#   'hr_q2': '74.0',
#   'hr_q1': '72.0',
#   'nv_0050_s': '',
#   'hr_q4': '77.0',
#   'evap_s': '',
#   'w_med_q1': '2.0',
#   'evap_n': '0',
#   'nv_0050_n': '0',
#   'nv_0050_q2': '',
#   'nv_0050_q3': '',
#   'q_max_md': '',
#   'nv_0050_q1': '',
#   'nv_0050_q4': '',
#   'q_max_mn': '',
#   'n_llu_min': '',
#   'ts_min_max': '13.7',
#   'evap_max': '',
#   'ta_min_q1': '-4.0',
#   'ta_min_q3': '-2.3',
#   'n_cub_cv': '',
#   'ta_min_q4': '-1.4',
#   'tm_mes_n': '25',
#   'tm_max_s': '2.56',
#   'nt_30_md': '0.0',
#   'tm_max_n': '25',
#   'tm_mes_s': '1.68',
#   'nt_30_mn': '0.0',
#   'ts_50_q4': '',
#   'ts_50_q3': '',
#   'ts_50_q2': '',
#   'ts_50_q1': '',
#   'q_mar_mn': '',
#   'np_100_q4': '4.2',
#   'np_100_q3': '3.0',
#   'np_100_q2': '2.0',
#   'np_100_q1': '1.0',
#   'n_des_cv': '',
#   'q_mar_md': '',
#   'tm_mes_q4': '8.9',
#   'tm_mes_q2': '6.7',
#   'tm_mes_q3': '8.0',
#   'np_300_min': '0.0',
#   'p_sol_min': '',
#   'n_cub_min': '',
#   'n_gra_s': '',
#   'w_racha_mn': '15.7',
#   'p_max_cv': '0.83',
#   'n_des_q4': '',
#   'n_des_q1': '',
#   'n_des_q3': '',
#   'n_des_q2': '',
#   'ti_max_max': '11.0',
#   'n_gra_n': '0',
#   'tm_min_n': '25',
#   'nt_30_max': '0.0',
#   'q_max_max': '',
#   'tm_min_s': '1.16',
#   'nt_00_n': '25',
#   'nv_0050_min': '',
#   'ts_10_s': '',
#   'n_nub_q4': '',
#   'n_nub_q1': '',
#   'n_nub_q2': '',
#   'n_nub_q3': '',
#   'ts_50_s': '',
#   'ts_10_n': '0',
#   'nt_00_s': '4.5',
#   'ts_10_min': '',
#   'tm_mes_mn': '7.2',
#   'np_100_min': '0.0',
#   'nv_1000_min': '',
#   'nt_30_s': '0.0',
#   'nt_00_q3': '10.0',
#   'nt_00_q2': '7.0',
#   'nt_00_q1': '5.0',
#   'n_tor_min': '',
#   'nt_00_q4': '13.0',
#   'ts_20_q3': '',
#   'nt_00_max': '20.0',
#   'nw_55_min': '0.0',
#   'n_llu_mn': '',
#   'ts_50_mn': '',
#   'glo_min': '',
#   'ts_50_md': '',
#   'q_med_min': '',
#   'nv_0050_cv': '',
#   'inso_q2': '',
#   'inso_q3': '',
#   'inso_q1': '',
#   'n_fog_max': '',
#   'np_100_s': '2.44',
#   'np_300_s': '1.08',
#   'ta_min_cv': '-0.48',
#   'tm_mes_cv': '0.23',
#   'ts_min_md': '8.6',
#   'ts_min_mn': '8.7',
#   'inso_cv': '',
#   'np_300_n': '25',
#   'np_100_n': '25',
#   'ts_min_n': '25',
#   'tm_max_md': '12.7',
#   'tm_max_mn': '13.4',
#   'ts_min_s': '2.34',
#   'tm_mes_q1': '5.7',
#   'p_max_q1': '13.6',
#   'p_max_q3': '34.4',
#   'p_max_q2': '27.9',
#   'p_max_q4': '44.9',
#   'n_nie_s': '',
#   'n_gra_min': '',
#   'nt_30_n': '25',
#   'n_nie_n': '0',
#   'ts_50_n': '0',
#   'nv_0100_min': '',
#   'q_mar_q1': '',
#   'q_mar_q2': '',
#   'q_mar_q3': '',
#   'q_mar_q4': '',
#   'p_max_min': '0.6',
#   'n_llu_cv': '',
#   'n_nub_mn': '',
#   'w_racha_q1': '13.7',
#   'w_racha_q3': '16.6',
#   'w_racha_q2': '15.4',
#   'n_nub_md': '',
#   'w_racha_q4': '18.3',
#   'nt_00_cv': '0.48',
#   'np_010_q4': '12.0',
#   'np_010_q1': '2.8',
#   'np_010_q3': '8.0',
#   'np_010_q2': '6.0',
#   'nv_1000_q3': '',
#   'ts_50_cv': '',
#   'nv_0100_s': '',
#   'n_llu_max': '',
#   'tm_max_min': '7.9',
#   'tm_min_md': '1.8',
#   'q_mar_cv': '',
#   'nv_0100_n': '0',
#   'tm_min_mn': '2.0',
#   'ts_10_mn': '',
#   'w_racha_cv': '0.19',
#   'evap_min': '',
#   'ta_max_cv': '0.14',
#   'n_llu_q4': '',
#   'n_llu_q2': '',
#   'n_llu_q3': '',
#   'n_llu_q1': '',
#   'q_min_q4': '',
#   'hr_min': '66.0',
#   'w_med_max': '5.0',
#   'nw_91_mn': '0.0',
#   'q_min_q1': '',
#   'q_min_q2': '',
#   'q_min_q3': '',
#   'q_min_n': '0',
#   'nw_91_md': '0.0',
#   'q_min_s': '',
#   'n_tor_q4': '',
#   'n_tor_q1': '',
#   'n_tor_q2': '',
#   'n_tor_q3': '',
#   'tm_mes_min': '4.3',
#   'n_cub_max': '',
#   'nw_55_cv': '1.1',
#   'tm_min_min': '-0.4',
#   'q_mar_max': '',
#   'nv_0100_q4': '',
#   'nv_0100_q1': '',
#   'nv_0100_q2': '',
#   'nv_0100_q3': '',
#   'q_max_q2': '',
#   'q_max_q3': '',
#   'q_max_q1': '',
#   'q_max_q4': '',
#   'nv_0100_cv': '',
#   'ts_10_q3': '',
#   'ts_10_q2': '',
#   'ts_10_q1': '',
#   'ts_10_q4': '',
#   'q_max_cv': '',
#   'ta_max_max': '23.0',
#   'np_010_cv': '0.64',
#   'ta_max_q4': '21.3',
#   'ta_max_q3': '20.4',
#   'ta_max_q2': '18.3',
#   'ta_max_q1': '16.6',
#   'np_010_min': '0.0',
#   'w_med_n': '24',
#   'nv_1000_q4': '',
#   'nv_1000_q2': '',
#   'n_nie_max': '',
#   'nv_1000_q1': '',
#   'nv_1000_cv': '',
#   'glo_max': '',
#   'n_fog_s': '',
#   'ti_max_q2': '5.9',
#   'n_fog_n': '0',
#   'n_nie_cv': '',
#   'np_001_min': '2.0',
#   'nw_55_q4': '2.8',
#   'n_fog_min': '',
#   'nw_55_q2': '1.0',
#   'nw_55_q3': '1.0',
#   'nw_55_q1': '0.0',
#   'hr_n': '23',
#   'hr_s': '4.34',
#   'q_med_s': '',
#   'nv_0050_max': '',
#   'ta_min_q2': '-3.0',
#   'n_des_max': '',
#   'n_fog_mn': '',
#   'p_sol_max': '',
#   'np_001_s': '6.24',
#   'n_fog_md': '',
#   'q_min_cv': '',
#   'np_001_n': '25',
#   'e_max': '88.0',
#   'nt_00_md': '9.4',
#   'np_100_mn': '2.0',
#   'nt_30_q1': '0.0',
#   'nt_00_mn': '9.0',
#   'glo_q4': '',
#   'glo_q2': '',
#   'glo_q3': '',
#   'np_100_md': '2.8',
#   'inso_n': '0',
#   'q_med_q1': '',
#   'np_001_md': '10.5',
#   'np_001_mn': '10.0',
#   'ti_max_cv': '0.5',
#   'nv_1000_mn': '',
#   'nv_1000_md': '',
#   'evap_md': '',
#   'ta_min_max': '-0.6',
#   'e_md': '77.0',
#   'e_mn': '77.0',
#   'nt_30_q3': '0.0',
#   'ti_max_md': '6.3',
#   'n_llu_n': '0',
#   'ti_max_mn': '6.1',
#   'glo_s': '',
#   'glo_n': '0',
#   'ts_min_cv': '0.27',
#   'n_llu_s': '',
#   'nv_0050_mn': '',
#   'n_nie_q3': '',
#   'n_nie_q2': '',
#   'n_nie_q4': '',
#   'glo_cv': '',
#   'tm_max_max': '16.6',
#   'ts_20_mn': '',
#   'tm_max_cv': '0.2',
#   'ts_20_md': '',
#   'np_001_cv': '0.59',
#   'p_max_mn': '30.6',
#   'nw_91_max': '0.0',
#   'p_max_md': '36.8',
#   'q_med_cv': '',
#   'ts_50_max': '',
#   'ts_50_min': '',
#   'ta_min_n': '25',
#   'e_q4': '85.0',
#   'e_q3': '78.0',
#   'e_q2': '75.0',
#   'e_q1': '69.0',
#   'glo_q1': '',
#   'w_racha_md': '16.3',
#   'q_min_min': '',
#   'ts_min_q3': '8.9',
#   'ts_min_q2': '8.4',
#   'ts_min_q1': '7.3',
#   'p_mes_max': '360.4',
#   'ts_min_q4': '9.7',
#   'q_mar_min': '',
#   'tm_max_q3': '13.9',
#   'tm_max_q2': '12.0',
#   'tm_max_q1': '10.3',
#   'p_mes_mn': '70.6',
#   'tm_max_q4': '15.0',
#   'n_gra_mn': '',
#   'tm_min_max': '3.6',
#   'np_001_q4': '17.0',
#   'np_001_q3': '12.0',
#   'np_001_q2': '8.0',
#   'np_001_q1': '4.6',
#   'ti_max_n': '25',
#   'w_med_md': '2.9',
#   'ti_max_q4': '9.2',
#   'ti_max_q3': '8.2',
#   'n_gra_q2': '',
#   'ti_max_q1': '3.3',
#   'ti_max_s': '3.19',
#   'q_med_q2': '',
#   'q_med_q3': '',
#   'nt_30_q2': '0.0',
#   'n_nie_min': '',
#   'nt_30_q4': '0.0',
#   'q_med_q4': '',
#   'n_cub_md': '',
#   'n_cub_mn': '',
#   'ta_max_min': '13.1',
#   'np_010_max': '16.0',
#   'inso_md': '',
#   'inso_mn': '',
#   'evap_mn': ''},
#  {'indicativo': 'B013X',
#   'w_racha_max': '20.3',
#   'np_010_n': '23',
#   'np_010_s': '2.91',
#   'q_max_s': '',
#   'n_tor_n': '0',
#   'n_tor_s': '',
#   'q_max_n': '0',
#   'tm_min_q4': '4.7',
#   'tm_min_q1': '2.7',
#   'tm_min_q3': '3.7',
#   'tm_min_q2': '3.1',
#   'q_mar_n': '0',
#   'n_des_min': '',
#   'q_mar_s': '',
#   'q_med_n': '0',
#   'ts_20_q1': '',
#   'ts_20_q2': '',
#   'e_cv': '0.08',
#   'ts_20_q4': '',
#   'e_min': '76.0',
#   'np_300_q4': '2.0',
#   'np_300_q1': '0.0',
#   'np_300_q3': '1.0',
#   'hr_max': '79.0',
#   'np_300_cv': '1.06',
#   'n_nub_max': '',
#   'tm_min_cv': '0.34',
#   'n_des_mn': '',
#   'n_des_md': '',
#   'ts_20_s': '',
#   'q_med_mn': '',
#   'evap_cv': '',
#   'q_med_md': '',
#   'nt_30_cv': '4.90',
#   'mes': '03',
#   'ts_20_cv': '',
#   'inso_max': '',
#   'ts_20_max': '',
#   'np_001_max': '16.0',
#   'n_llu_md': '',
#   'nv_1000_s': '',
#   'ta_min_mn': '-1.5',
#   'tm_mes_max': '12.9',
#   'ta_max_mn': '23.0',
#   'nv_1000_n': '0',
#   'ta_max_md': '23.0',
#   'nw_91_min': '0.0',
#   'ta_max_n': '24',
#   'ta_max_s': '2.88',
#   'ts_10_md': '',
#   'nw_55_mn': '1.0',
#   'ta_min_s': '1.41',
#   'nw_55_md': '1.7',
#   'np_300_mn': '1.0',
#   'evap_q4': '',
#   'evap_q1': '',
#   'np_300_md': '0.9',
#   'evap_q3': '',
#   'evap_q2': '',
#   'p_mes_min': '13.2',
#   'ts_min_min': '7.9',
#   'n_des_s': '',
#   'nv_0100_mn': '',
#   'p_mes_md': '98.8',
#   'n_tor_cv': '',
#   'nv_0100_md': '',
#   'q_min_max': '',
#   'n_des_n': '0',
#   'p_sol_s': '',
#   'ts_20_n': '0',
#   'ts_10_cv': '',
#   'nw_91_s': '0.0',
#   'nw_91_n': '20',
#   'nt_00_min': '0.0',
#   'p_sol_n': '0',
#   'n_nie_mn': '',
#   'n_nub_n': '0',
#   'n_nie_md': '',
#   'tm_mes_md': '9.4',
#   'p_sol_cv': '',
#   'n_nub_s': '',
#   'w_racha_min': '10.0',
#   'np_300_max': '3.0',
#   'nv_0050_md': '',
#   'ta_min_min': '-5.6',
#   'glo_mn': '',
#   'inso_s': '',
#   'glo_md': '',
#   'n_nie_q1': '',
#   'w_med_q4': '4.0',
#   'n_tor_max': '',
#   'w_med_q2': '3.0',
#   'w_med_q3': '3.2',
#   'n_gra_md': '',
#   'inso_q4': '',
#   'q_max_min': '',
#   'ts_10_max': '',
#   'nt_30_min': '0.0',
#   'n_nub_cv': '',
#   'p_mes_n': '23',
#   'p_mes_q1': '32.0',
#   'p_mes_q2': '62.1',
#   'p_mes_q3': '90.0',
#   'p_mes_q4': '170.4',
#   'hr_cv': '0.08',
#   'n_tor_md': '',
#   'p_mes_s': '80.2',
#   'nw_91_cv': '-',
#   'n_tor_mn': '',
#   'nv_1000_max': '',
#   'n_gra_cv': '',
#   'w_racha_n': '20',
#   'w_med_min': '2.0',
#   'w_racha_s': '2.93',
#   'np_100_max': '6.0',
#   'e_s': '6.39',
#   'w_med_s': '0.71',
#   'p_sol_md': '',
#   'n_cub_q4': '',
#   'n_cub_q3': '',
#   'n_cub_q2': '',
#   'n_cub_q1': '',
#   'nw_55_max': '5.0',
#   'p_sol_mn': '',
#   'n_cub_s': '',
#   'hr_mn': '71.0',
#   'q_med_max': '',
#   'hr_md': '71.0',
#   'np_010_md': '6.7',
#   'n_cub_n': '0',
#   'np_010_mn': '6.0',
#   'nw_91_q4': '0.0',
#   'p_max_n': '23',
#   'nw_91_q2': '0.0',
#   'nw_91_q3': '0.0',
#   'nw_91_q1': '0.0',
#   'n_gra_q4': '',
#   'n_gra_q1': '',
#   'n_gra_q3': '',
#   'nw_55_s': '1.66',
#   'nw_55_n': '20',
#   'w_med_mn': '3.0',
#   'n_nub_min': '',
#   'p_max_s': '40.09',
#   'ts_20_min': '',
#   'inso_min': '',
#   'n_gra_max': '',
#   'p_sol_q1': '',
#   'p_sol_q3': '',
#   'p_sol_q2': '',
#   'p_sol_q4': '',
#   'n_fog_q1': '',
#   'ta_min_md': '-1.5',
#   'n_fog_q3': '',
#   'n_fog_q2': '',
#   'n_fog_q4': '',
#   'w_med_cv': '0.21',
#   'p_max_max': '160.6',
#   'e_n': '23',
#   'q_min_md': '',
#   'n_fog_cv': '',
#   'p_mes_cv': '0.81',
#   'nv_0100_max': '',
#   'np_300_q2': '0.0',
#   'q_min_mn': '',
#   'ti_max_min': '3.1',
#   'np_100_cv': '0.69',
#   'hr_q3': '72.0',
#   'hr_q2': '69.0',
#   'hr_q1': '66.0',
#   'nv_0050_s': '',
#   'hr_q4': '76.0',
#   'evap_s': '',
#   'w_med_q1': '3.0',
#   'evap_n': '0',
#   'nv_0050_n': '0',
#   'nv_0050_q2': '',
#   'nv_0050_q3': '',
#   'q_max_md': '',
#   'nv_0050_q1': '',
#   'nv_0050_q4': '',
#   'q_max_mn': '',
#   'n_llu_min': '',
#   'ts_min_max': '18.5',
#   'evap_max': '',
#   'ta_min_q1': '-2.5',
#   'ta_min_q3': '-1.0',
#   'n_cub_cv': '',
#   'ta_min_q4': '-0.2',
#   'tm_mes_n': '24',
#   'tm_max_s': '1.68',
#   'nt_30_md': '0.1',
#   'tm_max_n': '24',
#   'tm_mes_s': '1.16',
#   'nt_30_mn': '0.0',
#   'ts_50_q4': '',
#   'ts_50_q3': '',
#   'ts_50_q2': '',
#   'ts_50_q1': '',
#   'q_mar_mn': '',
#   'np_100_q4': '5.0',
#   'np_100_q3': '3.0',
#   'np_100_q2': '2.0',
#   'np_100_q1': '1.0',
#   'n_des_cv': '',
#   'q_mar_md': '',
#   'tm_mes_q4': '10.3',
#   'tm_mes_q2': '8.9',
#   'tm_mes_q3': '9.6',
#   'np_300_min': '0.0',
#   'p_sol_min': '',
#   'n_cub_min': '',
#   'n_gra_s': '',
#   'w_racha_mn': '16.1',
#   'p_max_cv': '0.84',
#   'n_des_q4': '',
#   'n_des_q1': '',
#   'n_des_q3': '',
#   'n_des_q2': '',
#   'ti_max_max': '11.6',
#   'n_gra_n': '0',
#   'tm_min_n': '24',
#   'nt_30_max': '2.0',
#   'q_max_max': '',
#   'tm_min_s': '1.26',
#   'nt_00_n': '24',
#   'nv_0050_min': '',
#   'ts_10_s': '',
#   'n_nub_q4': '',
#   'n_nub_q1': '',
#   'n_nub_q2': '',
#   'n_nub_q3': '',
#   'ts_50_s': '',
#   'ts_10_n': '0',
#   'nt_00_s': '3.44',
#   'ts_10_min': '',
#   'tm_mes_mn': '9.4',
#   'np_100_min': '0.0',
#   'nv_1000_min': '',
#   'nt_30_s': '0.41',
#   'nt_00_q3': '4.0',
#   'nt_00_q2': '2.2',
#   'nt_00_q1': '1.0',
#   'n_tor_min': '',
#   'nt_00_q4': '7.0',
#   'ts_20_q3': '',
#   'nt_00_max': '11.0',
#   'nw_55_min': '0.0',
#   'n_llu_mn': '',
#   'ts_50_mn': '',
#   'glo_min': '',
#   'ts_50_md': '',
#   'q_med_min': '',
#   'nv_0050_cv': '',
#   'inso_q2': '',
#   'inso_q3': '',
#   'inso_q1': '',
#   'n_fog_max': '',
#   'np_100_s': '1.82',
#   'np_300_s': '0.92',
#   'ta_min_cv': '-0.91',
#   'tm_mes_cv': '0.12',
#   'ts_min_md': '10.6',
#   'ts_min_mn': '9.7',
#   'inso_cv': '',
#   'np_300_n': '23',
#   'np_100_n': '23',
#   'ts_min_n': '24',
#   'tm_max_md': '15.1',
#   'tm_max_mn': '15.0',
#   'ts_min_s': '2.44',
#   'tm_mes_q1': '8.4',
#   'p_max_q1': '16.6',
#   'p_max_q3': '48.0',
#   'p_max_q2': '20.9',
#   'p_max_q4': '74.6',
#   'n_nie_s': '',
#   'n_gra_min': '',
#   'nt_30_n': '24',
#   'n_nie_n': '0',
#   'ts_50_n': '0',
#   'nv_0100_min': '',
#   'q_mar_q1': '',
#   'q_mar_q2': '',
#   'q_mar_q3': '',
#   'q_mar_q4': '',
#   'p_max_min': '8.5',
#   'n_llu_cv': '',
#   'n_nub_mn': '',
#   'w_racha_q1': '12.7',
#   'w_racha_q3': '17.0',
#   'w_racha_q2': '15.6',
#   'n_nub_md': '',
#   'w_racha_q4': '18.7',
#   'nt_00_cv': '0.83',
#   'np_010_q4': '9.0',
#   'np_010_q1': '4.0',
#   'np_010_q3': '8.2',
#   'np_010_q2': '6.0',
#   'nv_1000_q3': '',
#   'ts_50_cv': '',
#   'nv_0100_s': '',
#   'n_llu_max': '',
#   'tm_max_min': '12.5',
#   'tm_min_md': '3.7',
#   'q_mar_cv': '',
#   'nv_0100_n': '0',
#   'tm_min_mn': '3.5',
#   'ts_10_mn': '',
#   'w_racha_cv': '0.18',
#   'evap_min': '',
#   'ta_max_cv': '0.13',
#   'n_llu_q4': '',
#   'n_llu_q2': '',
#   'n_llu_q3': '',
#   'n_llu_q1': '',
#   'q_min_q4': '',
#   'hr_min': '60.0',
#   'w_med_max': '5.0',
#   'nw_91_mn': '0.0',
#   'q_min_q1': '',
#   'q_min_q2': '',
#   'q_min_q3': '',
#   'q_min_n': '0',
#   'nw_91_md': '0.0',
#   'q_min_s': '',
#   'n_tor_q4': '',
#   'n_tor_q1': '',
#   'n_tor_q2': '',
#   'n_tor_q3': '',
#   'tm_mes_min': '7.8',
#   'n_cub_max': '',
#   'nw_55_cv': '1.01',
#   'tm_min_min': '1.7',
#   'q_mar_max': '',
#   'nv_0100_q4': '',
#   'nv_0100_q1': '',
#   'nv_0100_q2': '',
#   'nv_0100_q3': '',
#   'q_max_q2': '',
#   'q_max_q3': '',
#   'q_max_q1': '',
#   'q_max_q4': '',
#   'nv_0100_cv': '',
#   'ts_10_q3': '',
#   'ts_10_q2': '',
#   'ts_10_q1': '',
#   'ts_10_q4': '',
#   'q_max_cv': '',
#   'ta_max_max': '32.1',
#   'np_010_cv': '0.43',
#   'ta_max_q4': '24.4',
#   'ta_max_q3': '23.8',
#   'ta_max_q2': '22.6',
#   'ta_max_q1': '20.8',
#   'np_010_min': '2.0',
#   'w_med_n': '23',
#   'nv_1000_q4': '',
#   'nv_1000_q2': '',
#   'n_nie_max': '',
#   'nv_1000_q1': '',
#   'nv_1000_cv': '',
#   'glo_max': '',
#   'n_fog_s': '',
#   'ti_max_q2': '7.5',
#   'n_fog_n': '0',
#   'n_nie_cv': '',
#   'np_001_min': '3.0',
#   'nw_55_q4': '3.2',
#   'n_fog_min': '',
#   'nw_55_q2': '1.0',
#   'nw_55_q3': '1.0',
#   'nw_55_q1': '0.0',
#   'hr_n': '20',
#   'hr_s': '5.48',
#   'q_med_s': '',
#   'nv_0050_max': '',
#   'ta_min_q2': '-1.8',
#   'n_des_max': '',
#   'n_fog_mn': '',
#   'p_sol_max': '',
#   'np_001_s': '3.56',
#   'n_fog_md': '',
#   'q_min_cv': '',
#   'np_001_n': '23',
#   'e_max': '97.0',
#   'nt_00_md': '4.1',
#   'np_100_mn': '2.0',
#   'nt_30_q1': '0.0',
#   'nt_00_mn': '3.0',
#   'glo_q4': '',
#   'glo_q2': '',
#   'glo_q3': '',
#   'np_100_md': '2.7',
#   'inso_n': '0',
#   'q_med_q1': '',
#   'np_001_md': '9.1',
#   'np_001_mn': '10.0',
#   'ti_max_cv': '0.27',
#   'nv_1000_mn': '',
#   'nv_1000_md': '',
#   'evap_md': '',
#   'ta_min_max': '0.5',
#   'e_md': '85.0',
#   'e_mn': '84.0',
#   'nt_30_q3': '0.0',
#   'ti_max_md': '7.6',
#   'n_llu_n': '0',
#   'ti_max_mn': '7.8',
#   'glo_s': '',
#   'glo_n': '0',
#   'ts_min_cv': '0.23',
#   'n_llu_s': '',
#   'nv_0050_mn': '',
#   'n_nie_q3': '',
#   'n_nie_q2': '',
#   'n_nie_q4': '',
#   'glo_cv': '',
#   'tm_max_max': '19.2',
#   'ts_20_mn': '',
#   'tm_max_cv': '0.11',
#   'ts_20_md': '',
#   'np_001_cv': '0.39',
#   'p_max_mn': '42.4',
#   'nw_91_max': '0.0',
#   'p_max_md': '47.8',
#   'q_med_cv': '',
#   'ts_50_max': '',
#   'ts_50_min': '',
#   'ta_min_n': '24',
#   'e_q4': '90.0',
#   'e_q3': '85.0',
#   'e_q2': '83.0',
#   'e_q1': '78.0',
#   'glo_q1': '',
#   'w_racha_md': '16.0',
#   'q_min_min': '',
#   'ts_min_q3': '10.1',
#   'ts_min_q2': '9.3',
#   'ts_min_q1': '9.1',
#   'p_mes_max': '276.8',
#   'ts_min_q4': '12.1',
#   'q_mar_min': '',
#   'tm_max_q3': '15.4',
#   'tm_max_q2': '14.2',
#   'tm_max_q1': '13.8',
#   'p_mes_mn': '63.5',
#   'tm_max_q4': '16.2',
#   'n_gra_mn': '',
#   'tm_min_max': '6.5',
#   'np_001_q4': '12.0',
#   'np_001_q3': '10.0',
#   'np_001_q2': '8.6',
#   'np_001_q1': '6.0',
#   'ti_max_n': '24',
#   'w_med_md': '3.3',
#   'ti_max_q4': '9.4',
#   'ti_max_q3': '8.1',
#   'n_gra_q2': '',
#   'ti_max_q1': '5.8',
#   'ti_max_s': '2.05',
#   'q_med_q2': '',
#   'q_med_q3': '',
#   'nt_30_q2': '0.0',
#   'n_nie_min': '',
#   'nt_30_q4': '0.0',
#   'q_med_q4': '',
#   'n_cub_md': '',
#   'n_cub_mn': '',
#   'ta_max_min': '18.1',
#   'np_010_max': '12.0',
#   'inso_md': '',
#   'inso_mn': '',
#   'evap_mn': ''},
#  {'indicativo': 'B013X',
#   'w_racha_max': '19.7',
#   'np_010_n': '23',
#   'np_010_s': '2.97',
#   'q_max_s': '',
#   'n_tor_n': '1',
#   'n_tor_s': '',
#   'q_max_n': '0',
#   'tm_min_q4': '7.3',
#   'tm_min_q1': '5.0',
#   'tm_min_q3': '6.0',
#   'tm_min_q2': '5.7',
#   'q_mar_n': '0',
#   'n_des_min': '',
#   'q_mar_s': '',
#   'q_med_n': '0',
#   'ts_20_q1': '',
#   'ts_20_q2': '',
#   'e_cv': '0.11',
#   'ts_20_q4': '',
#   'e_min': '65.0',
#   'np_300_q4': '1.0',
#   'np_300_q1': '0.0',
#   'np_300_q3': '1.0',
#   'hr_max': '76.0',
#   'np_300_cv': '1.28',
#   'n_nub_max': '',
#   'tm_min_cv': '0.22',
#   'n_des_mn': '',
#   'n_des_md': '',
#   'ts_20_s': '',
#   'q_med_mn': '',
#   'evap_cv': '',
#   'q_med_md': '',
#   'nt_30_cv': '-',
#   'mes': '04',
#   'ts_20_cv': '',
#   'inso_max': '',
#   'ts_20_max': '',
#   'np_001_max': '15.0',
#   'n_llu_md': '',
#   'nv_1000_s': '',
#   'ta_min_mn': '0.6',
#   'tm_mes_max': '14.0',
#   'ta_max_mn': '23.9',
#   'nv_1000_n': '0',
#   'ta_max_md': '24.1',
#   'nw_91_min': '0.0',
#   'ta_max_n': '26',
#   'ta_max_s': '1.86',
#   'ts_10_md': '',
#   'nw_55_mn': '1.0',
#   'ta_min_s': '1.55',
#   'nw_55_md': '1.2',
#   'np_300_mn': '1.0',
#   'evap_q4': '',
#   'evap_q1': '',
#   'np_300_md': '0.8',
#   'evap_q3': '',
#   'evap_q2': '',
#   'p_mes_min': '3.8',
#   'ts_min_min': '8.3',
#   'n_des_s': '',
#   'nv_0100_mn': '',
#   'p_mes_md': '96.2',
#   'n_tor_cv': '',
#   'nv_0100_md': '',
#   'q_min_max': '',
#   'n_des_n': '0',
#   'p_sol_s': '',
#   'ts_20_n': '0',
#   'ts_10_cv': '',
#   'nw_91_s': '0.0',
#   'nw_91_n': '21',
#   'nt_00_min': '0.0',
#   'p_sol_n': '0',
#   'n_nie_mn': '',
#   'n_nub_n': '0',
#   'n_nie_md': '',
#   'tm_mes_md': '11.8',
#   'p_sol_cv': '',
#   'n_nub_s': '',
#   'w_racha_min': '9.7',
#   'np_300_max': '4.0',
#   'nv_0050_md': '',
#   'ta_min_min': '-1.5',
#   'glo_mn': '',
#   'inso_s': '',
#   'glo_md': '',
#   'n_nie_q1': '',
#   'w_med_q4': '4.6',
#   'n_tor_max': '',
#   'w_med_q2': '4.0',
#   'w_med_q3': '4.0',
#   'n_gra_md': '',
#   'inso_q4': '',
#   'q_max_min': '',
#   'ts_10_max': '',
#   'nt_30_min': '0.0',
#   'n_nub_cv': '',
#   'p_mes_n': '23',
#   'p_mes_q1': '25.9',
#   'p_mes_q2': '60.9',
#   'p_mes_q3': '95.6',
#   'p_mes_q4': '134.5',
#   'hr_cv': '0.07',
#   'n_tor_md': '',
#   'p_mes_s': '83.39',
#   'nw_91_cv': '-',
#   'n_tor_mn': '',
#   'nv_1000_max': '',
#   'n_gra_cv': '',
#   'w_racha_n': '21',
#   'w_med_min': '2.0',
#   'w_racha_s': '2.42',
#   'np_100_max': '6.0',
#   'e_s': '10.72',
#   'w_med_s': '0.89',
#   'p_sol_md': '',
#   'n_cub_q4': '',
#   'n_cub_q3': '',
#   'n_cub_q2': '',
#   'n_cub_q1': '',
#   'nw_55_max': '5.0',
#   'p_sol_mn': '',
#   'n_cub_s': '',
#   'hr_mn': '65.0',
#   'q_med_max': '',
#   'hr_md': '66.0',
#   'np_010_md': '6.1',
#   'n_cub_n': '0',
#   'np_010_mn': '6.0',
#   'nw_91_q4': '0.0',
#   'p_max_n': '23',
#   'nw_91_q2': '0.0',
#   'nw_91_q3': '0.0',
#   'nw_91_q1': '0.0',
#   'n_gra_q4': '',
#   'n_gra_q1': '',
#   'n_gra_q3': '',
#   'nw_55_s': '1.51',
#   'nw_55_n': '21',
#   'w_med_mn': '4.0',
#   'n_nub_min': '',
#   'p_max_s': '42.26',
#   'ts_20_min': '',
#   'inso_min': '',
#   'n_gra_max': '',
#   'p_sol_q1': '',
#   'p_sol_q3': '',
#   'p_sol_q2': '',
#   'p_sol_q4': '',
#   'n_fog_q1': '',
#   'ta_min_md': '0.8',
#   'n_fog_q3': '',
#   'n_fog_q2': '',
#   'n_fog_q4': '',
#   'w_med_cv': '0.23',
#   'p_max_max': '156.4',
#   'e_n': '25',
#   'q_min_md': '',
#   'n_fog_cv': '',
#   'p_mes_cv': '0.87',
#   'nv_0100_max': '',
#   'np_300_q2': '0.0',
#   'q_min_mn': '',
#   'ti_max_min': '8.0',
#   'np_100_cv': '0.76',
#   'hr_q3': '66.0',
#   'hr_q2': '63.0',
#   'hr_q1': '61.0',
#   'nv_0050_s': '',
#   'hr_q4': '69.0',
#   'evap_s': '',
#   'w_med_q1': '3.0',
#   'evap_n': '0',
#   'nv_0050_n': '0',
#   'nv_0050_q2': '',
#   'nv_0050_q3': '',
#   'q_max_md': '',
#   'nv_0050_q1': '',
#   'nv_0050_q4': '',
#   'q_max_mn': '',
#   'n_llu_min': '',
#   'ts_min_max': '18.4',
#   'evap_max': '',
#   'ta_min_q1': '-0.5',
#   'ta_min_q3': '1.2',
#   'n_cub_cv': '',
#   'ta_min_q4': '1.9',
#   'tm_mes_n': '26',
#   'tm_max_s': '1.27',
#   'nt_30_md': '0.0',
#   'tm_max_n': '26',
#   'tm_mes_s': '1.02',
#   'nt_30_mn': '0.0',
#   'ts_50_q4': '',
#   'ts_50_q3': '',
#   'ts_50_q2': '',
#   'ts_50_q1': '',
#   'q_mar_mn': '',
#   'np_100_q4': '4.0',
#   'np_100_q3': '2.0',
#   'np_100_q2': '2.0',
#   'np_100_q1': '1.0',
#   'n_des_cv': '',
#   'q_mar_md': '',
#   'tm_mes_q4': '12.7',
#   'tm_mes_q2': '11.3',
#   'tm_mes_q3': '12.2',
#   'np_300_min': '0.0',
#   'p_sol_min': '',
#   'n_cub_min': '',
#   'n_gra_s': '',
#   'w_racha_mn': '15.3',
#   'p_max_cv': '0.9',
#   'n_des_q4': '',
#   'n_des_q1': '',
#   'n_des_q3': '',
#   'n_des_q2': '',
#   'ti_max_max': '14.0',
#   'n_gra_n': '1',
#   'tm_min_n': '26',
#   'nt_30_max': '0.0',
#   'q_max_max': '',
#   'tm_min_s': '1.32',
#   'nt_00_n': '26',
#   'nv_0050_min': '',
#   'ts_10_s': '',
#   'n_nub_q4': '',
#   'n_nub_q1': '',
#   'n_nub_q2': '',
#   'n_nub_q3': '',
#   'ts_50_s': '',
#   'ts_10_n': '0',
#   'nt_00_s': '0.71',
#   'ts_10_min': '',
#   'tm_mes_mn': '11.7',
#   'np_100_min': '0.0',
#   'nv_1000_min': '',
#   'nt_30_s': '0.0',
#   'nt_00_q3': '0.0',
#   'nt_00_q2': '0.0',
#   'nt_00_q1': '0.0',
#   'n_tor_min': '',
#   'nt_00_q4': '1.0',
#   'ts_20_q3': '',
#   'nt_00_max': '2.0',
#   'nw_55_min': '0.0',
#   'n_llu_mn': '',
#   'ts_50_mn': '',
#   'glo_min': '',
#   'ts_50_md': '',
#   'q_med_min': '',
#   'nv_0050_cv': '',
#   'inso_q2': '',
#   'inso_q3': '',
#   'inso_q1': '',
#   'n_fog_max': '',
#   'np_100_s': '1.68',
#   'np_300_s': '1.0',
#   'ta_min_cv': '1.93',
#   'tm_mes_cv': '0.09',
#   'ts_min_md': '12.5',
#   'ts_min_mn': '12.3',
#   'inso_cv': '',
#   'np_300_n': '23',
#   'np_100_n': '23',
#   'ts_min_n': '26',
#   'tm_max_md': '17.5',
#   'tm_max_mn': '17.4',
#   'ts_min_s': '2.1',
#   'tm_mes_q1': '10.8',
#   'p_max_q1': '13.2',
#   'p_max_q3': '41.3',
#   'p_max_q2': '24.2',
#   'p_max_q4': '80.8',
#   'n_nie_s': '',
#   'n_gra_min': '',
#   'nt_30_n': '26',
#   'n_nie_n': '1',
#   'ts_50_n': '0',
#   'nv_0100_min': '',
#   'q_mar_q1': '',
#   'q_mar_q2': '',
#   'q_mar_q3': '',
#   'q_mar_q4': '',
#   'p_max_min': '2.0',
#   'n_llu_cv': '',
#   'n_nub_mn': '',
#   'w_racha_q1': '13.1',
#   'w_racha_q3': '15.6',
#   'w_racha_q2': '15.3',
#   'n_nub_md': '',
#   'w_racha_q4': '17.2',
#   'nt_00_cv': '1.53',
#   'np_010_q4': '9.6',
#   'np_010_q1': '3.4',
#   'np_010_q3': '6.2',
#   'np_010_q2': '5.0',
#   'nv_1000_q3': '',
#   'ts_50_cv': '',
#   'nv_0100_s': '',
#   'n_llu_max': '',
#   'tm_max_min': '15.2',
#   'tm_min_md': '6.0',
#   'q_mar_cv': '',
#   'nv_0100_n': '0',
#   'tm_min_mn': '5.9',
#   'ts_10_mn': '',
#   'w_racha_cv': '0.16',
#   'evap_min': '',
#   'ta_max_cv': '0.08',
#   'n_llu_q4': '',
#   'n_llu_q2': '',
#   'n_llu_q3': '',
#   'n_llu_q1': '',
#   'q_min_q4': '',
#   'hr_min': '60.0',
#   'w_med_max': '5.0',
#   'nw_91_mn': '0.0',
#   'q_min_q1': '',
#   'q_min_q2': '',
#   'q_min_q3': '',
#   'q_min_n': '0',
#   'nw_91_md': '0.0',
#   'q_min_s': '',
#   'n_tor_q4': '',
#   'n_tor_q1': '',
#   'n_tor_q2': '',
#   'n_tor_q3': '',
#   'tm_mes_min': '10.1',
#   'n_cub_max': '',
#   'nw_55_cv': '1.22',
#   'tm_min_min': '3.6',
#   'q_mar_max': '',
#   'nv_0100_q4': '',
#   'nv_0100_q1': '',
#   'nv_0100_q2': '',
#   'nv_0100_q3': '',
#   'q_max_q2': '',
#   'q_max_q3': '',
#   'q_max_q1': '',
#   'q_max_q4': '',
#   'nv_0100_cv': '',
#   'ts_10_q3': '',
#   'ts_10_q2': '',
#   'ts_10_q1': '',
#   'ts_10_q4': '',
#   'q_max_cv': '',
#   'ta_max_max': '28.1',
#   'np_010_cv': '0.49',
#   'ta_max_q4': '25.3',
#   'ta_max_q3': '24.1',
#   'ta_max_q2': '23.8',
#   'ta_max_q1': '22.5',
#   'np_010_min': '2.0',
#   'w_med_n': '23',
#   'nv_1000_q4': '',
#   'nv_1000_q2': '',
#   'n_nie_max': '',
#   'nv_1000_q1': '',
#   'nv_1000_cv': '',
#   'glo_max': '',
#   'n_fog_s': '',
#   'ti_max_q2': '9.6',
#   'n_fog_n': '1',
#   'n_nie_cv': '',
#   'np_001_min': '3.0',
#   'nw_55_q4': '2.0',
#   'n_fog_min': '',
#   'nw_55_q2': '1.0',
#   'nw_55_q3': '1.0',
#   'nw_55_q1': '0.0',
#   'hr_n': '24',
#   'hr_s': '4.84',
#   'q_med_s': '',
#   'nv_0050_max': '',
#   'ta_min_q2': '0.2',
#   'n_des_max': '',
#   'n_fog_mn': '',
#   'p_sol_max': '',
#   'np_001_s': '3.36',
#   'n_fog_md': '',
#   'q_min_cv': '',
#   'np_001_n': '23',
#   'e_max': '120.0',
#   'nt_00_md': '0.5',
#   'np_100_mn': '2.0',
#   'nt_30_q1': '0.0',
#   'nt_00_mn': '0.0',
#   'glo_q4': '',
#   'glo_q2': '',
#   'glo_q3': '',
#   'np_100_md': '2.2',
#   'inso_n': '0',
#   'q_med_q1': '',
#   'np_001_md': '9.3',
#   'np_001_mn': '9.0',
#   'ti_max_cv': '0.16',
#   'nv_1000_mn': '',
#   'nv_1000_md': '',
#   'evap_md': '',
#   'ta_min_max': '4.3',
#   'e_md': '98.0',
#   'e_mn': '95.0',
#   'nt_30_q3': '0.0',
#   'ti_max_md': '10.5',
#   'n_llu_n': '1',
#   'ti_max_mn': '10.2',
#   'glo_s': '',
#   'glo_n': '0',
#   'ts_min_cv': '0.17',
#   'n_llu_s': '',
#   'nv_0050_mn': '',
#   'n_nie_q3': '',
#   'n_nie_q2': '',
#   'n_nie_q4': '',
#   'glo_cv': '',
#   'tm_max_max': '19.9',
#   'ts_20_mn': '',
#   'tm_max_cv': '0.07',
#   'ts_20_md': '',
#   'np_001_cv': '0.36',
#   'p_max_mn': '36.0',
#   'nw_91_max': '0.0',
#   'p_max_md': '47.1',
#   'q_med_cv': '',
#   'ts_50_max': '',
#   'ts_50_min': '',
#   'ta_min_n': '26',
#   'e_q4': '105.0',
#   'e_q3': '100.0',
#   'e_q2': '94.0',
#   'e_q1': '92.0',
#   'glo_q1': '',
#   'w_racha_md': '15.2',
#   'q_min_min': '',
#   'ts_min_q3': '13.3',
#   'ts_min_q2': '11.8',
#   'ts_min_q1': '11.0',
#   'p_mes_max': '321.1',
#   'ts_min_q4': '13.7',
#   'q_mar_min': '',
#   'tm_max_q3': '17.8',
#   'tm_max_q2': '17.3',
#   'tm_max_q1': '16.5',
#   'p_mes_mn': '91.9',
#   'tm_max_q4': '18.8',
#   'n_gra_mn': '',
#   'tm_min_max': '8.1',
#   'np_001_q4': '13.0',
#   'np_001_q3': '9.2',
#   'np_001_q2': '8.8',
#   'np_001_q1': '7.0',
#   'ti_max_n': '26',
#   'w_med_md': '3.8',
#   'ti_max_q4': '12.2',
#   'ti_max_q3': '11.0',
#   'n_gra_q2': '',
#   'ti_max_q1': '8.9',
#   'ti_max_s': '1.73',
#   'q_med_q2': '',
#   'q_med_q3': '',
#   'nt_30_q2': '0.0',
#   'n_nie_min': '',
#   'nt_30_q4': '0.0',
#   'q_med_q4': '',
#   'n_cub_md': '',
#   'n_cub_mn': '',
#   'ta_max_min': '20.8',
#   'np_010_max': '11.0',
#   'inso_md': '',
#   'inso_mn': '',
#   'evap_mn': ''},
#  {'indicativo': 'B013X',
#   'w_racha_max': '16.4',
#   'np_010_n': '22',
#   'np_010_s': '2.98',
#   'q_max_s': '',
#   'n_tor_n': '1',
#   'n_tor_s': '',
#   'q_max_n': '0',
#   'tm_min_q4': '10.2',
#   'tm_min_q1': '7.7',
#   'tm_min_q3': '9.6',
#   'tm_min_q2': '9.1',
#   'q_mar_n': '0',
#   'n_des_min': '',
#   'q_mar_s': '',
#   'q_med_n': '0',
#   'ts_20_q1': '',
#   'ts_20_q2': '',
#   'e_cv': '0.09',
#   'ts_20_q4': '',
#   'e_min': '97.0',
#   'np_300_q4': '0.8',
#   'np_300_q1': '0.0',
#   'np_300_q3': '0.0',
#   'hr_max': '69.0',
#   'np_300_cv': '2.22',
#   'n_nub_max': '',
#   'tm_min_cv': '0.15',
#   'n_des_mn': '',
#   'n_des_md': '',
#   'ts_20_s': '',
#   'q_med_mn': '',
#   'evap_cv': '',
#   'q_med_md': '',
#   'nt_30_cv': '1.76',
#   'mes': '05',
#   'ts_20_cv': '',
#   'inso_max': '',
#   'ts_20_max': '',
#   'np_001_max': '14.0',
#   'n_llu_md': '',
#   'nv_1000_s': '',
#   'ta_min_mn': '3.9',
#   'tm_mes_max': '18.4',
#   'ta_max_mn': '28.0',
#   'nv_1000_n': '0',
#   'ta_max_md': '28.5',
#   'nw_91_min': '0.0',
#   'ta_max_n': '23',
#   'ta_max_s': '3.44',
#   'ts_10_md': '',
#   'nw_55_mn': '0.0',
#   'ta_min_s': '2.0',
#   'nw_55_md': '0.3',
#   'np_300_mn': '0.0',
#   'evap_q4': '',
#   'evap_q1': '',
#   'np_300_md': '0.5',
#   'evap_q3': '',
#   'evap_q2': '',
#   'p_mes_min': '5.4',
#   'ts_min_min': '11.8',
#   'n_des_s': '',
#   'nv_0100_mn': '',
#   'p_mes_md': '70.6',
#   'n_tor_cv': '',
#   'nv_0100_md': '',
#   'q_min_max': '',
#   'n_des_n': '0',
#   'p_sol_s': '',
#   'ts_20_n': '0',
#   'ts_10_cv': '',
#   'nw_91_s': '0.0',
#   'nw_91_n': '21',
#   'nt_00_min': '0.0',
#   'p_sol_n': '0',
#   'n_nie_mn': '',
#   'n_nub_n': '0',
#   'n_nie_md': '',
#   'tm_mes_md': '15.4',
#   'p_sol_cv': '',
#   'n_nub_s': '',
#   'w_racha_min': '10.6',
#   'np_300_max': '4.0',
#   'nv_0050_md': '',
#   'ta_min_min': '0.6',
#   'glo_mn': '',
#   'inso_s': '',
#   'glo_md': '',
#   'n_nie_q1': '',
#   'w_med_q4': '5.0',
#   'n_tor_max': '',
#   'w_med_q2': '4.0',
#   'w_med_q3': '4.0',
#   'n_gra_md': '',
#   'inso_q4': '',
#   'q_max_min': '',
#   'ts_10_max': '',
#   'nt_30_min': '0.0',
#   'n_nub_cv': '',
#   'p_mes_n': '22',
#   'p_mes_q1': '12.3',
#   'p_mes_q2': '28.7',
#   'p_mes_q3': '43.9',
#   'p_mes_q4': '81.4',
#   'hr_cv': '0.08',
#   'n_tor_md': '',
#   'p_mes_s': '94.66',
#   'nw_91_cv': '-',
#   'n_tor_mn': '',
#   'nv_1000_max': '',
#   'n_gra_cv': '',
#   'w_racha_n': '21',
#   'w_med_min': '3.0',
#   'w_racha_s': '1.74',
#   'np_100_max': '7.0',
#   'e_s': '11.31',
#   'w_med_s': '0.93',
#   'p_sol_md': '',
#   'n_cub_q4': '',
#   'n_cub_q3': '',
#   'n_cub_q2': '',
#   'n_cub_q1': '',
#   'nw_55_max': '2.0',
#   'p_sol_mn': '',
#   'n_cub_s': '',
#   'hr_mn': '61.0',
#   'q_med_max': '',
#   'hr_md': '61.0',
#   'np_010_md': '4.4',
#   'n_cub_n': '0',
#   'np_010_mn': '4.0',
#   'nw_91_q4': '0.0',
#   'p_max_n': '22',
#   'nw_91_q2': '0.0',
#   'nw_91_q3': '0.0',
#   'nw_91_q1': '0.0',
#   'n_gra_q4': '',
#   'n_gra_q1': '',
#   'n_gra_q3': '',
#   'nw_55_s': '0.64',
#   'nw_55_n': '21',
#   'w_med_mn': '4.0',
#   'n_nub_min': '',
#   'p_max_s': '55.15',
#   'ts_20_min': '',
#   'inso_min': '',
#   'n_gra_max': '',
#   'p_sol_q1': '',
#   'p_sol_q3': '',
#   'p_sol_q2': '',
#   'p_sol_q4': '',
#   'n_fog_q1': '',
#   'ta_min_md': '4.1',
#   'n_fog_q3': '',
#   'n_fog_q2': '',
#   'n_fog_q4': '',
#   'w_med_cv': '0.23',
#   'p_max_max': '234.4',
#   'e_n': '23',
#   'q_min_md': '',
#   'n_fog_cv': '',
#   'p_mes_cv': '1.34',
#   'nv_0100_max': '',
#   'np_300_q2': '0.0',
#   'q_min_mn': '',
#   'ti_max_min': '7.7',
#   'np_100_cv': '0.98',
#   'hr_q3': '64.0',
#   'hr_q2': '59.0',
#   'hr_q1': '57.0',
#   'nv_0050_s': '',
#   'hr_q4': '66.0',
#   'evap_s': '',
#   'w_med_q1': '3.0',
#   'evap_n': '0',
#   'nv_0050_n': '0',
#   'nv_0050_q2': '',
#   'nv_0050_q3': '',
#   'q_max_md': '',
#   'nv_0050_q1': '',
#   'nv_0050_q4': '',
#   'q_max_mn': '',
#   'n_llu_min': '',
#   'ts_min_max': '24.2',
#   'evap_max': '',
#   'ta_min_q1': '2.6',
#   'ta_min_q3': '4.1',
#   'n_cub_cv': '',
#   'ta_min_q4': '5.3',
#   'tm_mes_n': '23',
#   'tm_max_s': '2.21',
#   'nt_30_md': '0.8',
#   'tm_max_n': '23',
#   'tm_mes_s': '1.7',
#   'nt_30_mn': '0.0',
#   'ts_50_q4': '',
#   'ts_50_q3': '',
#   'ts_50_q2': '',
#   'ts_50_q1': '',
#   'q_mar_mn': '',
#   'np_100_q4': '3.0',
#   'np_100_q3': '2.0',
#   'np_100_q2': '1.0',
#   'np_100_q1': '0.0',
#   'n_des_cv': '',
#   'q_mar_md': '',
#   'tm_mes_q4': '16.7',
#   'tm_mes_q2': '14.9',
#   'tm_mes_q3': '16.0',
#   'np_300_min': '0.0',
#   'p_sol_min': '',
#   'n_cub_min': '',
#   'n_gra_s': '',
#   'w_racha_mn': '13.3',
#   'p_max_cv': '1.52',
#   'n_des_q4': '',
#   'n_des_q1': '',
#   'n_des_q3': '',
#   'n_des_q2': '',
#   'ti_max_max': '19.4',
#   'n_gra_n': '1',
#   'tm_min_n': '23',
#   'nt_30_max': '5.0',
#   'q_max_max': '',
#   'tm_min_s': '1.39',
#   'nt_00_n': '23',
#   'nv_0050_min': '',
#   'ts_10_s': '',
#   'n_nub_q4': '',
#   'n_nub_q1': '',
#   'n_nub_q2': '',
#   'n_nub_q3': '',
#   'ts_50_s': '',
#   'ts_10_n': '0',
#   'nt_00_s': '0.0',
#   'ts_10_min': '',
#   'tm_mes_mn': '15.8',
#   'np_100_min': '0.0',
#   'nv_1000_min': '',
#   'nt_30_s': '1.38',
#   'nt_00_q3': '0.0',
#   'nt_00_q2': '0.0',
#   'nt_00_q1': '0.0',
#   'n_tor_min': '',
#   'nt_00_q4': '0.0',
#   'ts_20_q3': '',
#   'nt_00_max': '0.0',
#   'nw_55_min': '0.0',
#   'n_llu_mn': '',
#   'ts_50_mn': '',
#   'glo_min': '',
#   'ts_50_md': '',
#   'q_med_min': '',
#   'nv_0050_cv': '',
#   'inso_q2': '',
#   'inso_q3': '',
#   'inso_q1': '',
#   'n_fog_max': '',
#   'np_100_s': '1.74',
#   'np_300_s': '1.01',
#   'ta_min_cv': '0.49',
#   'tm_mes_cv': '0.11',
#   'ts_min_md': '15.2',
#   'ts_min_mn': '14.5',
#   'inso_cv': '',
#   'np_300_n': '22',
#   'np_100_n': '22',
#   'ts_min_n': '23',
#   'tm_max_md': '21.6',
#   'tm_max_mn': '21.9',
#   'ts_min_s': '2.83',
#   'tm_mes_q1': '13.8',
#   'p_max_q1': '6.7',
#   'p_max_q3': '22.6',
#   'p_max_q2': '13.7',
#   'p_max_q4': '32.9',
#   'n_nie_s': '',
#   'n_gra_min': '',
#   'nt_30_n': '23',
#   'n_nie_n': '1',
#   'ts_50_n': '0',
#   'nv_0100_min': '',
#   'q_mar_q1': '',
#   'q_mar_q2': '',
#   'q_mar_q3': '',
#   'q_mar_q4': '',
#   'p_max_min': '1.8',
#   'n_llu_cv': '',
#   'n_nub_mn': '',
#   'w_racha_q1': '12.2',
#   'w_racha_q3': '13.6',
#   'w_racha_q2': '13.1',
#   'n_nub_md': '',
#   'w_racha_q4': '14.4',
#   'nt_00_cv': '-',
#   'np_010_q4': '6.8',
#   'np_010_q1': '2.0',
#   'np_010_q3': '4.0',
#   'np_010_q2': '3.0',
#   'nv_1000_q3': '',
#   'ts_50_cv': '',
#   'nv_0100_s': '',
#   'n_llu_max': '',
#   'tm_max_min': '18.1',
#   'tm_min_md': '9.2',
#   'q_mar_cv': '',
#   'nv_0100_n': '0',
#   'tm_min_mn': '9.3',
#   'ts_10_mn': '',
#   'w_racha_cv': '0.13',
#   'evap_min': '',
#   'ta_max_cv': '0.12',
#   'n_llu_q4': '',
#   'n_llu_q2': '',
#   'n_llu_q3': '',
#   'n_llu_q1': '',
#   'q_min_q4': '',
#   'hr_min': '52.0',
#   'w_med_max': '6.0',
#   'nw_91_mn': '0.0',
#   'q_min_q1': '',
#   'q_min_q2': '',
#   'q_min_q3': '',
#   'q_min_n': '0',
#   'nw_91_md': '0.0',
#   'q_min_s': '',
#   'n_tor_q4': '',
#   'n_tor_q1': '',
#   'n_tor_q2': '',
#   'n_tor_q3': '',
#   'tm_mes_min': '12.9',
#   'n_cub_max': '',
#   'nw_55_cv': '2.25',
#   'tm_min_min': '7.1',
#   'q_mar_max': '',
#   'nv_0100_q4': '',
#   'nv_0100_q1': '',
#   'nv_0100_q2': '',
#   'nv_0100_q3': '',
#   'q_max_q2': '',
#   'q_max_q3': '',
#   'q_max_q1': '',
#   'q_max_q4': '',
#   'nv_0100_cv': '',
#   'ts_10_q3': '',
#   'ts_10_q2': '',
#   'ts_10_q1': '',
#   'ts_10_q4': '',
#   'q_max_cv': '',
#   'ta_max_max': '36.3',
#   'np_010_cv': '0.68',
#   'ta_max_q4': '31.5',
#   'ta_max_q3': '28.8',
#   'ta_max_q2': '27.1',
#   'ta_max_q1': '25.4',
#   'np_010_min': '1.0',
#   'w_med_n': '25',
#   'nv_1000_q4': '',
#   'nv_1000_q2': '',
#   'n_nie_max': '',
#   'nv_1000_q1': '',
#   'nv_1000_cv': '',
#   'glo_max': '',
#   'n_fog_s': '',
#   'ti_max_q2': '12.8',
#   'n_fog_n': '1',
#   'n_nie_cv': '',
#   'np_001_min': '3.0',
#   'nw_55_q4': '0.0',
#   'n_fog_min': '',
#   'nw_55_q2': '0.0',
#   'nw_55_q3': '0.0',
#   'nw_55_q1': '0.0',
#   'hr_n': '21',
#   'hr_s': '4.88',
#   'q_med_s': '',
#   'nv_0050_max': '',
#   'ta_min_q2': '3.6',
#   'n_des_max': '',
#   'n_fog_mn': '',
#   'p_sol_max': '',
#   'np_001_s': '3.07',
#   'n_fog_md': '',
#   'q_min_cv': '',
#   'np_001_n': '22',
#   'e_max': '148.0',
#   'nt_00_md': '0.0',
#   'np_100_mn': '1.5',
#   'nt_30_q1': '0.0',
#   'nt_00_mn': '0.0',
#   'glo_q4': '',
#   'glo_q2': '',
#   'glo_q3': '',
#   'np_100_md': '1.8',
#   'inso_n': '0',
#   'q_med_q1': '',
#   'np_001_md': '7.0',
#   'np_001_mn': '6.5',
#   'ti_max_cv': '0.21',
#   'nv_1000_mn': '',
#   'nv_1000_md': '',
#   'evap_md': '',
#   'ta_min_max': '8.5',
#   'e_md': '120.0',
#   'e_mn': '120.0',
#   'nt_30_q3': '0.0',
#   'ti_max_md': '13.6',
#   'n_llu_n': '1',
#   'ti_max_mn': '13.6',
#   'glo_s': '',
#   'glo_n': '0',
#   'ts_min_cv': '0.19',
#   'n_llu_s': '',
#   'nv_0050_mn': '',
#   'n_nie_q3': '',
#   'n_nie_q2': '',
#   'n_nie_q4': '',
#   'glo_cv': '',
#   'tm_max_max': '25.4',
#   'ts_20_mn': '',
#   'tm_max_cv': '0.1',
#   'ts_20_md': '',
#   'np_001_cv': '0.44',
#   'p_max_mn': '19.3',
#   'nw_91_max': '0.0',
#   'p_max_md': '36.2',
#   'q_med_cv': '',
#   'ts_50_max': '',
#   'ts_50_min': '',
#   'ta_min_n': '23',
#   'e_q4': '126.0',
#   'e_q3': '121.0',
#   'e_q2': '119.0',
#   'e_q1': '111.0',
#   'glo_q1': '',
#   'w_racha_md': '13.4',
#   'q_min_min': '',
#   'ts_min_q3': '15.6',
#   'ts_min_q2': '13.9',
#   'ts_min_q1': '12.8',
#   'p_mes_max': '365.2',
#   'ts_min_q4': '16.5',
#   'q_mar_min': '',
#   'tm_max_q3': '22.6',
#   'tm_max_q2': '20.8',
#   'tm_max_q1': '19.3',
#   'p_mes_mn': '39.8',
#   'tm_max_q4': '23.5',
#   'n_gra_mn': '',
#   'tm_min_max': '11.5',
#   'np_001_q4': '9.8',
#   'np_001_q3': '7.0',
#   'np_001_q2': '6.0',
#   'np_001_q1': '4.2',
#   'ti_max_n': '23',
#   'w_med_md': '4.0',
#   'ti_max_q4': '15.1',
#   'ti_max_q3': '13.9',
#   'n_gra_q2': '',
#   'ti_max_q1': '11.3',
#   'ti_max_s': '2.81',
#   'q_med_q2': '',
#   'q_med_q3': '',
#   'nt_30_q2': '0.0',
#   'n_nie_min': '',
#   'nt_30_q4': '2.0',
#   'q_med_q4': '',
#   'n_cub_md': '',
#   'n_cub_mn': '',
#   'ta_max_min': '23.8',
#   'np_010_max': '14.0',
#   'inso_md': '',
#   'inso_mn': '',
#   'evap_mn': ''},
#  {'indicativo': 'B013X',
#   'w_racha_max': '19.7',
#   'np_010_n': '19',
#   'np_010_s': '1.82',
#   'q_max_s': '',
#   'n_tor_n': '1',
#   'n_tor_s': '',
#   'q_max_n': '0',
#   'tm_min_q4': '13.7',
#   'tm_min_q1': '12.1',
#   'tm_min_q3': '13.2',
#   'tm_min_q2': '12.5',
#   'q_mar_n': '0',
#   'n_des_min': '',
#   'q_mar_s': '',
#   'q_med_n': '0',
#   'ts_20_q1': '',
#   'ts_20_q2': '',
#   'e_cv': '0.07',
#   'ts_20_q4': '',
#   'e_min': '127.0',
#   'np_300_q4': '0.0',
#   'np_300_q1': '0.0',
#   'np_300_q3': '0.0',
#   'hr_max': '68.0',
#   'np_300_cv': '2.54',
#   'n_nub_max': '',
#   'tm_min_cv': '0.09',
#   'n_des_mn': '',
#   'n_des_md': '',
#   'ts_20_s': '',
#   'q_med_mn': '',
#   'evap_cv': '',
#   'q_med_md': '',
#   'nt_30_cv': '0.68',
#   'mes': '06',
#   'ts_20_cv': '',
# ...
#   'hr_cv': '0.05',
#   'n_tor_md': '',
#   'p_mes_s': '170.46',
#   'nw_91_cv': '',
#   'n_tor_mn': '',
#   'nv_1000_max': '',
#   'n_gra_cv': '',
#   'w_racha_n': '14',
#   'w_med_min': '1.0',
#   'w_racha_s': '',
#   'np_100_max': '9.0',
#   'e_s': '6.94',
#   'w_med_s': '1.09',
#   'p_sol_md': '',
#   'n_cub_q4': '',
#   'n_cub_q3': '',
#   'n_cub_q2': '',
#   'n_cub_q1': '',
#   'nw_55_max': '',
#   'p_sol_mn': '',
#   'n_cub_s': '',
#   'hr_mn': '80.0',
#   'q_med_max': '',
#   'hr_md': '78.0',
#   'np_010_md': '8.1',
#   'n_cub_n': '0',
#   'np_010_mn': '9.0',
#   'nw_91_q4': '',
#   'p_max_n': '19',
#   'nw_91_q2': '',
#   'nw_91_q3': '',
#   'nw_91_q1': '',
#   'n_gra_q4': '',
#   'n_gra_q1': '',
#   'n_gra_q3': '',
#   'nw_55_s': '',
#   'nw_55_n': '14',
#   'w_med_mn': '3.0',
#   'n_nub_min': '',
#   'p_max_s': '85.76',
#   'ts_20_min': '',
#   'inso_min': '',
#   'n_gra_max': '',
#   'p_sol_q1': '',
#   'p_sol_q3': '',
#   'p_sol_q2': '',
#   'p_sol_q4': '',
#   'n_fog_q1': '',
#   'ta_min_md': '-1.5',
#   'n_fog_q3': '',
#   'n_fog_q2': '',
#   'n_fog_q4': '',
#   'w_med_cv': '0.37',
#   'p_max_max': '276.2',
#   'e_n': '23',
#   'q_min_md': '',
#   'n_fog_cv': '',
#   'p_mes_cv': '1.05',
#   'nv_0100_max': '',
#   'np_300_q2': '1.0',
#   'q_min_mn': '',
#   'ti_max_min': '2.4',
#   'np_100_cv': '0.76',
#   'hr_q3': '80.0',
#   'hr_q2': '79.0',
#   'hr_q1': '73.0',
#   'nv_0050_s': '',
#   'hr_q4': '81.0',
#   'evap_s': '',
#   'w_med_q1': '2.0',
#   'evap_n': '0',
#   'nv_0050_n': '0',
#   'nv_0050_q2': '',
#   'nv_0050_q3': '',
#   'q_max_md': '',
#   'nv_0050_q1': '',
#   'nv_0050_q4': '',
#   'q_max_mn': '',
#   'n_llu_min': '',
#   'ts_min_max': '16.8',
#   'evap_max': '',
#   'ta_min_q1': '-2.3',
#   'ta_min_q3': '-1.1',
#   'n_cub_cv': '',
#   'ta_min_q4': '-0.8',
#   'tm_mes_n': '23',
#   'tm_max_s': '1.58',
#   'nt_30_md': '0.0',
#   'tm_max_n': '23',
#   'tm_mes_s': '1.32',
#   'nt_30_mn': '0.0',
#   'ts_50_q4': '',
#   'ts_50_q3': '',
#   'ts_50_q2': '',
#   'ts_50_q1': '',
#   'q_mar_mn': '',
#   'np_100_q4': '5.0',
#   'np_100_q3': '3.0',
#   'np_100_q2': '2.0',
#   'np_100_q1': '1.0',
#   'n_des_cv': '',
#   'q_mar_md': '',
#   'tm_mes_q4': '9.4',
#   'tm_mes_q2': '8.6',
#   'tm_mes_q3': '8.9',
#   'np_300_min': '0.0',
#   'p_sol_min': '',
#   'n_cub_min': '',
#   'n_gra_s': '',
#   'w_racha_mn': '',
#   'p_max_cv': '1.12',
#   'n_des_q4': '',
#   'n_des_q1': '',
#   'n_des_q3': '',
#   'n_des_q2': '',
#   'ti_max_max': '12.4',
#   'n_gra_n': '0',
#   'tm_min_n': '23',
#   'nt_30_max': '0.0',
#   'q_max_max': '',
#   'tm_min_s': '1.65',
#   'nt_00_n': '23',
#   'nv_0050_min': '',
#   'ts_10_s': '',
#   'n_nub_q4': '',
#   'n_nub_q1': '',
#   'n_nub_q2': '',
#   'n_nub_q3': '',
#   'ts_50_s': '',
#   'ts_10_n': '0',
#   'nt_00_s': '4.72',
#   'ts_10_min': '',
#   'tm_mes_mn': '8.7',
#   'np_100_min': '0.0',
#   'nv_1000_min': '',
#   'nt_30_s': '0.0',
#   'nt_00_q3': '4.2',
#   'nt_00_q2': '2.8',
#   'nt_00_q1': '1.4',
#   'n_tor_min': '',
#   'nt_00_q4': '6.8',
#   'ts_20_q3': '',
#   'nt_00_max': '22.0',
#   'nw_55_min': '',
#   'n_llu_mn': '',
#   'ts_50_mn': '',
#   'glo_min': '',
#   'ts_50_md': '',
#   'q_med_min': '',
#   'nv_0050_cv': '',
#   'inso_q2': '',
#   'inso_q3': '',
#   'inso_q1': '',
#   'n_fog_max': '',
#   'np_100_s': '2.52',
#   'np_300_s': '1.87',
#   'ta_min_cv': '-1.0',
#   'tm_mes_cv': '0.16',
#   'ts_min_md': '10.3',
#   'ts_min_mn': '10.6',
#   'inso_cv': '',
#   'np_300_n': '19',
#   'np_100_n': '19',
#   'ts_min_n': '23',
#   'tm_max_md': '13.4',
#   'tm_max_mn': '13.4',
#   'ts_min_s': '3.53',
#   'tm_mes_q1': '7.7',
#   'p_max_q1': '20.4',
#   'p_max_q3': '51.4',
#   'p_max_q2': '35.8',
#   'p_max_q4': '109.8',
#   'n_nie_s': '',
#   'n_gra_min': '',
#   'nt_30_n': '23',
#   'n_nie_n': '0',
#   'ts_50_n': '0',
#   'nv_0100_min': '',
#   'q_mar_q1': '',
#   'q_mar_q2': '',
#   'q_mar_q3': '',
#   'q_mar_q4': '',
#   'p_max_min': '0.0',
#   'n_llu_cv': '',
#   'n_nub_mn': '',
#   'w_racha_q1': '',
#   'w_racha_q3': '',
#   'w_racha_q2': '',
#   'n_nub_md': '',
#   'w_racha_q4': '',
#   'nt_00_cv': '1.00',
#   'np_010_q4': '11.4',
#   'np_010_q1': '4.2',
#   'np_010_q3': '9.0',
#   'np_010_q2': '7.4',
#   'nv_1000_q3': '',
#   'ts_50_cv': '',
#   'nv_0100_s': '',
#   'n_llu_max': '',
#   'tm_max_min': '10.1',
#   'tm_min_md': '3.6',
#   'q_mar_cv': '',
#   'nv_0100_n': '0',
#   'tm_min_mn': '3.9',
#   'ts_10_mn': '',
#   'w_racha_cv': '',
#   'evap_min': '',
#   'ta_max_cv': '0.08',
#   'n_llu_q4': '',
#   'n_llu_q2': '',
#   'n_llu_q3': '',
#   'n_llu_q1': '',
#   'q_min_q4': '',
#   'hr_min': '72.0',
#   'w_med_max': '5.0',
#   'nw_91_mn': '',
#   'q_min_q1': '',
#   'q_min_q2': '',
#   'q_min_q3': '',
#   'q_min_n': '0',
#   'nw_91_md': '',
#   'q_min_s': '',
#   'n_tor_q4': '',
#   'n_tor_q1': '',
#   'n_tor_q2': '',
#   'n_tor_q3': '',
#   'tm_mes_min': '4.4',
#   'n_cub_max': '',
#   'nw_55_cv': '',
#   'tm_min_min': '-1.2',
#   'q_mar_max': '',
#   'nv_0100_q4': '',
#   'nv_0100_q1': '',
#   'nv_0100_q2': '',
#   'nv_0100_q3': '',
#   'q_max_q2': '',
#   'q_max_q3': '',
#   'q_max_q1': '',
#   'q_max_q4': '',
#   'nv_0100_cv': '',
#   'ts_10_q3': '',
#   'ts_10_q2': '',
#   'ts_10_q1': '',
#   'ts_10_q4': '',
#   'q_max_cv': '',
#   'ta_max_max': '23.6',
#   'np_010_cv': '0.53',
#   'ta_max_q4': '20.0',
#   'ta_max_q3': '19.5',
#   'ta_max_q2': '19.0',
#   'ta_max_q1': '17.9',
#   'np_010_min': '0.0',
#   'w_med_n': '17',
#   'nv_1000_q4': '',
#   'nv_1000_q2': '',
#   'n_nie_max': '',
#   'nv_1000_q1': '',
#   'nv_1000_cv': '',
#   'glo_max': '',
#   'n_fog_s': '',
#   'ti_max_q2': '6.3',
#   'n_fog_n': '0',
#   'n_nie_cv': '',
#   'np_001_min': '0.0',
#   'nw_55_q4': '',
#   'n_fog_min': '',
#   'nw_55_q2': '',
#   'nw_55_q3': '',
#   'nw_55_q1': '',
#   'hr_n': '22',
#   'hr_s': '3.67',
#   'q_med_s': '',
#   'nv_0050_max': '',
#   'ta_min_q2': '-1.3',
#   'n_des_max': '',
#   'n_fog_mn': '',
#   'p_sol_max': '',
#   'np_001_s': '5.53',
#   'n_fog_md': '',
#   'q_min_cv': '',
#   'np_001_n': '19',
#   'e_max': '99.0',
#   'nt_00_md': '4.7',
#   'np_100_mn': '3.0',
#   'nt_30_q1': '0.0',
#   'nt_00_mn': '4.0',
#   'glo_q4': '',
#   'glo_q2': '',
#   'glo_q3': '',
#   'np_100_md': '3.3',
#   'inso_n': '0',
#   'q_med_q1': '',
#   'np_001_md': '11.5',
#   'np_001_mn': '11.0',
#   'ti_max_cv': '0.35',
#   'nv_1000_mn': '',
#   'nv_1000_md': '',
#   'evap_md': '',
#   'ta_min_max': '0.5',
#   'e_md': '87.0',
#   'e_mn': '88.0',
#   'nt_30_q3': '0.0',
#   'ti_max_md': '7.3',
#   'n_llu_n': '0',
#   'ti_max_mn': '6.8',
#   'glo_s': '',
#   'glo_n': '0',
#   'ts_min_cv': '0.34',
#   'n_llu_s': '',
#   'nv_0050_mn': '',
#   'n_nie_q3': '',
#   'n_nie_q2': '',
#   'n_nie_q4': '',
#   'glo_cv': '',
#   'tm_max_max': '16.3',
#   'ts_20_mn': '',
#   'tm_max_cv': '0.12',
#   'ts_20_md': '',
#   'np_001_cv': '0.48',
#   'p_max_mn': '41.2',
#   'nw_91_max': '',
#   'p_max_md': '76.5',
#   'q_med_cv': '',
#   'ts_50_max': '',
#   'ts_50_min': '',
#   'ta_min_n': '23',
#   'e_q4': '92.0',
#   'e_q3': '90.0',
#   'e_q2': '86.0',
#   'e_q1': '82.0',
#   'glo_q1': '',
#   'w_racha_md': '',
#   'q_min_min': '',
#   'ts_min_q3': '10.9',
#   'ts_min_q2': '10.0',
#   'ts_min_q1': '7.0',
#   'p_mes_max': '561.5',
#   'ts_min_q4': '13.5',
#   'q_mar_min': '',
#   'tm_max_q3': '13.9',
#   'tm_max_q2': '13.0',
#   'tm_max_q1': '12.2',
#   'p_mes_mn': '104.0',
#   'tm_max_q4': '14.4',
#   'n_gra_mn': '',
#   'tm_min_max': '5.9',
#   'np_001_q4': '15.4',
#   'np_001_q3': '13.8',
#   'np_001_q2': '11.0',
#   'np_001_q1': '7.6',
#   'ti_max_n': '23',
#   'w_med_md': '2.9',
#   'ti_max_q4': '9.3',
#   'ti_max_q3': '7.7',
#   'n_gra_q2': '',
#   'ti_max_q1': '5.3',
#   'ti_max_s': '2.52',
#   'q_med_q2': '',
#   'q_med_q3': '',
#   'nt_30_q2': '0.0',
#   'n_nie_min': '',
#   'nt_30_q4': '0.0',
#   'q_med_q4': '',
#   'n_cub_md': '',
#   'n_cub_mn': '',
#   'ta_max_min': '15.9',
#   'np_010_max': '16.0',
#   'inso_md': '',
#   'inso_mn': '',
#   'evap_mn': ''},
#  {'indicativo': 'B013X',
#   'w_racha_max': '',
#   'np_010_n': '7',
#   'np_010_s': '',
#   'q_max_s': '',
#   'n_tor_n': '0',
#   'n_tor_s': '',
#   'q_max_n': '0',
#   'tm_min_q4': '',
#   'tm_min_q1': '',
#   'tm_min_q3': '',
#   'tm_min_q2': '',
#   'q_mar_n': '0',
#   'n_des_min': '',
#   'q_mar_s': '',
#   'q_med_n': '0',
#   'ts_20_q1': '',
#   'ts_20_q2': '',
#   'e_cv': '',
#   'ts_20_q4': '',
#   'e_min': '',
#   'np_300_q4': '',
#   'np_300_q1': '',
#   'np_300_q3': '',
#   'hr_max': '',
#   'np_300_cv': '',
#   'n_nub_max': '',
#   'tm_min_cv': '',
#   'n_des_mn': '',
#   'n_des_md': '',
#   'ts_20_s': '',
#   'q_med_mn': '',
#   'evap_cv': '',
#   'q_med_md': '',
#   'nt_30_cv': '',
#   'mes': '13',
#   'ts_20_cv': '',
#   'inso_max': '',
#   'ts_20_max': '',
#   'np_001_max': '',
#   'n_llu_md': '',
#   'nv_1000_s': '',
#   'ta_min_mn': '',
#   'tm_mes_max': '',
#   'ta_max_mn': '',
#   'nv_1000_n': '0',
#   'ta_max_md': '',
#   'nw_91_min': '',
#   'ta_max_n': '13',
#   'ta_max_s': '',
#   'ts_10_md': '',
#   'nw_55_mn': '',
#   'ta_min_s': '',
#   'nw_55_md': '',
#   'np_300_mn': '',
#   'evap_q4': '',
#   'evap_q1': '',
#   'np_300_md': '',
#   'evap_q3': '',
#   'evap_q2': '',
#   'p_mes_min': '',
#   'ts_min_min': '',
#   'n_des_s': '',
#   'nv_0100_mn': '',
#   'p_mes_md': '',
#   'n_tor_cv': '',
#   'nv_0100_md': '',
#   'q_min_max': '',
#   'n_des_n': '0',
#   'p_sol_s': '',
#   'ts_20_n': '0',
#   'ts_10_cv': '',
#   'nw_91_s': '',
#   'nw_91_n': '3',
#   'nt_00_min': '',
#   'p_sol_n': '0',
#   'n_nie_mn': '',
#   'n_nub_n': '0',
#   'n_nie_md': '',
#   'tm_mes_md': '',
#   'p_sol_cv': '',
#   'n_nub_s': '',
#   'w_racha_min': '',
#   'np_300_max': '',
#   'nv_0050_md': '',
#   'ta_min_min': '',
#   'glo_mn': '',
#   'inso_s': '',
#   'glo_md': '',
#   'n_nie_q1': '',
#   'w_med_q4': '',
#   'n_tor_max': '',
#   'w_med_q2': '',
#   'w_med_q3': '',
#   'n_gra_md': '',
#   'inso_q4': '',
#   'q_max_min': '',
#   'ts_10_max': '',
#   'nt_30_min': '',
#   'n_nub_cv': '',
#   'p_mes_n': '7',
#   'p_mes_q1': '',
#   'p_mes_q2': '',
#   'p_mes_q3': '',
#   'p_mes_q4': '',
#   'hr_cv': '',
#   'n_tor_md': '',
#   'p_mes_s': '',
#   'nw_91_cv': '',
#   'n_tor_mn': '',
#   'nv_1000_max': '',
#   'n_gra_cv': '',
#   'w_racha_n': '3',
#   'w_med_min': '',
#   'w_racha_s': '',
#   'np_100_max': '',
#   'e_s': '',
#   'w_med_s': '',
#   'p_sol_md': '',
#   'n_cub_q4': '',
#   'n_cub_q3': '',
#   'n_cub_q2': '',
#   'n_cub_q1': '',
#   'nw_55_max': '',
#   'p_sol_mn': '',
#   'n_cub_s': '',
#   'hr_mn': '',
#   'q_med_max': '',
#   'hr_md': '',
#   'np_010_md': '',
#   'n_cub_n': '0',
#   'np_010_mn': '',
#   'nw_91_q4': '',
#   'p_max_n': '7',
#   'nw_91_q2': '',
#   'nw_91_q3': '',
#   'nw_91_q1': '',
#   'n_gra_q4': '',
#   'n_gra_q1': '',
#   'n_gra_q3': '',
#   'nw_55_s': '',
#   'nw_55_n': '3',
#   'w_med_mn': '',
#   'n_nub_min': '',
#   'p_max_s': '',
#   'ts_20_min': '',
#   'inso_min': '',
#   'n_gra_max': '',
#   'p_sol_q1': '',
#   'p_sol_q3': '',
#   'p_sol_q2': '',
#   'p_sol_q4': '',
#   'n_fog_q1': '',
#   'ta_min_md': '',
#   'n_fog_q3': '',
#   'n_fog_q2': '',
#   'n_fog_q4': '',
#   'w_med_cv': '',
#   'p_max_max': '',
#   'e_n': '8',
#   'q_min_md': '',
#   'n_fog_cv': '',
#   'p_mes_cv': '',
#   'nv_0100_max': '',
#   'np_300_q2': '',
#   'q_min_mn': '',
#   'ti_max_min': '',
#   'np_100_cv': '',
#   'hr_q3': '',
#   'hr_q2': '',
#   'hr_q1': '',
#   'nv_0050_s': '',
#   'hr_q4': '',
#   'evap_s': '',
#   'w_med_q1': '',
#   'evap_n': '0',
#   'nv_0050_n': '0',
#   'nv_0050_q2': '',
#   'nv_0050_q3': '',
#   'q_max_md': '',
#   'nv_0050_q1': '',
#   'nv_0050_q4': '',
#   'q_max_mn': '',
#   'n_llu_min': '',
#   'ts_min_max': '',
#   'evap_max': '',
#   'ta_min_q1': '',
#   'ta_min_q3': '',
#   'n_cub_cv': '',
#   'ta_min_q4': '',
#   'tm_mes_n': '13',
#   'tm_max_s': '',
#   'nt_30_md': '',
#   'tm_max_n': '13',
#   'tm_mes_s': '',
#   'nt_30_mn': '',
#   'ts_50_q4': '',
#   'ts_50_q3': '',
#   'ts_50_q2': '',
#   'ts_50_q1': '',
#   'q_mar_mn': '',
#   'np_100_q4': '',
#   'np_100_q3': '',
#   'np_100_q2': '',
#   'np_100_q1': '',
#   'n_des_cv': '',
#   'q_mar_md': '',
#   'tm_mes_q4': '',
#   'tm_mes_q2': '',
#   'tm_mes_q3': '',
#   'np_300_min': '',
#   'p_sol_min': '',
#   'n_cub_min': '',
#   'n_gra_s': '',
#   'w_racha_mn': '',
#   'p_max_cv': '',
#   'n_des_q4': '',
#   'n_des_q1': '',
#   'n_des_q3': '',
#   'n_des_q2': '',
#   'ti_max_max': '',
#   'n_gra_n': '0',
#   'tm_min_n': '13',
#   'nt_30_max': '',
#   'q_max_max': '',
#   'tm_min_s': '',
#   'nt_00_n': '13',
#   'nv_0050_min': '',
#   'ts_10_s': '',
#   'n_nub_q4': '',
#   'n_nub_q1': '',
#   'n_nub_q2': '',
#   'n_nub_q3': '',
#   'ts_50_s': '',
#   'ts_10_n': '0',
#   'nt_00_s': '',
#   'ts_10_min': '',
#   'tm_mes_mn': '',
#   'np_100_min': '',
#   'nv_1000_min': '',
#   'nt_30_s': '',
#   'nt_00_q3': '',
#   'nt_00_q2': '',
#   'nt_00_q1': '',
#   'n_tor_min': '',
#   'nt_00_q4': '',
#   'ts_20_q3': '',
#   'nt_00_max': '',
#   'nw_55_min': '',
#   'n_llu_mn': '',
#   'ts_50_mn': '',
#   'glo_min': '',
#   'ts_50_md': '',
#   'q_med_min': '',
#   'nv_0050_cv': '',
#   'inso_q2': '',
#   'inso_q3': '',
#   'inso_q1': '',
#   'n_fog_max': '',
#   'np_100_s': '',
#   'np_300_s': '',
#   'ta_min_cv': '',
#   'tm_mes_cv': '',
#   'ts_min_md': '',
#   'ts_min_mn': '',
#   'inso_cv': '',
#   'np_300_n': '7',
#   'np_100_n': '7',
#   'ts_min_n': '13',
#   'tm_max_md': '',
#   'tm_max_mn': '',
#   'ts_min_s': '',
#   'tm_mes_q1': '',
#   'p_max_q1': '',
#   'p_max_q3': '',
#   'p_max_q2': '',
#   'p_max_q4': '',
#   'n_nie_s': '',
#   'n_gra_min': '',
#   'nt_30_n': '13',
#   'n_nie_n': '0',
#   'ts_50_n': '0',
#   'nv_0100_min': '',
#   'q_mar_q1': '',
#   'q_mar_q2': '',
#   'q_mar_q3': '',
#   'q_mar_q4': '',
#   'p_max_min': '',
#   'n_llu_cv': '',
#   'n_nub_mn': '',
#   'w_racha_q1': '',
#   'w_racha_q3': '',
#   'w_racha_q2': '',
#   'n_nub_md': '',
#   'w_racha_q4': '',
#   'nt_00_cv': '',
#   'np_010_q4': '',
#   'np_010_q1': '',
#   'np_010_q3': '',
#   'np_010_q2': '',
#   'nv_1000_q3': '',
#   'ts_50_cv': '',
#   'nv_0100_s': '',
#   'n_llu_max': '',
#   'tm_max_min': '',
#   'tm_min_md': '',
#   'q_mar_cv': '',
#   'nv_0100_n': '0',
#   'tm_min_mn': '',
#   'ts_10_mn': '',
#   'w_racha_cv': '',
#   'evap_min': '',
#   'ta_max_cv': '',
#   'n_llu_q4': '',
#   'n_llu_q2': '',
#   'n_llu_q3': '',
#   'n_llu_q1': '',
#   'q_min_q4': '',
#   'hr_min': '',
#   'w_med_max': '',
#   'nw_91_mn': '',
#   'q_min_q1': '',
#   'q_min_q2': '',
#   'q_min_q3': '',
#   'q_min_n': '0',
#   'nw_91_md': '',
#   'q_min_s': '',
#   'n_tor_q4': '',
#   'n_tor_q1': '',
#   'n_tor_q2': '',
#   'n_tor_q3': '',
#   'tm_mes_min': '',
#   'n_cub_max': '',
#   'nw_55_cv': '',
#   'tm_min_min': '',
#   'q_mar_max': '',
#   'nv_0100_q4': '',
#   'nv_0100_q1': '',
#   'nv_0100_q2': '',
#   'nv_0100_q3': '',
#   'q_max_q2': '',
#   'q_max_q3': '',
#   'q_max_q1': '',
#   'q_max_q4': '',
#   'nv_0100_cv': '',
#   'ts_10_q3': '',
#   'ts_10_q2': '',
#   'ts_10_q1': '',
#   'ts_10_q4': '',
#   'q_max_cv': '',
#   'ta_max_max': '',
#   'np_010_cv': '',
#   'ta_max_q4': '',
#   'ta_max_q3': '',
#   'ta_max_q2': '',
#   'ta_max_q1': '',
#   'np_010_min': '',
#   'w_med_n': '9',
#   'nv_1000_q4': '',
#   'nv_1000_q2': '',
#   'n_nie_max': '',
#   'nv_1000_q1': '',
#   'nv_1000_cv': '',
#   'glo_max': '',
#   'n_fog_s': '',
#   'ti_max_q2': '',
#   'n_fog_n': '0',
#   'n_nie_cv': '',
#   'np_001_min': '',
#   'nw_55_q4': '',
#   'n_fog_min': '',
#   'nw_55_q2': '',
#   'nw_55_q3': '',
#   'nw_55_q1': '',
#   'hr_n': '6',
#   'hr_s': '',
#   'q_med_s': '',
#   'nv_0050_max': '',
#   'ta_min_q2': '',
#   'n_des_max': '',
#   'n_fog_mn': '',
#   'p_sol_max': '',
#   'np_001_s': '',
#   'n_fog_md': '',
#   'q_min_cv': '',
#   'np_001_n': '7',
#   'e_max': '',
#   'nt_00_md': '',
#   'np_100_mn': '',
#   'nt_30_q1': '',
#   'nt_00_mn': '',
#   'glo_q4': '',
#   'glo_q2': '',
#   'glo_q3': '',
#   'np_100_md': '',
#   'inso_n': '0',
#   'q_med_q1': '',
#   'np_001_md': '',
#   'np_001_mn': '',
#   'ti_max_cv': '',
#   'nv_1000_mn': '',
#   'nv_1000_md': '',
#   'evap_md': '',
#   'ta_min_max': '',
#   'e_md': '',
#   'e_mn': '',
#   'nt_30_q3': '',
#   'ti_max_md': '',
#   'n_llu_n': '0',
#   'ti_max_mn': '',
#   'glo_s': '',
#   'glo_n': '0',
#   'ts_min_cv': '',
#   'n_llu_s': '',
#   'nv_0050_mn': '',
#   'n_nie_q3': '',
#   'n_nie_q2': '',
#   'n_nie_q4': '',
#   'glo_cv': '',
#   'tm_max_max': '',
#   'ts_20_mn': '',
#   'tm_max_cv': '',
#   'ts_20_md': '',
#   'np_001_cv': '',
#   'p_max_mn': '',
#   'nw_91_max': '',
#   'p_max_md': '',
#   'q_med_cv': '',
#   'ts_50_max': '',
#   'ts_50_min': '',
#   'ta_min_n': '13',
#   'e_q4': '',
#   'e_q3': '',
#   'e_q2': '',
#   'e_q1': '',
#   'glo_q1': '',
#   'w_racha_md': '',
#   'q_min_min': '',
#   'ts_min_q3': '',
#   'ts_min_q2': '',
#   'ts_min_q1': '',
#   'p_mes_max': '',
#   'ts_min_q4': '',
#   'q_mar_min': '',
#   'tm_max_q3': '',
#   'tm_max_q2': '',
#   'tm_max_q1': '',
#   'p_mes_mn': '',
#   'tm_max_q4': '',
#   'n_gra_mn': '',
#   'tm_min_max': '',
#   'np_001_q4': '',
#   'np_001_q3': '',
#   'np_001_q2': '',
#   'np_001_q1': '',
#   'ti_max_n': '13',
#   'w_med_md': '',
#   'ti_max_q4': '',
#   'ti_max_q3': '',
#   'n_gra_q2': '',
#   'ti_max_q1': '',
#   'ti_max_s': '',
#   'q_med_q2': '',
#   'q_med_q3': '',
#   'nt_30_q2': '',
#   'n_nie_min': '',
#   'nt_30_q4': '',
#   'q_med_q4': '',
#   'n_cub_md': '',
#   'n_cub_mn': '',
#   'ta_max_min': '',
#   'np_010_max': '',
#   'inso_md': '',
#   'inso_mn': '',
#   'evap_mn': ''}]

# %%
df_B013X_clima_normal_1991_2020 = pd.DataFrame(B013X_clima_normal_1991_2020)
display(df_B013X_clima_normal_1991_2020)
df_B013X_clima_normal_1991_2020.info()
# Out:
#    indicativo w_racha_max np_010_n np_010_s q_max_s n_tor_n n_tor_s q_max_n  \
# 0       B013X        23.1       24     3.44               0               0
# 1       B013X        23.9       25     4.92               0               0
# 2       B013X        20.3       23     2.91               0               0
# 3       B013X        19.7       23     2.97               1               0
# 4       B013X        16.4       22     2.98               1               0
# 5       B013X        19.7       19     1.82               1               0
# 6       B013X        21.4       23     0.98               0               0
# 7       B013X        18.3       21      2.2               0               0
# 8       B013X        41.1       15     2.45               0               0
# 9       B013X        20.3       20     3.98               0               0
# 10      B013X        21.7       17     3.59               0               0
# 11      B013X                   19     4.27               0               0
# 12      B013X                    7                        0               0
#
#    tm_min_q4 tm_min_q1  ... n_nie_min nt_30_q4 q_med_q4 n_cub_md n_cub_mn  \
# 0        3.3       1.0  ...                0.0
# 1        3.0       1.1  ...                0.0
# 2        4.7       2.7  ...                0.0
# 3        7.3       5.0  ...                0.0
# 4       10.2       7.7  ...                2.0
# 5       13.7      12.1  ...                8.0
# 6       16.6      15.1  ...               19.4
# 7       17.4      15.4  ...               22.0
# 8       14.3      12.2  ...                4.0
# 9       11.3       9.0  ...                0.0
# 10       7.0       4.8  ...                0.0
# 11       4.8       2.6  ...                0.0
# 12                      ...
#
#    ta_max_min np_010_max inso_md inso_mn evap_mn
# 0        13.8       18.0
# 1        13.1       16.0
# 2        18.1       12.0
# 3        20.8       11.0
# 4        23.8       14.0
# 5        28.7        5.0
# 6        31.6        3.0
# 7        30.0        8.0
# 8        27.1       10.0
# 9        23.0       16.0
# 10       18.8       14.0
# 11       15.9       16.0
# 12
#
# [13 rows x 475 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Columns: 475 entries, indicativo to evap_mn
# dtypes: object(475)
# memory usage: 48.4+ KB

# %%
df_B013X_clima_normal_1991_2020.to_csv('./data/raw/clima_normal_1991_2020_B013X.csv',
                                       index = False)

# %% [markdown]
# ### Esta información tiene muchas columnas cuyo siginificado hay que analizar bien antes de poder trabajar con él.

# %% [markdown]
# ## 6 - Valores extremos <a id="6-valores-extremos"></a>
#
# Valores extremos para la estación y la variable (precipitación, temperatura y viento) pasadas por parámetro. Periodicidad: 1 vez al día.

# %%
# Valores extremos para la estación y la variable (precipitación, temperatura y viento) 
# pasadas por parámetro. Periodicidad: 1 vez al día.
end_point = '/api/valores/climatologicos/valoresextremos/parametro/{parametro}/estacion/{idema}'

# Parametro = 'T' (temperatura), 'P' (presión), o 'V' (Viento)
parametro = 'T'
idema = 'B013X' # idema de Baleares

end_point = end_point.format(parametro = parametro, idema = idema)

url = base_url + end_point

response = requests.request("GET", url, headers=headers, params=querystring)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/e7855782', 'metadatos': 'https://opendata.aemet.es/opendata/sh/81c232d8'}

# %%
# Acceso a la información de los METADATOS, que describe la información de las columnas
metadatos = requests.get(response.json()['metadatos']).json()
metadatos
# Out:
# {'unidad_generadora': 'Servicio del Banco Nacional de Datos Climatológicos',
#  'periodicidad': '1 vez al día',
#  'descripcion': 'Extremos registrados. Temperaturas',
#  'formato': 'json/xml',
#  'copyright': '© AEMET. Autorizado el uso de la información y su reproducción citando a AEMET como autora de la misma.',
#  'notaLegal': 'https://www.aemet.es/es/nota_legal',
#  'campos': [{'id': 'indicativo',
#    'descripcion': 'Indicativo de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'nombre',
#    'descripcion': 'Nombre de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'ubicacion',
#    'descripcion': 'Ubicación de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'codigo',
#    'descripcion': 'Código de la variable',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'temMin',
#    'descripcion': 'Temperatura mínima absoluta de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último a la mínima absoluta',
#    'tipo_datos': 'array de string',
#    'unidad': 'décimas de °C',
#    'requerido': True},
#   {'id': 'diaMin',
#    'descripcion': 'Día del mes en que se dio la mínima absoluta de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último al día de la mínima absoluta',
#    'tipo_datos': 'array de string',
#    'requerido': True},
#   {'id': 'anioMin',
#    'descripcion': 'Año en que se dio la mímina absoluta de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último al año de la mínima absoluta',
#    'tipo_datos': 'array de string',
#    'requerido': True},
#   {'id': 'mesMin',
#    'descripcion': 'Mes en que se dio la mínima absoluta de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'temMax',
#    'descripcion': 'Temperatura máxima absoluta de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último a la máxima absoluta',
#    'tipo_datos': 'array de string',
#    'unidad': 'décimas de °C',
#    'requerido': True},
#   {'id': 'diaMax',
#    'descripcion': 'Día del mes en que se dio la máxima absoluta de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último al día de la máxima absoluta',
#    'tipo_datos': 'array de string',
#    'requerido': True},
#   {'id': 'anioMax',
#    'descripcion': 'Año en que se dio la máxima absoluta de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último al año de la máxima absoluta',
#    'tipo_datos': 'array de string',
#    'requerido': True},
#   {'id': 'mesMax',
#    'descripcion': 'Mes en que se dio la máxima absoluta de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'temMedBaja',
#    'descripcion': 'Temperatura media mensual más baja de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último a la mínima absoluta',
#    'tipo_datos': 'array de string',
#    'unidad': 'décimas de °C',
#    'requerido': True},
#   {'id': 'anioMedBaja',
#    'descripcion': 'Año en que se dio la temperatura media mensual más baja de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último al año de la mínima absoluta',
#    'tipo_datos': 'array de string',
#    'requerido': True},
#   {'id': 'mesMedBaja',
#    'descripcion': 'Mes en que se dio la temperatura media mensual más baja de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'temMedAlta',
#    'descripcion': 'Temperatura media mensual mas alta de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último a la máxima absoluta',
#    'tipo_datos': 'array de string',
#    'unidad': 'décimas de °C',
#    'requerido': True},
#   {'id': 'anioMedAlta',
#    'descripcion': 'Año en que se dio la temperatura media mensual más alta de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último al año de la máxima absoluta',
#    'tipo_datos': 'array de string',
#    'requerido': True},
#   {'id': 'mesMedAlta',
#    'descripcion': 'Mes en que se dio la temperatura media mensual más alta de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'temMedMin',
#    'descripcion': 'Temperatura media de las mínimas más baja de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último a la mínima absoluta',
#    'tipo_datos': 'array de string',
#    'unidad': 'décimas de °C',
#    'requerido': True},
#   {'id': 'anioMedMin',
#    'descripcion': 'Año en que se dio la temperatura media de las mínima más baja de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último al año de la mínima absoluta',
#    'tipo_datos': 'array de string',
#    'requerido': True},
#   {'id': 'mesMedMin',
#    'descripcion': 'Mes en que se dio la temperatura media de las mínima más baja de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'temMedMax',
#    'descripcion': 'Temperatura media de las máximas más alta de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último a la máxima absoluta',
#    'tipo_datos': 'array de string',
#    'unidad': 'décimas de °C',
#    'requerido': True},
#   {'id': 'anioMedMax',
#    'descripcion': 'Año en que se dio la temperatura media de las máximas más alta de la estación. Contiene 13 campos correspondientes a los 12 meses del año y el último al año de la máxima absoluta',
#    'tipo_datos': 'array de string',
#    'requerido': True},
#   {'id': 'mesMedMax',
#    'descripcion': 'Mes en que se dio la temperatura media de las máximas más alta de la estación',
#    'tipo_datos': 'string',
#    'requerido': True}]}

# %%
# La información de las columnas está en la columna "campos"
df_metadatos = pd.DataFrame(metadatos['campos'])
df_metadatos
# Out:
#              id                                        descripcion  \
# 0    indicativo                          Indicativo de la estación
# 1        nombre                              Nombre de la estación
# 2     ubicacion                           Ubicación de la estación
# 3        codigo                              Código de la variable
# 4        temMin  Temperatura mínima absoluta de la estación. Co...
# 5        diaMin  Día del mes en que se dio la mínima absoluta d...
# 6       anioMin  Año en que se dio la mímina absoluta de la est...
# 7        mesMin  Mes en que se dio la mínima absoluta de la est...
# 8        temMax  Temperatura máxima absoluta de la estación. Co...
# 9        diaMax  Día del mes en que se dio la máxima absoluta d...
# 10      anioMax  Año en que se dio la máxima absoluta de la est...
# 11       mesMax  Mes en que se dio la máxima absoluta de la est...
# 12   temMedBaja  Temperatura media mensual más baja de la estac...
# 13  anioMedBaja  Año en que se dio la temperatura media mensual...
# 14   mesMedBaja  Mes en que se dio la temperatura media mensual...
# 15   temMedAlta  Temperatura media mensual mas alta de la estac...
# 16  anioMedAlta  Año en que se dio la temperatura media mensual...
# 17   mesMedAlta  Mes en que se dio la temperatura media mensual...
# 18    temMedMin  Temperatura media de las mínimas más baja de l...
# 19   anioMedMin  Año en que se dio la temperatura media de las ...
# 20    mesMedMin  Mes en que se dio la temperatura media de las ...
# 21    temMedMax  Temperatura media de las máximas más alta de l...
# 22   anioMedMax  Año en que se dio la temperatura media de las ...
# 23    mesMedMax  Mes en que se dio la temperatura media de las ...
#
#          tipo_datos  requerido         unidad
# 0            string       True            NaN
# 1            string       True            NaN
# 2            string       True            NaN
# 3            string       True            NaN
# 4   array de string       True  décimas de °C
# 5   array de string       True            NaN
# 6   array de string       True            NaN
# 7            string       True            NaN
# 8   array de string       True  décimas de °C
# 9   array de string       True            NaN
# 10  array de string       True            NaN
# 11           string       True            NaN
# 12  array de string       True  décimas de °C
# 13  array de string       True            NaN
# 14           string       True            NaN
# 15  array de string       True  décimas de °C
# 16  array de string       True            NaN
# 17           string       True            NaN
# 18  array de string       True  décimas de °C
# 19  array de string       True            NaN
# 20           string       True            NaN
# 21  array de string       True  décimas de °C
# 22  array de string       True            NaN
# 23           string       True            NaN

# %%
# Guardar la información de los metadatos de la climatología normal (1991-2020)
df_metadatos.to_csv('./data/raw/metadatos_valores_extremos_T.csv',
                    index = False)

# %%
# Acceso a los DATOS
B013X_valores_extremos = requests.get(response.json()['datos']).json()
B013X_valores_extremos
# Out:
# {'indicativo': 'B013X',
#  'nombre': 'ESCORCA, LLUC',
#  'ubicacion': 'ILLES BALEAR',
#  'codigo': '023000',
#  'temMin': ['-63',
#   '-54',
#   '-68',
#   '-15',
#   '6',
#   '63',
#   '81',
#   '77',
#   '57',
#   '16',
#   '-24',
#   '-71',
#   '-71'],
#  'diaMin': ['26',
#   '26',
#   '11',
#   '1',
#   '1',
#   '2',
#   '7',
#   '31',
#   '28',
#   '27',
#   '24',
#   '25',
#   '25'],
#  'anioMin': ['2011',
#   '2001',
#   '2010',
#   '2001',
#   '2001',
#   '2016',
#   '1997',
#   '1993',
#   '1995',
#   '2010',
#   '1999',
#   '2001',
#   '2001'],
#  'mesMin': '12',
#  'temMax': ['230',
#   '232',
#   '321',
#   '329',
#   '363',
#   '371',
#   '414',
#   '414',
#   '356',
#   '331',
#   '263',
#   '236',
#   '414'],
#  'diaMax': ['28',
#   '3',
#   '23',
#   '29',
#   '14',
#   '25',
#   '18',
#   '25',
#   '4',
#   '28',
#   '7',
#   '14',
#   '25'],
#  'anioMax': ['2021',
#   '2021',
#   '2001',
#   '2023',
#   '2015',
#   '2001',
#   '2023',
#   '2000',
#   '2016',
#   '1999',
#   '2013',
#   '2000',
#   '2000'],
#  'mesMax': '8',
#  'temMedBaja': ['56',
#   '43',
#   '78',
#   '101',
#   '129',
#   '175',
#   '211',
#   '205',
#   '169',
#   '136',
#   '85',
#   '44',
#   '43'],
#  'anioMedBaja': ['2005',
#   '2005',
#   '2005',
#   '2002',
#   '2004',
#   '2010',
#   '1997',
#   '2002',
#   '1996',
#   '1996',
#   '2001',
#   '2001',
#   '2005'],
#  'mesMedBaja': '2',
#  'temMedAlta': ['97',
#   '105',
#   '129',
#   '141',
#   '184',
#   '234',
#   '262',
#   '255',
#   '218',
#   '190',
#   '136',
#   '121',
#   '262'],
#  'anioMedAlta': ['2024',
#   '2021',
#   '2001',
#   '2023',
#   '1999',
#   '2022',
#   '2023',
#   '2023',
#   '2021',
#   '2022',
#   '2022',
#   '2022',
#   '2023'],
#  'mesMedAlta': '7',
#  'temMedMin': ['-2',
#   '-4',
#   '17',
#   '36',
#   '71',
#   '110',
#   '136',
#   '145',
#   '113',
#   '77',
#   '34',
#   '-12',
#   '-12'],
#  'anioMedMin': ['2002',
#   '2002',
#   '2003',
#   '1995',
#   '2019',
#   '2010',
#   '1996',
#   '2002',
#   '1996',
#   '1998',
#   '2017',
#   '2001',
#   '2001'],
#  'mesMedMin': '12',
#  'temMedMax': ['153',
#   '166',
#   '196',
#   '210',
#   '254',
#   '304',
#   '331',
#   '330',
#   '279',
#   '253',
#   '187',
#   '176',
#   '331'],
#  'anioMedMax': ['2024',
#   '2020',
#   '2023',
#   '2023',
#   '2000',
#   '2022',
#   '2022',
#   '2000',
#   '1999',
#   '2022',
#   '2023',
#   '2022',
#   '2022'],
#  'mesMedMax': '7'}

# %%
B013X_valores_extremos = pd.DataFrame(B013X_valores_extremos)
display(B013X_valores_extremos)
B013X_valores_extremos.info()
# Out:
#    indicativo         nombre     ubicacion  codigo temMin diaMin anioMin  \
# 0       B013X  ESCORCA, LLUC  ILLES BALEAR  023000    -63     26    2011
# 1       B013X  ESCORCA, LLUC  ILLES BALEAR  023000    -54     26    2001
# 2       B013X  ESCORCA, LLUC  ILLES BALEAR  023000    -68     11    2010
# 3       B013X  ESCORCA, LLUC  ILLES BALEAR  023000    -15      1    2001
# 4       B013X  ESCORCA, LLUC  ILLES BALEAR  023000      6      1    2001
# 5       B013X  ESCORCA, LLUC  ILLES BALEAR  023000     63      2    2016
# 6       B013X  ESCORCA, LLUC  ILLES BALEAR  023000     81      7    1997
# 7       B013X  ESCORCA, LLUC  ILLES BALEAR  023000     77     31    1993
# 8       B013X  ESCORCA, LLUC  ILLES BALEAR  023000     57     28    1995
# 9       B013X  ESCORCA, LLUC  ILLES BALEAR  023000     16     27    2010
# 10      B013X  ESCORCA, LLUC  ILLES BALEAR  023000    -24     24    1999
# 11      B013X  ESCORCA, LLUC  ILLES BALEAR  023000    -71     25    2001
# 12      B013X  ESCORCA, LLUC  ILLES BALEAR  023000    -71     25    2001
#
#    mesMin temMax diaMax  ... mesMedBaja temMedAlta anioMedAlta mesMedAlta  \
# 0      12    230     28  ...          2         97        2024          7
# 1      12    232      3  ...          2        105        2021          7
# 2      12    321     23  ...          2        129        2001          7
# 3      12    329     29  ...          2        141        2023          7
# 4      12    363     14  ...          2        184        1999          7
# 5      12    371     25  ...          2        234        2022          7
# 6      12    414     18  ...          2        262        2023          7
# 7      12    414     25  ...          2        255        2023          7
# 8      12    356      4  ...          2        218        2021          7
# 9      12    331     28  ...          2        190        2022          7
# 10     12    263      7  ...          2        136        2022          7
# 11     12    236     14  ...          2        121        2022          7
# 12     12    414     25  ...          2        262        2023          7
#
#    temMedMin anioMedMin mesMedMin temMedMax anioMedMax mesMedMax
# 0         -2       2002        12       153       2024         7
# 1         -4       2002        12       166       2020         7
# 2         17       2003        12       196       2023         7
# 3         36       1995        12       210       2023         7
# 4         71       2019        12       254       2000         7
# 5        110       2010        12       304       2022         7
# 6        136       1996        12       331       2022         7
# 7        145       2002        12       330       2000         7
# 8        113       1996        12       279       1999         7
# 9         77       1998        12       253       2022         7
# 10        34       2017        12       187       2023         7
# 11       -12       2001        12       176       2022         7
# 12       -12       2001        12       331       2022         7
#
# [13 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   indicativo   13 non-null     object
#  1   nombre       13 non-null     object
#  2   ubicacion    13 non-null     object
#  3   codigo       13 non-null     object
#  4   temMin       13 non-null     object
#  5   diaMin       13 non-null     object
#  6   anioMin      13 non-null     object
#  7   mesMin       13 non-null     object
#  8   temMax       13 non-null     object
#  9   diaMax       13 non-null     object
#  10  anioMax      13 non-null     object
#  11  mesMax       13 non-null     object
#  12  temMedBaja   13 non-null     object
#  13  anioMedBaja  13 non-null     object
#  14  mesMedBaja   13 non-null     object
#  15  temMedAlta   13 non-null     object
#  16  anioMedAlta  13 non-null     object
#  17  mesMedAlta   13 non-null     object
#  18  temMedMin    13 non-null     object
#  19  anioMedMin   13 non-null     object
#  20  mesMedMin    13 non-null     object
#  21  temMedMax    13 non-null     object
#  22  anioMedMax   13 non-null     object
#  23  mesMedMax    13 non-null     object
# dtypes: object(24)
# memory usage: 2.6+ KB

# %%
B013X_valores_extremos.to_csv('./data/raw/clima_extremo_B013X_T.csv',
                                       index = False)
