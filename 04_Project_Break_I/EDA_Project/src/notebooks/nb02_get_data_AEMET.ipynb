# %% [markdown]
# # GET data de la API de AEMET
#
# Este Notebook se va a emplear para obtener el primer dataset completo con datos climatológicos del EDA.
#
#
# ## Tabla de contenidos
#
# <nav>
#   <ol>
#     <li><a href="#1-data-selection">Data selection</a></li>
#     <li><a href="#2-BC-data">Basque Country data accessing</a></li>
#     <li><a href="#3-data-cleaning">Basque Country data clean and merge</a></li>
#   </ol>
# </nav>

# %% [markdown]
# ## 1 - Data selection <a id="1-data-selection"></a>
#
# Select data information that will be requested.

# %% [markdown]
# A través de la API de AEMET OpenData, se acceder a datos históricos que se remontan hasta el año 1805. La estación de San Fernando en Cádiz posee la serie de datos de precipitación más antigua, con registros que abarcan casi 200 años.
#
# En total, 29 estaciones meteorológicas en España cuentan con series centenarias, proporcionando información de gran valor histórico y climatológico.

# %%
# Libraries
import os
import re
import sys
import time

import numpy as np
import pandas as pd
import requests

# %%
current_directory = os.getcwd()
root_path = os.path.abspath(os.path.join(current_directory, '..'))
print(current_directory) 
print(root_path)  

# Validate if the path exists before adding it
if os.path.exists(root_path) and root_path not in sys.path:
    sys.path.append(root_path)
                        
from utils.functions import fetch_data_aemet
# Out:
# c:\Users\Lander\Documents\Bootcamp_DS\ONLINE_DS_THEBRIDGE_2024\04_Project_Break_I\EDA_Project\src\notebooks
# c:\Users\Lander\Documents\Bootcamp_DS\ONLINE_DS_THEBRIDGE_2024\04_Project_Break_I\EDA_Project\src

# %% [markdown]
# ### 1.1 - Accessing AEMET API

# %%
# Load API-Key so I have permission to access AEMET OpenData 

with open('C:/Users/Lander/Documents/API_Keys/apiKey_aemet.txt') as f:
    api_key = f.read()

# %%
# API AEMET URL base. Found in https://opendata.aemet.es/dist/index.html
base_url = 'https://opendata.aemet.es/opendata'

# Parameters for the request
querystring = {"api_key": api_key}
headers = {'cache-control': "no-cache"}

# %% [markdown]
# ### 1.2 - Provinces selection

# %%
# File .csv contains info related to all Spanish Automatic Weather Stations (AWS)
# EMA = Estación Meteorológica Automática (EMA)
df_stations = pd.read_csv('../data/raw/EMA_info.csv')

# Spanish provinces
display(df_stations.sample(5))
display(df_stations['provincia'].unique())
# Out:
#      latitud provincia  altitud  idema                     nombre  indsinop  \
# 629  374712N   SEVILLA      200  5654X  LA PUEBLA DE LOS INFANTES       NaN
# 772  394252N    CUENCA      815  8245Y                       MIRA       NaN
# 284  433904N      LUGO       80  1347T                     BURELA       NaN
# 227  430544N   BIZKAIA      270  1064L             OROZKO, IBARRA       NaN
# 869  413716N  ZARAGOZA      258  9434P    ZARAGOZA, VALDESPARTERA    8159.0
#
#     longitud
# 629  052216W
# 772  012633W
# 284  072126W
# 227  025137W
# 869  005605W
# array(['ILLES BALEARS', 'BALEARES', 'LAS PALMAS', 'STA. CRUZ DE TENERIFE',
#        'TARRAGONA', 'BARCELONA', 'GIRONA', 'NAVARRA', 'GIPUZKOA',
#        'ARABA/ALAVA', 'BIZKAIA', 'CANTABRIA', 'ASTURIAS', 'LEON', 'LUGO',
#        'A CORUÑA', 'PONTEVEDRA', 'OURENSE', 'SORIA', 'BURGOS', 'SEGOVIA',
#        'VALLADOLID', 'PALENCIA', 'AVILA', 'MADRID', 'SALAMANCA', 'ZAMORA',
#        'GUADALAJARA', 'CUENCA', 'TOLEDO', 'CACERES', 'ALBACETE',
#        'CIUDAD REAL', 'BADAJOZ', 'CORDOBA', 'HUELVA', 'CEUTA', 'JAEN',
#        'GRANADA', 'ALMERIA', 'SEVILLA', 'CADIZ', 'MELILLA', 'MALAGA',
#        'MURCIA', 'ALICANTE', 'VALENCIA', 'TERUEL', 'CASTELLON',
#        'LA RIOJA', 'HUESCA', 'ZARAGOZA', 'LLEIDA'], dtype=object)

# %%
# Provinces for the EDA
provinces = ['BIZKAIA', 'ARABA/ALAVA', 'GIPUZKOA']

df_EMA_euskadi = df_stations[df_stations['provincia'].isin(provinces)]
df_EMA_euskadi.sample(5)
# Out:
#      latitud    provincia  altitud  idema             nombre  indsinop  \
# 216  431808N     GIPUZKOA       28  1041A             ZUMAIA    8026.0
# 225  432230N      BIZKAIA       90  1059X        PUNTA GALEA    8059.0
# 230  431050N      BIZKAIA      210  1078C          BALMASEDA       NaN
# 217  430328N  ARABA/ALAVA      617  1044X  ARAMAIO, ETXAGUEN       NaN
# 819  423614N  ARABA/ALAVA      612  9122I          LABASTIDA       NaN
#
#     longitud
# 216  021504W
# 225  030118W
# 230  031235W
# 217  023522W
# 819  024636W

# %%
len(df_EMA_euskadi)
# Out:
# 37

# %% [markdown]
# ### 1.3 Accessing AWS informatin

# %%
# Accesing ONE single AWS
end_point = '/api/valores/climatologicos/mensualesanuales/datos/anioini/{anioIniStr}/aniofin/{anioFinStr}/estacion/{idema}'

anioIniStr = '2010'
anioFinStr = '2013'
idema = '1012P' # Irun station "idema"

end_point = end_point.format(anioIniStr = anioIniStr, anioFinStr = anioFinStr, idema = idema)

url = base_url + end_point

response = requests.request("GET", url, headers=headers, params=querystring)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/273c5535', 'metadatos': 'https://opendata.aemet.es/opendata/sh/997c0034'}

# %%
# Accessing Irún data
df_Irun = pd.DataFrame(requests.get(response.json()['datos']).json())
display(df_Irun.head())
df_Irun.shape
# Out:
#      fecha indicativo     p_max   hr tm_min    ta_max ts_min nt_30 np_100  \
# 0  2010-10      1012P  50.8(10)   70   11.8  29.4(02)   20.2     0      4
# 1  2010-11      1012P  33.4(22)   77    8.4  23.2(12)   14.7     0     12
# 2  2010-12      1012P  41.2(22)   68    4.6  21.0(06)   14.3     0      6
# 3  2010-13      1012P       NaN  NaN    NaN       NaN    NaN   NaN    NaN
# 4   2010-1      1012P       NaN  NaN    NaN       NaN    NaN   NaN    NaN
#
#   np_001  ... nt_00 ti_max tm_mes tm_max np_010 nw_55      w_racha nw_91  \
# 0     11  ...     0   12.2   15.6   19.3      8   NaN          NaN   NaN
# 1     26  ...     0    7.1   11.1   13.7     20     9  24/20.3(15)     0
# 2     13  ...     6    2.7    8.2   11.8     12     5  16/21.1(06)     0
# 3    NaN  ...   NaN    NaN    NaN    NaN    NaN   NaN          NaN   NaN
# 4    NaN  ...   NaN    NaN    NaN    NaN    NaN   NaN  25/28.6(14)   NaN
#
#   w_rec w_med
# 0   NaN   NaN
# 1   272    11
# 2   158     7
# 3   NaN   NaN
# 4   NaN   NaN
#
# [5 rows x 24 columns]
# (52, 24)

# %% [markdown]
# ### Conclusion:
#
# For the EDA the following data will be used:
# - Climatic parameters for the last 100 year (if storaged).
# - Basque Country data (Bizkaia, Araba, Gipuzkoa)
# - Mean values per month per year
# - JOIN climate parameters with AWS information

# %% [markdown]
# ## 2 - Basque Country data accessing <a id="2-BC-data"></a>

# %%
# Inspection of all the AWS
df_stations
# Out:
#      latitud      provincia  altitud  idema               nombre  indsinop  \
# 0    394924N  ILLES BALEARS      490  B013X        ESCORCA, LLUC    8304.0
# 1    394744N  ILLES BALEARS        5  B051A       SÓLLER, PUERTO    8316.0
# 2    394121N  ILLES BALEARS       60  B087X          BANYALBUFAR       NaN
# 3    393445N  ILLES BALEARS       52  B103B   ANDRATX - SANT ELM   99103.0
# 4    393305N  ILLES BALEARS       50  B158X  CALVIÀ, ES CAPDELLÀ       NaN
# ..       ...            ...      ...    ...                  ...       ...
# 942  424131N         LLEIDA     2467  9988B      CAP DE VAQUÈIRA    8936.0
# 943  424201N         LLEIDA     1161  9990X   NAUT ARAN, ARTIES     8107.0
# 944  424634N         LLEIDA      722  9994X              BOSSÒST       NaN
# 945  430528N        NAVARRA      334  9995Y    VALCARLOS/LUZAIDE       NaN
# 946  405517N         TERUEL     1006  9998X                BELLO       NaN
#
#     longitud
# 0    025309E
# 1    024129E
# 2    023046E
# 3    022208E
# 4    022759E
# ..       ...
# 942  005826E
# 943  005237E
# 944  004123E
# 945  011803W
# 946  012940W
#
# [947 rows x 7 columns]

# %%
df_EMA_euskadi.idema.unique()
# Out:
# array(['1012P', '1014', '1014A', '1021X', '1024E', '1025A', '1025X',
#        '1026X', '1037X', '1037Y', '1038X', '1041A', '1044X', '1048X',
#        '1049N', '1050J', '1052A', '1055B', '1056K', '1057B', '1059X',
#        '1060X', '1064L', '1069Y', '1074C', '1078C', '1078I', '1082',
#        '1083B', '9060X', '9073X', '9087', '9091O', '9091R', '9122I',
#        '9145X', '9178X'], dtype=object)

# %%
# Get climate data per AWS, per month, per year

df_climate_month_year = pd.DataFrame()    # Empty DataFrame

for idema in df_EMA_euskadi['idema']:
    for year in range(1924, 2025, 4):
        print(f'Accessing {idema} {year}\'s info...')
        end_point = '/api/valores/climatologicos/mensualesanuales/datos/anioini/{anioIniStr}/aniofin/{anioFinStr}/estacion/{idema}'
        anioIniStr = str(year)
        anioFinStr = str(year+3)

        end_point = end_point.format(anioIniStr = anioIniStr, anioFinStr = anioFinStr, idema = idema)
        url = base_url + end_point
        
        time.sleep(3)   # To prevent requests limit
        
        # Complete request dataset
        df_idema_data = fetch_data_aemet(url, headers, querystring)
        
        if isinstance(df_idema_data, pd.DataFrame):
            df_climate_month_year = pd.concat([df_climate_month_year, df_idema_data])
        
        print('')


# Display data frame
display(df_climate_month_year)
    
# Storage dataset
df_climate_month_year.to_csv('../data/raw/climate_month_year_euskadi_RAW.csv',
                             index = False)
# Out:
# Accessing 1012P 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1964's info...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 15
#      12 end_point = end_point.format(anioIniStr = anioIniStr, anioFinStr = anioFinStr, idema = idema)
#      13 url = base_url + end_point
# ---> 15 time.sleep(3)   # To prevent requests limit
#      17 # Complete request dataset
#      18 df_idema_data = fetch_data_aemet(url, headers, querystring)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3 - Basque Country data cleaning <a id="3-data-cleaning"></a>

# %%
df_euskadi = pd.read_csv('../data/raw/climate_month_year_euskadi_RAW.csv')
df_euskadi
# Out:
#          fecha indicativo     p_max    hr  nw_55  tm_min    ta_max  ts_min  \
# 0      2009-10      1012P  35.2(22)  74.0    1.0    12.7  30.8(06)    22.9
# 1      2009-11      1012P       NaN  67.0   14.0    10.6  26.9(01)    17.2
# 2      2009-12      1012P       NaN  73.0   10.0     6.6  19.6(29)    16.0
# 3      2009-13      1012P       NaN   NaN    NaN     NaN       NaN     NaN
# 4       2009-1      1012P       NaN   NaN    NaN     NaN       NaN     NaN
# ...        ...        ...       ...   ...    ...     ...       ...     ...
# 12397   2024-9      9178X       NaN   NaN    NaN     NaN       NaN     NaN
# 12398   2024-3      9178X  20.8(07)  73.0    NaN     3.4  24.1(22)    11.0
# 12399   2024-4      9178X  10.4(27)  65.0    NaN     4.5  27.2(13)    11.8
# 12400   2024-5      9178X  22.8(18)  67.0    NaN     7.5  26.4(28)    12.7
# 12401   2024-6      9178X  18.8(20)  66.0    NaN    11.4  31.6(27)    16.6
#
#        nt_30      w_racha  ...  q_max  q_mar  q_med q_min  inso  p_sol  ts_20  \
# 0        1.0  16/15.3(20)  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 1        0.0  25/27.2(07)  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2        0.0  14/26.1(21)  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 3        NaN          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 4        NaN          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# ...      ...          ...  ...    ...    ...    ...   ...   ...    ...    ...
# 12397    NaN          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 12398    0.0          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 12399    0.0          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 12400    0.0          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 12401    7.0          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN
#
#        ts_10  ts_50  glo
# 0        NaN    NaN  NaN
# 1        NaN    NaN  NaN
# 2        NaN    NaN  NaN
# 3        NaN    NaN  NaN
# 4        NaN    NaN  NaN
# ...      ...    ...  ...
# 12397    NaN    NaN  NaN
# 12398    NaN    NaN  NaN
# 12399    NaN    NaN  NaN
# 12400    NaN    NaN  NaN
# 12401    NaN    NaN  NaN
#
# [12402 rows x 46 columns]

# %%
df_euskadi.fecha.min()  # Oldest data
# Out:
# '1928-1'

# %% [markdown]
# ### 3.1 - Climate mean values per year
#
# AEMET mean data is storage per year in the month numer "13". But this data is missing a lot of values. Maybe I won't use this information.

# %%
# Filter: month "13" storages mean values of each year. Data provided directly by AEMET
df_euskadi_anual = df_euskadi[df_euskadi['fecha'].str.contains(r'-13$', regex=True)]

# Delete "13" suffix
df_euskadi_anual.loc[:, 'fecha'] = df_euskadi_anual['fecha'].str.replace(r'-13$', '', regex=True)
df_euskadi_anual
# Out:
#       fecha indicativo         p_max    hr  nw_55  tm_min        ta_max  \
# 3      2009      1012P           NaN   NaN    NaN     NaN           NaN
# 16     2010      1012P           NaN   NaN    NaN     NaN           NaN
# 29     2011      1012P           NaN  74.0    NaN    12.0  39.1(21/ago)
# 42     2012      1012P  67.0(20/oct)  75.0   28.0    10.7  38.2(17/ago)
# 55     2013      1012P  89.2(08/jun)  76.0   44.0    10.9  37.6(31/jul)
# ...     ...        ...           ...   ...    ...     ...           ...
# 12340  2020      9178X  34.0(06/nov)   NaN    NaN     NaN           NaN
# 12353  2021      9178X           NaN  73.0    NaN     6.9  40.0(14/ago)
# 12366  2022      9178X  27.0(09/ene)  69.0    NaN     7.6  40.9(16/jul)
# 12379  2023      9178X  52.8(01/sep)  71.0    NaN     7.6  40.0(24/ago)
# 12392  2024      9178X           NaN   NaN    NaN     NaN           NaN
#
#        ts_min  nt_30          w_racha  ...  q_max  q_mar  q_med q_min  inso  \
# 3         NaN    NaN              NaN  ...    NaN    NaN    NaN   NaN   NaN
# 16        NaN    NaN              NaN  ...    NaN    NaN    NaN   NaN   NaN
# 29       21.6   10.0              NaN  ...    NaN    NaN    NaN   NaN   NaN
# 42       22.1   16.0  26/24.4(05/ene)  ...    NaN    NaN    NaN   NaN   NaN
# 55       21.0    5.0  23/27.5(26/ene)  ...    NaN    NaN    NaN   NaN   NaN
# ...       ...    ...              ...  ...    ...    ...    ...   ...   ...
# 12340     NaN    NaN              NaN  ...    NaN    NaN    NaN   NaN   NaN
# 12353    20.8   29.0              NaN  ...    NaN    NaN    NaN   NaN   NaN
# 12366    20.8   57.0              NaN  ...    NaN    NaN    NaN   NaN   NaN
# 12379    24.2   37.0              NaN  ...    NaN    NaN    NaN   NaN   NaN
# 12392     NaN    NaN              NaN  ...    NaN    NaN    NaN   NaN   NaN
#
#        p_sol  ts_20  ts_10  ts_50  glo
# 3        NaN    NaN    NaN    NaN  NaN
# 16       NaN    NaN    NaN    NaN  NaN
# 29       NaN    NaN    NaN    NaN  NaN
# 42       NaN    NaN    NaN    NaN  NaN
# 55       NaN    NaN    NaN    NaN  NaN
# ...      ...    ...    ...    ...  ...
# 12340    NaN    NaN    NaN    NaN  NaN
# 12353    NaN    NaN    NaN    NaN  NaN
# 12366    NaN    NaN    NaN    NaN  NaN
# 12379    NaN    NaN    NaN    NaN  NaN
# 12392    NaN    NaN    NaN    NaN  NaN
#
# [954 rows x 46 columns]

# %%
df_euskadi_anual = df_euskadi_anual.rename(columns={'indicativo' : 'idema'})
df_euskadi_anual.sort_values(by = ['idema', 'fecha'])

df_euskadi_anual
# Out:
#       fecha  idema         p_max    hr  nw_55  tm_min        ta_max  ts_min  \
# 3      2009  1012P           NaN   NaN    NaN     NaN           NaN     NaN
# 16     2010  1012P           NaN   NaN    NaN     NaN           NaN     NaN
# 29     2011  1012P           NaN  74.0    NaN    12.0  39.1(21/ago)    21.6
# 42     2012  1012P  67.0(20/oct)  75.0   28.0    10.7  38.2(17/ago)    22.1
# 55     2013  1012P  89.2(08/jun)  76.0   44.0    10.9  37.6(31/jul)    21.0
# ...     ...    ...           ...   ...    ...     ...           ...     ...
# 12340  2020  9178X  34.0(06/nov)   NaN    NaN     NaN           NaN     NaN
# 12353  2021  9178X           NaN  73.0    NaN     6.9  40.0(14/ago)    20.8
# 12366  2022  9178X  27.0(09/ene)  69.0    NaN     7.6  40.9(16/jul)    20.8
# 12379  2023  9178X  52.8(01/sep)  71.0    NaN     7.6  40.0(24/ago)    24.2
# 12392  2024  9178X           NaN   NaN    NaN     NaN           NaN     NaN
#
#        nt_30          w_racha  ...  q_max  q_mar  q_med q_min  inso  p_sol  \
# 3        NaN              NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN
# 16       NaN              NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN
# 29      10.0              NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN
# 42      16.0  26/24.4(05/ene)  ...    NaN    NaN    NaN   NaN   NaN    NaN
# 55       5.0  23/27.5(26/ene)  ...    NaN    NaN    NaN   NaN   NaN    NaN
# ...      ...              ...  ...    ...    ...    ...   ...   ...    ...
# 12340    NaN              NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN
# 12353   29.0              NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN
# 12366   57.0              NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN
# 12379   37.0              NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN
# 12392    NaN              NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN
#
#        ts_20  ts_10  ts_50  glo
# 3        NaN    NaN    NaN  NaN
# 16       NaN    NaN    NaN  NaN
# 29       NaN    NaN    NaN  NaN
# 42       NaN    NaN    NaN  NaN
# 55       NaN    NaN    NaN  NaN
# ...      ...    ...    ...  ...
# 12340    NaN    NaN    NaN  NaN
# 12353    NaN    NaN    NaN  NaN
# 12366    NaN    NaN    NaN  NaN
# 12379    NaN    NaN    NaN  NaN
# 12392    NaN    NaN    NaN  NaN
#
# [954 rows x 46 columns]

# %%
df_euskadi_anual.to_csv('../data/processed/BC_anual_climate.csv',
                        index = False)

# %%
df_euskadi_anual.idema.unique()
# Out:
# array(['1012P', '1014', '1014A', '1021X', '1024E', '1025A', '1025X',
#        '1026X', '1037X', '1037Y', '1038X', '1041A', '1044X', '1048X',
#        '1049N', '1050J', '1052A', '1055B', '1056K', '1057B', '1059X',
#        '1060X', '1064L', '1069Y', '1074C', '1078C', '1078I', '1082',
#        '1083B', '9060X', '9073X', '9087', '9091O', '9091R', '9122I',
#        '9145X', '9178X'], dtype=object)

# %%
df_euskadi_anual.fecha.unique()
# Out:
# array(['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024',
#        '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962',
#        '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '1928', '1929',
#        '1930', '1931', '1932', '1933', '1934', '1935', '1936', '1937',
#        '1938', '1939', '1940', '1941', '1942', '1943', '1944', '1945',
#        '1946', '1947', '1948', '1949', '1950', '1951', '1952', '1953',
#        '1954'], dtype=object)

# %% [markdown]
# ### 3.2 - Clima per month, per yer

# %%
# Filter: only months from 1 to 12
df_euskadi_month_year = df_euskadi[~df_euskadi['fecha'].str.contains(r'-13$', regex=True)]

df_euskadi_month_year = df_euskadi_month_year.rename(columns={'indicativo' : 'idema'})
df_euskadi_month_year.sort_values(by = ['idema', 'fecha'])

df_euskadi_month_year
# Out:
#          fecha  idema     p_max    hr  nw_55  tm_min    ta_max  ts_min  nt_30  \
# 0      2009-10  1012P  35.2(22)  74.0    1.0    12.7  30.8(06)    22.9    1.0
# 1      2009-11  1012P       NaN  67.0   14.0    10.6  26.9(01)    17.2    0.0
# 2      2009-12  1012P       NaN  73.0   10.0     6.6  19.6(29)    16.0    0.0
# 4       2009-1  1012P       NaN   NaN    NaN     NaN       NaN     NaN    NaN
# 5       2009-2  1012P       NaN   NaN    NaN     NaN       NaN     NaN    NaN
# ...        ...    ...       ...   ...    ...     ...       ...     ...    ...
# 12397   2024-9  9178X       NaN   NaN    NaN     NaN       NaN     NaN    NaN
# 12398   2024-3  9178X  20.8(07)  73.0    NaN     3.4  24.1(22)    11.0    0.0
# 12399   2024-4  9178X  10.4(27)  65.0    NaN     4.5  27.2(13)    11.8    0.0
# 12400   2024-5  9178X  22.8(18)  67.0    NaN     7.5  26.4(28)    12.7    0.0
# 12401   2024-6  9178X  18.8(20)  66.0    NaN    11.4  31.6(27)    16.6    7.0
#
#            w_racha  ...  q_max  q_mar  q_med q_min  inso  p_sol  ts_20  ts_10  \
# 0      16/15.3(20)  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 1      25/27.2(07)  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 2      14/26.1(21)  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 4              NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 5              NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# ...            ...  ...    ...    ...    ...   ...   ...    ...    ...    ...
# 12397          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 12398          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 12399          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 12400          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 12401          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
#
#        ts_50  glo
# 0        NaN  NaN
# 1        NaN  NaN
# 2        NaN  NaN
# 4        NaN  NaN
# 5        NaN  NaN
# ...      ...  ...
# 12397    NaN  NaN
# 12398    NaN  NaN
# 12399    NaN  NaN
# 12400    NaN  NaN
# 12401    NaN  NaN
#
# [11448 rows x 46 columns]

# %%
# Save dataset
df_euskadi_month_year.to_csv('../data/processed/BC_month_year_climate.csv',
                            index = False)
