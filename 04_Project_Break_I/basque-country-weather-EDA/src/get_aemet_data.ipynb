# %% [markdown]
# # Getting weather data: AEMET OpenData API
#
# The State Meteorological Agency (AEMET in spanish) aims at the development, implementation and delivery of state's weather services and at supporting the performance of other public policies and private activities, contributing to the safety of persons and property, and to the welfare and sustainable development of Spanish society. The Agency has the status of meteorological authority of the state, as well as aeronautical meteorological authority.
#
# In this kernel I am going to explore AEMET OpenData API (v2.0) and get the neccesary weather data for a furture EDA (Exploratory Data Analysis).
#
# # Table of contents
#
# <nav>
#   <ul>
#     <li><a href="#libraries">Libraries</a></li>
#     <li><a href="#opendata-request">AEMET OpenData API requests</a></li>
#     <ul>
#       <li><a href="#get-idema">Get AWS ID</a></li>
#       <li><a href="#monthly-anual-mean-data">Monthly and annual mean values of climatological data</a></li>
#       <li><a href="#basque-country-requests">Basque Country Data Requests</a></li>
#     </ul>
#     <li><a href="#process-clean">Process and Clean datasets</a></li>
#   </ul>
# </nav>
#
# <h1 id="libraries">Libraries</h3>
#
# I do import all the libraries that will be used in this kernel.

# %%
# Import libraries
import time

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import pandas as pd
import requests
import seaborn as sns

from utils.functions import fetch_data_aemet, convert_coordinate

# %% [markdown]
# <h1 id="opendata-request">AEMET OpenData API requests</h1>
#
# AEMET OpenData is a REST API developed by AEMET that allows the dissemination and reuse of the Agency's meteorological and climatological information, in the sense indicated in Law 18/2015, of July 9, amending Law 37/2007, of November 16, on reuse of public sector information.
#
# IMPORTANT: In order to make requests, it is necessary to enter in API Key. All the information in the link below:
#
# https://opendata.aemet.es/dist/index.html
#
# First step is getting an API-key and load it.

# %%
# Load my personal API-key
with open('C:/Users/Lander/Documents/API_Keys/apiKey_aemet.txt') as f:
    api_key = f.read()

# %% [markdown]
# After investigating the API structure for requests, I know that the following must be defined.

# %%
# API base URL and additional queries
base_url = 'https://opendata.aemet.es/opendata'
querystring = {"api_key": api_key}
headers = {'cache-control': "no-cache"}

# %% [markdown]
# <h2 id="get-idema">Get AWS ID</h2>
#
# "idema" refers to the Autonomous Weather Station (AWS) identifier. In spanish, EMA (Estación Metereológica Automática).
#
# The following request will get all the Spanish AWS ID and information related to them.
#
# Through the AEMET OpenData API, historical data since 1805 can be accessed. The San Fernando station in Cadiz has the oldest precipitation data series, with records spanning almost 200 years. In total, 29 weather stations in Spain have hundred of series, providing information of great historical and climatological value.

# %%
# Inventory of all AWS. Frequency: once a day
end_point = '/api/valores/climatologicos/inventarioestaciones/todasestaciones'

# Complete URL
url = base_url + end_point

# Request
response = requests.request("GET", url, headers = headers, params = querystring)
print('Response:', response.status_code)

response_content = response.json()
print('Content:', response_content)
# Out:
# Response: 200
# Content: {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/fa4a3c72', 'metadatos': 'https://opendata.aemet.es/opendata/sh/0556af7a'}

# %% [markdown]
# The information is not directly accessible, but stored in another URLs that we can inspected.
#
# `"metadatos" contains the json-style data information storaged in "datos".` So this will be the first URL that I am requesting.

# %%
# View metadata content
sub_response = requests.get(response_content['metadatos'])
print('Response:', sub_response.status_code)

metadata_idema = sub_response.json()
display(metadata_idema)
# Out:
# Response: 200
# {'unidad_generadora': 'Servicio del Banco de Datos Nacional de Climatología',
#  'periodicidad': '1 vez al día',
#  'descripcion': 'Inventario de estaciones para el apartado Valores Climatología',
#  'formato': 'application/json',
#  'copyright': '© AEMET. Autorizado el uso de la información y su reproducción citando a AEMET como autora de la misma.',
#  'notaLegal': 'https://www.aemet.es/es/nota_legal',
#  'campos': [{'id': 'latitud',
#    'descripcion': 'latitud de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'provincia',
#    'descripcion': 'provincia donde reside la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'indicativo',
#    'descripcion': 'indicativo climatológico de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'altitud',
#    'descripcion': 'altitud de la estación ',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'nombre',
#    'descripcion': 'ubicación de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'indsinop',
#    'descripcion': 'Indicativo sinóptico',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'longitud',
#    'descripcion': 'longitud de la estación',
#    'tipo_datos': 'string',
#    'requerido': True}]}

# %% [markdown]
# The description I am interested at is located under de key: "campos". I access and save it.

# %%
# pandas.DataFrame-style metadata from "campos" key
pd.DataFrame(metadata_idema['campos'])
# Out:
#            id                              descripcion tipo_datos  requerido
# 0     latitud                   latitud de la estación     string       True
# 1   provincia       provincia donde reside la estación     string       True
# 2  indicativo  indicativo climatológico de la estación     string       True
# 3     altitud                  altitud de la estación      string       True
# 4      nombre                 ubicación de la estación     string       True
# 5    indsinop                     Indicativo sinóptico     string       True
# 6    longitud                  longitud de la estación     string       True

# %%
# Save metadata in a .csv
pd.DataFrame(metadata_idema['campos']).to_csv('./data/raw/metadata_AWS.csv', index = False)

# %% [markdown]
# Now that we understand fields contents, let's access "datos", inspect and save them too.

# %%
# View "datos" content. Renaming "sub_response" variable
sub_response = requests.get(response_content['datos'])
print('Response:', sub_response.status_code)

idema = sub_response.json()
display(idema)
# Out:
# Response: 200
# [{'latitud': '394924N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '490',
#   'indicativo': 'B013X',
#   'nombre': 'ESCORCA, LLUC',
#   'indsinop': '08304',
#   'longitud': '025309E'},
#  {'latitud': '394744N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '5',
#   'indicativo': 'B051A',
#   'nombre': 'SÓLLER, PUERTO',
#   'indsinop': '08316',
#   'longitud': '024129E'},
#  {'latitud': '394121N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '60',
#   'indicativo': 'B087X',
#   'nombre': 'BANYALBUFAR',
#   'indsinop': '',
#   'longitud': '023046E'},
#  {'latitud': '393445N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '52',
#   'indicativo': 'B103B',
#   'nombre': 'ANDRATX - SANT ELM',
#   'indsinop': '99103',
#   'longitud': '022208E'},
#  {'latitud': '393305N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '50',
#   'indicativo': 'B158X',
#   'nombre': 'CALVIÀ, ES CAPDELLÀ',
#   'indsinop': '',
#   'longitud': '022759E'},
#  {'latitud': '393319N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '3',
#   'indicativo': 'B228',
#   'nombre': 'PALMA, PUERTO',
#   'indsinop': '08301',
#   'longitud': '023731E'},
#  {'latitud': '393832N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '95',
#   'indicativo': 'B236C',
#   'nombre': 'PALMA, UNIVERSIDAD',
#   'indsinop': '',
#   'longitud': '023837E'},
#  {'latitud': '394406N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '1030',
#   'indicativo': 'B248',
#   'nombre': 'SIERRA DE ALFABIA, BUNYOLA',
#   'indsinop': '08303',
#   'longitud': '024247E'},
#  {'latitud': '393621N',
#   'provincia': 'BALEARES',
#   'altitud': '49',
#   'indicativo': 'B275E',
#   'nombre': 'SON BONET, AEROPUERTO',
#   'indsinop': '08302',
#   'longitud': '024224E'},
#  {'latitud': '393339N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '8',
#   'indicativo': 'B278',
#   'nombre': 'PALMA DE MALLORCA, AEROPUERTO',
#   'indsinop': '08306',
#   'longitud': '024412E'},
#  {'latitud': '392247N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '113',
#   'indicativo': 'B301',
#   'nombre': 'LLUCMAJOR, CAP BLANC',
#   'indsinop': '08308',
#   'longitud': '024706E'},
#  {'latitud': '392944N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '140',
#   'indicativo': 'B334X',
#   'nombre': 'LLUCMAJOR',
#   'indsinop': '',
#   'longitud': '025330E'},
#  {'latitud': '393022N',
#   'provincia': 'BALEARES',
#   'altitud': '149',
#   'indicativo': 'B341X',
#   'nombre': 'PORRERES',
#   'indsinop': '',
#   'longitud': '030020E'},
#  {'latitud': '393118N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '120',
#   'indicativo': 'B346X',
#   'nombre': 'PORRERES',
#   'indsinop': '08310',
#   'longitud': '030109E'},
#  {'latitud': '392421N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '40',
#   'indicativo': 'B362X',
#   'nombre': 'CAMPOS, CAN SION',
#   'indsinop': '',
#   'longitud': '030351E'},
#  {'latitud': '392104N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '3',
#   'indicativo': 'B373X',
#   'nombre': 'CAMPOS, SALINES LLEVANT',
#   'indsinop': '',
#   'longitud': '030043E'},
#  {'latitud': '390808N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '165',
#   'indicativo': 'B398A',
#   'nombre': 'CABRERA, PARQUE NACIONAL DE CABRERA',
#   'indsinop': '',
#   'longitud': '025612E'},
#  {'latitud': '392024N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '45',
#   'indicativo': 'B410B',
#   'nombre': 'SANTANYÍ',
#   'indsinop': '',
#   'longitud': '030845E'},
#  {'latitud': '392452N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '17',
#   'indicativo': 'B434X',
#   'nombre': 'PORTOCOLOM  ',
#   'indsinop': '08309',
#   'longitud': '031618E'},
#  {'latitud': '393749N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '25',
#   'indicativo': 'B496X',
#   'nombre': 'SON SERVERA',
#   'indsinop': '',
#   'longitud': '032301E'},
#  {'latitud': '394119N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '110',
#   'indicativo': 'B526X',
#   'nombre': 'ARTÀ',
#   'indsinop': '',
#   'longitud': '032104E'},
#  {'latitud': '394300N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '57',
#   'indicativo': 'B569X',
#   'nombre': 'CAPDEPERA',
#   'indsinop': '08311',
#   'longitud': '032841E'},
#  {'latitud': '394323N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '99',
#   'indicativo': 'B603X',
#   'nombre': 'ARTÀ-COLÒNIA DE SANT PERE',
#   'indsinop': '',
#   'longitud': '031643E'},
#  {'latitud': '394748N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '2',
#   'indicativo': 'B605X',
#   'nombre': "MURO, S'ALBUFERA",
#   'indsinop': '',
#   'longitud': '030617E'},
#  {'latitud': '393325N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '95',
#   'indicativo': 'B614E',
#   'nombre': 'MANACOR',
#   'indsinop': '',
#   'longitud': '031304E'},
#  {'latitud': '393659N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '95',
#   'indicativo': 'B640X',
#   'nombre': 'PETRA',
#   'indsinop': '',
#   'longitud': '030716E'},
#  {'latitud': '393836N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '120',
#   'indicativo': 'B644B',
#   'nombre': 'SINEU',
#   'indsinop': '',
#   'longitud': '030008E'},
#  {'latitud': '393909N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '121',
#   'indicativo': 'B656A',
#   'nombre': 'SANTA MARÍA DEL CAMÍ',
#   'indsinop': '',
#   'longitud': '024801E'},
#  {'latitud': '394041N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '105',
#   'indicativo': 'B662X',
#   'nombre': 'BINISSALEM',
#   'indsinop': '',
#   'longitud': '025226E'},
#  {'latitud': '394734N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '842',
#   'indicativo': 'B684A',
#   'nombre': 'ESCORCA, SON TORRELLA',
#   'indsinop': '',
#   'longitud': '024716E'},
#  {'latitud': '394454N',
#   'provincia': 'BALEARES',
#   'altitud': '40',
#   'indicativo': 'B691',
#   'nombre': 'LA PUEBLA (SA CANOVA)',
#   'indsinop': '',
#   'longitud': '030055E'},
#  {'latitud': '394457N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '40',
#   'indicativo': 'B691Y',
#   'nombre': 'SA POBLA',
#   'indsinop': '08312',
#   'longitud': '030100E'},
#  {'latitud': '395237N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '35',
#   'indicativo': 'B760X',
#   'nombre': 'POLLENÇA',
#   'indsinop': '',
#   'longitud': '030127E'},
#  {'latitud': '395434N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '2',
#   'indicativo': 'B780X',
#   'nombre': 'PORT DE POLLENÇA',
#   'indsinop': '',
#   'longitud': '030601E'},
#  {'latitud': '395234N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '78',
#   'indicativo': 'B800X',
#   'nombre': 'LA MOLA, MAÓ',
#   'indsinop': '',
#   'longitud': '041926E'},
#  {'latitud': '395926N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '80',
#   'indicativo': 'B825B',
#   'nombre': 'ES MERCADAL',
#   'indsinop': '',
#   'longitud': '040511E'},
#  {'latitud': '395934N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '20',
#   'indicativo': 'B860X',
#   'nombre': 'CIUTADELLA',
#   'indsinop': '',
#   'longitud': '035114E'},
#  {'latitud': '395641N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '43',
#   'indicativo': 'B870C',
#   'nombre': 'CIUTADELLA, CALA GALDANA',
#   'indsinop': '',
#   'longitud': '035724E'},
#  {'latitud': '395117N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '91',
#   'indicativo': 'B893',
#   'nombre': 'MENORCA, AEROPUERTO',
#   'indsinop': '08314',
#   'longitud': '041256E'},
#  {'latitud': '390322N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '110',
#   'indicativo': 'B908X',
#   'nombre': 'SANT JOAN DE LABRITJA',
#   'indsinop': '',
#   'longitud': '012933E'},
#  {'latitud': '385747N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '32',
#   'indicativo': 'B925',
#   'nombre': 'SANT ANTONI DE PORTMANY',
#   'indsinop': '',
#   'longitud': '011917E'},
#  {'latitud': '385235N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '6',
#   'indicativo': 'B954',
#   'nombre': 'IBIZA, AEROPUERTO',
#   'indsinop': '08373',
#   'longitud': '012304E'},
#  {'latitud': '385521N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '3',
#   'indicativo': 'B957',
#   'nombre': 'EIVISSA',
#   'indsinop': '',
#   'longitud': '012629E'},
#  {'latitud': '384137N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '24',
#   'indicativo': 'B986',
#   'nombre': 'FORMENTERA',
#   'indsinop': '',
#   'longitud': '012749E'},
#  {'latitud': '285806N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '376',
#   'indicativo': 'C018J',
#   'nombre': 'TÍAS',
#   'indsinop': '',
#   'longitud': '134129W'},
#  {'latitud': '285127N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '6',
#   'indicativo': 'C019V',
#   'nombre': 'YAIZA',
#   'indsinop': '',
#   'longitud': '135010W'},
#  {'latitud': '285707N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '14',
#   'indicativo': 'C029O',
#   'nombre': 'LANZAROTE AEROPUERTO',
#   'indsinop': '60040',
#   'longitud': '133601W'},
#  {'latitud': '290837N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '277',
#   'indicativo': 'C038N',
#   'nombre': 'HARÍA',
#   'indsinop': '',
#   'longitud': '132921W'},
#  {'latitud': '290233N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '275',
#   'indicativo': 'C048W',
#   'nombre': 'TINAJO',
#   'indsinop': '',
#   'longitud': '134051W'},
#  {'latitud': '284521N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '2223',
#   'indicativo': 'C101A',
#   'nombre': 'ROQUE DE LOS MUCHACHOS',
#   'indsinop': '',
#   'longitud': '175343W'},
#  {'latitud': '284539N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '684',
#   'indicativo': 'C117A',
#   'nombre': 'PUNTAGORDA',
#   'indsinop': '',
#   'longitud': '175908W'},
#  {'latitud': '284029N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '733',
#   'indicativo': 'C117Z',
#   'nombre': 'TIJARAFE',
#   'indsinop': '',
#   'longitud': '175613W'},
#  {'latitud': '283914N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '844',
#   'indicativo': 'C126A',
#   'nombre': 'EL PASO',
#   'indsinop': '',
#   'longitud': '175112W'},
#  {'latitud': '282718N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '30',
#   'indicativo': 'C129V',
#   'nombre': 'FUENCALIENTE',
#   'indsinop': '',
#   'longitud': '175028W'},
#  {'latitud': '283545N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '62',
#   'indicativo': 'C129Z',
#   'nombre': 'TAZACORTE',
#   'indsinop': '60004',
#   'longitud': '175455W'},
#  {'latitud': '283759N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '33',
#   'indicativo': 'C139E',
#   'nombre': 'LA PALMA AEROPUERTO',
#   'indsinop': '60005',
#   'longitud': '174518W'},
#  {'latitud': '284818N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '362',
#   'indicativo': 'C148F',
#   'nombre': 'SAN ANDRÉS Y SAUCES',
#   'indsinop': '',
#   'longitud': '174657W'},
#  {'latitud': '280257N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '15',
#   'indicativo': 'C229J',
#   'nombre': 'PÁJARA',
#   'indsinop': '60034',
#   'longitud': '142129W'},
#  {'latitud': '281231N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '1',
#   'indicativo': 'C239N',
#   'nombre': 'TUINEJE,PUERTO GRAN TARAJAL',
#   'indsinop': '',
#   'longitud': '140123W'},
#  {'latitud': '282502N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '252',
#   'indicativo': 'C248E',
#   'nombre': 'ANTIGUA',
#   'indsinop': '',
#   'longitud': '140110W'},
#  {'latitud': '282641N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '25',
#   'indicativo': 'C249I',
#   'nombre': 'FUERTEVENTURA AEROPUERTO',
#   'indsinop': '60035',
#   'longitud': '135147W'},
#  {'latitud': '283645N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '217',
#   'indicativo': 'C258K',
#   'nombre': 'LA OLIVA',
#   'indsinop': '',
#   'longitud': '135555W'},
#  {'latitud': '280625N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1475',
#   'indicativo': 'C314Z',
#   'nombre': 'VALLEHERMOSO, ALTO IGUALERO  ',
#   'indsinop': '',
#   'longitud': '171457W'},
#  {'latitud': '280742N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '916',
#   'indicativo': 'C316I',
#   'nombre': 'ARURE',
#   'indsinop': '',
#   'longitud': '171854W'},
#  {'latitud': '281044N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '765',
#   'indicativo': 'C317B',
#   'nombre': 'AGULO',
#   'indsinop': '',
#   'longitud': '171247W'},
#  {'latitud': '280316N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '190',
#   'indicativo': 'C319W',
#   'nombre': 'VALLEHERMOSO, DAMA',
#   'indsinop': '',
#   'longitud': '171824W'},
#  {'latitud': '280949N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '252',
#   'indicativo': 'C328W',
#   'nombre': 'HERMIGUA',
#   'indsinop': '',
#   'longitud': '171139W'},
#  {'latitud': '280154N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '219',
#   'indicativo': 'C329B',
#   'nombre': 'LA GOMERA, AEROPUERTO',
#   'indsinop': '60007',
#   'longitud': '171239W'},
#  {'latitud': '280523N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '15',
#   'indicativo': 'C329Z',
#   'nombre': 'SAN SEBASTIÁN DE LA GOMERA',
#   'indsinop': '60008',
#   'longitud': '170641W'},
#  {'latitud': '281327N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '2150',
#   'indicativo': 'C406G',
#   'nombre': 'LA OROTAVA, CAÑADAS TEIDE',
#   'indsinop': '',
#   'longitud': '163735W'},
#  {'latitud': '281311N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '2071',
#   'indicativo': 'C412N',
#   'nombre': 'CITFAGRO_89_CHAVAO',
#   'indsinop': '',
#   'longitud': '164219W'},
#  {'latitud': '281819N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '990',
#   'indicativo': 'C415A',
#   'nombre': 'CITFAGRO_64_HOYOS',
#   'indsinop': '',
#   'longitud': '164820W'},
#  {'latitud': '281400N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '735',
#   'indicativo': 'C417J',
#   'nombre': 'CITFAGRO_74_CHIO',
#   'indsinop': '',
#   'longitud': '164721W'},
#  {'latitud': '281252N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '476',
#   'indicativo': 'C418I',
#   'nombre': 'CITFAGRO_05_GUIAISO1',
#   'indsinop': '',
#   'longitud': '164723W'},
#  {'latitud': '281201N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '700',
#   'indicativo': 'C418L',
#   'nombre': 'CITFAGRO_76_POZO',
#   'indsinop': '',
#   'longitud': '164547W'},
#  {'latitud': '281225N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '403',
#   'indicativo': 'C419L',
#   'nombre': 'LOMO DEL BALO',
#   'indsinop': '',
#   'longitud': '164731W'},
#  {'latitud': '280453N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '130',
#   'indicativo': 'C419X',
#   'nombre': 'ADEJE',
#   'indsinop': '',
#   'longitud': '164240W'},
#  {'latitud': '281019N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1833',
#   'indicativo': 'C422A',
#   'nombre': 'CITFAGRO_94_LOSTOPOS',
#   'indsinop': '',
#   'longitud': '163905W'},
#  {'latitud': '281327N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1654',
#   'indicativo': 'C423R',
#   'nombre': 'CITFAGRO_90_PICACHO',
#   'indsinop': '',
#   'longitud': '163116W'},
#  {'latitud': '280839N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1258',
#   'indicativo': 'C426E',
#   'nombre': 'CITFAGRO_13_VILAFLOR',
#   'indsinop': '',
#   'longitud': '163741W'},
#  {'latitud': '280737N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '880',
#   'indicativo': 'C426I',
#   'nombre': 'CITFAGRO_77_PINAL',
#   'indsinop': '',
#   'longitud': '163621W'},
#  {'latitud': '281301N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '930',
#   'indicativo': 'C426R',
#   'nombre': 'CITFAGRO_09_HELECHO',
#   'indsinop': '',
#   'longitud': '162926W'},
#  {'latitud': '281052N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '418',
#   'indicativo': 'C428T',
#   'nombre': 'ARICO',
#   'indsinop': '',
#   'longitud': '162901W'},
#  {'latitud': '280752N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '135',
#   'indicativo': 'C428U',
#   'nombre': 'CITFAGRO_01_ARICO',
#   'indsinop': '',
#   'longitud': '162821W'},
#  {'latitud': '280249N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'indsinop': '60025',
#   'longitud': '163340W'},
#  {'latitud': '281832N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '2369',
#   'indicativo': 'C430E',
#   'nombre': 'IZAÑA',
#   'indsinop': '60010',
#   'longitud': '162958W'},
#  {'latitud': '281935N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '290',
#   'indicativo': 'C436I',
#   'nombre': 'CITFAGRO_54_TOPONEGRO',
#   'indsinop': '',
#   'longitud': '162420W'},
#  {'latitud': '282214N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '525',
#   'indicativo': 'C436L',
#   'nombre': 'CITFAGRO_96_ARAYA',
#   'indsinop': '',
#   'longitud': '162351W'},
#  {'latitud': '281611N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '500',
#   'indicativo': 'C437E',
#   'nombre': 'CITFAGRO_81_MENA',
#   'indsinop': '',
#   'longitud': '162511W'},
#  {'latitud': '282132N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '463',
#   'indicativo': 'C438N',
#   'nombre': 'CANDELARIA',
#   'indsinop': '',
#   'longitud': '162405W'},
#  {'latitud': '281906N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'indsinop': '60018',
#   'longitud': '162256W'},
#  {'latitud': '283136N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '868',
#   'indicativo': 'C446G',
#   'nombre': 'SAN CRISTÓBAL DE LA LAGUNA,LLANO DE LOS LOROS',
#   'indsinop': '',
#   'longitud': '161650W'},
#  {'latitud': '282839N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'indsinop': '60015',
#   'longitud': '161946W'},
#  {'latitud': '282745N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '136',
#   'indicativo': 'C448C',
#   'nombre': 'CITFAGRO_92_SANTACRUZ',
#   'indsinop': '',
#   'longitud': '161624W'},
#  {'latitud': '282748N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '36',
#   'indicativo': 'C449C',
#   'nombre': 'STA. CRUZ DE TENERIFE',
#   'indsinop': '60020',
#   'longitud': '161519W'},
#  {'latitud': '283029N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '19',
#   'indicativo': 'C449F',
#   'nombre': 'ANAGA ',
#   'indsinop': '',
#   'longitud': '161144W'},
#  {'latitud': '283336N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '305',
#   'indicativo': 'C449Q',
#   'nombre': 'CITFAGRO_97_TAGANANA',
#   'indsinop': '',
#   'longitud': '161341W'},
#  {'latitud': '282341N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1744',
#   'indicativo': 'C453I',
#   'nombre': 'CITFAGRO_88_GAITERO',
#   'indsinop': '',
#   'longitud': '162600W'},
#  {'latitud': '282142N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1065',
#   'indicativo': 'C455M',
#   'nombre': 'CITFAGRO_87_AGUAMANSA',
#   'indsinop': '',
#   'longitud': '162949W'},
#  {'latitud': '282714N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '922',
#   'indicativo': 'C456E',
#   'nombre': 'CITFAGRO_10_RAVELO',
#   'indsinop': '',
#   'longitud': '162431W'},
#  {'latitud': '282141N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '906',
#   'indicativo': 'C456P',
#   'nombre': 'CITFAGRO_70_BENIJO',
#   'indsinop': '',
#   'longitud': '163248W'},
#  {'latitud': '282222N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '551',
#   'indicativo': 'C456R',
#   'nombre': 'CITFAGRO_69_SUERTE',
#   'indsinop': '',
#   'longitud': '163231W'},
#  {'latitud': '282658N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '650',
#   'indicativo': 'C457E',
#   'nombre': 'CITFAGRO_67_MATANZA',
#   'indsinop': '',
#   'longitud': '162617W'},
#  {'latitud': '282605N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '567',
#   'indicativo': 'C457I',
#   'nombre': 'LA VICTORIA DE ACENTEJO',
#   'indsinop': '',
#   'longitud': '162717W'},
#  {'latitud': '282947N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '310',
#   'indicativo': 'C458A',
#   'nombre': 'TACORONTE',
#   'indsinop': '',
#   'longitud': '162512W'},
#  {'latitud': '282207N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '595',
#   'indicativo': 'C458U',
#   'nombre': 'CITFAGRO_71_PALOB',
#   'indsinop': '',
#   'longitud': '163441W'},
#  {'latitud': '282505N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '25',
#   'indicativo': 'C459Z',
#   'nombre': 'PUERTO DE LA CRUZ',
#   'indsinop': '60012',
#   'longitud': '163253W'},
#  {'latitud': '282021N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '878',
#   'indicativo': 'C466O',
#   'nombre': 'CITFAGRO_91_CUBO',
#   'indsinop': '',
#   'longitud': '164740W'},
#  {'latitud': '282112N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '525',
#   'indicativo': 'C467I',
#   'nombre': 'CITFAGRO_73_REDON',
#   'indsinop': '',
#   'longitud': '164230W'},
#  {'latitud': '282201N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '218',
#   'indicativo': 'C468I',
#   'nombre': 'CITFAGRO_98_ELDRAGO',
#   'indsinop': '',
#   'longitud': '164320W'},
#  {'latitud': '282125N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '450',
#   'indicativo': 'C468O',
#   'nombre': 'CITFAGRO_62_TRIGO',
#   'indsinop': '',
#   'longitud': '164805W'},
#  {'latitud': '282223N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '677',
#   'indicativo': 'C468X',
#   'nombre': 'SAN JUAN DE LA RAMBLA',
#   'indsinop': '',
#   'longitud': '163733W'},
#  {'latitud': '275838N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '1702',
#   'indicativo': 'C611E',
#   'nombre': 'VEGA DE SAN MATEO',
#   'indsinop': '',
#   'longitud': '153502W'},
#  {'latitud': '280025N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '1514',
#   'indicativo': 'C612F',
#   'nombre': 'TEJEDA, CRUZ DE TEJEDA',
#   'indsinop': '',
#   'longitud': '153556W'},
#  {'latitud': '275943N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '1060',
#   'indicativo': 'C614H',
#   'nombre': 'TEJEDA',
#   'indsinop': '60038',
#   'longitud': '153657W'},
#  {'latitud': '280003N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C619I',
#   'nombre': 'LA ALDEA DE SAN NICOLÁS',
#   'indsinop': '60027',
#   'longitud': '154850W'},
#  {'latitud': '280604N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '5',
#   'indicativo': 'C619X',
#   'nombre': 'AGAETE',
#   'indsinop': '',
#   'longitud': '154246W'},
#  {'latitud': '280004N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '13',
#   'indicativo': 'C619Y',
#   'nombre': 'LA ALDEA DE SAN NICOLÁS',
#   'indsinop': '60027',
#   'longitud': '154827W'},
#  {'latitud': '275536N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '1220',
#   'indicativo': 'C623I',
#   'nombre': 'SAN BARTOLOME TIRAJANA, CUEVAS DEL PINAR',
#   'indsinop': '',
#   'longitud': '153600W'},
#  {'latitud': '275125N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '806',
#   'indicativo': 'C625O',
#   'nombre': 'SAN BARTOLOME TIRAJANA, LOMOS PEDRO AFONSO',
#   'indsinop': '',
#   'longitud': '153842W'},
#  {'latitud': '275432N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '318',
#   'indicativo': 'C628B',
#   'nombre': 'LA ALDEA DE SAN NICOLÁS, TASARTE',
#   'indsinop': '',
#   'longitud': '154612W'},
#  {'latitud': '274648N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C629Q',
#   'nombre': 'MOGÁN, PUERTO RICO',
#   'indsinop': '',
#   'longitud': '154240W'},
#  {'latitud': '274859N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C629X',
#   'nombre': 'MOGÁN, PUERTO',
#   'indsinop': '60036',
#   'longitud': '154551W'},
#  {'latitud': '275512N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '960',
#   'indicativo': 'C635B',
#   'nombre': 'SAN BARTOLOME TIRAJANA, LAS TIRAJANAS',
#   'indsinop': '',
#   'longitud': '153427W'},
#  {'latitud': '274529N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '45',
#   'indicativo': 'C639M',
#   'nombre': 'MASPALOMAS, C. INSULAR TURISMO ',
#   'indsinop': '',
#   'longitud': '153432W'},
#  {'latitud': '274845N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '41',
#   'indicativo': 'C639U',
#   'nombre': 'SAN BARTOLOME TIRAJANA, EL MATORRAL',
#   'indsinop': '',
#   'longitud': '152712W'},
#  {'latitud': '275409N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '306',
#   'indicativo': 'C648C',
#   'nombre': 'AGÜIMES',
#   'indsinop': '',
#   'longitud': '152714W'},
#  {'latitud': '275915N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '344',
#   'indicativo': 'C648N',
#   'nombre': 'TELDE, CENTRO FORESTAL DORAMAS',
#   'indsinop': '',
#   'longitud': '152728W'},
#  {'latitud': '275504N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '24',
#   'indicativo': 'C649I',
#   'nombre': 'GRAN CANARIA AEROPUERTO',
#   'indsinop': '60030',
#   'longitud': '152343W'},
#  {'latitud': '275913N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '9',
#   'indicativo': 'C649R',
#   'nombre': 'TELDE, MELENARA',
#   'indsinop': '',
#   'longitud': '152240W'},
#  {'latitud': '280431N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '683',
#   'indicativo': 'C656V',
#   'nombre': 'TEROR',
#   'indsinop': '',
#   'longitud': '153250W'},
#  {'latitud': '280430N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '269',
#   'indicativo': 'C658L',
#   'nombre': 'LAS PALMAS DE G.C. (TAFIRA CMT)',
#   'indsinop': '',
#   'longitud': '152703W'},
#  {'latitud': '280441N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '269',
#   'indicativo': 'C658X',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, TAFIRA',
#   'indsinop': '',
#   'longitud': '152712W'},
#  {'latitud': '280523N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '55',
#   'indicativo': 'C659H',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, SAN CRISTOBAL',
#   'indsinop': '60029',
#   'longitud': '152458W'},
#  {'latitud': '280647N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '15',
#   'indicativo': 'C659M',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, PL. DE LA FERIA',
#   'indsinop': '60032',
#   'longitud': '152517W'},
#  {'latitud': '280358N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '900',
#   'indicativo': 'C665T',
#   'nombre': 'VALLESECO',
#   'indsinop': '',
#   'longitud': '153357W'},
#  {'latitud': '280540N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '352',
#   'indicativo': 'C668V',
#   'nombre': 'AGAETE - SUERTE ALTA',
#   'indsinop': '',
#   'longitud': '154030W'},
#  {'latitud': '280830N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '86',
#   'indicativo': 'C669B',
#   'nombre': 'ARUCAS',
#   'indsinop': '',
#   'longitud': '153025W'},
#  {'latitud': '274409N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '6',
#   'indicativo': 'C689E',
#   'nombre': 'MASPALOMAS',
#   'indsinop': '60037',
#   'longitud': '153545W'},
#  {'latitud': '291355N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C839I',
#   'nombre': 'TEGUISE',
#   'indsinop': '',
#   'longitud': '133007W'},
#  {'latitud': '291346N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '19',
#   'indicativo': 'C839X',
#   'nombre': 'LA GRACIOSA',
#   'indsinop': '60045',
#   'longitud': '133037W'},
#  {'latitud': '274308N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '948',
#   'indicativo': 'C916Q',
#   'nombre': 'EL PINAR, DEPÓSITO',
#   'indsinop': '',
#   'longitud': '175841W'},
#  {'latitud': '274331N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '715',
#   'indicativo': 'C917E',
#   'nombre': 'EL PINAR, LA DEHESA',
#   'indsinop': '',
#   'longitud': '180654W'},
#  {'latitud': '273955N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '98',
#   'indicativo': 'C919K',
#   'nombre': 'TACORON-LAPILLAS-TORTUGA',
#   'indsinop': '',
#   'longitud': '180107W'},
#  {'latitud': '274607N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '1070',
#   'indicativo': 'C925F',
#   'nombre': 'SAN ANDRÉS, VALVERDE',
#   'indsinop': '',
#   'longitud': '175736W'},
#  {'latitud': '274839N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '670',
#   'indicativo': 'C928I',
#   'nombre': 'VALVERDE',
#   'indsinop': '',
#   'longitud': '175510W'},
#  {'latitud': '274908N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '32',
#   'indicativo': 'C929I',
#   'nombre': 'HIERRO AEROPUERTO',
#   'indsinop': '60001',
#   'longitud': '175320W'},
#  {'latitud': '274523N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '20',
#   'indicativo': 'C939T',
#   'nombre': 'FRONTERA, SABINOSA',
#   'indsinop': '',
#   'longitud': '180624W'},
#  {'latitud': '405729N',
#   'provincia': 'TARRAGONA',
#   'altitud': '32',
#   'indicativo': '0002I',
#   'nombre': 'VANDELLÒS  ',
#   'indsinop': '08169',
#   'longitud': '005217E'},
#  {'latitud': '411250N',
#   'provincia': 'TARRAGONA',
#   'altitud': '406',
#   'indicativo': '0009X',
#   'nombre': 'ALFORJA',
#   'indsinop': '',
#   'longitud': '005748E'},
#  {'latitud': '410842N',
#   'provincia': 'TARRAGONA',
#   'altitud': '71',
#   'indicativo': '0016A',
#   'nombre': 'REUS AEROPUERTO',
#   'indsinop': '08175',
#   'longitud': '010949E'},
#  {'latitud': '410915N',
#   'provincia': 'TARRAGONA',
#   'altitud': '118',
#   'indicativo': '0016B',
#   'nombre': 'REUS (CENTRE LECTURA)',
#   'indsinop': '',
#   'longitud': '010632E'},
#  {'latitud': '411735N',
#   'provincia': 'TARRAGONA',
#   'altitud': '233',
#   'indicativo': '0034X',
#   'nombre': 'VALLS',
#   'indsinop': '',
#   'longitud': '011539E'},
#  {'latitud': '410726N',
#   'provincia': 'TARRAGONA',
#   'altitud': '55',
#   'indicativo': '0042Y',
#   'nombre': 'TARRAGONA ',
#   'indsinop': '',
#   'longitud': '011457E'},
#  {'latitud': '412501N',
#   'provincia': 'BARCELONA',
#   'altitud': '632',
#   'indicativo': '0061X',
#   'nombre': 'PONTONS',
#   'indsinop': '',
#   'longitud': '013109E'},
#  {'latitud': '411949N',
#   'provincia': 'BARCELONA',
#   'altitud': '177',
#   'indicativo': '0066X',
#   'nombre': 'VILAFRANCA DEL PENEDÈS',
#   'indsinop': '',
#   'longitud': '014037E'},
#  {'latitud': '411438N',
#   'provincia': 'BARCELONA',
#   'altitud': '58',
#   'indicativo': '0073X',
#   'nombre': 'SITGES',
#   'indsinop': '',
#   'longitud': '015109E'},
#  {'latitud': '411734N',
#   'provincia': 'BARCELONA',
#   'altitud': '4',
#   'indicativo': '0076',
#   'nombre': 'BARCELONA AEROPUERTO',
#   'indsinop': '08181',
#   'longitud': '020412E'},
#  {'latitud': '420605N',
#   'provincia': 'BARCELONA',
#   'altitud': '682',
#   'indicativo': '0092X',
#   'nombre': 'BERGA',
#   'indsinop': '',
#   'longitud': '015127E'},
#  {'latitud': '415159N',
#   'provincia': 'BARCELONA',
#   'altitud': '361',
#   'indicativo': '0106X',
#   'nombre': 'BALSARENY',
#   'indsinop': '',
#   'longitud': '015221E'},
#  {'latitud': '420025N',
#   'provincia': 'BARCELONA',
#   'altitud': '700',
#   'indicativo': '0114X',
#   'nombre': 'PRATS DE LLUÇANÈS',
#   'indsinop': '',
#   'longitud': '020136E'},
#  {'latitud': '414848N',
#   'provincia': 'BARCELONA',
#   'altitud': '742',
#   'indicativo': '0120X',
#   'nombre': 'MOIÀ',
#   'indsinop': '',
#   'longitud': '020543E'},
#  {'latitud': '414312N',
#   'provincia': 'BARCELONA',
#   'altitud': '291',
#   'indicativo': '0149D',
#   'nombre': 'MANRESA (LA CULLA)',
#   'indsinop': '',
#   'longitud': '015025E'},
#  {'latitud': '414312N',
#   'provincia': 'BARCELONA',
#   'altitud': '291',
#   'indicativo': '0149X',
#   'nombre': 'MANRESA',
#   'indsinop': '08174',
#   'longitud': '015025E'},
#  {'latitud': '413540N',
#   'provincia': 'BARCELONA',
#   'altitud': '738',
#   'indicativo': '0158O',
#   'nombre': 'MONTSERRAT',
#   'indsinop': '',
#   'longitud': '015021E'},
#  {'latitud': '413540N',
#   'provincia': 'BARCELONA',
#   'altitud': '738',
#   'indicativo': '0158X',
#   'nombre': 'MONISTROL DE MONTSERRAT',
#   'indsinop': '',
#   'longitud': '015021E'},
#  {'latitud': '413444N',
#   'provincia': 'BARCELONA',
#   'altitud': '313',
#   'indicativo': '0171X',
#   'nombre': 'IGUALADA',
#   'indsinop': '08172',
#   'longitud': '013704E'},
#  {'latitud': '412429N',
#   'provincia': 'BARCELONA',
#   'altitud': '647',
#   'indicativo': '0194D',
#   'nombre': "CORBERA, PIC D'AGULLES",
#   'indsinop': '08179',
#   'longitud': '015306E'},
#  {'latitud': '412506N',
#   'provincia': 'BARCELONA',
#   'altitud': '408',
#   'indicativo': '0200E',
#   'nombre': 'BARCELONA, FABRA',
#   'indsinop': '',
#   'longitud': '020727E'},
#  {'latitud': '412326N',
#   'provincia': 'BARCELONA',
#   'altitud': '26',
#   'indicativo': '0201D',
#   'nombre': 'BARCELONA, PORT OLÍMPIC',
#   'indsinop': '08180',
#   'longitud': '021200E'},
#  {'latitud': '412230N',
#   'provincia': 'BARCELONA',
#   'altitud': '11',
#   'indicativo': '0201X',
#   'nombre': 'BARCELONA, DRASSANES',
#   'indsinop': '',
#   'longitud': '021026E'},
#  {'latitud': '413646N',
#   'provincia': 'BARCELONA',
#   'altitud': '175',
#   'indicativo': '0222X',
#   'nombre': 'CALDES DE MONTBUI',
#   'indsinop': '',
#   'longitud': '021006E'},
#  {'latitud': '413125N',
#   'provincia': 'BARCELONA',
#   'altitud': '146',
#   'indicativo': '0229I',
#   'nombre': 'SABADELL AEROPUERTO',
#   'indsinop': '08192',
#   'longitud': '020611E'},
#  {'latitud': '413018N',
#   'provincia': 'BARCELONA',
#   'altitud': '56',
#   'indicativo': '0244X',
#   'nombre': 'VILASSAR DE DALT',
#   'indsinop': '',
#   'longitud': '022145E'},
#  {'latitud': '413515N',
#   'provincia': 'BARCELONA',
#   'altitud': '74',
#   'indicativo': '0252D',
#   'nombre': 'ARENYS DE MAR',
#   'indsinop': '08186',
#   'longitud': '023224E'},
#  {'latitud': '413903N',
#   'provincia': 'BARCELONA',
#   'altitud': '40',
#   'indicativo': '0255B',
#   'nombre': 'SANTA SUSANNA',
#   'indsinop': '08188',
#   'longitud': '024149E'},
#  {'latitud': '414536N',
#   'provincia': 'BARCELONA',
#   'altitud': '936',
#   'indicativo': '0260X',
#   'nombre': 'FOGARS DE MONTCLÚS',
#   'indsinop': '',
#   'longitud': '022552E'},
#  {'latitud': '414037N',
#   'provincia': 'GIRONA',
#   'altitud': '45',
#   'indicativo': '0281Y',
#   'nombre': 'BLANES',
#   'indsinop': '',
#   'longitud': '024818E'},
#  {'latitud': '414828N',
#   'provincia': 'GIRONA',
#   'altitud': '14',
#   'indicativo': '0284X',
#   'nombre': "CASTELL, PLATJA D'ARO ",
#   'indsinop': '',
#   'longitud': '030151E'},
#  {'latitud': '415804N',
#   'provincia': 'GIRONA',
#   'altitud': '51',
#   'indicativo': '0294B',
#   'nombre': "LA BISBAL (D'EMPORDA 3)",
#   'indsinop': '',
#   'longitud': '030232E'},
#  {'latitud': '421530N',
#   'provincia': 'GIRONA',
#   'altitud': '851',
#   'indicativo': '0312X',
#   'nombre': 'SANT PAU DE SEGÚRIES',
#   'indsinop': '',
#   'longitud': '022152E'},
#  {'latitud': '421901N',
#   'provincia': 'GIRONA',
#   'altitud': '1151',
#   'indicativo': '0320I',
#   'nombre': 'PLANOLES',
#   'indsinop': '',
#   'longitud': '020610E'},
#  {'latitud': '421322N',
#   'provincia': 'GIRONA',
#   'altitud': '731',
#   'indicativo': '0321',
#   'nombre': 'CAMPDEVANOL',
#   'indsinop': '',
#   'longitud': '021002E'},
#  {'latitud': '421129N',
#   'provincia': 'GIRONA',
#   'altitud': '675',
#   'indicativo': '0324A',
#   'nombre': 'RIPOLL',
#   'indsinop': '08118',
#   'longitud': '021146E'},
#  {'latitud': '415048N',
#   'provincia': 'BARCELONA',
#   'altitud': '611',
#   'indicativo': '0341',
#   'nombre': 'TONA (ESCOLA)',
#   'indsinop': '',
#   'longitud': '021336E'},
#  {'latitud': '415049N',
#   'provincia': 'BARCELONA',
#   'altitud': '607',
#   'indicativo': '0341X',
#   'nombre': 'TONA',
#   'indsinop': '',
#   'longitud': '021321E'},
#  {'latitud': '415534N',
#   'provincia': 'BARCELONA',
#   'altitud': '578',
#   'indicativo': '0349',
#   'nombre': 'SANT JULIÀ  DE VILATORTA',
#   'indsinop': '08119',
#   'longitud': '021903E'},
#  {'latitud': '420310N',
#   'provincia': 'GIRONA',
#   'altitud': '322',
#   'indicativo': '0360X',
#   'nombre': "LES PLANES D'HOSTOLES",
#   'indsinop': '',
#   'longitud': '023304E'},
#  {'latitud': '415251N',
#   'provincia': 'GIRONA',
#   'altitud': '810',
#   'indicativo': '0363X',
#   'nombre': 'SANT HILARI',
#   'indsinop': '',
#   'longitud': '023048E'},
#  {'latitud': '415442N',
#   'provincia': 'GIRONA',
#   'altitud': '143',
#   'indicativo': '0367',
#   'nombre': 'GIRONA AEROPUERTO',
#   'indsinop': '08184',
#   'longitud': '024548E'},
#  {'latitud': '415848N',
#   'provincia': 'GIRONA',
#   'altitud': '95',
#   'indicativo': '0370B',
#   'nombre': 'GIRONA, ANTIC INSTITUT',
#   'indsinop': '',
#   'longitud': '024931E'},
#  {'latitud': '415820N',
#   'provincia': 'GIRONA',
#   'altitud': '76',
#   'indicativo': '0370E',
#   'nombre': 'GIRONA',
#   'indsinop': '',
#   'longitud': '024910E'},
#  {'latitud': '420616N',
#   'provincia': 'GIRONA',
#   'altitud': '157',
#   'indicativo': '0372C',
#   'nombre': 'PORQUERES',
#   'indsinop': '08120',
#   'longitud': '024549E'},
#  {'latitud': '420314N',
#   'provincia': 'GIRONA',
#   'altitud': '1',
#   'indicativo': '0385X',
#   'nombre': "L'ESTARTIT",
#   'indsinop': '',
#   'longitud': '031205E'},
#  {'latitud': '421238N',
#   'provincia': 'GIRONA',
#   'altitud': '350',
#   'indicativo': '0394X',
#   'nombre': 'LA VALL DE BIANYA',
#   'indsinop': '',
#   'longitud': '022819E'},
#  {'latitud': '421329N',
#   'provincia': 'GIRONA',
#   'altitud': '2',
#   'indicativo': '0411X',
#   'nombre': "CASTELLÓ D'EMPÚRIES",
#   'indsinop': '',
#   'longitud': '030535E'},
#  {'latitud': '422313N',
#   'provincia': 'GIRONA',
#   'altitud': '355',
#   'indicativo': '0413A',
#   'nombre': 'MAÇANET DE CABRENYS',
#   'indsinop': '',
#   'longitud': '024520E'},
#  {'latitud': '422324N',
#   'provincia': 'GIRONA',
#   'altitud': '100',
#   'indicativo': '0421E',
#   'nombre': "ESPOLLA 'LES ALBERES'",
#   'indsinop': '',
#   'longitud': '030022E'},
#  {'latitud': '422324N',
#   'provincia': 'GIRONA',
#   'altitud': '100',
#   'indicativo': '0421X',
#   'nombre': 'ESPOLLA',
#   'indsinop': '',
#   'longitud': '030022E'},
#  {'latitud': '421533N',
#   'provincia': 'GIRONA',
#   'altitud': '45',
#   'indicativo': '0429X',
#   'nombre': 'FIGUERES',
#   'indsinop': '',
#   'longitud': '025737E'},
#  {'latitud': '421909N',
#   'provincia': 'GIRONA',
#   'altitud': '75',
#   'indicativo': '0433D',
#   'nombre': 'CABO DE CREUS',
#   'indsinop': '08121',
#   'longitud': '031856E'},
#  {'latitud': '430809N',
#   'provincia': 'NAVARRA',
#   'altitud': '183',
#   'indicativo': '1002Y',
#   'nombre': 'BAZTAN, IRURITA ',
#   'indsinop': '08030',
#   'longitud': '013235W'},
#  {'latitud': '431643N',
#   'provincia': 'NAVARRA',
#   'altitud': '54',
#   'indicativo': '1010X',
#   'nombre': 'BERA',
#   'indsinop': '',
#   'longitud': '014033W'},
#  {'latitud': '431935N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '120',
#   'indicativo': '1012P',
#   'nombre': 'IRUN',
#   'indsinop': '',
#   'longitud': '014748W'},
#  {'latitud': '432125N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '4',
#   'indicativo': '1014',
#   'nombre': 'HONDARRIBIA, MALKARROA',
#   'indsinop': '08029',
#   'longitud': '014732W'},
#  {'latitud': '432125N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '4',
#   'indicativo': '1014A',
#   'nombre': 'DONOSTIA / SAN SEBASTIÁN AEROPUERTO',
#   'indsinop': '08029',
#   'longitud': '014732W'},
#  {'latitud': '431247N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '165',
#   'indicativo': '1021X',
#   'nombre': 'ERRENTERIA, AÑARBE',
#   'indsinop': '',
#   'longitud': '015244W'},
#  {'latitud': '431244N',
#   'provincia': 'NAVARRA',
#   'altitud': '305',
#   'indicativo': '1021Y',
#   'nombre': 'ARTICUTZA (AUTOMATICA)',
#   'indsinop': '',
#   'longitud': '014752W'},
#  {'latitud': '431823N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '250',
#   'indicativo': '1024E',
#   'nombre': 'DONOSTIA / SAN SEBASTIÁN, IGELDO',
#   'indsinop': '08027',
#   'longitud': '020228W'},
#  {'latitud': '430056N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '255',
#   'indicativo': '1025A',
#   'nombre': 'SEGURA',
#   'indsinop': '',
#   'longitud': '021524W'},
#  {'latitud': '430317N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '255',
#   'indicativo': '1025X',
#   'nombre': 'BEASAIN, ARRIARAN',
#   'indsinop': '',
#   'longitud': '021355W'},
#  {'latitud': '430329N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '290',
#   'indicativo': '1026X',
#   'nombre': 'ORDIZIA',
#   'indsinop': '',
#   'longitud': '021103W'},
#  {'latitud': '430506N',
#   'provincia': 'NAVARRA',
#   'altitud': '520',
#   'indicativo': '1033X',
#   'nombre': 'ARESO',
#   'indsinop': '',
#   'longitud': '015703W'},
#  {'latitud': '430306N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '460',
#   'indicativo': '1037X',
#   'nombre': 'LEGAZPI',
#   'indsinop': '',
#   'longitud': '022013W'},
#  {'latitud': '430448N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '420',
#   'indicativo': '1037Y',
#   'nombre': 'ZUMARRAGA',
#   'indsinop': '08037',
#   'longitud': '021903W'},
#  {'latitud': '431021N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '180',
#   'indicativo': '1038X',
#   'nombre': 'AZPEITIA',
#   'indsinop': '',
#   'longitud': '021602W'},
#  {'latitud': '431808N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '28',
#   'indicativo': '1041A',
#   'nombre': 'ZUMAIA',
#   'indsinop': '08026',
#   'longitud': '021504W'},
#  {'latitud': '430328N',
#   'provincia': 'ARABA/ALAVA',
#   'altitud': '617',
#   'indicativo': '1044X',
#   'nombre': 'ARAMAIO, ETXAGUEN',
#   'indsinop': '',
#   'longitud': '023522W'},
#  {'latitud': '430130N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '308',
#   'indicativo': '1048X',
#   'nombre': 'ARETXABALETA',
#   'indsinop': '',
#   'longitud': '022756W'},
#  {'latitud': '430818N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '470',
#   'indicativo': '1049N',
#   'nombre': 'ELGETA',
#   'indsinop': '',
#   'longitud': '022945W'},
#  {'latitud': '431234N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '119',
#   'indicativo': '1050J',
#   'nombre': 'ELGOIBAR',
#   'indsinop': '08036',
#   'longitud': '022448W'},
#  {'latitud': '431902N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '150',
#   'indicativo': '1052A',
#   'nombre': 'MUTRIKU',
#   'indsinop': '',
#   'longitud': '022350W'},
#  {'latitud': '432237N',
#   'provincia': 'BIZKAIA',
#   'altitud': '12',
#   'indicativo': '1055B',
#   'nombre': 'LEKEITIO',
#   'indsinop': '08024',
#   'longitud': '023037W'},
#  {'latitud': '432033N',
#   'provincia': 'BIZKAIA',
#   'altitud': '45',
#   'indicativo': '1056K',
#   'nombre': 'FORUA',
#   'indsinop': '',
#   'longitud': '024016W'},
#  {'latitud': '432714N',
#   'provincia': 'BIZKAIA',
#   'altitud': '93',
#   'indicativo': '1057B',
#   'nombre': 'MATXITXAKO',
#   'indsinop': '',
#   'longitud': '024510W'},
#  {'latitud': '432230N',
#   'provincia': 'BIZKAIA',
#   'altitud': '90',
#   'indicativo': '1059X',
#   'nombre': 'PUNTA GALEA',
#   'indsinop': '08059',
#   'longitud': '030118W'},
#  {'latitud': '430301N',
#   'provincia': 'ARABA/ALAVA',
#   'altitud': '240',
#   'indicativo': '1060X',
#   'nombre': 'AMURRIO',
#   'indsinop': '',
#   'longitud': '030020W'},
#  {'latitud': '430544N',
#   'provincia': 'BIZKAIA',
#   'altitud': '270',
#   'indicativo': '1064L',
#   'nombre': 'OROZKO, IBARRA',
#   'indsinop': '',
#   'longitud': '025137W'},
#  {'latitud': '430557N',
#   'provincia': 'BIZKAIA',
#   'altitud': '747',
#   'indicativo': '1069Y',
#   'nombre': 'ABADIÑO, URKIOLA',
#   'indsinop': '',
#   'longitud': '023839W'},
#  {'latitud': '431210N',
#   'provincia': 'BIZKAIA',
#   'altitud': '100',
#   'indicativo': '1074C',
#   'nombre': 'AMOREBIETA-ETXANO',
#   'indsinop': '',
#   'longitud': '024222W'},
#  {'latitud': '431050N',
#   'provincia': 'BIZKAIA',
#   'altitud': '210',
#   'indicativo': '1078C',
#   'nombre': 'BALMASEDA',
#   'indsinop': '',
#   'longitud': '031235W'},
#  {'latitud': '431212N',
#   'provincia': 'BIZKAIA',
#   'altitud': '208',
#   'indicativo': '1078I',
#   'nombre': 'GÜEÑES',
#   'indsinop': '08035',
#   'longitud': '030617W'},
#  {'latitud': '431753N',
#   'provincia': 'BIZKAIA',
#   'altitud': '42',
#   'indicativo': '1082',
#   'nombre': 'BILBAO AEROPUERTO',
#   'indsinop': '08025',
#   'longitud': '025423W'},
#  {'latitud': '431647N',
#   'provincia': 'BIZKAIA',
#   'altitud': '177',
#   'indicativo': '1083B',
#   'nombre': 'SOPUERTA',
#   'indsinop': '',
#   'longitud': '031007W'},
#  {'latitud': '432341N',
#   'provincia': 'CANTABRIA',
#   'altitud': '45',
#   'indicativo': '1083L',
#   'nombre': 'CASTRO URDIALES',
#   'indsinop': '08020',
#   'longitud': '031402W'},
#  {'latitud': '431521N',
#   'provincia': 'CANTABRIA',
#   'altitud': '80',
#   'indicativo': '1089U',
#   'nombre': 'RAMALES DE LA VICTORIA',
#   'indsinop': '',
#   'longitud': '032815W'},
#  {'latitud': '432348N',
#   'provincia': 'CANTABRIA',
#   'altitud': '1',
#   'indicativo': '1096X',
#   'nombre': 'BARCENA DE CICERO, TRETO',
#   'indsinop': '',
#   'longitud': '032811W'},
#  {'latitud': '431339N',
#   'provincia': 'CANTABRIA',
#   'altitud': '849',
#   'indicativo': '1103X',
#   'nombre': 'SAN ROQUE DE RIOMIERA',
#   'indsinop': '',
#   'longitud': '034316W'},
#  {'latitud': '432526N',
#   'provincia': 'CANTABRIA',
#   'altitud': '3',
#   'indicativo': '1109',
#   'nombre': 'SANTANDER AEROPUERTO',
#   'indsinop': '08021',
#   'longitud': '034932W'},
#  {'latitud': '432543N',
#   'provincia': 'CANTABRIA',
#   'altitud': '3',
#   'indicativo': '1109X',
#   'nombre': 'SANTANDER AEROPUERTO',
#   'indsinop': '08021',
#   'longitud': '034953W'},
#  {'latitud': '432754N',
#   'provincia': 'CANTABRIA',
#   'altitud': '64',
#   'indicativo': '1110',
#   'nombre': 'SANTANDER, CIUDAD',
#   'indsinop': '',
#   'longitud': '034908W'},
#  {'latitud': '432928N',
#   'provincia': 'CANTABRIA',
#   'altitud': '52',
#   'indicativo': '1111',
#   'nombre': 'SANTANDER',
#   'indsinop': '08023',
#   'longitud': '034802W'},
#  {'latitud': '432928N',
#   'provincia': 'CANTABRIA',
#   'altitud': '51',
#   'indicativo': '1111X',
#   'nombre': 'SANTANDER',
#   'indsinop': '08023',
#   'longitud': '034802W'},
#  {'latitud': '431444N',
#   'provincia': 'CANTABRIA',
#   'altitud': '196',
#   'indicativo': '1124E',
#   'nombre': 'VILLACARRIEDO',
#   'indsinop': '',
#   'longitud': '035058W'},
#  {'latitud': '430849N',
#   'provincia': 'CANTABRIA',
#   'altitud': '460',
#   'indicativo': '1135C',
#   'nombre': 'LOS TOJOS, BÁRCENA MAYOR',
#   'indsinop': '',
#   'longitud': '041251W'},
#  {'latitud': '431619N',
#   'provincia': 'CANTABRIA',
#   'altitud': '105',
#   'indicativo': '1152C',
#   'nombre': 'SAN FELICES DE BUELNA',
#   'indsinop': '',
#   'longitud': '040255W'},
#  {'latitud': '432131N',
#   'provincia': 'CANTABRIA',
#   'altitud': '110',
#   'indicativo': '1154H',
#   'nombre': 'TORRELAVEGA, SIERRAPANDO',
#   'indsinop': '',
#   'longitud': '040139W'},
#  {'latitud': '432336N',
#   'provincia': 'CANTABRIA',
#   'altitud': '38',
#   'indicativo': '1159',
#   'nombre': 'SAN VICENTE DE LA BARQUERA',
#   'indsinop': '08017',
#   'longitud': '042332W'},
#  {'latitud': '430838N',
#   'provincia': 'CANTABRIA',
#   'altitud': '1100',
#   'indicativo': '1167B',
#   'nombre': 'CAMALEÑO, FUENTE DE',
#   'indsinop': '',
#   'longitud': '044846W'},
#  {'latitud': '430918N',
#   'provincia': 'CANTABRIA',
#   'altitud': '1910',
#   'indicativo': '1167G',
#   'nombre': 'MIRADOR DEL CABLE, PARQUE NACIONAL PICOS DE EUROPA',
#   'indsinop': '',
#   'longitud': '044811W'},
#  {'latitud': '430521N',
#   'provincia': 'CANTABRIA',
#   'altitud': '1722',
#   'indicativo': '1167J',
#   'nombre': 'CORISCAO, PARQUE NACIONAL PICOS DE EUROPA',
#   'indsinop': '',
#   'longitud': '044626W'},
#  {'latitud': '431058N',
#   'provincia': 'CANTABRIA',
#   'altitud': '251',
#   'indicativo': '1174I',
#   'nombre': 'CILLÓRIGO DE LIÉBANA, TAMA',
#   'indsinop': '',
#   'longitud': '043606W'},
#  {'latitud': '431521N',
#   'provincia': 'CANTABRIA',
#   'altitud': '940',
#   'indicativo': '1176A',
#   'nombre': 'TRESVISO',
#   'indsinop': '',
#   'longitud': '044006W'},
#  {'latitud': '431415N',
#   'provincia': 'ASTURIAS',
#   'altitud': '1236',
#   'indicativo': '1178R',
#   'nombre': 'SOTRES, PARQUE NACIONAL PICOS DE EUROPA',
#   'indsinop': '',
#   'longitud': '044412W'},
#  {'latitud': '430843N',
#   'provincia': 'LEON',
#   'altitud': '953',
#   'indicativo': '1178Y',
#   'nombre': 'POSADA DE VALDEÓN, SOTO ',
#   'indsinop': '',
#   'longitud': '045554W'},
#  {'latitud': '431840N',
#   'provincia': 'ASTURIAS',
#   'altitud': '458',
#   'indicativo': '1179B',
#   'nombre': 'CABRALES',
#   'indsinop': '',
#   'longitud': '045110W'},
#  {'latitud': '432513N',
#   'provincia': 'ASTURIAS',
#   'altitud': '10',
#   'indicativo': '1183X',
#   'nombre': 'LLANES',
#   'indsinop': '08016',
#   'longitud': '044453W'},
#  {'latitud': '431600N',
#   'provincia': 'ASTURIAS',
#   'altitud': '370',
#   'indicativo': '1186P',
#   'nombre': 'AMIEVA, PANIZALES',
#   'indsinop': '',
#   'longitud': '050709W'},
#  {'latitud': '432240N',
#   'provincia': 'ASTURIAS',
#   'altitud': '280',
#   'indicativo': '1199X',
#   'nombre': 'PILOÑA, BARGAÉU',
#   'indsinop': '',
#   'longitud': '052348W'},
#  {'latitud': '432933N',
#   'provincia': 'ASTURIAS',
#   'altitud': '30',
#   'indicativo': '1203D',
#   'nombre': 'COLUNGA',
#   'indsinop': '',
#   'longitud': '051450W'},
#  {'latitud': '433123N',
#   'provincia': 'ASTURIAS',
#   'altitud': '26',
#   'indicativo': '1207U',
#   'nombre': 'GIJÓN, CAMPUS',
#   'indsinop': '08065',
#   'longitud': '053716W'},
#  {'latitud': '433220N',
#   'provincia': 'ASTURIAS',
#   'altitud': '3',
#   'indicativo': '1208',
#   'nombre': 'GIJÓN',
#   'indsinop': '',
#   'longitud': '053815W'},
#  {'latitud': '433230N',
#   'provincia': 'ASTURIAS',
#   'altitud': '22',
#   'indicativo': '1208A',
#   'nombre': 'GIJÓN. LA MERCED',
#   'indsinop': '',
#   'longitud': '053943W'},
#  {'latitud': '433336N',
#   'provincia': 'ASTURIAS',
#   'altitud': '5',
#   'indicativo': '1208H',
#   'nombre': 'GIJÓN, PUERTO',
#   'indsinop': '08014',
#   'longitud': '054203W'},
#  {'latitud': '433921N',
#   'provincia': 'ASTURIAS',
#   'altitud': '100',
#   'indicativo': '1210X',
#   'nombre': 'CABO PEÑAS',
#   'indsinop': '08012',
#   'longitud': '055055W'},
#  {'latitud': '433401N',
#   'provincia': 'ASTURIAS',
#   'altitud': '127',
#   'indicativo': '1212E',
#   'nombre': 'ASTURIAS AEROPUERTO',
#   'indsinop': '08011',
#   'longitud': '060239W'},
#  {'latitud': '425843N',
#   'provincia': 'ASTURIAS',
#   'altitud': '1480',
#   'indicativo': '1221D',
#   'nombre': 'PAJARES-VALGRANDE',
#   'indsinop': '08031',
#   'longitud': '054635W'},
#  {'latitud': '430758N',
#   'provincia': 'ASTURIAS',
#   'altitud': '370',
#   'indicativo': '1223P',
#   'nombre': 'LENA, RONZÓN',
#   'indsinop': '',
#   'longitud': '054922W'},
#  {'latitud': '430543N',
#   'provincia': 'ASTURIAS',
#   'altitud': '750',
#   'indicativo': '1226X',
#   'nombre': 'ALLER, FELECHOSA',
#   'indsinop': '',
#   'longitud': '052837W'},
#  {'latitud': '431630N',
#   'provincia': 'ASTURIAS',
#   'altitud': '170',
#   'indicativo': '1234P',
#   'nombre': 'MIERES, BAIÑA',
#   'indsinop': '',
#   'longitud': '054909W'},
#  {'latitud': '432112N',
#   'provincia': 'ASTURIAS',
#   'altitud': '336',
#   'indicativo': '1249I',
#   'nombre': 'OVIEDO',
#   'indsinop': '08015',
#   'longitud': '055227W'},
#  {'latitud': '432112N',
# ...
#   'indsinop': '08087',
#   'longitud': '012831W'},
#  {'latitud': '415453N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '475',
#   'indicativo': '9299X',
#   'nombre': 'TARAZONA',
#   'indsinop': '',
#   'longitud': '014324W'},
#  {'latitud': '415732N',
#   'provincia': 'NAVARRA',
#   'altitud': '410',
#   'indicativo': '9301X',
#   'nombre': 'MONTEAGUDO',
#   'indsinop': '',
#   'longitud': '014126W'},
#  {'latitud': '420320N',
#   'provincia': 'NAVARRA',
#   'altitud': '297',
#   'indicativo': '9302Y',
#   'nombre': 'TUDELA',
#   'indsinop': '',
#   'longitud': '013634W'},
#  {'latitud': '420716N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '321',
#   'indicativo': '9321X',
#   'nombre': 'EJEA DE LOS CABALLEROS',
#   'indsinop': '',
#   'longitud': '010823W'},
#  {'latitud': '415903N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '543',
#   'indicativo': '9336D',
#   'nombre': 'CASTEJON DE VALDEJASA',
#   'indsinop': '',
#   'longitud': '005945W'},
#  {'latitud': '411259N',
#   'provincia': 'SORIA',
#   'altitud': '863',
#   'indicativo': '9344C',
#   'nombre': 'ARCOS DE JALÓN',
#   'indsinop': '',
#   'longitud': '021735W'},
#  {'latitud': '413429N',
#   'provincia': 'SORIA',
#   'altitud': '1000',
#   'indicativo': '9352A',
#   'nombre': 'ALMAZUL',
#   'indsinop': '',
#   'longitud': '020825W'},
#  {'latitud': '411735N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '703',
#   'indicativo': '9354X',
#   'nombre': 'ALHAMA DE ARAGON',
#   'indsinop': '',
#   'longitud': '015343W'},
#  {'latitud': '403400N',
#   'provincia': 'TERUEL',
#   'altitud': '1000',
#   'indicativo': '9374X',
#   'nombre': 'SANTA EULALIA DEL CAMPO',
#   'indsinop': '',
#   'longitud': '011915W'},
#  {'latitud': '404643N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '1185',
#   'indicativo': '9377Y',
#   'nombre': 'EL PEDREGAL',
#   'indsinop': '',
#   'longitud': '013406W'},
#  {'latitud': '405154N',
#   'provincia': 'TERUEL',
#   'altitud': '932',
#   'indicativo': '9381',
#   'nombre': 'CALAMOCHA, AERÓDROMO',
#   'indsinop': '',
#   'longitud': '011818W'},
#  {'latitud': '405534N',
#   'provincia': 'TERUEL',
#   'altitud': '884',
#   'indicativo': '9381I',
#   'nombre': 'CALAMOCHA',
#   'indsinop': '08233',
#   'longitud': '011736W'},
#  {'latitud': '410652N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '779',
#   'indicativo': '9390',
#   'nombre': 'DAROCA',
#   'indsinop': '08157',
#   'longitud': '012436W'},
#  {'latitud': '411952N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '582',
#   'indicativo': '9394X',
#   'nombre': 'CALATAYUD',
#   'indsinop': '08156',
#   'longitud': '013843W'},
#  {'latitud': '412852N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '370',
#   'indicativo': '9427X',
#   'nombre': 'LA ALMUNIA DE DOÑA GODINA',
#   'indsinop': '',
#   'longitud': '012251W'},
#  {'latitud': '413938N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '249',
#   'indicativo': '9434',
#   'nombre': 'ZARAGOZA, AEROPUERTO',
#   'indsinop': '08160',
#   'longitud': '010015W'},
#  {'latitud': '413716N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '258',
#   'indicativo': '9434P',
#   'nombre': 'ZARAGOZA, VALDESPARTERA',
#   'indsinop': '08159',
#   'longitud': '005605W'},
#  {'latitud': '405943N',
#   'provincia': 'TERUEL',
#   'altitud': '1255',
#   'indicativo': '9436X',
#   'nombre': 'FONFRÍA',
#   'indsinop': '',
#   'longitud': '010515W'},
#  {'latitud': '424545N',
#   'provincia': 'HUESCA',
#   'altitud': '1800',
#   'indicativo': '9445L',
#   'nombre': 'FORMIGAL, SARRIOS',
#   'indsinop': '08096',
#   'longitud': '002334W'},
#  {'latitud': '424216N',
#   'provincia': 'HUESCA',
#   'altitud': '1850',
#   'indicativo': '9451F',
#   'nombre': 'PANTICOSA, PETROSOS',
#   'indsinop': '08915',
#   'longitud': '001631W'},
#  {'latitud': '424157N',
#   'provincia': 'HUESCA',
#   'altitud': '1100',
#   'indicativo': '9453X',
#   'nombre': 'BIESCAS, EMBALSE DE BÚBAL',
#   'indsinop': '',
#   'longitud': '001908W'},
#  {'latitud': '423046N',
#   'provincia': 'HUESCA',
#   'altitud': '775',
#   'indicativo': '9460X',
#   'nombre': 'SABIÑÁNIGO',
#   'indsinop': '',
#   'longitud': '002120W'},
#  {'latitud': '420146N',
#   'provincia': 'HUESCA',
#   'altitud': '390',
#   'indicativo': '9491X',
#   'nombre': 'ALMUDÉVAR',
#   'indsinop': '',
#   'longitud': '003509W'},
#  {'latitud': '414748N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '405',
#   'indicativo': '9495Y',
#   'nombre': 'LECIÑENA',
#   'indsinop': '',
#   'longitud': '003702W'},
#  {'latitud': '412635N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '535',
#   'indicativo': '9501X',
#   'nombre': 'VALMADRID ',
#   'indsinop': '',
#   'longitud': '005309W'},
#  {'latitud': '412545N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '205',
#   'indicativo': '9510X',
#   'nombre': 'QUINTO',
#   'indsinop': '',
#   'longitud': '003014W'},
#  {'latitud': '410152N',
#   'provincia': 'TERUEL',
#   'altitud': '800',
#   'indicativo': '9513X',
#   'nombre': 'MUNIESA',
#   'indsinop': '',
#   'longitud': '004820W'},
#  {'latitud': '404943N',
#   'provincia': 'TERUEL',
#   'altitud': '895',
#   'indicativo': '9531Y',
#   'nombre': 'MONTALBÁN',
#   'indsinop': '',
#   'longitud': '004735W'},
#  {'latitud': '411019N',
#   'provincia': 'TERUEL',
#   'altitud': '305',
#   'indicativo': '9546B',
#   'nombre': 'HIJAR',
#   'indsinop': '',
#   'longitud': '002631W'},
#  {'latitud': '405828N',
#   'provincia': 'TERUEL',
#   'altitud': '762',
#   'indicativo': '9550C',
#   'nombre': 'ANDORRA, HORCALLANA',
#   'indsinop': '',
#   'longitud': '002428W'},
#  {'latitud': '404754N',
#   'provincia': 'TERUEL',
#   'altitud': '755',
#   'indicativo': '9561X',
#   'nombre': 'CASTELLOTE',
#   'indsinop': '',
#   'longitud': '001855W'},
#  {'latitud': '403718N',
#   'provincia': 'CASTELLON',
#   'altitud': '990',
#   'indicativo': '9562X',
#   'nombre': 'MORELLA',
#   'indsinop': '',
#   'longitud': '000607W'},
#  {'latitud': '402955N',
#   'provincia': 'CASTELLON',
#   'altitud': '1220',
#   'indicativo': '9563X',
#   'nombre': 'CASTELLFORT',
#   'indsinop': '08237',
#   'longitud': '001112W'},
#  {'latitud': '405648N',
#   'provincia': 'TERUEL',
#   'altitud': '466',
#   'indicativo': '9569A',
#   'nombre': 'CALANDA',
#   'indsinop': '08166',
#   'longitud': '001416W'},
#  {'latitud': '410329N',
#   'provincia': 'TERUEL',
#   'altitud': '334',
#   'indicativo': '9573X',
#   'nombre': 'ALCAÑIZ',
#   'indsinop': '08164',
#   'longitud': '000830W'},
#  {'latitud': '411433N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '215',
#   'indicativo': '9574B',
#   'nombre': 'CASPE, PLANA DEL PILÓN',
#   'indsinop': '08165',
#   'longitud': '000407W'},
#  {'latitud': '413121N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '357',
#   'indicativo': '9576C',
#   'nombre': 'BUJARALOZ',
#   'indsinop': '08165',
#   'longitud': '001028W'},
#  {'latitud': '421957N',
#   'provincia': 'GIRONA',
#   'altitud': '1699',
#   'indicativo': '9585',
#   'nombre': 'LA MOLINA',
#   'indsinop': '08117',
#   'longitud': '015622E'},
#  {'latitud': '422144N',
#   'provincia': 'LLEIDA',
#   'altitud': '1038',
#   'indicativo': '9590',
#   'nombre': 'MARTINET  ',
#   'indsinop': '',
#   'longitud': '014136E'},
#  {'latitud': '422549N',
#   'provincia': 'LLEIDA',
#   'altitud': '1940',
#   'indicativo': '9590D',
#   'nombre': 'CAP DE REC',
#   'indsinop': '08940',
#   'longitud': '014004E'},
#  {'latitud': '422117N',
#   'provincia': 'LLEIDA',
#   'altitud': '677',
#   'indicativo': '9619',
#   'nombre': "LA SEU D'URGELL",
#   'indsinop': '08115',
#   'longitud': '012747E'},
#  {'latitud': '421349N',
#   'provincia': 'LLEIDA',
#   'altitud': '1196',
#   'indicativo': '9632X',
#   'nombre': 'TUIXENT',
#   'indsinop': '',
#   'longitud': '013410E'},
#  {'latitud': '420916N',
#   'provincia': 'LLEIDA',
#   'altitud': '609',
#   'indicativo': '9638D',
#   'nombre': 'COLL DE NARGÓ',
#   'indsinop': '',
#   'longitud': '011843E'},
#  {'latitud': '414821N',
#   'provincia': 'LLEIDA',
#   'altitud': '435',
#   'indicativo': '9647X',
#   'nombre': 'TORÀ',
#   'indsinop': '',
#   'longitud': '012344E'},
#  {'latitud': '415253N',
#   'provincia': 'LLEIDA',
#   'altitud': '400',
#   'indicativo': '9650X',
#   'nombre': 'ARTESA DE SEGRE',
#   'indsinop': '',
#   'longitud': '010631E'},
#  {'latitud': '423730N',
#   'provincia': 'LLEIDA',
#   'altitud': '952',
#   'indicativo': '9657X',
#   'nombre': "ESTERRI D'ÀNEU",
#   'indsinop': '',
#   'longitud': '010734E'},
#  {'latitud': '423451N',
#   'provincia': 'LLEIDA',
#   'altitud': '1907',
#   'indicativo': '9660',
#   'nombre': 'SANT MAURICI (LLAC)',
#   'indsinop': '',
#   'longitud': '010027E'},
#  {'latitud': '422436N',
#   'provincia': 'LLEIDA',
#   'altitud': '2410',
#   'indicativo': '9677',
#   'nombre': 'PORT AINÉ',
#   'indsinop': '08938',
#   'longitud': '011253E'},
#  {'latitud': '422759N',
#   'provincia': 'LLEIDA',
#   'altitud': '1273',
#   'indicativo': '9689X',
#   'nombre': 'TORRE DE CABDELLA ',
#   'indsinop': '',
#   'longitud': '005927E'},
#  {'latitud': '421219N',
#   'provincia': 'LLEIDA',
#   'altitud': '807',
#   'indicativo': '9698U',
#   'nombre': 'TALARN',
#   'indsinop': '08112',
#   'longitud': '005155E'},
#  {'latitud': '420401N',
#   'provincia': 'LLEIDA',
#   'altitud': '515',
#   'indicativo': '9707',
#   'nombre': 'LLIMIANA',
#   'indsinop': '',
#   'longitud': '005426E'},
#  {'latitud': '414052N',
#   'provincia': 'LLEIDA',
#   'altitud': '463',
#   'indicativo': '9718X',
#   'nombre': 'TORDERA - GRANYANELLA',
#   'indsinop': '',
#   'longitud': '011323E'},
#  {'latitud': '413902N',
#   'provincia': 'LLEIDA',
#   'altitud': '388',
#   'indicativo': '9720X',
#   'nombre': 'TÀRREGA',
#   'indsinop': '08173',
#   'longitud': '010858E'},
#  {'latitud': '415224N',
#   'provincia': 'LLEIDA',
#   'altitud': '520',
#   'indicativo': '9724X',
#   'nombre': 'OS DE BALAGUER',
#   'indsinop': '',
#   'longitud': '004522E'},
#  {'latitud': '413326N',
#   'provincia': 'TARRAGONA',
#   'altitud': '657',
#   'indicativo': '9726E',
#   'nombre': 'LLORAC',
#   'indsinop': '',
#   'longitud': '011834E'},
#  {'latitud': '413701N',
#   'provincia': 'LLEIDA',
#   'altitud': '252',
#   'indicativo': '9729X',
#   'nombre': 'MOLLERUSSA',
#   'indsinop': '',
#   'longitud': '005200E'},
#  {'latitud': '423012N',
#   'provincia': 'LLEIDA',
#   'altitud': '1089',
#   'indicativo': '9744B',
#   'nombre': 'VALL DE BOÍ',
#   'indsinop': '',
#   'longitud': '004756E'},
#  {'latitud': '421907N',
#   'provincia': 'HUESCA',
#   'altitud': '760',
#   'indicativo': '9751',
#   'nombre': 'SOPEIRA',
#   'indsinop': '',
#   'longitud': '004449E'},
#  {'latitud': '420645N',
#   'provincia': 'HUESCA',
#   'altitud': '765',
#   'indicativo': '9756X',
#   'nombre': 'BENABARRE',
#   'indsinop': '',
#   'longitud': '002848E'},
#  {'latitud': '413702N',
#   'provincia': 'LLEIDA',
#   'altitud': '199',
#   'indicativo': '9771',
#   'nombre': 'LLEIDA, OBSERVATORIO',
#   'indsinop': '',
#   'longitud': '003716E'},
#  {'latitud': '413734N',
#   'provincia': 'LLEIDA',
#   'altitud': '186',
#   'indicativo': '9771C',
#   'nombre': 'LLEIDA',
#   'indsinop': '08171',
#   'longitud': '003553E'},
#  {'latitud': '412158N',
#   'provincia': 'LLEIDA',
#   'altitud': '673',
#   'indicativo': '9772X',
#   'nombre': 'LA POBLA DE CÉRVOLES',
#   'indsinop': '',
#   'longitud': '005449E'},
#  {'latitud': '412449N',
#   'provincia': 'LLEIDA',
#   'altitud': '392',
#   'indicativo': '9775X',
#   'nombre': 'EL SOLERÀS',
#   'indsinop': '',
#   'longitud': '004042E'},
#  {'latitud': '412336N',
#   'provincia': 'LLEIDA',
#   'altitud': '488',
#   'indicativo': '9776D',
#   'nombre': 'ELS TORMS',
#   'indsinop': '',
#   'longitud': '004403E'},
#  {'latitud': '423748N',
#   'provincia': 'HUESCA',
#   'altitud': '992',
#   'indicativo': '9784P',
#   'nombre': 'BIELSA',
#   'indsinop': '08103',
#   'longitud': '001329E'},
#  {'latitud': '422518N',
#   'provincia': 'HUESCA',
#   'altitud': '610',
#   'indicativo': '9808X',
#   'nombre': 'AÍNSA-SOBRARBE, LA SERRETA',
#   'indsinop': '',
#   'longitud': '000817E'},
#  {'latitud': '423919N',
#   'provincia': 'HUESCA',
#   'altitud': '1206',
#   'indicativo': '9812M',
#   'nombre': 'PARADOR DE ORDESA, PARQUE NACIONAL ORDESA Y MONTEPERDIDO',
#   'indsinop': '',
#   'longitud': '000557W'},
#  {'latitud': '423736N',
#   'provincia': 'HUESCA',
#   'altitud': '1020',
#   'indicativo': '9814A',
#   'nombre': 'TORLA',
#   'indsinop': '08101',
#   'longitud': '000642W'},
#  {'latitud': '423922N',
#   'provincia': 'HUESCA',
#   'altitud': '1905',
#   'indicativo': '9814I',
#   'nombre': 'TORLA-ORDESA, EL CEBOLLAR',
#   'indsinop': '08919',
#   'longitud': '000728W'},
#  {'latitud': '423815N',
#   'provincia': 'HUESCA',
#   'altitud': '1076',
#   'indicativo': '9814X',
#   'nombre': 'TORLA - ORDESA',
#   'indsinop': '',
#   'longitud': '000644W'},
#  {'latitud': '423558N',
#   'provincia': 'HUESCA',
#   'altitud': '1120',
#   'indicativo': '9838B',
#   'nombre': 'BENASQUE',
#   'indsinop': '',
#   'longitud': '003114E'},
#  {'latitud': '423318N',
#   'provincia': 'HUESCA',
#   'altitud': '2374',
#   'indicativo': '9839V',
#   'nombre': 'CERLER, COGULLA',
#   'indsinop': '08923',
#   'longitud': '003235E'},
#  {'latitud': '422837N',
#   'provincia': 'HUESCA',
#   'altitud': '825',
#   'indicativo': '9843A',
#   'nombre': 'SEIRA',
#   'indsinop': '',
#   'longitud': '002603E'},
#  {'latitud': '421205N',
#   'provincia': 'HUESCA',
#   'altitud': '600',
#   'indicativo': '9855E',
#   'nombre': 'CAPELLA, LAGUARRES',
#   'indsinop': '',
#   'longitud': '002758E'},
#  {'latitud': '420117N',
#   'provincia': 'HUESCA',
#   'altitud': '305',
#   'indicativo': '9866C',
#   'nombre': 'BARBASTRO',
#   'indsinop': '',
#   'longitud': '000826E'},
#  {'latitud': '414757N',
#   'provincia': 'HUESCA',
#   'altitud': '300',
#   'indicativo': '9894Y',
#   'nombre': 'SARIÑENA',
#   'indsinop': '',
#   'longitud': '000939W'},
#  {'latitud': '420504N',
#   'provincia': 'HUESCA',
#   'altitud': '546',
#   'indicativo': '9898',
#   'nombre': 'HUESCA, AEROPUERTO',
#   'indsinop': '08094',
#   'longitud': '001932W'},
#  {'latitud': '420820N',
#   'provincia': 'HUESCA',
#   'altitud': '463',
#   'indicativo': '9901X',
#   'nombre': 'HUESCA',
#   'indsinop': '',
#   'longitud': '002342W'},
#  {'latitud': '414626N',
#   'provincia': 'HUESCA',
#   'altitud': '380',
#   'indicativo': '9908X',
#   'nombre': 'LANAJA',
#   'indsinop': '',
#   'longitud': '001959W'},
#  {'latitud': '413710N',
#   'provincia': 'HUESCA',
#   'altitud': '178',
#   'indicativo': '9911X',
#   'nombre': 'BALLOBAR',
#   'indsinop': '',
#   'longitud': '001116E'},
#  {'latitud': '414651N',
#   'provincia': 'HUESCA',
#   'altitud': '218',
#   'indicativo': '9918Y',
#   'nombre': 'TAMARITE DE LITERA, LA MELUSA',
#   'indsinop': '',
#   'longitud': '002237E'},
#  {'latitud': '413129N',
#   'provincia': 'HUESCA',
#   'altitud': '170',
#   'indicativo': '9924X',
#   'nombre': 'FRAGA',
#   'indsinop': '',
#   'longitud': '002120E'},
#  {'latitud': '405224N',
#   'provincia': 'TERUEL',
#   'altitud': '483',
#   'indicativo': '9935X',
#   'nombre': 'VALDERROBRES',
#   'indsinop': '',
#   'longitud': '000847E'},
#  {'latitud': '405711N',
#   'provincia': 'TARRAGONA',
#   'altitud': '495',
#   'indicativo': '9946X',
#   'nombre': 'HORTA DE SANT JOAN',
#   'indsinop': '',
#   'longitud': '001842E'},
#  {'latitud': '411038N',
#   'provincia': 'TARRAGONA',
#   'altitud': '370',
#   'indicativo': '9947X',
#   'nombre': 'LA POBLA DE MASSALUCA',
#   'indsinop': '',
#   'longitud': '002112E'},
#  {'latitud': '411458N',
#   'provincia': 'TARRAGONA',
#   'altitud': '363',
#   'indicativo': '9961X',
#   'nombre': 'CABACÉS',
#   'indsinop': '',
#   'longitud': '004407E'},
#  {'latitud': '410018N',
#   'provincia': 'TARRAGONA',
#   'altitud': '112',
#   'indicativo': '9975X',
#   'nombre': 'RASQUERA',
#   'indsinop': '',
#   'longitud': '003649E'},
#  {'latitud': '404913N',
#   'provincia': 'TARRAGONA',
#   'altitud': '50',
#   'indicativo': '9981A',
#   'nombre': 'ESTACIÓN DE TORTOSA (ROQUETES)',
#   'indsinop': '08238',
#   'longitud': '002936E'},
#  {'latitud': '404157N',
#   'provincia': 'TARRAGONA',
#   'altitud': '1',
#   'indicativo': '9987P',
#   'nombre': "SANT JAUME D'ENVEJA",
#   'indsinop': '08240',
#   'longitud': '004836E'},
#  {'latitud': '424131N',
#   'provincia': 'LLEIDA',
#   'altitud': '2467',
#   'indicativo': '9988B',
#   'nombre': 'CAP DE VAQUÈIRA',
#   'indsinop': '08936',
#   'longitud': '005826E'},
#  {'latitud': '424201N',
#   'provincia': 'LLEIDA',
#   'altitud': '1161',
#   'indicativo': '9990X',
#   'nombre': 'NAUT ARAN, ARTIES ',
#   'indsinop': '08107',
#   'longitud': '005237E'},
#  {'latitud': '424634N',
#   'provincia': 'LLEIDA',
#   'altitud': '722',
#   'indicativo': '9994X',
#   'nombre': 'BOSSÒST',
#   'indsinop': '',
#   'longitud': '004123E'},
#  {'latitud': '430528N',
#   'provincia': 'NAVARRA',
#   'altitud': '334',
#   'indicativo': '9995Y',
#   'nombre': 'VALCARLOS/LUZAIDE',
#   'indsinop': '',
#   'longitud': '011803W'},
#  {'latitud': '405517N',
#   'provincia': 'TERUEL',
#   'altitud': '1006',
#   'indicativo': '9998X',
#   'nombre': 'BELLO',
#   'indsinop': '',
#   'longitud': '012940W'}]

# %%
# pandas.DataFrame-style data from each of the 947 Spanish AWSs.
pd.DataFrame(idema)
# Out:
#      latitud      provincia altitud indicativo               nombre indsinop  \
# 0    394924N  ILLES BALEARS     490      B013X        ESCORCA, LLUC    08304
# 1    394744N  ILLES BALEARS       5      B051A       SÓLLER, PUERTO    08316
# 2    394121N  ILLES BALEARS      60      B087X          BANYALBUFAR
# 3    393445N  ILLES BALEARS      52      B103B   ANDRATX - SANT ELM    99103
# 4    393305N  ILLES BALEARS      50      B158X  CALVIÀ, ES CAPDELLÀ
# ..       ...            ...     ...        ...                  ...      ...
# 942  424131N         LLEIDA    2467      9988B      CAP DE VAQUÈIRA    08936
# 943  424201N         LLEIDA    1161      9990X   NAUT ARAN, ARTIES     08107
# 944  424634N         LLEIDA     722      9994X              BOSSÒST
# 945  430528N        NAVARRA     334      9995Y    VALCARLOS/LUZAIDE
# 946  405517N         TERUEL    1006      9998X                BELLO
#
#     longitud
# 0    025309E
# 1    024129E
# 2    023046E
# 3    022208E
# 4    022759E
# ..       ...
# 942  005826E
# 943  005237E
# 944  004123E
# 945  011803W
# 946  012940W
#
# [947 rows x 7 columns]

# %% [markdown]
# I do rename "indicativo" as it will be name like "idema" in other data bases, and save it in a .csv file in just one comand line

# %%
# Rename "indicativo" column to "idema", and save data in .csv
pd.DataFrame(idema).rename(columns = {'indicativo' : 'idema'}).to_csv(
        './data/raw/AWS_info_RAW.csv',
        index = False
        )

# %% [markdown]
# Conclusions about this dataset:
# - It is quite clean, whit most of its columns complete (except "indsinop").
# - “idema” is unique, and it is the data that will allow to do more requests in the API.
# - Latitude and Longitude are object-type, with letters and numbers. I'll have to solve this to use the coordinates.
#
# <h2 id="monthly-anual-mean-data">Monthly and annual mean values of climatological data</h2>
#
# Through this request I will get Monthly and annual mean values of climatological data for the station and the period of past years by parameter. Update periodicity: 1 time per day.
#
# IMPORTANT: Data cannot be accessed if period is longer than 48 months, and there is also a limit request per minute and per day, so I will slow the requests, and filter data accessing to just Basque Country data bases.
#
# But first I am going to request information of just one AWS to undertand the data inside.

# %%
# Request to Monthly and annual mean values of climatological data
end_point = '/api/valores/climatologicos/mensualesanuales/datos/anioini/{anioIniStr}/aniofin/{anioFinStr}/estacion/{idema}'

anioIniStr = '2021'
anioFinStr = '2024'
idema = '1012P' # Irún AWS identifier

end_point = end_point.format(anioIniStr = anioIniStr, anioFinStr = anioFinStr, idema = idema)

url = base_url + end_point

response = requests.request("GET", url, headers = headers, params = querystring)
print(response.status_code)
response_content = response.json()
print(response_content)
# Out:
# 200
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/98abdd70', 'metadatos': 'https://opendata.aemet.es/opendata/sh/997c0034'}

# %% [markdown]
# Once again, information is storage in two different URLs. Like previosly I request first the metadata.

# %%
# View metadata content
sub_response = requests.get(response_content['metadatos'])
print('Response:', sub_response.status_code)

metadata_weather = sub_response.json()
display(metadata_weather)
# Out:
# Response: 200
# {'unidad_generadora': 'Servicio del Banco Nacional de Datos Climatológicos',
#  'periodicidad': '1 vez al día',
#  'descripcion': 'Climatologías mensuales anuales',
#  'formato': 'application/json',
#  'copyright': '© AEMET. Autorizado el uso de la información y su reproducción citando a AEMET como autora de la misma.',
#  'notaLegal': 'https://www.aemet.es/es/nota_legal',
#  'campos': [{'id': 'fecha',
#    'descripcion': 'año y mes (AAAA-X) donde X es un número del 1 aa 13, indicando el mes y el valor 13 indica valor anual',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'indicativo',
#    'descripcion': 'indicativo climatológico',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'nombre',
#    'descripcion': 'nombre (ubicación) de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'provincia',
#    'descripcion': 'provincia de la estación',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'altitud',
#    'descripcion': 'altitud de la estación en m sobre el nivel del mar',
#    'tipo_datos': 'string',
#    'unidad': 'm',
#    'requerido': True},
#   {'id': 'tm_mes',
#    'descripcion': 'Temperatura media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_max',
#    'descripcion': 'Temperatura media mensual/anual de las máximas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'tm_min',
#    'descripcion': 'Temperatura media mensual/anual de las mínimas',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ta_max',
#    'descripcion': 'Temperatura máxima absoluta del mes/año y fecha',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ta_min',
#    'descripcion': 'Temperatura mínima absoluta del mes/año y fecha',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_min',
#    'descripcion': 'Temperatura mínima mas alta del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ti_max',
#    'descripcion': 'Temperatura máxima mas baja del mes/año',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'nt_30',
#    'descripcion': 'Nº de días de temperatura máxima mayor o igual que 30 °C',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nt_00',
#    'descripcion': 'Nº de días de temperatura mínima menor o igual que 0 °C',
#    'tipo_datos': 'número de días',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'p_mes',
#    'descripcion': 'Precipitación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'mm',
#    'requerido': False},
#   {'id': 'p_max',
#    'descripcion': 'Precipitación máxima diaria del mes/año y fecha',
#    'tipo_datos': 'string',
#    'unidad': 'mm (dia o fecha del año)',
#    'requerido': False},
#   {'id': 'np_001',
#    'descripcion': 'Nº de días de precipitación apreciable (>= 0,1 mm) en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_010',
#    'descripcion': 'Nº de días de precipitación mayor o igual que 1 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_100',
#    'descripcion': 'Nº de días de precipitación mayor o igual que 10 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'np_300',
#    'descripcion': 'Nº de días de precipitación mayor o igual que 30 mm en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'hr',
#    'descripcion': 'Humedad relativa media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': '%',
#    'requerido': False},
#   {'id': 'e',
#    'descripcion': 'Tensión de vapor media mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'décimas de hPa',
#    'requerido': False},
#   {'id': 'n_llu',
#    'descripcion': 'Nº de días de lluvia en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nie',
#    'descripcion': 'Nº de días de nieve en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_gra',
#    'descripcion': 'Nº de días de granizo en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_tor',
#    'descripcion': 'Nº de días de tormenta en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_fog',
#    'descripcion': 'Nº de días de niebla en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_des',
#    'descripcion': 'Nº de días despejados en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_nub',
#    'descripcion': 'Nº de días nubosos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'n_cub',
#    'descripcion': 'Nº de días cubiertos en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'inso',
#    'descripcion': 'Media mensual/anual de la insolación diaria',
#    'tipo_datos': 'string',
#    'unidad': 'horas',
#    'requerido': False},
#   {'id': 'p_sol',
#    'descripcion': 'Porcentaje medio mensual de la insolación diaria frente a la insolación teórica',
#    'tipo_datos': 'string',
#    'unidad': '%',
#    'requerido': False},
#   {'id': 'glo',
#    'descripcion': 'Radiación global mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'decenas de kJ/m2',
#    'requerido': False},
#   {'id': 'evap',
#    'descripcion': 'Evaporación total mensual/anual',
#    'tipo_datos': 'string',
#    'unidad': 'décimas de mm',
#    'requerido': False},
#   {'id': 'w_rec',
#    'descripcion': 'Recorrido medio diario (de 07 a 07 UTC) del mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'km',
#    'requerido': False},
#   {'id': 'w_racha',
#    'descripcion': 'Dirección, Velocidad y fecha de la racha máxima en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Dirección en decenas de grado (99 = dirección variable)(88 = sin dato de dirección). Velocidad en m/sg',
#    'requerido': False},
#   {'id': 'nw_55',
#    'descripcion': 'Nº de días de velocidad del viento mayor o igual a 55 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nw_91',
#    'descripcion': 'Nº de días de velocidad del viento mayor o igual a 91 km/h en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'w_med',
#    'descripcion': 'Velocidad media mensual elaborada a partir de las observaciones de 07, 13 y 18 UTC',
#    'tipo_datos': 'string',
#    'unidad': 'km/h',
#    'requerido': False},
#   {'id': 'q_med',
#    'descripcion': 'Presión media mensual/anual al nivel de la estación)',
#    'tipo_datos': 'string',
#    'unidad': 'hPa',
#    'requerido': False},
#   {'id': 'q_max',
#    'descripcion': 'Presión máxima absoluta mensual/anual y fecha',
#    'tipo_datos': 'string',
#    'unidad': 'hPa',
#    'requerido': False},
#   {'id': 'q_min',
#    'descripcion': 'Presión máxima mínima mensual/anual y fecha',
#    'tipo_datos': 'string',
#    'unidad': 'hPa',
#    'requerido': False},
#   {'id': 'q_mar',
#    'descripcion': 'Presión media mensual/anual al nivel del mar',
#    'tipo_datos': 'string',
#    'unidad': 'hPa',
#    'requerido': False},
#   {'id': 'ts_10',
#    'descripcion': 'Temperatura media mensual/anual a 10 cm de profundidad',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_20',
#    'descripcion': 'Temperatura media mensual/anual a 20 cm',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'ts_50',
#    'descripcion': 'Temperatura media mensual/anual a 20 cm',
#    'tipo_datos': 'string',
#    'unidad': '°C',
#    'requerido': False},
#   {'id': 'nv_0050',
#    'descripcion': 'Nº de días con visibilidad inferior a 50 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_0100',
#    'descripcion': 'Nº de días con visibilidad superior o igual a 50 m e inferior a 100 m en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False},
#   {'id': 'nv_1000',
#    'descripcion': 'Nº de días con visibilidad superior o igual a 100 m e inferior a 1 km en el mes/año',
#    'tipo_datos': 'string',
#    'unidad': 'Nº de días',
#    'requerido': False}]}

# %% [markdown]
# Metadata information is super useful, so it will be stored in a .csv file again.

# %%
# pandas.DataFrame-style metadata from "campos" key
pd.DataFrame(metadata_weather['campos'])
# Out:
#             id                                        descripcion  \
# 0        fecha  año y mes (AAAA-X) donde X es un número del 1 ...
# 1   indicativo                           indicativo climatológico
# 2       nombre                  nombre (ubicación) de la estación
# 3    provincia                           provincia de la estación
# 4      altitud  altitud de la estación en m sobre el nivel del...
# 5       tm_mes                    Temperatura media mensual/anual
# 6       tm_max     Temperatura media mensual/anual de las máximas
# 7       tm_min     Temperatura media mensual/anual de las mínimas
# 8       ta_max    Temperatura máxima absoluta del mes/año y fecha
# 9       ta_min    Temperatura mínima absoluta del mes/año y fecha
# 10      ts_min            Temperatura mínima mas alta del mes/año
# 11      ti_max            Temperatura máxima mas baja del mes/año
# 12       nt_30  Nº de días de temperatura máxima mayor o igual...
# 13       nt_00  Nº de días de temperatura mínima menor o igual...
# 14       p_mes                  Precipitación total mensual/anual
# 15       p_max    Precipitación máxima diaria del mes/año y fecha
# 16      np_001  Nº de días de precipitación apreciable (>= 0,1...
# 17      np_010  Nº de días de precipitación mayor o igual que ...
# 18      np_100  Nº de días de precipitación mayor o igual que ...
# 19      np_300  Nº de días de precipitación mayor o igual que ...
# 20          hr               Humedad relativa media mensual/anual
# 21           e               Tensión de vapor media mensual/anual
# 22       n_llu                 Nº de días de lluvia en el mes/año
# 23       n_nie                  Nº de días de nieve en el mes/año
# 24       n_gra                Nº de días de granizo en el mes/año
# 25       n_tor               Nº de días de tormenta en el mes/año
# 26       n_fog                 Nº de días de niebla en el mes/año
# 27       n_des                Nº de días despejados en el mes/año
# 28       n_nub                   Nº de días nubosos en el mes/año
# 29       n_cub                 Nº de días cubiertos en el mes/año
# 30        inso        Media mensual/anual de la insolación diaria
# 31       p_sol  Porcentaje medio mensual de la insolación diar...
# 32         glo                     Radiación global mensual/anual
# 33        evap                    Evaporación total mensual/anual
# 34       w_rec  Recorrido medio diario (de 07 a 07 UTC) del me...
# 35     w_racha  Dirección, Velocidad y fecha de la racha máxim...
# 36       nw_55  Nº de días de velocidad del viento mayor o igu...
# 37       nw_91  Nº de días de velocidad del viento mayor o igu...
# 38       w_med  Velocidad media mensual elaborada a partir de ...
# 39       q_med  Presión media mensual/anual al nivel de la est...
# 40       q_max      Presión máxima absoluta mensual/anual y fecha
# 41       q_min        Presión máxima mínima mensual/anual y fecha
# 42       q_mar       Presión media mensual/anual al nivel del mar
# 43       ts_10  Temperatura media mensual/anual a 10 cm de pro...
# 44       ts_20            Temperatura media mensual/anual a 20 cm
# 45       ts_50            Temperatura media mensual/anual a 20 cm
# 46     nv_0050  Nº de días con visibilidad inferior a 50 m en ...
# 47     nv_0100  Nº de días con visibilidad superior o igual a ...
# 48     nv_1000  Nº de días con visibilidad superior o igual a ...
#
#         tipo_datos  requerido  \
# 0           string       True
# 1           string       True
# 2           string       True
# 3           string       True
# 4           string       True
# 5           string      False
# 6           string      False
# 7           string      False
# 8           string      False
# 9           string      False
# 10          string      False
# 11          string      False
# 12          string      False
# 13  número de días      False
# 14          string      False
# 15          string      False
# 16          string      False
# 17          string      False
# 18          string      False
# 19          string      False
# 20          string      False
# 21          string      False
# 22          string      False
# 23          string      False
# 24          string      False
# 25          string      False
# 26          string      False
# 27          string      False
# 28          string      False
# 29          string      False
# 30          string      False
# 31          string      False
# 32          string      False
# 33          string      False
# 34          string      False
# 35          string      False
# 36          string      False
# 37          string      False
# 38          string      False
# 39          string      False
# 40          string      False
# 41          string      False
# 42          string      False
# 43          string      False
# 44          string      False
# 45          string      False
# 46          string      False
# 47          string      False
# 48          string      False
#
#                                                unidad
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                   m
# 5                                                  °C
# 6                                                  °C
# 7                                                  °C
# 8                                                  °C
# 9                                                  °C
# 10                                                 °C
# 11                                                 °C
# 12                                         Nº de días
# 13                                                 °C
# 14                                                 mm
# 15                           mm (dia o fecha del año)
# 16                                         Nº de días
# 17                                         Nº de días
# 18                                         Nº de días
# 19                                         Nº de días
# 20                                                  %
# 21                                     décimas de hPa
# 22                                         Nº de días
# 23                                         Nº de días
# 24                                         Nº de días
# 25                                         Nº de días
# 26                                         Nº de días
# 27                                         Nº de días
# 28                                         Nº de días
# 29                                         Nº de días
# 30                                              horas
# 31                                                  %
# 32                                   decenas de kJ/m2
# 33                                      décimas de mm
# 34                                                 km
# 35  Dirección en decenas de grado (99 = dirección ...
# 36                                         Nº de días
# 37                                         Nº de días
# 38                                               km/h
# 39                                                hPa
# 40                                                hPa
# 41                                                hPa
# 42                                                hPa
# 43                                                 °C
# 44                                                 °C
# 45                                                 °C
# 46                                         Nº de días
# 47                                         Nº de días
# 48                                         Nº de días

# %%
# Save metadata in a .csv
pd.DataFrame(metadata_weather['campos']).to_csv('./data/raw/metadata_weather_month_year.csv',
                                                index = False)

# %% [markdown]
# Now we are ready to understand the meaning of this data I can request the whole information to the data base from `Basque Country` from the last 100 years (if possible).
#
# <h2 id="basque-country-requests">Basque Country Data Requests</h3>

# %%
# Load all AWS info and show provinces
df_AWS = pd.read_csv('./data/raw/AWS_info_RAW.csv')
df_AWS['provincia'].unique()
# Out:
# array(['ILLES BALEARS', 'BALEARES', 'LAS PALMAS', 'STA. CRUZ DE TENERIFE',
#        'TARRAGONA', 'BARCELONA', 'GIRONA', 'NAVARRA', 'GIPUZKOA',
#        'ARABA/ALAVA', 'BIZKAIA', 'CANTABRIA', 'ASTURIAS', 'LEON', 'LUGO',
#        'A CORUÑA', 'PONTEVEDRA', 'OURENSE', 'SORIA', 'BURGOS', 'SEGOVIA',
#        'VALLADOLID', 'PALENCIA', 'AVILA', 'MADRID', 'SALAMANCA', 'ZAMORA',
#        'GUADALAJARA', 'CUENCA', 'TOLEDO', 'CACERES', 'ALBACETE',
#        'CIUDAD REAL', 'BADAJOZ', 'CORDOBA', 'HUELVA', 'CEUTA', 'JAEN',
#        'GRANADA', 'ALMERIA', 'SEVILLA', 'CADIZ', 'MELILLA', 'MALAGA',
#        'MURCIA', 'ALICANTE', 'VALENCIA', 'TERUEL', 'CASTELLON',
#        'LA RIOJA', 'HUESCA', 'ZARAGOZA', 'LLEIDA'], dtype=object)

# %%
# Provinces of Basque Country, for this EDA
provinces = ['BIZKAIA', 'ARABA/ALAVA', 'GIPUZKOA']

# Filter DataFrame
df_AWS_euskadi = df_AWS[df_AWS['provincia'].isin(provinces)]

# Sample of the dataset
display(df_AWS_euskadi.sample(5))

# All unique AWS identifiers in Basque Country
display(df_AWS_euskadi.idema.unique())
display(df_AWS_euskadi.idema.nunique())
# Out:
#      latitud    provincia  altitud  idema     nombre  indsinop longitud
# 819  423614N  ARABA/ALAVA      612  9122I  LABASTIDA       NaN  024636W
# 214  430448N     GIPUZKOA      420  1037Y  ZUMARRAGA    8037.0  021903W
# 222  432237N      BIZKAIA       12  1055B   LEKEITIO    8024.0  023037W
# 213  430306N     GIPUZKOA      460  1037X    LEGAZPI       NaN  022013W
# 230  431050N      BIZKAIA      210  1078C  BALMASEDA       NaN  031235W
# array(['1012P', '1014', '1014A', '1021X', '1024E', '1025A', '1025X',
#        '1026X', '1037X', '1037Y', '1038X', '1041A', '1044X', '1048X',
#        '1049N', '1050J', '1052A', '1055B', '1056K', '1057B', '1059X',
#        '1060X', '1064L', '1069Y', '1074C', '1078C', '1078I', '1082',
#        '1083B', '9060X', '9073X', '9087', '9091O', '9091R', '9122I',
#        '9145X', '9178X'], dtype=object)
# 37

# %%
# Get climate data per AWS, per month, per year from AEMET OpenData API

# Empty DataFrame
df_weather_month_year_euskadi = pd.DataFrame()

for idema in df_AWS_euskadi['idema']:
    for year in range(1924, 2025, 4):
        print(f'Accessing {idema} {year}\'s info...')
        end_point = '/api/valores/climatologicos/mensualesanuales/datos/anioini/{anioIniStr}/aniofin/{anioFinStr}/estacion/{idema}'
        anioIniStr = str(year)
        anioFinStr = str(year+3)

        end_point = end_point.format(anioIniStr = anioIniStr, anioFinStr = anioFinStr, idema = idema)
        url = base_url + end_point
        
        # To prevent requests limit
        time.sleep(3)
        
        # Complete request dataset
        df_idema_data = fetch_data_aemet(url, headers, querystring)
        
        if isinstance(df_idema_data, pd.DataFrame):
            df_weather_month_year_euskadi = pd.concat([df_weather_month_year_euskadi, df_idema_data])
        
        print('')


# Display DataFrame
display(df_weather_month_year_euskadi)
    
# Storage dataset in a .csv
df_weather_month_year_euskadi.to_csv('./data/raw/BC_weather_month_year_RAW.csv',
                                     index = False)
# Out:
# Accessing 1012P 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 2000's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 2004's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1012P 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1012P 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1012P 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1012P 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1012P 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014 1952's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1956's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1960's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1964's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1968's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1972's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1976's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1980's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1984's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1988's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1992's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 1996's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 2000's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014A 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 2000's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1014A 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014A 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014A 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014A 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014A 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1014A 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1021X 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1021X 2000's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1021X 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1021X 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1021X 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1021X 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1021X 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1021X 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1024E 1928's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1932's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1936's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1940's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1944's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1948's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1952's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1956's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1960's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1964's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1968's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1972's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1976's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1980's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1984's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1988's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1992's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 1996's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 2000's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1024E 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1025A 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 2000's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 2004's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 2008's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 2012's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025A 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1025A 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1025A 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1025X 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 2000's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 2004's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1025X 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1025X 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1025X 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1025X 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1025X 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1026X 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 2000's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 2004's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1026X 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1026X 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1026X 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1026X 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1026X 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037X 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037X 2000's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037X 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037X 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037X 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037X 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037X 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037X 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037Y 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 2000's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 2004's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1037Y 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037Y 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037Y 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037Y 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1037Y 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1038X 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 2000's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 2004's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1038X 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1038X 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1038X 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1038X 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1038X 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1041A 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1041A 1996's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1041A 2000's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1041A 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1041A 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1041A 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1041A 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1041A 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1041A 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1044X 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1044X 2000's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1044X 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1044X 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1044X 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1044X 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1044X 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1044X 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1048X 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 2000's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 2004's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1048X 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1048X 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1048X 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1048X 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1048X 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 1049N 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1049N 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1049N 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1049N 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1049N 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 1049N 1944's info...
# ...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9091O 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9091O 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9091O 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9091R 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9091R 2000's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9091R 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9091R 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9091R 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9091R 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9091R 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9091R 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9122I 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9122I 2000's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9122I 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9122I 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9122I 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9122I 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9122I 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9122I 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9145X 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9145X 2000's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9145X 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9145X 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9145X 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9145X 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9145X 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9145X 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9178X 1924's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1928's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1932's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1936's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1940's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1944's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1948's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1952's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1956's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1960's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1964's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1968's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1972's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1976's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1980's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1984's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1988's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1992's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 1996's info...
# Request Status Code:  200
# Data Info:  {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}
#
# Accessing 9178X 2000's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9178X 2004's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9178X 2008's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9178X 2012's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9178X 2016's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9178X 2020's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#
# Accessing 9178X 2024's info...
# Request Status Code:  200
# Data Accessing Status code:  200
#       fecha indicativo     p_max   hr nw_55 tm_min    ta_max ts_min nt_30  \
# 0   2009-10      1012P  35.2(22)   74     1   12.7  30.8(06)   22.9     1
# 1   2009-11      1012P       NaN   67    14   10.6  26.9(01)   17.2     0
# 2   2009-12      1012P       NaN   73    10    6.6  19.6(29)   16.0     0
# 3   2009-13      1012P       NaN  NaN   NaN    NaN       NaN    NaN   NaN
# 4    2009-1      1012P       NaN  NaN   NaN    NaN       NaN    NaN   NaN
# ..      ...        ...       ...  ...   ...    ...       ...    ...   ...
# 8    2024-9      9178X       NaN  NaN   NaN    NaN       NaN    NaN   NaN
# 9    2024-3      9178X  20.8(07)   73   NaN    3.4  24.1(22)   11.0     0
# 10   2024-4      9178X  10.4(27)   65   NaN    4.5  27.2(13)   11.8     0
# 11   2024-5      9178X  22.8(18)   67   NaN    7.5  26.4(28)   12.7     0
# 12   2024-6      9178X  18.8(20)   66   NaN   11.4  31.6(27)   16.6     7
#
#         w_racha  ... q_max q_mar q_med q_min inso p_sol ts_20 ts_10 ts_50  glo
# 0   16/15.3(20)  ...   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  NaN
# 1   25/27.2(07)  ...   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  NaN
# 2   14/26.1(21)  ...   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  NaN
# 3           NaN  ...   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  NaN
# 4           NaN  ...   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  NaN
# ..          ...  ...   ...   ...   ...   ...  ...   ...   ...   ...   ...  ...
# 8           NaN  ...   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  NaN
# 9           NaN  ...   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  NaN
# 10          NaN  ...   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  NaN
# 11          NaN  ...   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  NaN
# 12          NaN  ...   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  NaN
#
# [12402 rows x 46 columns]

# %% [markdown]
# <h1 id="process-clean">Process and Clean datasets</h1>
#
# In this section I will inspect the data, process, clean and combine so I can use it to an EDA.
#
# First I will focus on all AWS information: "df_aws".

# %%
# Load datasets
df_aws = pd.read_csv('./data/raw/AWS_info_RAW.csv')

df_aws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 947 entries, 0 to 946
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitud    947 non-null    object
#  1   provincia  947 non-null    object
#  2   altitud    947 non-null    int64
#  3   idema      947 non-null    object
#  4   nombre     947 non-null    object
#  5   indsinop   301 non-null    float64
#  6   longitud   947 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 51.9+ KB

# %% [markdown]
# As I told in advanced, Longitude and Latitude are strings and I want to convert them into float so I can scatter-plot them over a map.
#
# Geographic coordinates usually have the following structure:
#
# - Latitude: degrees (0-90) with a direction (N or S).
# - Longitude: degrees (0-180) with a direction (E or W).
#
# In Spain we only have latitudes N, and longitudes E and W (separated by the Greenwich meridian). It is necessary to apply a conversion to be able to work with the data provided by AEMET. For this task I have built the function `convert_coordinate`.

# %%
# Convert coordinates from string to float
df_aws['latitud'] = df_aws['latitud'].apply(convert_coordinate)
df_aws['longitud'] = df_aws['longitud'].apply(convert_coordinate)

display(df_aws)
# Out:
#        latitud      provincia  altitud  idema               nombre  indsinop  \
# 0    39.823333  ILLES BALEARS      490  B013X        ESCORCA, LLUC    8304.0
# 1    39.795556  ILLES BALEARS        5  B051A       SÓLLER, PUERTO    8316.0
# 2    39.689167  ILLES BALEARS       60  B087X          BANYALBUFAR       NaN
# 3    39.579167  ILLES BALEARS       52  B103B   ANDRATX - SANT ELM   99103.0
# 4    39.551389  ILLES BALEARS       50  B158X  CALVIÀ, ES CAPDELLÀ       NaN
# ..         ...            ...      ...    ...                  ...       ...
# 942  42.691944         LLEIDA     2467  9988B      CAP DE VAQUÈIRA    8936.0
# 943  42.700278         LLEIDA     1161  9990X   NAUT ARAN, ARTIES     8107.0
# 944  42.776111         LLEIDA      722  9994X              BOSSÒST       NaN
# 945  43.091111        NAVARRA      334  9995Y    VALCARLOS/LUZAIDE       NaN
# 946  40.921389         TERUEL     1006  9998X                BELLO       NaN
#
#      longitud
# 0    2.885833
# 1    2.691389
# 2    2.512778
# 3    2.368889
# 4    2.466389
# ..        ...
# 942  0.973889
# 943  0.876944
# 944  0.689722
# 945 -1.300833
# 946 -1.494444
#
# [947 rows x 7 columns]

# %%
df_aws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 947 entries, 0 to 946
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitud    947 non-null    float64
#  1   provincia  947 non-null    object
#  2   altitud    947 non-null    int64
#  3   idema      947 non-null    object
#  4   nombre     947 non-null    object
#  5   indsinop   301 non-null    float64
#  6   longitud   947 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 51.9+ KB

# %%
df_aws.nombre.nunique()
# Out:
# 934

# %%
plt.figure(figsize=(5, 4))
sns.scatterplot(df_aws, x = 'longitud', y = 'latitud')
# Out:
# <Axes: xlabel='longitud', ylabel='latitud'>

# %%
# Save dataset processed
df_aws.to_csv('./data/processed/AWS_info.csv', index = False)

# %% [markdown]
# Now lets investigate `Basque Country Weather data.`

# %%
df_weather_euskadi = pd.read_csv('./data/raw/BC_weather_month_year_RAW.csv')

with pd.option_context('display.max_columns', None):
    display(df_weather_euskadi.head())
# Out:
#      fecha indicativo     p_max    hr  nw_55  tm_min    ta_max  ts_min  nt_30  \
# 0  2009-10      1012P  35.2(22)  74.0    1.0    12.7  30.8(06)    22.9    1.0
# 1  2009-11      1012P       NaN  67.0   14.0    10.6  26.9(01)    17.2    0.0
# 2  2009-12      1012P       NaN  73.0   10.0     6.6  19.6(29)    16.0    0.0
# 3  2009-13      1012P       NaN   NaN    NaN     NaN       NaN     NaN    NaN
# 4   2009-1      1012P       NaN   NaN    NaN     NaN       NaN     NaN    NaN
#
#        w_racha  np_100  nw_91  np_001    ta_min  w_rec      e  np_300  p_mes  \
# 0  16/15.3(20)     3.0    0.0    12.0   1.9(16)   99.0  142.0     1.0  117.4
# 1  25/27.2(07)     NaN    1.0     NaN   5.3(30)  254.0  107.0     NaN    NaN
# 2  14/26.1(21)     NaN    1.0     NaN  -1.3(19)  189.0   88.0     NaN    NaN
# 3          NaN     NaN    NaN     NaN       NaN    NaN    NaN     NaN    NaN
# 4          NaN     NaN    NaN     NaN       NaN    NaN    NaN     NaN    NaN
#
#    w_med  nt_00  ti_max  tm_mes  tm_max  np_010  n_cub  n_des  n_nub  evap  \
# 0    4.0    0.0    11.4    16.8    20.9    10.0    NaN    NaN    NaN   NaN
# 1   10.0    0.0    10.3    14.1    17.5     NaN    NaN    NaN    NaN   NaN
# 2    7.0    3.0     2.4     9.4    12.2     NaN    NaN    NaN    NaN   NaN
# 3    NaN    NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN
# 4    NaN    NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN
#
#    n_fog  n_tor  n_gra  n_llu  n_nie  nv_0050  nv_1000  nv_0100 q_max  q_mar  \
# 0    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
#
#    q_med q_min  inso  p_sol  ts_20  ts_10  ts_50  glo
# 0    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN
# 1    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN
# 2    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN
# 3    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN
# 4    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN

# %%
# Oldest data
df_weather_euskadi.fecha.min()
# Out:
# '1928-1'

# %% [markdown]
# AEMET mean data per year is directly provideed by AEMET and storage in the month numer "13". BUT after some inspections I realize this data is full of missing values, so I won't use that information. Instead, if needed during the EDA I will construct my own mean-weather data per year.

# %%
# Filter: only months from 1 to 12
df_weather_month_year_euskadi = df_weather_euskadi[~df_weather_euskadi['fecha'].str.contains(r'-13$', regex=True)]

df_weather_month_year_euskadi = df_weather_month_year_euskadi.rename(columns={'indicativo' : 'idema'})
df_weather_month_year_euskadi.sort_values(by = ['idema', 'fecha'])

df_weather_month_year_euskadi.head()
# Out:
#      fecha  idema     p_max    hr  nw_55  tm_min    ta_max  ts_min  nt_30  \
# 0  2009-10  1012P  35.2(22)  74.0    1.0    12.7  30.8(06)    22.9    1.0
# 1  2009-11  1012P       NaN  67.0   14.0    10.6  26.9(01)    17.2    0.0
# 2  2009-12  1012P       NaN  73.0   10.0     6.6  19.6(29)    16.0    0.0
# 4   2009-1  1012P       NaN   NaN    NaN     NaN       NaN     NaN    NaN
# 5   2009-2  1012P       NaN   NaN    NaN     NaN       NaN     NaN    NaN
#
#        w_racha  ...  q_max  q_mar  q_med q_min  inso  p_sol  ts_20  ts_10  \
# 0  16/15.3(20)  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 1  25/27.2(07)  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 2  14/26.1(21)  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 4          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
# 5          NaN  ...    NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN
#
#    ts_50  glo
# 0    NaN  NaN
# 1    NaN  NaN
# 2    NaN  NaN
# 4    NaN  NaN
# 5    NaN  NaN
#
# [5 rows x 46 columns]

# %%
df_weather_month_year_euskadi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11448 entries, 0 to 12401
# Data columns (total 46 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   fecha    11448 non-null  object
#  1   idema    11448 non-null  object
#  2   p_max    10419 non-null  object
#  3   hr       9111 non-null   float64
#  4   nw_55    7747 non-null   float64
#  5   tm_min   10148 non-null  float64
#  6   ta_max   10143 non-null  object
#  7   ts_min   10115 non-null  float64
#  8   nt_30    10143 non-null  float64
#  9   w_racha  7772 non-null   object
#  10  np_100   10410 non-null  float64
#  11  nw_91    7747 non-null   float64
#  12  np_001   10410 non-null  float64
#  13  ta_min   10148 non-null  object
#  14  w_rec    7463 non-null   float64
#  15  e        9176 non-null   float64
#  16  np_300   10410 non-null  float64
#  17  p_mes    10423 non-null  float64
#  18  w_med    8550 non-null   float64
#  19  nt_00    10148 non-null  float64
#  20  ti_max   10110 non-null  float64
#  21  tm_mes   10137 non-null  float64
#  22  tm_max   10143 non-null  float64
#  23  np_010   10410 non-null  float64
#  24  n_cub    4968 non-null   float64
#  25  n_des    4968 non-null   float64
#  26  n_nub    4968 non-null   float64
#  27  evap     3576 non-null   float64
#  28  n_fog    4309 non-null   float64
#  29  n_tor    4305 non-null   float64
#  30  n_gra    4307 non-null   float64
#  31  n_llu    4307 non-null   float64
#  32  n_nie    4307 non-null   float64
#  33  nv_0050  3829 non-null   float64
#  34  nv_1000  3829 non-null   float64
#  35  nv_0100  3829 non-null   float64
#  36  q_max    4757 non-null   object
#  37  q_mar    4799 non-null   float64
#  38  q_med    4876 non-null   float64
#  39  q_min    4751 non-null   object
#  40  inso     3836 non-null   float64
#  41  p_sol    3836 non-null   float64
#  42  ts_20    686 non-null    float64
#  43  ts_10    691 non-null    float64
#  44  ts_50    688 non-null    float64
#  45  glo      1254 non-null   float64
# dtypes: float64(38), object(8)
# memory usage: 4.1+ MB

# %% [markdown]
# The last step is combine AWS info with the annual monthly weather data of the Basque Country, so I will have in a single dataset with all the weather and AWS information.

# %%
# Merge weather data with AWS information
df_basque_country = df_weather_month_year_euskadi.merge(df_aws, how = 'left', on = 'idema')

with pd.option_context('display.max_columns', None):
    display(df_basque_country.head(8))
# Out:
#      fecha  idema     p_max    hr  nw_55  tm_min    ta_max  ts_min  nt_30  \
# 0  2009-10  1012P  35.2(22)  74.0    1.0    12.7  30.8(06)    22.9    1.0
# 1  2009-11  1012P       NaN  67.0   14.0    10.6  26.9(01)    17.2    0.0
# 2  2009-12  1012P       NaN  73.0   10.0     6.6  19.6(29)    16.0    0.0
# 3   2009-1  1012P       NaN   NaN    NaN     NaN       NaN     NaN    NaN
# 4   2009-2  1012P       NaN   NaN    NaN     NaN       NaN     NaN    NaN
# 5   2009-3  1012P  30.4(04)  68.0    3.0     7.1  24.5(17)    13.5    0.0
# 6   2009-4  1012P  74.4(10)  75.0    2.0     8.4  24.6(09)    11.0    0.0
# 7   2009-5  1012P  24.6(14)  78.0    1.0    12.0  26.2(30)    15.5    0.0
#
#        w_racha  np_100  nw_91  np_001    ta_min  w_rec      e  np_300  p_mes  \
# 0  16/15.3(20)     3.0    0.0    12.0   1.9(16)   99.0  142.0     1.0  117.4
# 1  25/27.2(07)     NaN    1.0     NaN   5.3(30)  254.0  107.0     NaN    NaN
# 2  14/26.1(21)     NaN    1.0     NaN  -1.3(19)  189.0   88.0     NaN    NaN
# 3          NaN     NaN    NaN     NaN       NaN    NaN    NaN     NaN    NaN
# 4          NaN     NaN    NaN     NaN       NaN    NaN    NaN     NaN    NaN
# 5  29/27.8(05)     4.0    1.0    13.0   3.2(04)  169.0   88.0     1.0   97.8
# 6  12/20.0(09)    10.0    0.0    18.0   6.2(18)  179.0  105.0     1.0  251.6
# 7  23/16.4(15)     4.0    0.0    17.0   8.9(06)  143.0  143.0     0.0  135.8
#
#    w_med  nt_00  ti_max  tm_mes  tm_max  np_010  n_cub  n_des  n_nub  evap  \
# 0    4.0    0.0    11.4    16.8    20.9    10.0    NaN    NaN    NaN   NaN
# 1   10.0    0.0    10.3    14.1    17.5     NaN    NaN    NaN    NaN   NaN
# 2    7.0    3.0     2.4     9.4    12.2     NaN    NaN    NaN    NaN   NaN
# 3    NaN    NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN
# 4    NaN    NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN
# 5    7.0    0.0     8.6    10.9    14.6    10.0    NaN    NaN    NaN   NaN
# 6    7.0    0.0    10.5    12.2    15.9    17.0    NaN    NaN    NaN   NaN
# 7    7.0    0.0    13.5    15.6    19.0    16.0    NaN    NaN    NaN   NaN
#
#    n_fog  n_tor  n_gra  n_llu  n_nie  nv_0050  nv_1000  nv_0100 q_max  q_mar  \
# 0    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 5    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 6    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
# 7    NaN    NaN    NaN    NaN    NaN      NaN      NaN      NaN   NaN    NaN
#
#    q_med q_min  inso  p_sol  ts_20  ts_10  ts_50  glo    latitud provincia  \
# 0    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN  43.326389  GIPUZKOA
# 1    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN  43.326389  GIPUZKOA
# 2    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN  43.326389  GIPUZKOA
# 3    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN  43.326389  GIPUZKOA
# 4    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN  43.326389  GIPUZKOA
# 5    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN  43.326389  GIPUZKOA
# 6    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN  43.326389  GIPUZKOA
# 7    NaN   NaN   NaN    NaN    NaN    NaN    NaN  NaN  43.326389  GIPUZKOA
#
#    altitud nombre  indsinop  longitud
# 0      120   IRUN       NaN -1.796667
# 1      120   IRUN       NaN -1.796667
# 2      120   IRUN       NaN -1.796667
# 3      120   IRUN       NaN -1.796667
# 4      120   IRUN       NaN -1.796667
# 5      120   IRUN       NaN -1.796667
# 6      120   IRUN       NaN -1.796667
# 7      120   IRUN       NaN -1.796667

# %%
df_basque_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11448 entries, 0 to 11447
# Data columns (total 52 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   fecha      11448 non-null  object
#  1   idema      11448 non-null  object
#  2   p_max      10419 non-null  object
#  3   hr         9111 non-null   float64
#  4   nw_55      7747 non-null   float64
#  5   tm_min     10148 non-null  float64
#  6   ta_max     10143 non-null  object
#  7   ts_min     10115 non-null  float64
#  8   nt_30      10143 non-null  float64
#  9   w_racha    7772 non-null   object
#  10  np_100     10410 non-null  float64
#  11  nw_91      7747 non-null   float64
#  12  np_001     10410 non-null  float64
#  13  ta_min     10148 non-null  object
#  14  w_rec      7463 non-null   float64
#  15  e          9176 non-null   float64
#  16  np_300     10410 non-null  float64
#  17  p_mes      10423 non-null  float64
#  18  w_med      8550 non-null   float64
#  19  nt_00      10148 non-null  float64
#  20  ti_max     10110 non-null  float64
#  21  tm_mes     10137 non-null  float64
#  22  tm_max     10143 non-null  float64
#  23  np_010     10410 non-null  float64
#  24  n_cub      4968 non-null   float64
#  25  n_des      4968 non-null   float64
#  26  n_nub      4968 non-null   float64
#  27  evap       3576 non-null   float64
#  28  n_fog      4309 non-null   float64
#  29  n_tor      4305 non-null   float64
#  30  n_gra      4307 non-null   float64
#  31  n_llu      4307 non-null   float64
#  32  n_nie      4307 non-null   float64
#  33  nv_0050    3829 non-null   float64
#  34  nv_1000    3829 non-null   float64
#  35  nv_0100    3829 non-null   float64
#  36  q_max      4757 non-null   object
#  37  q_mar      4799 non-null   float64
#  38  q_med      4876 non-null   float64
#  39  q_min      4751 non-null   object
#  40  inso       3836 non-null   float64
#  41  p_sol      3836 non-null   float64
#  42  ts_20      686 non-null    float64
#  43  ts_10      691 non-null    float64
#  44  ts_50      688 non-null    float64
#  45  glo        1254 non-null   float64
#  46  latitud    11448 non-null  float64
#  47  provincia  11448 non-null  object
#  48  altitud    11448 non-null  int64
#  49  nombre     11448 non-null  object
#  50  indsinop   5856 non-null   float64
#  51  longitud   11448 non-null  float64
# dtypes: float64(41), int64(1), object(10)
# memory usage: 4.5+ MB

# %% [markdown]
# The code below is just a demostration of how now I can scatter-plot the results. During the EDA I will transform it in a function.

# %%
# Example of how could I plot some results

# Load the image
image_path = './img/basque_country_map.jpg'
image = mpimg.imread(image_path)

# Data for the scatter plot
x = df_basque_country.longitud
y = df_basque_country.latitud

# Configure the plot
fig, ax = plt.subplots()

# Add the background image, adjusting the values according to the data
extent = [-3.55, -1.55, 42.47, 43.47]
ax.imshow(image, extent=extent, aspect='auto', alpha=0.3)

# Create the scatter plot
ax.scatter(x, y, c='blue', s=50)  # Customize color and size of points

# Adjust the axis limits
ax.set_xlim([-3.55, -1.5])
ax.set_ylim([42.45, 43.55])

# (Optional) Add labels and title
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('AWS')

# Show the plot
plt.show()

# %% [markdown]
# Finally, I save the dataset.

# %%
df_basque_country.to_csv('./data/processed/BC_weather_month_year.csv', 
                         index=False)
